# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# importing the needed libraries
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import re 
import string
import preprocessor as p
import emoji
from emot.emo_unicode import EMOTICONS_EMO
from flashtext import KeywordProcessor

import torch
from transformers import BertTokenizer, BertModel

# %% [markdown]
# # Contextual Embeddings Using BERT

# %% [markdown]
# This documentation provides a detailed guide to preprocessing text data and extracting contextual embeddings using the BERT model. This process enhances the representation of text for advanced NLP tasks

# %% [markdown]
# ## Import Dataset

# %%
# Read CSV file and drop any rows with missing values immediately
df = pd.read_csv('../data/labeled_texts_1000.csv')
df.dropna(inplace=True)
df
# Out:
#                                                Content  label
# 0    The #Binance towel comes everywhere with me......      1
# 1    Drop your $SOL address below and\r\nmake sure ...      1
# 2                                           £52,356.70      1
# 3    It only takes one good altcoin to change the w...      2
# 4                 disrespectful is one of my top 3 fav      2
# ..                                                 ...    ...
# 980                  LADY GAGA IS A FUCKING MOVIE STAR      0
# 981  Te haré salir volando como un cohete! 🚀💥 I’ll ...      2
# 982                                 hawl awn… is that—      1
# 983  You’re invited! See you in Rogueport on May 23...      2
# 984                                      Alien mothers      0
#
# [985 rows x 2 columns]

# %% [markdown]
# ## Prepare Data

# %%
# Extract content and labels into separate variables
X = df['Content']
y = df['label']
X, y
# Out:
# (0      The #Binance towel comes everywhere with me......
#  1      Drop your $SOL address below and\r\nmake sure ...
#  2                                             £52,356.70
#  3      It only takes one good altcoin to change the w...
#  4                   disrespectful is one of my top 3 fav
#                               ...
#  980                    LADY GAGA IS A FUCKING MOVIE STAR
#  981    Te haré salir volando como un cohete! 🚀💥 I’ll ...
#  982                                   hawl awn… is that—
#  983    You’re invited! See you in Rogueport on May 23...
#  984                                        Alien mothers
#  Name: Content, Length: 985, dtype: object,
#  0      1
#  1      1
#  2      1
#  3      2
#  4      2
#        ..
#  980    0
#  981    2
#  982    1
#  983    2
#  984    0
#  Name: label, Length: 985, dtype: int64)

# %% [markdown]
# The content of the tweets and their labels are separated to facilitate preprocessing and model training.

# %% [markdown]
# ## Preprocess Text For BERT

# %% [markdown]
# ### Text Cleaning and Normalization

# %% [markdown]
# Define Helper Functions

# %%
# Function to convert emoticons to words
def convert_emoticons(text):
    # Merge emoji and emoticon dictionaries into one dictionary
    all_emoji_emoticons = {**EMOTICONS_EMO}
    
    # Replace colons and underscores in keys with spaces, and trim spaces
    all_emoji_emoticons = {k:v.replace(":","").replace("_"," ").strip() for k,v in all_emoji_emoticons.items()}
    
    # Initialize a KeywordProcessor for replacing keywords
    kp_all_emoji_emoticons = KeywordProcessor()
    
    # Add each emoticon and its corresponding word to the KeywordProcessor
    for k, v in all_emoji_emoticons.items():
        kp_all_emoji_emoticons.add_keyword(k, v)
    
    # Replace all emoticons in the text with corresponding words
    return kp_all_emoji_emoticons.replace_keywords(text)

# %%
# Function to handle abbreviations and normalize text
def normalize_text(text):
    # Replace 'fav' with 'favorite'
    text = re.sub(r'\bfav\b', "favorite", text)
    
    # Replace 'tkt' with 'ticket'
    text = re.sub(r'\btkt\b', "ticket", text)
    
    # Replace '(gm)' with 'good morning'
    text = re.sub(r'\(gm\)', 'good morning', text)
    
    # Replace '(r.i.p)' with 'rest in peace'
    text = re.sub(r'\(r.i.p\)', 'rest in peace', text)
    
    # Remove parenthetical references (typically credits like via or hat tips)
    text = re.sub(r'\([^)]*(via|h/t)[^)]*\)', '', text)
    
    # Reduce excess letter repetitions (more than two) to two
    text = re.sub(r'([a-zA-Z])\1{2,}', r'\1\1', text)
    
    return text

# %%
import re

def clean_characters(text):
    # Replace special characters (hyphens, underscores, colons) with a space
    text = re.sub(r'[-_:]', ' ', text)
    
    # Normalize line endings, replacing carriage return and newline with just newline
    normalized_text = re.sub(r'\r\n', '\n', text)
    
    # Remove decimal points used in numbers
    no_decimal_text = re.sub(r'(\d)\.(\d)', r'\1\2', normalized_text)
    
    # Remove characters that are not letters, numbers, basic punctuation, or newline
    cleaned_text = re.sub(r"[^a-zA-Z0-9 '.\n]", '', no_decimal_text)
    
    # Reduce multiple consecutive dots to a single dot
    cleaned_text = re.sub(r'\.{2,}', '.', cleaned_text)
    
    # Reduce multiple consecutive question marks to a single one
    cleaned_text = re.sub(r'\?{2,}', '?', cleaned_text)
    
    # Replace multiple consecutive newlines with a single period or space
    cleaned_text = re.sub(r'(\n)+', lambda m: '.' if m.group().startswith('\n') and not m.group().endswith('.') else '. ', cleaned_text)
    
    # Clean up multiple spaces or periods into a single space or period
    cleaned_text = re.sub(r'\. \.', '. ', cleaned_text)
    
    # Reduce multiple spaces to a single space
    cleaned_text = re.sub(r' {2,}', ' ', cleaned_text)
    
    # Return the cleaned text, stripped of leading/trailing whitespace
    return cleaned_text.strip()

# %%
def clean_tweet(tweet):
    # Configure the preprocessor to remove URLs, mentions, and reserved words like RT or FAV
    p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.RESERVED)
    
    # Clean the tweet using preprocessor settings
    cleaned_tweet = p.clean(tweet)
    
    # Convert all emojis in the tweet to text
    cleaned_tweet = emoji.demojize(cleaned_tweet)
    
    # Convert emoticons within the tweet to words
    cleaned_tweet = convert_emoticons(cleaned_tweet)
    
    # Normalize text to handle abbreviations and remove unnecessary parts
    normalized_text = normalize_text(cleaned_tweet.lower())
    
    # Clean characters and correct formatting issues
    sentence_cleaned = clean_characters(normalized_text)
    
    # Return the fully cleaned and processed tweet
    return sentence_cleaned

# %%
def get_cleaned_tweets(tweets):
    # Process a list of tweets, cleaning each one using clean_tweet function
    return [clean_tweet(tweet) for tweet in tweets]

# %%
# Apply the cleaning process to all tweets in X and store results
result = get_cleaned_tweets(X)
result[:5]
# Out:
# ['the binance towel comes everywhere with me. including breakfast cooking',
#  'drop your sol address below and make sure you are following me dont ask why backhand index pointing down medium light skin tone',
#  '5235670',
#  'it only takes one good altcoin to change the world. sparkles',
#  'disrespectful is one of my top 3 favorite',
#  'some congressional republicans call the affordable connectivity program wasteful. i call it necessary. its time congress extended it so the 23 million households across america that rely on the program can stay connected.',
#  'donald trump wont do what an american president must do. he refuses to denounce political violence. ill say what trump wont political violence is never ever acceptable in america.',
#  'there is a massive bitcoin breakout coming. are you ready',
#  'max pain.',
#  'ok so the vote is in. ill do a 25 ticket giveaway on station head in 10 mins. if i feel like it ill come on spaces give out another 5 10 after that. the generous queen princess medium skin tone',
#  'my whole heart',
#  'im tired of people using me as their punching bag leave me tf alone its my day off',
#  'lets take a deep dive shall wee chapter one water wave',
#  'april 03 2024 09 21 am utc current price of bitcoin btc usd 6648480 btc eur 6175773',
#  'how is pitbull not in the big 3',
#  "35 a month insulin for seniors. 35 inhalers for asthma. 2000 a year cap on prescription drugs for seniors starting next year. with senator sanders' help were showing how health care should be a right not a privilege in america.",
#  'cryptoo',
#  'major pump incoming.',
#  'the world is a stage. joker folie deux trailer coming april 9. joker',
#  'video shows abducted us girl fatally shot by police',
#  'the best bravest baddest barbz win',
#  'bitcoin is going to 100000 eth is going to 10000 altcoins will pump 10x halving in 15 days. you are not bullish enough.',
#  'what conan lyric feels like this',
#  'the more tether prints the higher bitcoin goes.',
#  'which of these artists is the biggest hit maker',
#  'bitcoin navigating the high seas of finance steering the ship of economic evolution. sailboat money bag water wave',
#  'album moments cyclone i hear you feeling optimistic about this week',
#  "not in the path of totality for the total solar eclipse on april 8 we'll bring totality to you by broadcasting from several locations along its trajectory including our only center in the eclipses path. how to watch",
#  "it's a tough gig being the binance intern. good morning",
#  'donald trump doesnt trust women. i do.',
#  'there is no bigger red flag in an adult than lack of children. if youre 46 and not yet bored of weed and alcohol youre immature and soulless. how can you be trusted to vote you have a warped world view with zero vested interest in the future. the poorest people alive',
#  '1 whole bitcoin hodlers are becoming rare',
#  'dogecoin as tipping option eyes',
#  'my targets for next 12 16 months btc 100k 250keth 10k 15kbnb 900 1400sol 450 650xrp 3 5doge 1dot 100 120link 250 500 backhand index pointing down medium light skin tone',
#  '6135748',
#  'introducing a new simple earn flexible products promotion subscribe to either sui or usdt simple earn flexible products to grab your share of 20000 sui while also earning bonus apr. get started today right arrow curving down',
#  '6941650bitcoin btc btc usd',
#  'through laws i wrote and signed i enacted tax credits that save an average of 800 per person per year reducing health care premiums for millions of families. those credits expire next year. congress make that 800 expanded affordable health care tax credit permanent.',
#  'you already made your statement donald.',
#  'tag a light mode user backhand index pointing down',
#  'coinbase blackrock will pump crypto higher',
#  '5206863',
#  'pitbull chingy and baby bash',
#  'eth will explode soon fire',
#  'my station head seems to not be working guys. what a shocker',
#  'if i say im 25 then im 25 the fuk',
#  'psalm camera by saint',
#  'the next bitcoin halving is just 2 weeks out. and historically the most gains are always realized after the halving. are you prepared',
#  'moment taiwan maternity staff rush to keep babies safe during earthquake',
#  '13900 eggs. 200000 in rewards. 1 bitcoin. get started with the binance egg drop backhand index pointing down',
#  'congratulations to and for being selected to move forward in developing the artemis lunar terrain vehicle this moon rover will allow future astronauts to travel far on the lunar surface',
#  'i am outraged and heartbroken by the deaths of seven humanitarian workers from world central kitchen including one american in gaza yesterday. incidents like yesterdays simply should not happen. here is my full statement.',
#  'bitcoin is a symbol of digital revolution and financial freedom. light bulb globe with meridians money with wings',
#  'miss shanel does what must be done',
#  "is whale watching on your bucket list if so you'll be glad to know that you don't have to travel to do it. well not for crypto whale watching anyway.",
#  'i want honest criticism on this ai portfolio 25 btc15 tao15 rndr10 grt10 akt5 ait5 paal5',
#  'blue heart white heart red heart',
#  'are you still with me argentina star star star gutsworldtour',
#  'como mi amor',
#  '5254255',
#  "kamala and i continue to call on congress to restore the protections of roe in every state. the majority of americans support a woman's right to choose including in florida where voters will have the opportunity to support a reproductive freedom ballot initiative this fall.",
#  'the category is albums that deserved way more success',
#  'white house wants moon to have its own time zone',
#  'introducing the binanceclubhouse a global hub for all binance users to connect work and talk all things crypto. stay tuned for more info to come handshake',
#  'yesterdays extreme florida supreme court decision puts desperately needed medical care even further out of reach for millions of women in florida and across the south. its outrageousand it was made possible by trump ending roe v. wade.',
#  '5198706bitcoin btc btc gbp',
#  'ready to rock with for the april 8 eclipse submit your favorite solar themed songs to be added to a sun moon and eyes playlist',
#  'baby steps sir weary face grinning face with sweat',
#  '.s in search of the antidote debuts at no. 3 on top album sales chart',
#  'only 3 more sleeps till wrestlemania 40. talking to and on the show tonight. finalboss tribalchief',
#  'one crypto that will show a monster god candle this summer',
#  'writing hand dark skin tone signature script backhand index pointing right dark skin tone',
#  'deadly air strike shows system to protect aid workers in crisis agencies say',
#  'binance will list wormhole w with seed tag applied. right arrow',
#  'happy 90th birthday and please give my regards to mr. h. janeat90 goodallday',
#  'gaza aid convoy strike what do we know',
#  'thank you ny for a night to remember',
#  'watch tomorrow x together bring deja vu to kelly clarkson show',
#  'its not that no one told you.',
#  'if the prior administration and extreme republicans in congress had succeeded in gutting the aca 45 million people nationwide would have lost their health insurance.',
#  'helloo have we ever seen this',
#  'which album is making more noise this friday',
#  'barbz since yall like yappyity yapping i took screenshots of who been on here. yall asses report to station head im doing a gagcity giveaway right now. in 10 mins. who wanna win tickets ticket admission tickets lets go should i give away 50 tickets or 25 winners get a plus 1',
#  'so about the cake do we think conan would be proud smiling face with hearts',
#  'i remember this. i remember him withdrawing me from the tournament when i was 6 years old. i beat the first two adults then lost 3 in a row. i asked will i be able to beat them at chess when im grown up he replied son once youre grown up youll beat anyone at anything',
#  'the bitcoin halving is now only about 17 days away eyes',
#  'all eyes are on the sky on april 8 for the total solar eclipse did you know you can help us while experiencing the big event listen in from scientists in this episode of our curious universe podcast',
#  'r.i.p. gale sparrow.',
#  'bitcoin will hit 100000 in next 3 months or i am deleting my x account',
#  'trading is now live for ena on binance right arrow',
#  'vechains importance isnt talked about enough. vet',
#  'cul es el mejor video de shakira y por qu',
#  'inhalers cost less than 5 to make. but drug companies charge americans up to 600 to increase their profits. my administration has been cracking down on big pharma and now three of the four largest inhaler manufacturers are capping out of pocket costs at 35.',
#  "lulu i don't speak before 12 noon. i'm not lying",
#  'como mi amor daily',
#  'teniamos que recordarles que somos latinas ig',
#  'guys. he answered my question im gonna cryy i love this man so much',
#  'the category is most controversial music videos',
#  'polls are opening up in states across the country. head to to confirm your polling place.',
#  'the final deadline for 7 spot ethereum etfs is in 50 days',
#  'can you guys give me a rundown on everything he said about the unreleased tracks',
#  'google looks to ai paywall option report',
#  'solar eclipse 2024 how to watch stream live from anywhere',
#  'gagcity was everything nicki monica and 50 cent did what needed to be done two hearts gagcitydc',
#  "live now how will future astronauts drive across the surface of the moon we're announcing the companies that will advance the capabilities of the lunar terrain vehicle a rover for exploration during the artemis v missions and beyond.",
#  'time to supply you with some crypto knowledge. literally. maximum total and circulating supply explained backhand index pointing down',
#  "for anyone who received a checkmark today you can earn money for the stuff you're already posting. no extra effort required. apply to be monetized in settings monetization",
#  'explore new taker fee promotions on binance you can now trade usdc spot and margin trading pairs to enjoy discounted taker fees from 10 april 2024. learn more right arrow curving down',
#  'tune in as i deliver remarks on lowering health care costs for americans.',
#  'oh this is extremely gaggy babe',
#  'like what',
#  'truck crash spills live salmon into wrong oregon river',
#  'celebrate the upcoming bitcoin halving with the binance futures ultimate challenge. join the daily price prediction and weekly task challenges for a chance to win btc rewards and a tesla model y join now right arrow',
#  'police car light breaking police car light grayscale has transferred 1983 btc worth 1314 million to coinbase',
#  'bitcoin always pumps after the halving. 1st halving 8000 2nd halving 3000 3rd halving 800 in 15 days the 4th halving is here. are you mentally prepared',
#  'today i had a candid conversation with president xi jinping of the peoples republic of china on a range of issues including areas of cooperation and areas of difference. i emphasized the importance of maintaining peace and stability across the taiwan strait and in the south',
#  'same reason why you felt comfortable calling me a mexican when im dominican and i asked you why you feel comfortable calling me a mexican when ice and jharell jerome zoe saldana are dominicans and you dont do that to them. you do it to me because you know thats what people use',
#  'gagcitybaltimore is taking it dmv i missed youuyall dont know man. weary face flying saucer cityscape thank you. idk what to say. the best night ive ever had on earth and gagcity. may god bless each every one of you. ill never forget you. heavyonit',
#  'binance respectfully requests that tigran gambaryan who has no decision making power in the company is not held responsible while current discussions are ongoing between binance and nigerian government officials.bringtigranhomeread more backhand index pointing down',
#  'after 204 days 3264 orbits and dozens of experiments in space is heading home. undocking and return coverage on nasa and other platforms begins at 8pm et friday april 5 0000 utc april 6',
#  "don't buy bitcoin for your first name. buy bitcoin for your last name.",
#  'billie eilish pearl jam nicki minaj among 200 artists calling for responsible ai music practices',
#  'school shooting brings up tough questions for finland',
#  'instead of seniors with diabetes paying as much as 400 a month for their insulin they so badly need they now only have to pay 35 a month. period. i want to extend those savings to everyone who needs lifesaving insulin whether youre a senior or not.',
#  'heart hands medium skin tone ribbon',
#  "trade responsibly. employing risk management strategies is an important step to reducing your portfolio's risk. so we've listed out 5 strategies which you can find right here backhand index pointing down",
#  'binance has expanded portfolio margin to non vip users optimise your portfolio with enhanced capital efficiency risk management and trading strategies made more accessible. learn more backhand index pointing down',
#  'collision breaking the spot bitcoin etf had positive inflow of 40300000 yesterday',
#  'binance charity partners with the children of heroes foundation this collaboration will launch i am da vinci a 12 day therapeutic camp to support children who have lost their parents in the war. read more right arrow curving down',
#  'floridas bans and laws like them in states across america are putting the health and lives of millions of women at risk. they take away womens freedom to make their own health care decisions and threaten physicians for providing the care they were trained to provide.',
#  "don't panic saluting face",
#  'never magic wand',
#  "we've officially hit 1m posts on binance square thank you for sharing content on your feeds and spreading crypto knowledge worldwide handshake keep building right arrow",
#  'thats not what you said. you said nobody called me ghetto and now you moving the goal post you know why im at where im at right now because i took all those nos and recognized what i had to change. i had to change the way i talk the way i act and the way i respond and how',
#  '',
#  'honestly a great product feel more energized and stronger ever since ive taken it',
#  "lizzo clarifies she is not quitting music industry just 'negative energy'",
#  'olivia rodrigo kisses chappell roan during guts world tours boston stop',
#  "yesterday floridas supreme court upheld a state abortion ban likely triggering the governor's more extreme law eliminating access before many even know they're pregnant. outrageous. and i remain committed to protecting reproductive freedom in florida and across the u.s.",
#  'ukraine gives award to foreign vigilantes for hacks on russia',
#  'i got 45 mins to give away my own personal tkts to soldoutminaj shows guys. but im doing it on station head so nanabooboo barbz dont start. i miss you face with hand over mouth',
#  "the flies our newest class of officially graduated basic training last monthand what's a graduation without a few superlatives if you want to join the next astronaut class our applications are still open get yours in by april 16",
#  'just in coinbase ceo says its bitcoin lightning network integration should be launching soon high voltage eyes',
#  'dont pinch me please',
#  'rashee rice super bowl champion admits role in texas hit and run',
#  'this week america lost a hero. when lou conter passed away at the age of 102 america said farewell to the last known survivor of the u.s.s. arizona which was stationed on battleship row at pearl harbor on december 7 1941. today our hearts are with those who knew him and',
#  'i think there might be some confusion on what was said. i asked why he feels so comfortable calling me mexican i have no mexican parents. my mom is trini. she came out of a whole black woman. my father is dominicanim dominican just like you. i also used other dominicans as',
#  'all i wanted to give my fans an album tour that touched them in every way reminded them of why how we fell in love in the 1st place. to give them the tour that they never knew they needed prove to them how much i value them how much i value the arts pink heart',
#  'beyonc jennifer hudson host mini dreamgirls reunion at 2024 iheartradio music awards',
#  'why this amateur scientist measured snowfall for 50 years',
#  'happy tipping tuesday shibes tip in dogecoin dog dog face money with wings',
#  'doge is the og tipping currency of the internet',
#  'police car light breaking police car light united states proshares have launched a leveraged 2x ultra bitcoin etf today. bullish fire',
#  'april is a big month for sky gazing star struck big planets jupiter will be visible all month mars and saturn will rise together on april 10 11 big eclipse on april 8 catch the last total solar eclipse in the u.s. for 20 years big moon catch a full moon on april 23',
#  'irish basketball teams ordered to replay last 03 seconds of quarter final tie',
#  'will beyonc finally win album of the year grammy with cowboy carter',
#  'lovee that title. lets go bravo. call me face with tongue',
#  'worst migraines ever for like 3 weeks now. skull why wont these things go away i have tried everything. what is your secret',
#  'god.',
#  "tennessee passes 'chemtrail' bill banning airborne chemicals",
#  'aww weary face pink heart',
#  'heres my advice to you raymonte it takes time right now i get brand deals for over 5 million for a campaign i got social media famous in 2014my first brand deal from fashion nova was in 2016 and 200 a post. you could reach any height no matter how ghetto or where you',
#  'something is cooking at eyes',
#  'eyes',
#  'mysterious streak of light seen across southern california sky',
#  'here are the performers and presenters for 2024 cmt music awards',
#  'botswana offers to send 20000 elephants to germany',
#  'two letters dc gagcitydc',
#  'french couple who kept 159 cats banned from keeping pets',
#  'police car light breaking police car light 1000000000 usdt just got minted at tether treasury yesterday also 1 billion usdt was minted. are whales preparing for a huge bitcoin pump',
#  'rebel wilson book release put back in uk and australia',
#  'instagram tiktok facebook',
#  "world central kitchen founder jos andrs says israel targeted staff in gaza 'car by car'",
#  'who were the seven aid workers killed in gaza',
#  'listen lots of my friends have made tons and tons of money on crypto while i cling to my little bag of silver. i realize that crypto has been more successful in the last several years than what i think would be. and i obviously admit that and people shouldnt take investment',
#  'super valid. worth a podcast someday.',
#  'taylor swift is officially a billionaire',
#  'will truth social post a financial bailout for trump',
#  'three british aid workers killed in israeli strike in gaza named',
#  "tesla 'disaster' with fewest deliveries since 2022",
#  'best doge meme wins 69420 trophy like repost this post to participate. dog upload your meme in the comments. speech balloon',
#  'judges dog',
#  'trump sues truth social co founders over alleged mismanagement',
#  'ukraine lowers combat call up age to boost numbers',
#  '2024 mlb season how to watch baseball games online for free without cable',
#  "congratulations to buid 7952 on being our first winner of the tesla car lucky draw in second installment of futureschallenge party popper don't worry there are 3 weeks left to get your hands on your very own tesla participate now right arrow",
#  'tuesday already watch and me play password tonight at 109c on after weakestlink',
#  'i went to gagcitydc alone and ended up w the sweetest girl next to me who was also alone so fun and it was her bday loudly crying face loudly crying face loudly crying face loudly crying face pink heart pink heart pink heart it was just a magical and fun night overall. im so overwhelmed and grateful',
#  'r.i.p. michael mcmartin.',
#  "time to look at this month's market insights our research team analyzed the state of the crypto market and provided insights on bitcoin etf inflows ethereum's dencun upgrade solana's dex volumes and more. check it out down arrow",
#  "x is bringing the tip jar to the web app it was an iosandroid feature for years and now it's finally finding its way to the web version here you can see a full list of the supported services",
#  'cool cool',
#  'israeli government says it will block al jazeera from broadcasting',
#  "new senegal president bassirou diomaye faye and his two wives in our african culture divorce is a taboo. a man isn't allowed to divorce a woman unless she has committed infidelity only that is unforgivable as for a man wanting to divorce a woman because she's no longer young",
#  'the deluxe tracks from guts spilled on this weeks billboard hot 100 14 obsessed 58 so american 75 stranger 90 scared of my guitar 99 girl ive always been',
#  'janet jackson returns to japan for triumphant together again tour chronicling legendary career',
#  'small orange diamond bitcoin has closed over 60000 for 33 days in a row. consolidation then. rocket',
#  'ohh i gots to have these smiling face with heart eyes smiling face with heart eyes smiling face with heart eyes two hearts',
#  'we wear our solar glasses in space. smiling face with sunglasses while millions of people on earth watch the total solar eclipse on april 8 astronauts aboard the space station will watch from 250 miles above. theyll have three opportunities to view the ground shadow as they orbit earth',
#  'x will soon let you save the trends from the explore tab',
#  'very cool',
#  'country garden china property giant suspends shares in hong kong',
#  'reconhecem o dreamland museu em gramado rio grande do sul inaugurou uma estatua de cera de katy perry.',
#  'just in united states us government sends over 30170 bitcoin worth 2 billion to coinbase using silk road hack funds arkham data shows eyes',
#  'struggling to level with vips nows your chance to trade like a vip9 on usdc margined contracts enjoy zero maker fee and only 0017 taker fee for all users read more right arrow',
#  '.password on now nbc and peacock',
#  'bet on the future. bitcoin',
#  'all elite.',
#  'him refusing to speak on the meaning behind boys girls loudly crying face loudly crying face',
#  'novo vdeo de katy perry e jared leto durante o iheartradioawards que aconteceu na ltima segunda feira.',
#  'global citizen festival to return to central park in 2024',
#  'coneheads its time for u to find out which found heaven song u are',
#  'the houston texans are making the moves the dallas cowboys should have if they were really all in.',
#  'person in texas diagnosed with rare bird flu after contact with cattle',
#  'im a freak i need it',
#  'shut down that hospital please',
#  'how michael rubin and his posh parties unite the sports and music worlds',
#  'i know dumb ass richy jackson choreo when i see it',
#  'whered you go go alley rose idk conan just text the gc',
#  "police car light attention katycats and all our friends the industry has always been cruel to katy perry we need to bring this to everyone's attention reply to my tweet withjusticeforkatyperry goal 100 replies",
#  'endeavor going private in deal with majority shareholder silver lake',
#  'chile woman steals gun from guard and opens fire',
#  'nicki concert was literally everything face holding back tears',
#  'ive been hearing people ask at what point in a potential downfall should they leave the us. now i hear the same from canadians and europeans. the issues with all of this is where will you go we all need to fight to keep our countries in order or there will be nowhere to run.',
#  'hundred points',
#  '. notches second hot rock alternative songs no. 1 with too sweet',
#  'cigar night qa tonight at 8pm universal tate time.',
#  'stefano cherchi jockey dies two weeks after fall at canberra races',
#  'hunter schafer opens up about dating rosala in 2019 shes family no matter what',
#  'its everybody tonight with they pink on for mother crying face pink heart heart hands medium skin tone gagcitydc',
#  'elon a la benjamin franklin in a tesla my midjourney prompt was benjamin franklin driving a tesla grinning squinting face sparkles',
#  'magic wand',
#  "why there's a revolution on the way in glass making",
#  'firebloodchallenge it taste like orange juice tangerine',
#  'g',
#  'made in america festival canceled for second consecutive year',
#  'its us vol. 1 4524',
#  "world central kitchen founder jos andrs criticises israel over aid workers' deaths",
#  'hot 100 first timers allison russell debuts with hozier team up wildflower and barley',
#  'the list goes on and on and on',
#  "ye and ty dolla ign's vultures listening parties won't go ahead.",
#  'coinbase is now officially integrating the bitcoin lightning network clapping hands coinbase has over 100 million users rocket',
#  'grok 1 vs grok 15',
#  'big breaking police car light ethereum etf approval police car light sec asks for public comment for grayscale bitwise and fidelity spot ethereum etfs',
#  'glorilla recalls the beautiful feeling of visiting the white house i still havent accepted the reality of it',
#  "following their first playoff appearance in decades the marlins tried to demote gm kim ng. she turned that down and left the organization. the marlins are behind early today and if they lose to the angels they'll be 0 7 to start this season.",
#  'the meaning behinf miss you is so deep fuck',
#  'ukraine war deepest ukraine drone attack into russian territory injures 12',
#  'harleys in hawaii 500m barreira bloody mary 443m',
#  'damn nigga you bought this from god',
#  'lizzo clarifies what she meant with i quit statement im going to keep being me',
#  "andrew tate's coldest moment in fighting",
#  'john summit dom dolla kaskade more to headline desert nights coachella parties',
#  'dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote 1000000000 usdt 1000027499 usd minted at tether treasury',
#  '. marvin winans able tops gospel airplay chart',
#  "seeing sht like this back to back at every show puts into perspective who it is nicki minaj is in real life so going back forth with fls on here trying to prove a point is so useless. nothing negative on here should even phase y'all let them live in their delusion.",
#  'beyonc thanks jack white for inspiring cowboy carter',
#  'google to delete records from incognito tracking',
#  'we are not slowing down high speed train soccer ball soccer ball soccer ball',
#  'we blinked',
#  'lady gagas harley quinn speaks listen to the first taste of singers character in joker folie deux',
#  'uk surfer laura crane in class of her own at big wave spot nazare',
#  'but you did a good job of really fuckin up my day',
#  'congrats',
#  'julia garner is playing a female silver surfer in fantasticfour',
#  'big breaking police car light coinbase goes big on bitcoin coinbase partners with lightspark to integrate bitcoin lightning network.',
#  'i hate pending transactions. please just take the money.',
#  'pensando en que ya me aprend todas las canciones de las mujeres ya no lloran y ahora tendr que esperar mnimo 7 aos para que shakira saque nuevo lbum. sad but relieved face',
#  '10010 amazing show smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts gagcitybaltimore',
#  'top 8 most profitable crypto narratives in 2024 1. memecoin 1313 2. rwa 286 3. ai 222 4. defi 99 5. depin 81 6. layer 1 70 7. gaming 64 8. layer 2 39',
#  'if i was famous id make a fanpage for myself and post rares that literally no one has ever seen because i took them and everyone would be like how does this person always have rare pics crying face bc i am her duh',
#  'i cant say nothing every body gets offended over every little thing',
#  'i wish gaga would stop bringing her hair makeup friends with her for her movie projects too so we could seehow do i put this nicely',
#  'fake nationalist zionist agents not a word from these fake nationalists about the 3 former british military members killed by israel. israel first',
#  'super valid point.',
#  "every dip is just the universe's way of asking do you have the courage to double down on your dreams",
#  'raymonte is not wrong.',
#  'nova esttua de cera de katy perry inaugurada no dreamland museu em gramado rio grande do sul.',
#  'i am currently 18h 53m 16s of light travel time from earth 2024 095 000000 1l',
#  'conan gray disse no talk shop live que sua msica favorita das que ainda no foram lanadas do found heaven fainted love mas que sua favorita do lbum todo alley rose',
#  'no offense bardi its cus i have a dominican parent a black one loudly crying face black heart',
#  'what is your most anticipated performance of 2024',
#  'race vs ethnicity vs nationality be beating my community ass.',
#  "it's cute when kids say what they want to be when they grow up. you're gonna write emails on the computer buddy",
#  "katyperry's harleys in hawaii has surpassed 500 million streams on spotify. its her 15th song to reach this milestone flexed biceps motorcycle sun collision keycap 5 keycap 0 keycap 0 circled m multiply keycap 1 keycap 5 musical notes fire crown pink heart",
#  'fun fact all of lady gagas lead roles are for films rated r',
#  'police car light tenemos nueva colaboracin en camino y es ya inminente',
#  'pouria zeraati three accused of tv presenter attack have left uk',
#  'starship will be on mars within the decade and i cant wait to help build the booster thatll send it on its way face with steam from nose fire rocket',
#  'katy perrys lead single between april and may. the music video is ready. xx',
#  'joker 2 soundtrack album under gagas label omgg',
#  "it's a stormy day at the spaceport what's the weather like for you right arrow curving down",
#  'its crazy how it all happened when she was 33 just like jesus',
#  'the fact that it never charted on the hot 100 is insane',
#  'look how cute we are smiling face with heart eyes face holding back tears pink heart',
#  'doja cat says she doesnt care about music leaks theres nothing i can do about it',
#  'will you buy a tesla with dogecoin',
#  'hundred points',
#  'names of three british aid workers killed in israeli strike in gaza are john chapman james henderson and james kirby bbc establishes',
#  'live now',
#  'are we on the timeline or on the dms we were talking in dms and now youre back on the timeline. you cant gaslight me and i wont let you confuse people by bringing up things that are irrelevant to the initial discussion. you say people never called me ghetto. i responded',
#  'all of the barbies are bad it girls and we aint playing tag two hearts star struck gagcitybaltimore',
#  'big breaking police car light bitcoin to reach 150k by the end of this year per morgan creek capital management ceo mark yusko',
#  'how fox sports resident deadheads brought jam bands to big games',
#  'boys girls foi a msica que conan levou mais tempo a fazer no lbum found heaven.',
#  'is winning saluting face',
#  'crying. over. this. face holding back tears purple heart we love you',
#  'katchatheevu tiny sri lankan island sparks political row in india',
#  "when gaga did house of gucci she got dragged for having an accent for joker she's getting dragging for not having one",
#  'gaga daily wouldve loved today pleading face broken heart',
#  'its time for katycats to move justiceforkatyperry',
#  'nicki concert 1010',
#  'its been 4 years and youre still a brokie',
#  'i reiterate my firm call for an immediate ceasefire in the gaza strip. i express my deep sorrow for the volunteers who were killed while distributing humanitarian aid in gaza. i pray for them and their families.',
#  'katy perrys teenage dream album cover is actually a painting',
#  'coneheads join cone for a live qa on now star black heart',
#  'new shakira collaboration on the way. xx',
#  'just in apple exploring the creation of home robots as next big thing.',
#  'estoy en usa y ha estado ms veces en tendencia que esta semana en twitter. aunque amo a las dos solo escribo para que vean la relevancia de shakira aqu.',
#  'what if i said house of gucci has the best poster',
#  'we need katys documentary about what happened from 2017 2018',
#  'new look at moana 2 set 3 years after the first movie. in theaters on november 27.',
#  'taylor swift competing with travis kelce for a 2024 webby award full nominations announced',
#  'two margaritas deep i heard a song playing called you can go your own way and i was like wow they are really singing their ass off. looked it up its two band members breaking up i am in tears you can go your own way loudly crying face loudly crying face watched the live performance. he cant even look at her',
#  '.s las mujeres ya no lloran hit number one on top latin albums and latin pop albums gem stone',
#  'sister ship 1 is 22h 32m 47s of light travel time from earth 2024 094 120000 1l',
#  'un fan de karol g pero cuntos streams de spotify tiene selena enraged face',
#  'justice for katy perry broken heart crying cat',
#  'conans gonna be personally at the gates of the arena asking people if they are in a relationship and if they say yeah hell be like good for you get out.',
#  "usa today attended 's gagcitydc and gave their review of her show for her first u.s. run in eight years minaj has crafted her most grandiose productionshe is still the queen of rap for a reason.",
#  'nine milestones beyonc could reach at 2025 grammys',
#  'israels pm says its forces unintentionally hit innocent people in gaza after strike on aid workers kills seven follow latest updates',
#  'the most sold car on planet earth in 2023 was a tesla',
#  "thanks to free media this particular chapter of the genocide in palestine is happening in front of everybody's eyes. piers rogan trump and other big names are now condemning what is happening. but on day one was telling piers what would happen. he knew.",
#  'when barbie touch downn zany face pink heart im ready for you babes.',
#  'beyoncs cowboy carter is galloping to no. 1 in the u.k.',
#  'breaking news newspaper police car light bitcoin bull run is coming ox the bitcoin halving is now only about 17 days away. eyes fire',
#  'algum disse voc vem ao brasil. eu espero que sim mas est fora do meu controle infelizmente. conan gray ao vivo no talk shop live.',
#  'im here gagcitybaltimore',
#  'remembered as a hero family pays tribute to james kirby one of three britons killed in israeli strike on gaza aid convoy',
#  'the everything app gets closer every single day. were building new ways for everyone to find community and connect to one another.',
#  'feid announces joint album with yandel heres what we know',
#  'which pussy can mek mi run',
#  'mi n di gyaldem',
#  'some likkle gyal a stalk mi',
#  ".'s never really over is now certified diamond in brazil. brazil",
#  'define cultural reset',
#  "does conan sell the found heaven necklace separately because i don't collect cds i'm a vinyl girlie",
#  'first look at mufasa the lion king. in theaters on december 20',
#  'funimation has officially closed',
#  'she sounds exactly like the countess i am screaming',
#  'am i the only one that didnt notice conan start singing a song from found heaven by accident during the live the sheer panic in his eyes loudly crying face',
#  'what does it mean',
#  'just in u.s. sec calls for comments on spot eth etfs',
#  'i dont give a damn how pretty it is. australia will never see me',
#  'united states las mujeres ya no lloran on us billboard 1. top latin albums 1. top latin pop albums 2. top album sales 2. top current album sales 4. top vinyl albums 13. billboard 200 30. top streaming albums',
#  'new look at moana 2 out november 27th.',
#  'the sleeper hit of the year this song watches those other hits come and go while it stays smashing on the charts loudly crying face',
#  'atta baby flag in hole 40 500 winners money bag money bag radio button repost this video radio button reply saying something nice to somebody radio button put the easiest way to pay you in the post as wellpmslive',
#  'high heels on my tippies nail polish medium light skin tone heart with ribbon pinkfridaynails',
#  'mediquen a shakmiley por favor. la pobre ya est en las drogas.',
#  'just in united states us government transfers 30174 bitcoin worth 21 billion seized from silk road to coinbase.',
#  'playstation 5 deals the limited edition spider man 2 console bundle is 110 off at amazon',
#  'conan still being in a friend group with his ex oh my god',
#  'i dont know how shell top this cover',
#  'atta baby flag in hole 40 500 winners money bag money bag radio button repost this video radio button reply saying something nice to somebody radio button put the easiest way to pay you in the post as wellpmslive',
#  'i dont give a damn how pretty it is. australia will never see me',
#  'united states las mujeres ya no lloran on us billboard 1. top latin albums 1. top latin pop albums 2. top album sales 2. top current album sales 4. top vinyl albums 13. billboard 200 30. top streaming albums',
#  'new look at moana 2 out november 27th.',
#  'the sleeper hit of the year this song watches those other hits come and go while it stays smashing on the charts loudly crying face',
#  'what does it mean',
#  'just in u.s. sec calls for comments on spot eth etfs',
#  'funimation has officially closed',
#  'she sounds exactly like the countess i am screaming',
#  'am i the only one that didnt notice conan start singing a song from found heaven by accident during the live the sheer panic in his eyes loudly crying face',
#  'first look at mufasa the lion king. in theaters on december 20',
#  'define cultural reset',
#  "does conan sell the found heaven necklace separately because i don't collect cds i'm a vinyl girlie",
#  'some likkle gyal a stalk mi',
#  ".'s never really over is now certified diamond in brazil. brazil",
#  'the everything app gets closer every single day. were building new ways for everyone to find community and connect to one another.',
#  'feid announces joint album with yandel heres what we know',
#  'which pussy can mek mi run',
#  'mi n di gyaldem',
#  'im here gagcitybaltimore',
#  'remembered as a hero family pays tribute to james kirby one of three britons killed in israeli strike on gaza aid convoy',
#  'breaking news newspaper police car light bitcoin bull run is coming ox the bitcoin halving is now only about 17 days away. eyes fire',
#  'algum disse voc vem ao brasil. eu espero que sim mas est fora do meu controle infelizmente. conan gray ao vivo no talk shop live.',
#  'when barbie touch downn zany face pink heart im ready for you babes.',
#  'beyoncs cowboy carter is galloping to no. 1 in the u.k.',
#  'the most sold car on planet earth in 2023 was a tesla',
#  "thanks to free media this particular chapter of the genocide in palestine is happening in front of everybody's eyes. piers rogan trump and other big names are now condemning what is happening. but on day one was telling piers what would happen. he knew.",
#  "usa today attended 's gagcitydc and gave their review of her show for her first u.s. run in eight years minaj has crafted her most grandiose productionshe is still the queen of rap for a reason.",
#  'nine milestones beyonc could reach at 2025 grammys',
#  'israels pm says its forces unintentionally hit innocent people in gaza after strike on aid workers kills seven follow latest updates',
#  'justice for katy perry broken heart crying cat',
#  'conans gonna be personally at the gates of the arena asking people if they are in a relationship and if they say yeah hell be like good for you get out.',
#  'un fan de karol g pero cuntos streams de spotify tiene selena enraged face',
#  'taylor swift competing with travis kelce for a 2024 webby award full nominations announced',
#  'two margaritas deep i heard a song playing called you can go your own way and i was like wow they are really singing their ass off. looked it up its two band members breaking up i am in tears you can go your own way loudly crying face loudly crying face watched the live performance. he cant even look at her',
#  '.s las mujeres ya no lloran hit number one on top latin albums and latin pop albums gem stone',
#  'sister ship 1 is 22h 32m 47s of light travel time from earth 2024 094 120000 1l',
#  'new look at moana 2 set 3 years after the first movie. in theaters on november 27.',
#  'just in apple exploring the creation of home robots as next big thing.',
#  'estoy en usa y ha estado ms veces en tendencia que esta semana en twitter. aunque amo a las dos solo escribo para que vean la relevancia de shakira aqu.',
#  'what if i said house of gucci has the best poster',
#  'we need katys documentary about what happened from 2017 2018',
#  'katy perrys teenage dream album cover is actually a painting',
#  'coneheads join cone for a live qa on now star black heart',
#  'new shakira collaboration on the way. xx',
#  'nicki concert 1010',
#  'its been 4 years and youre still a brokie',
#  'i reiterate my firm call for an immediate ceasefire in the gaza strip. i express my deep sorrow for the volunteers who were killed while distributing humanitarian aid in gaza. i pray for them and their families.',
#  'its time for katycats to move justiceforkatyperry',
#  'katchatheevu tiny sri lankan island sparks political row in india',
#  "when gaga did house of gucci she got dragged for having an accent for joker she's getting dragging for not having one",
#  'gaga daily wouldve loved today pleading face broken heart',
#  'crying. over. this. face holding back tears purple heart we love you',
#  'big breaking police car light bitcoin to reach 150k by the end of this year per morgan creek capital management ceo mark yusko',
#  'how fox sports resident deadheads brought jam bands to big games',
#  'boys girls foi a msica que conan levou mais tempo a fazer no lbum found heaven.',
#  'is winning saluting face',
#  'katchatheevu tiny sri lankan island sparks political row in india',
#  "when gaga did house of gucci she got dragged for having an accent for joker she's getting dragging for not having one",
#  'gaga daily wouldve loved today pleading face broken heart',
#  'its time for katycats to move justiceforkatyperry',
#  'nicki concert 1010',
#  'its been 4 years and youre still a brokie',
#  'i reiterate my firm call for an immediate ceasefire in the gaza strip. i express my deep sorrow for the volunteers who were killed while distributing humanitarian aid in gaza. i pray for them and their families.',
#  'katy perrys teenage dream album cover is actually a painting',
#  'coneheads join cone for a live qa on now star black heart',
#  'new shakira collaboration on the way. xx',
#  'just in apple exploring the creation of home robots as next big thing.',
#  'estoy en usa y ha estado ms veces en tendencia que esta semana en twitter. aunque amo a las dos solo escribo para que vean la relevancia de shakira aqu.',
#  'what if i said house of gucci has the best poster',
#  'we need katys documentary about what happened from 2017 2018',
#  'new look at moana 2 set 3 years after the first movie. in theaters on november 27.',
#  'taylor swift competing with travis kelce for a 2024 webby award full nominations announced',
#  'two margaritas deep i heard a song playing called you can go your own way and i was like wow they are really singing their ass off. looked it up its two band members breaking up i am in tears you can go your own way loudly crying face loudly crying face watched the live performance. he cant even look at her',
#  '.s las mujeres ya no lloran hit number one on top latin albums and latin pop albums gem stone',
#  'sister ship 1 is 22h 32m 47s of light travel time from earth 2024 094 120000 1l',
#  'un fan de karol g pero cuntos streams de spotify tiene selena enraged face',
#  'justice for katy perry broken heart crying cat',
#  'conans gonna be personally at the gates of the arena asking people if they are in a relationship and if they say yeah hell be like good for you get out.',
#  "usa today attended 's gagcitydc and gave their review of her show for her first u.s. run in eight years minaj has crafted her most grandiose productionshe is still the queen of rap for a reason.",
#  'nine milestones beyonc could reach at 2025 grammys',
#  'israels pm says its forces unintentionally hit innocent people in gaza after strike on aid workers kills seven follow latest updates',
#  'the most sold car on planet earth in 2023 was a tesla',
#  "thanks to free media this particular chapter of the genocide in palestine is happening in front of everybody's eyes. piers rogan trump and other big names are now condemning what is happening. but on day one was telling piers what would happen. he knew.",
#  'when barbie touch downn zany face pink heart im ready for you babes.',
#  'beyoncs cowboy carter is galloping to no. 1 in the u.k.',
#  'breaking news newspaper police car light bitcoin bull run is coming ox the bitcoin halving is now only about 17 days away. eyes fire',
#  'algum disse voc vem ao brasil. eu espero que sim mas est fora do meu controle infelizmente. conan gray ao vivo no talk shop live.',
#  'im here gagcitybaltimore',
#  'remembered as a hero family pays tribute to james kirby one of three britons killed in israeli strike on gaza aid convoy',
#  'the everything app gets closer every single day. were building new ways for everyone to find community and connect to one another.',
#  'feid announces joint album with yandel heres what we know',
#  'which pussy can mek mi run',
#  'mi n di gyaldem',
#  'some likkle gyal a stalk mi',
#  ".'s never really over is now certified diamond in brazil. brazil",
#  'define cultural reset',
#  "does conan sell the found heaven necklace separately because i don't collect cds i'm a vinyl girlie",
#  'first look at mufasa the lion king. in theaters on december 20',
#  'funimation has officially closed',
#  'she sounds exactly like the countess i am screaming',
#  'am i the only one that didnt notice conan start singing a song from found heaven by accident during the live the sheer panic in his eyes loudly crying face',
#  'what does it mean',
#  'just in u.s. sec calls for comments on spot eth etfs',
#  'i dont give a damn how pretty it is. australia will never see me',
#  'united states las mujeres ya no lloran on us billboard 1. top latin albums 1. top latin pop albums 2. top album sales 2. top current album sales 4. top vinyl albums 13. billboard 200 30. top streaming albums',
#  'new look at moana 2 out november 27th.',
#  'the sleeper hit of the year this song watches those other hits come and go while it stays smashing on the charts loudly crying face',
#  'atta baby flag in hole 40 500 winners money bag money bag radio button repost this video radio button reply saying something nice to somebody radio button put the easiest way to pay you in the post as wellpmslive',
#  'high heels on my tippies nail polish medium light skin tone heart with ribbon pinkfridaynails',
#  'mediquen a shakmiley por favor. la pobre ya est en las drogas.',
#  'just in united states us government transfers 30174 bitcoin worth 21 billion seized from silk road to coinbase.',
#  'playstation 5 deals the limited edition spider man 2 console bundle is 110 off at amazon',
#  'conan still being in a friend group with his ex oh my god',
#  'i dont know how shell top this cover',
#  'nah i love the barbz fr',
#  'chance the rapper wife kirsten corley announce divorce after 5 years of marriage',
#  'one child dead and two seriously wounded in finland school shooting after pupil 12 opened fire police say',
#  'community notes now active on india',
#  'best concert ever i cried danced and all unicorn unicorn unicorn gagcitybaltimore',
#  'cts eventim to buy vivendis ticketing events businesses',
#  'my pf2 tour fit i am definitely permanently signing my contract as a resident into gag city again amazing show',
#  'whats your favorite shakira no. 1 billboard latin pop airplay hit vote',
#  'microsoft technology giant splits teams and office globally',
#  'breaking bloomberg is dying. headstone media sites are continuously experiencing a decline in traffic.',
#  'i am the most famous man in the world and avoid speaking to famous people because theyre all gay and weird.',
# ...
#  'ukraine war deepest ukraine drone attack into russian territory injures 12',
#  'hot 100 first timers tito double p joel de la p arrive with peso pluma collab la people ii',
#  'alien will re release in theaters on april 26',
#  'taylor swift and sza were among the record setters at the 2024 iheartawards.',
#  'harleys in hawaii by katy perry has reached 500 million streams on spotify. its her 15th song to achieve this.',
#  '. opens up about her yellowstone themed album stellaria mental health more',
#  'romania chantaje feat. maluma debuta en el top 200 de spotify rumania 185 a 7 aos de su lanzamiento es la 6 cancin de en el chart y el 55 pas en el que ingres',
#  'remembering that after friday we wont have new music for about a year',
#  "new bitcoin etfs saw a record volume of 111 billion in march. that's triple the inflows from february exploding head",
#  'eminem pranks fans with april fools day album announcement',
#  'meet the major league executives bringing music to sports',
#  '. has major plans for 2024 eyes he teases his next album going on tour diving into acting with billboardnews. watch his full interview',
#  'we have an incredible team of engineers building the app that will change. everything.',
#  '. takes lead on christian airplay chart for first time i hope the message keeps going',
#  'full nudityy and it better be from ga',
#  '. on new whiskey jypsi release upcoming nashville residency it was important to us that we could be creative',
#  'google to delete records from incognito tracking',
#  'joker joker 2',
#  'venice launches new career assistant tool for artists',
#  'this was soo',
#  'the 10 member space station crew worked on cargo spacesuits and human research on tuesday as weekend crew departure preps continue.',
#  "the polaris dawn dragon is headed to vacuum chamber testing spacex teams celebrate dragon's departure with and ahead of launching to orbit this summer",
#  'the cast of real housewives of potomac are in gag city tonightrhopgagcitydc',
#  'kristen wiigs old snl dressing room gets completely taken over in new promo',
#  'soca superstar breaks down five favorite tracks from first album in 10 years its time to position ourselves in a global way',
#  'bassirou diomaye faye senegal election offers hope to frustrated young africans',
#  'there was plenty of drama when ziggy and mackenzie sol entered a sing off on americanidol.',
#  'pink heart folded hands medium skin tone',
#  'louis conter last survivor of attack on pearl harbor ship dies aged 102',
#  'lizard eliminated after sink or swim experience on the masked singer im not used to losing',
#  'at least 29 people now confirmed to have died in fire at istanbul nightclub undergoing renovations',
#  '20 best travel deals to help you get away on a budget',
#  'qgtm history in the fng making. thank you a million times over. trophy gagcitydc shall go in the gagcity history books.',
#  'michelle obama praises beyoncs cowboy carter while encouraging fans to register to vote we all have power',
#  'k pop star karina and actor lee jae wook split shortly after going public',
#  'act fast the ipad pro ipad air ipad mini are on sale at amazon save up to 100 off',
#  'spotify a pesar del supuesto backlash las mujeres ya no lloran increment sus streams diarios ayer whenever wherever tuvo su mejor da en lo que va del 2024 479768 streams y la tortura recibi ms de 400 mil streams por primera vez 408059',
#  'i love this other katy perry accounts. but i need to make this clear there was no press event was a private preview for some industry people and i wasnt there. all very positive reactions to batch of songs they heard. album not 100 percent finished but katy is coming soon',
#  'ye has been sued by another former donda academy staffer alleging a sexually abusive environment. billboardnews',
#  'breaking the bills are trading wr stefon diggs to the texans per .',
#  'adele reschedules 2024 weekends las vegas residency shows postponed by illness',
#  'just a few sec of this scene added in the teaser trailer could make me faint',
#  'crawler transporter 2 update as we prepare for future missions right arrow curving down',
#  "james kirby cousins pay tribute to 'selfless hero'",
#  'magic johnson posts heartfelt celebration of living icon beyoncs cowboy carter',
#  'jon batiste hopes his work on beyoncs cowboy carter helps dismantle the genre machine',
#  'the first amendment. congress shall make no law respecting an establishment of religion or prohibiting the free exercise thereof or abridging the freedom of speech or of the press or the right of the people peaceably to assemble and to petition the government for a redress',
#  'bless ft wvw pre save link',
#  'where it all began star',
#  'first poster for joker 2 starring joaquin phoenix and lady gaga.',
#  'billie piper says classmate amy winehouse was bullied in school',
#  'slipknot avenged sevenfold disturbed to headline 2024 rocklahoma festival',
#  'cash cobain speaks out on nyc concert canceled for reasons out of my control',
#  'karol g in latin america all the guests on her maana ser bonito tour',
#  'bizarrap natanael cano drop explosive two song collaboration bzrp music session 59 stream it here',
#  'shakira has surpasses billie eilish to become the 21 1 artist with the most monthly listeners on spotify and 8 female artist. globe showing americas',
#  "two investors plead guilty in insider trading scheme linked to the trump media deal that brought the former president's social media business public",
#  'strongest earthquake in 25 years rocks taiwan with tsunami warnings issued for nearby countries',
#  'craig gillespie is in talks to direct supergirl. he has previously directed cruella and i tonya source deadline',
#  'do not trust men who are easily afraid. loyalty requires bravery. anyone whos easily scared will easily turn. without balls your sentiment as a man means absolutely zero. as soon as a weak man has to suffer for the person they are loyal to loyalty disappears.',
#  'kai media company behind k pop label hello82 raises more funding for expansion',
#  'finland shooting several injured in vantaa school shooting police',
#  "ken griffin says u.s. is being 'irresponsible' with national debt and politicians are spending 'at the expense of future generations per fortune.",
#  'we are on. pink heart party popper party popper party popper party popper birthday cake balloon confetti ball gagcity ticket give away ticket admission tickets may the best barbz win. trophy',
#  "just in china taiwan 30 chinese warplanes and 9 navy vessels have positioned around taiwan according to taiwan's defense ministry. thinking face",
#  'donald trump getting booed in mi today brings joy to my heart.',
#  'fed chairman powell finally told the truth. last week he finally admitted inflation is winning. the fed can no longer promise i flation at 2 or that inflation is transitory. again he finally stopped lying. congratulations. the problem is most people have no idea what the',
#  'just in hedge fund billionaire steve cohen told cnbc he owns a very little amount of bitcoin eyes',
#  'fellas is it antismitic to think that aid workers shouldnt be airstriked',
#  'current joker folie deux box office predictions. with a predicted worldwide box office of just under 800m the film would currently be the 3rd highest grossing r rated movie of all time behind oppenheimer and the original joker.',
#  'there is no future without kids',
#  "there have been a few recent articles in the press about 'winning' its proxy contest with nelson peltz based on early election returns that have been leaked to the media. we don't have an investment in disney but i thought it useful to point out the inappropriateness of",
#  "aileen cannon should have been removed from the case a long time ago with her bullshit rulings blatantly causing delays that favor defendant trump. it's a fucking joke.",
#  'wanna be face with hand over mouth heart on fire 0405',
#  "in the movie 'the matrix' neo's passport has an expiration date set to 9112001",
#  ".'s harleys in hawaii has now surpassed 500 million streams on spotify.",
#  'her mind. shes sick.',
#  'x premium costs just 23 cents a day when bought annually via web. united states subscribe to x premium to support this platform.',
#  'is there anything more overrated than a solar eclipse face with tears of joy',
#  "loral o'hara one of five currently on the station is returning to earth on april 6. she conducted one spacewalk and researched advanced space phenomena during her six and a half month mission. more.",
#  "it's been 6 years since we became a public company. its pretty wild to think that by most metrics spotify is now 3x or more on where we were that day. i am reminded of bill gates quote most people overestimate what they can do in one year and underestimate what they can do",
#  '2 . 1 of 8 bands in the 2200 to 7300 spectral region then on to a photomultipler tube. by study of these emission intensity data information on surface texture composition of planets could be obtained along w information.',
#  'joker 2 poster has been seen 14 million times in just 10 hours on one twitter account comparing it to other major releases first poster posts these numbers are incredible.',
#  'police car light police car light police car light police car light police car light police car light police car light police car light police car light police car light 370000000 usdt 370047175 usd transferred from tether treasury to bitfinex',
#  "ftc responds to esrb's proposal for an ai powered face scanning 'age estimation' system no",
#  "why hasn't judge cannon ruled on the doj reconsideration motion to block the release of witness lists i'm guessing she knows if she releases them smith will go to the 11th circuit. so she's sitting on it.",
#  'police car light breaking police car light sec asks for public comment for grayscale bitwise and fidelity spot ethereum etfs. giga bullish fire',
#  'this is evil',
#  "what's going on here",
#  'update on samplingmars i recently collected my 24th sample from an area called bunsen peak named for the landmark. the rock core is filled with silica and carbonate.',
#  'knowledge is power. bitcoin',
#  'truly mothers daughter',
#  'did you know that legacy media have notifications on for',
#  'hunter schafer euphoria star says she no longer wants to play trans characters',
#  'perfection.',
#  'wonder where she is now loudly crying face',
#  'dms are still up running just saying',
#  'big breaking police car light coinbase ceo says its bitcoin lightning network integration should be launching soon. eyes fire',
#  'joker folie deux official website. link',
#  'dolce doll pink heart',
#  'gagcitybaltimore',
#  'katy perry exalando beleza durante as gravaes do american idol no hawaii.',
#  'olivia via instagram stories',
#  "katy perry esquecida .'s harleys in hawaii has now surpassed 500 million streams on spotify. 's never really over is now certified diamond in brazil. gente que fracassada 2 msicas solo do ltimo lbum sendo diamante e 500m de streams do spotify",
#  'katy perry x american idol brown heart sparkles',
#  'joker 2 trailer is really coming to break the internet. were talking hundreds of millions of views across all platforms. a global event.',
#  'shakira is set to appear on hot ones tomorrow april 4 heart on fire',
#  'started stan twitter started the concept of eras started the whole mother and fanbase relationship like im so serious',
#  "lavar ball blames the nba training staffs and puma's 'raggedy' shoes for his sons' injuries the reason they hurt is because they got away from me. and they start doing these rooty toot workouts. because if you keep running them hills you're going to keep that power and that",
#  'former observer huffpost journalist claims katy perrys career decline was planned by some people similar to how christina aguileras career was sabotaged. they then alleged writers trashed katy to generate clicks more money. last year former pitchfork writers alleged',
#  'lady gaga photographed by steven klein.',
#  'breaking the sec requested public comment on major ethereum spot etfs',
#  'btc bitcoin is holding that weekly range low 65600 as support for nowbtc crypto bitcoin',
#  'what other payment options do you think should be added to the tip jar',
#  'doge',
#  'harry potter said what loudly crying face',
#  'im glad gaga is keeping her og voice nobody wants to hear that squeaky ass over exaggerated voice',
#  'were 5 days away from the eclipse check out my eclipse guide linked in bio for some tips on how to see it. remember the difference between 99 100 is one that will literally change your life. the eclipse i saw in 2017 ignited a passion to pursue astrophotography.',
#  "fans from selected countries can now watch shakira's videos on spotify go and stream",
#  "why are cities dominated by highways and cars it's partly because of one of the most influential people you've never heard of norman bel geddes. in 1939 he created futurama a huge exhibition that tried to predict the future and ended up changing the world.",
#  'breaking coinbase is working with lightspark to integrate the bitcoin lightning network for all its customers high voltage',
#  'from these 4 accounts alone nearly 31 million views in 24 hours.',
#  'finally restocked lady gaga the fame monster picture disc. will be included in our friday drop as well',
#  "rumor aparentemente houve uma listening sessions de algumas msicas do kp6 e um jornalista que estava presente comentou sobre o novo lbum de katy perry. katy est prestes a realizar o maior retorno musical desde mariah carey com 'the emancipation of mimi'. seu novo lbum",
#  'breaking the guy that rammed his car into the fbi field office in atlanta the other day has social media accounts associated with q anon anti vaxx stuff election denialism sidney powell and donald trump. super shocked source',
#  'a warner bros. divulgou todas as fotos de joker folie deux que sairam sem cortes. joker2 clapper board joker',
#  "spotify top songs 0402 streams hips don't lie 1138286 tqg 1038174 puntera 961461 entre parntesis 846840 cohete 603393 bzrp music sessions vol. 53 570837 whenever wherever 479768 chantaje 422502 la tortura 408059 dia de enero 403425",
#  'mxico puerto rico repblica dominicana costa rica panam el lugar podra dejarlos por fuera colombia brasil ecuador per bolivia chile argentina paraguay uruguay gem stone gem stone gem stone gem stone gem stone gem stone',
#  "what if i tell you that there's more adult content on threadz instagram than on onlyfans. eyes",
#  'keityn feid carlos vives and yng lvcas talk major wins at 2024 latin ascap awards',
#  'ferrari sf90 palm tree',
#  'anya taylor joy confirms she secretly got married to malcolm mcrae in 2022',
#  'thank you baby kiss mark',
#  'tonights tank top says w star men at gutsworldtourboston',
#  'up green circle facebook down red circle instagram down red circle whatsapp down red circle',
#  'we all remember where we were',
#  'just in united states blackrock and fidelity now own a combined 399741 btc worth 262 billion for their spot bitcoin etfs.',
#  'united states shakira is the female artist with the most songs currently on the us itunes top 100 latin songs totaling 8 songs.',
#  "shakira's amazing 12th studio album 'las mujeres ya no lloran' scores the 3rd highest new entry on the united world album chart landing at 6 flexed biceps 3rd place medal top arrow new button collision keycap 6 globe showing americas chart increasing crown heart on fire 'las mujeres ya no lloran' featuring cardib rauwalejandro manuelturizo grupofrontera ozuna karolg",
#  'news tesla overtook mercedes as the second largest seller of imported vehicles in korea last month. it marked the first time for tesla to beat mercedes benz in korea in terms of sales.',
#  'the ultimate guide to festivals celebrating latin music in 2024',
#  'lady gaga is a fucking movie star',
#  'te har salir volando como un cohete rocket collision ill make you fly like a rocket lmynl',
#  'hawl awn is that',
#  'youre invited see you in rogueport on may 23 in papermariothethousandyeardoor coming to nintendoswitch',
#  'alien mothers']

# %% [markdown]
# ## Add BERT Special Tokens

# %%
def add_special_tokens(sentence):
    # Step 1: Adding the [CLS] token at the beginning
    sentence_with_cls = "[CLS] " + sentence
    
    # Step 2: Adding the [SEP] token before each full stop
    split_sentence = sentence_with_cls.split('.')
    sentence_with_sep = " [SEP].".join(split_sentence)
    
    # Clean up to handle cases where [SEP] might be added at the end unnecessarily
    sentence_with_sep = sentence_with_sep.replace(" [SEP].", " [SEP]").rstrip()
    
    return sentence_with_sep

# %% [markdown]
# BERT requires specific tokens to be added to the text. This function inserts the [CLS] token at the start and the [SEP] token at sentence boundaries.

# %%
# Applying the function to all sentences in the results list
processed_results = [add_special_tokens(sentence) for sentence in result]
processed_results[:5]
# Out:
# ['[CLS] the binance towel comes everywhere with me [SEP] including breakfast cooking',
#  '[CLS] drop your sol address below and make sure you are following me dont ask why backhand index pointing down medium light skin tone',
#  '[CLS] 5235670',
#  '[CLS] it only takes one good altcoin to change the world [SEP] sparkles',
#  '[CLS] disrespectful is one of my top 3 favorite',
#  '[CLS] some congressional republicans call the affordable connectivity program wasteful [SEP] i call it necessary [SEP] its time congress extended it so the 23 million households across america that rely on the program can stay connected [SEP]',
#  '[CLS] donald trump wont do what an american president must do [SEP] he refuses to denounce political violence [SEP] ill say what trump wont political violence is never ever acceptable in america [SEP]',
#  '[CLS] there is a massive bitcoin breakout coming [SEP] are you ready',
#  '[CLS] max pain [SEP]',
#  '[CLS] ok so the vote is in [SEP] ill do a 25 ticket giveaway on station head in 10 mins [SEP] if i feel like it ill come on spaces give out another 5 10 after that [SEP] the generous queen princess medium skin tone',
#  '[CLS] my whole heart',
#  '[CLS] im tired of people using me as their punching bag leave me tf alone its my day off',
#  '[CLS] lets take a deep dive shall wee chapter one water wave',
#  '[CLS] april 03 2024 09 21 am utc current price of bitcoin btc usd 6648480 btc eur 6175773',
#  '[CLS] how is pitbull not in the big 3',
#  "[CLS] 35 a month insulin for seniors [SEP] 35 inhalers for asthma [SEP] 2000 a year cap on prescription drugs for seniors starting next year [SEP] with senator sanders' help were showing how health care should be a right not a privilege in america [SEP]",
#  '[CLS] cryptoo',
#  '[CLS] major pump incoming [SEP]',
#  '[CLS] the world is a stage [SEP] joker folie deux trailer coming april 9 [SEP] joker',
#  '[CLS] video shows abducted us girl fatally shot by police',
#  '[CLS] the best bravest baddest barbz win',
#  '[CLS] bitcoin is going to 100000 eth is going to 10000 altcoins will pump 10x halving in 15 days [SEP] you are not bullish enough [SEP]',
#  '[CLS] what conan lyric feels like this',
#  '[CLS] the more tether prints the higher bitcoin goes [SEP]',
#  '[CLS] which of these artists is the biggest hit maker',
#  '[CLS] bitcoin navigating the high seas of finance steering the ship of economic evolution [SEP] sailboat money bag water wave',
#  '[CLS] album moments cyclone i hear you feeling optimistic about this week',
#  "[CLS] not in the path of totality for the total solar eclipse on april 8 we'll bring totality to you by broadcasting from several locations along its trajectory including our only center in the eclipses path [SEP] how to watch",
#  "[CLS] it's a tough gig being the binance intern [SEP] good morning",
#  '[CLS] donald trump doesnt trust women [SEP] i do [SEP]',
#  '[CLS] there is no bigger red flag in an adult than lack of children [SEP] if youre 46 and not yet bored of weed and alcohol youre immature and soulless [SEP] how can you be trusted to vote you have a warped world view with zero vested interest in the future [SEP] the poorest people alive',
#  '[CLS] 1 whole bitcoin hodlers are becoming rare',
#  '[CLS] dogecoin as tipping option eyes',
#  '[CLS] my targets for next 12 16 months btc 100k 250keth 10k 15kbnb 900 1400sol 450 650xrp 3 5doge 1dot 100 120link 250 500 backhand index pointing down medium light skin tone',
#  '[CLS] 6135748',
#  '[CLS] introducing a new simple earn flexible products promotion subscribe to either sui or usdt simple earn flexible products to grab your share of 20000 sui while also earning bonus apr [SEP] get started today right arrow curving down',
#  '[CLS] 6941650bitcoin btc btc usd',
#  '[CLS] through laws i wrote and signed i enacted tax credits that save an average of 800 per person per year reducing health care premiums for millions of families [SEP] those credits expire next year [SEP] congress make that 800 expanded affordable health care tax credit permanent [SEP]',
#  '[CLS] you already made your statement donald [SEP]',
#  '[CLS] tag a light mode user backhand index pointing down',
#  '[CLS] coinbase blackrock will pump crypto higher',
#  '[CLS] 5206863',
#  '[CLS] pitbull chingy and baby bash',
#  '[CLS] eth will explode soon fire',
#  '[CLS] my station head seems to not be working guys [SEP] what a shocker',
#  '[CLS] if i say im 25 then im 25 the fuk',
#  '[CLS] psalm camera by saint',
#  '[CLS] the next bitcoin halving is just 2 weeks out [SEP] and historically the most gains are always realized after the halving [SEP] are you prepared',
#  '[CLS] moment taiwan maternity staff rush to keep babies safe during earthquake',
#  '[CLS] 13900 eggs [SEP] 200000 in rewards [SEP] 1 bitcoin [SEP] get started with the binance egg drop backhand index pointing down',
#  '[CLS] congratulations to and for being selected to move forward in developing the artemis lunar terrain vehicle this moon rover will allow future astronauts to travel far on the lunar surface',
#  '[CLS] i am outraged and heartbroken by the deaths of seven humanitarian workers from world central kitchen including one american in gaza yesterday [SEP] incidents like yesterdays simply should not happen [SEP] here is my full statement [SEP]',
#  '[CLS] bitcoin is a symbol of digital revolution and financial freedom [SEP] light bulb globe with meridians money with wings',
#  '[CLS] miss shanel does what must be done',
#  "[CLS] is whale watching on your bucket list if so you'll be glad to know that you don't have to travel to do it [SEP] well not for crypto whale watching anyway [SEP]",
#  '[CLS] i want honest criticism on this ai portfolio 25 btc15 tao15 rndr10 grt10 akt5 ait5 paal5',
#  '[CLS] blue heart white heart red heart',
#  '[CLS] are you still with me argentina star star star gutsworldtour',
#  '[CLS] como mi amor',
#  '[CLS] 5254255',
#  "[CLS] kamala and i continue to call on congress to restore the protections of roe in every state [SEP] the majority of americans support a woman's right to choose including in florida where voters will have the opportunity to support a reproductive freedom ballot initiative this fall [SEP]",
#  '[CLS] the category is albums that deserved way more success',
#  '[CLS] white house wants moon to have its own time zone',
#  '[CLS] introducing the binanceclubhouse a global hub for all binance users to connect work and talk all things crypto [SEP] stay tuned for more info to come handshake',
#  '[CLS] yesterdays extreme florida supreme court decision puts desperately needed medical care even further out of reach for millions of women in florida and across the south [SEP] its outrageousand it was made possible by trump ending roe v [SEP] wade [SEP]',
#  '[CLS] 5198706bitcoin btc btc gbp',
#  '[CLS] ready to rock with for the april 8 eclipse submit your favorite solar themed songs to be added to a sun moon and eyes playlist',
#  '[CLS] baby steps sir weary face grinning face with sweat',
#  '[CLS]  [SEP]s in search of the antidote debuts at no [SEP] 3 on top album sales chart',
#  '[CLS] only 3 more sleeps till wrestlemania 40 [SEP] talking to and on the show tonight [SEP] finalboss tribalchief',
#  '[CLS] one crypto that will show a monster god candle this summer',
#  '[CLS] writing hand dark skin tone signature script backhand index pointing right dark skin tone',
#  '[CLS] deadly air strike shows system to protect aid workers in crisis agencies say',
#  '[CLS] binance will list wormhole w with seed tag applied [SEP] right arrow',
#  '[CLS] happy 90th birthday and please give my regards to mr [SEP] h [SEP] janeat90 goodallday',
#  '[CLS] gaza aid convoy strike what do we know',
#  '[CLS] thank you ny for a night to remember',
#  '[CLS] watch tomorrow x together bring deja vu to kelly clarkson show',
#  '[CLS] its not that no one told you [SEP]',
#  '[CLS] if the prior administration and extreme republicans in congress had succeeded in gutting the aca 45 million people nationwide would have lost their health insurance [SEP]',
#  '[CLS] helloo have we ever seen this',
#  '[CLS] which album is making more noise this friday',
#  '[CLS] barbz since yall like yappyity yapping i took screenshots of who been on here [SEP] yall asses report to station head im doing a gagcity giveaway right now [SEP] in 10 mins [SEP] who wanna win tickets ticket admission tickets lets go should i give away 50 tickets or 25 winners get a plus 1',
#  '[CLS] so about the cake do we think conan would be proud smiling face with hearts',
#  '[CLS] i remember this [SEP] i remember him withdrawing me from the tournament when i was 6 years old [SEP] i beat the first two adults then lost 3 in a row [SEP] i asked will i be able to beat them at chess when im grown up he replied son once youre grown up youll beat anyone at anything',
#  '[CLS] the bitcoin halving is now only about 17 days away eyes',
#  '[CLS] all eyes are on the sky on april 8 for the total solar eclipse did you know you can help us while experiencing the big event listen in from scientists in this episode of our curious universe podcast',
#  '[CLS] r [SEP]i [SEP]p [SEP] gale sparrow [SEP]',
#  '[CLS] bitcoin will hit 100000 in next 3 months or i am deleting my x account',
#  '[CLS] trading is now live for ena on binance right arrow',
#  '[CLS] vechains importance isnt talked about enough [SEP] vet',
#  '[CLS] cul es el mejor video de shakira y por qu',
#  '[CLS] inhalers cost less than 5 to make [SEP] but drug companies charge americans up to 600 to increase their profits [SEP] my administration has been cracking down on big pharma and now three of the four largest inhaler manufacturers are capping out of pocket costs at 35 [SEP]',
#  "[CLS] lulu i don't speak before 12 noon [SEP] i'm not lying",
#  '[CLS] como mi amor daily',
#  '[CLS] teniamos que recordarles que somos latinas ig',
#  '[CLS] guys [SEP] he answered my question im gonna cryy i love this man so much',
#  '[CLS] the category is most controversial music videos',
#  '[CLS] polls are opening up in states across the country [SEP] head to to confirm your polling place [SEP]',
#  '[CLS] the final deadline for 7 spot ethereum etfs is in 50 days',
#  '[CLS] can you guys give me a rundown on everything he said about the unreleased tracks',
#  '[CLS] google looks to ai paywall option report',
#  '[CLS] solar eclipse 2024 how to watch stream live from anywhere',
#  '[CLS] gagcity was everything nicki monica and 50 cent did what needed to be done two hearts gagcitydc',
#  "[CLS] live now how will future astronauts drive across the surface of the moon we're announcing the companies that will advance the capabilities of the lunar terrain vehicle a rover for exploration during the artemis v missions and beyond [SEP]",
#  '[CLS] time to supply you with some crypto knowledge [SEP] literally [SEP] maximum total and circulating supply explained backhand index pointing down',
#  "[CLS] for anyone who received a checkmark today you can earn money for the stuff you're already posting [SEP] no extra effort required [SEP] apply to be monetized in settings monetization",
#  '[CLS] explore new taker fee promotions on binance you can now trade usdc spot and margin trading pairs to enjoy discounted taker fees from 10 april 2024 [SEP] learn more right arrow curving down',
#  '[CLS] tune in as i deliver remarks on lowering health care costs for americans [SEP]',
#  '[CLS] oh this is extremely gaggy babe',
#  '[CLS] like what',
#  '[CLS] truck crash spills live salmon into wrong oregon river',
#  '[CLS] celebrate the upcoming bitcoin halving with the binance futures ultimate challenge [SEP] join the daily price prediction and weekly task challenges for a chance to win btc rewards and a tesla model y join now right arrow',
#  '[CLS] police car light breaking police car light grayscale has transferred 1983 btc worth 1314 million to coinbase',
#  '[CLS] bitcoin always pumps after the halving [SEP] 1st halving 8000 2nd halving 3000 3rd halving 800 in 15 days the 4th halving is here [SEP] are you mentally prepared',
#  '[CLS] today i had a candid conversation with president xi jinping of the peoples republic of china on a range of issues including areas of cooperation and areas of difference [SEP] i emphasized the importance of maintaining peace and stability across the taiwan strait and in the south',
#  '[CLS] same reason why you felt comfortable calling me a mexican when im dominican and i asked you why you feel comfortable calling me a mexican when ice and jharell jerome zoe saldana are dominicans and you dont do that to them [SEP] you do it to me because you know thats what people use',
#  '[CLS] gagcitybaltimore is taking it dmv i missed youuyall dont know man [SEP] weary face flying saucer cityscape thank you [SEP] idk what to say [SEP] the best night ive ever had on earth and gagcity [SEP] may god bless each every one of you [SEP] ill never forget you [SEP] heavyonit',
#  '[CLS] binance respectfully requests that tigran gambaryan who has no decision making power in the company is not held responsible while current discussions are ongoing between binance and nigerian government officials [SEP]bringtigranhomeread more backhand index pointing down',
#  '[CLS] after 204 days 3264 orbits and dozens of experiments in space is heading home [SEP] undocking and return coverage on nasa and other platforms begins at 8pm et friday april 5 0000 utc april 6',
#  "[CLS] don't buy bitcoin for your first name [SEP] buy bitcoin for your last name [SEP]",
#  '[CLS] billie eilish pearl jam nicki minaj among 200 artists calling for responsible ai music practices',
#  '[CLS] school shooting brings up tough questions for finland',
#  '[CLS] instead of seniors with diabetes paying as much as 400 a month for their insulin they so badly need they now only have to pay 35 a month [SEP] period [SEP] i want to extend those savings to everyone who needs lifesaving insulin whether youre a senior or not [SEP]',
#  '[CLS] heart hands medium skin tone ribbon',
#  "[CLS] trade responsibly [SEP] employing risk management strategies is an important step to reducing your portfolio's risk [SEP] so we've listed out 5 strategies which you can find right here backhand index pointing down",
#  '[CLS] binance has expanded portfolio margin to non vip users optimise your portfolio with enhanced capital efficiency risk management and trading strategies made more accessible [SEP] learn more backhand index pointing down',
#  '[CLS] collision breaking the spot bitcoin etf had positive inflow of 40300000 yesterday',
#  '[CLS] binance charity partners with the children of heroes foundation this collaboration will launch i am da vinci a 12 day therapeutic camp to support children who have lost their parents in the war [SEP] read more right arrow curving down',
#  '[CLS] floridas bans and laws like them in states across america are putting the health and lives of millions of women at risk [SEP] they take away womens freedom to make their own health care decisions and threaten physicians for providing the care they were trained to provide [SEP]',
#  "[CLS] don't panic saluting face",
#  '[CLS] never magic wand',
#  "[CLS] we've officially hit 1m posts on binance square thank you for sharing content on your feeds and spreading crypto knowledge worldwide handshake keep building right arrow",
#  '[CLS] thats not what you said [SEP] you said nobody called me ghetto and now you moving the goal post you know why im at where im at right now because i took all those nos and recognized what i had to change [SEP] i had to change the way i talk the way i act and the way i respond and how',
#  '[CLS]',
#  '[CLS] honestly a great product feel more energized and stronger ever since ive taken it',
#  "[CLS] lizzo clarifies she is not quitting music industry just 'negative energy'",
#  '[CLS] olivia rodrigo kisses chappell roan during guts world tours boston stop',
#  "[CLS] yesterday floridas supreme court upheld a state abortion ban likely triggering the governor's more extreme law eliminating access before many even know they're pregnant [SEP] outrageous [SEP] and i remain committed to protecting reproductive freedom in florida and across the u [SEP]s [SEP]",
#  '[CLS] ukraine gives award to foreign vigilantes for hacks on russia',
#  '[CLS] i got 45 mins to give away my own personal tkts to soldoutminaj shows guys [SEP] but im doing it on station head so nanabooboo barbz dont start [SEP] i miss you face with hand over mouth',
#  "[CLS] the flies our newest class of officially graduated basic training last monthand what's a graduation without a few superlatives if you want to join the next astronaut class our applications are still open get yours in by april 16",
#  '[CLS] just in coinbase ceo says its bitcoin lightning network integration should be launching soon high voltage eyes',
#  '[CLS] dont pinch me please',
#  '[CLS] rashee rice super bowl champion admits role in texas hit and run',
#  '[CLS] this week america lost a hero [SEP] when lou conter passed away at the age of 102 america said farewell to the last known survivor of the u [SEP]s [SEP]s [SEP] arizona which was stationed on battleship row at pearl harbor on december 7 1941 [SEP] today our hearts are with those who knew him and',
#  '[CLS] i think there might be some confusion on what was said [SEP] i asked why he feels so comfortable calling me mexican i have no mexican parents [SEP] my mom is trini [SEP] she came out of a whole black woman [SEP] my father is dominicanim dominican just like you [SEP] i also used other dominicans as',
#  '[CLS] all i wanted to give my fans an album tour that touched them in every way reminded them of why how we fell in love in the 1st place [SEP] to give them the tour that they never knew they needed prove to them how much i value them how much i value the arts pink heart',
#  '[CLS] beyonc jennifer hudson host mini dreamgirls reunion at 2024 iheartradio music awards',
#  '[CLS] why this amateur scientist measured snowfall for 50 years',
#  '[CLS] happy tipping tuesday shibes tip in dogecoin dog dog face money with wings',
#  '[CLS] doge is the og tipping currency of the internet',
#  '[CLS] police car light breaking police car light united states proshares have launched a leveraged 2x ultra bitcoin etf today [SEP] bullish fire',
#  '[CLS] april is a big month for sky gazing star struck big planets jupiter will be visible all month mars and saturn will rise together on april 10 11 big eclipse on april 8 catch the last total solar eclipse in the u [SEP]s [SEP] for 20 years big moon catch a full moon on april 23',
#  '[CLS] irish basketball teams ordered to replay last 03 seconds of quarter final tie',
#  '[CLS] will beyonc finally win album of the year grammy with cowboy carter',
#  '[CLS] lovee that title [SEP] lets go bravo [SEP] call me face with tongue',
#  '[CLS] worst migraines ever for like 3 weeks now [SEP] skull why wont these things go away i have tried everything [SEP] what is your secret',
#  '[CLS] god [SEP]',
#  "[CLS] tennessee passes 'chemtrail' bill banning airborne chemicals",
#  '[CLS] aww weary face pink heart',
#  '[CLS] heres my advice to you raymonte it takes time right now i get brand deals for over 5 million for a campaign i got social media famous in 2014my first brand deal from fashion nova was in 2016 and 200 a post [SEP] you could reach any height no matter how ghetto or where you',
#  '[CLS] something is cooking at eyes',
#  '[CLS] eyes',
#  '[CLS] mysterious streak of light seen across southern california sky',
#  '[CLS] here are the performers and presenters for 2024 cmt music awards',
#  '[CLS] botswana offers to send 20000 elephants to germany',
#  '[CLS] two letters dc gagcitydc',
#  '[CLS] french couple who kept 159 cats banned from keeping pets',
#  '[CLS] police car light breaking police car light 1000000000 usdt just got minted at tether treasury yesterday also 1 billion usdt was minted [SEP] are whales preparing for a huge bitcoin pump',
#  '[CLS] rebel wilson book release put back in uk and australia',
#  '[CLS] instagram tiktok facebook',
#  "[CLS] world central kitchen founder jos andrs says israel targeted staff in gaza 'car by car'",
#  '[CLS] who were the seven aid workers killed in gaza',
#  '[CLS] listen lots of my friends have made tons and tons of money on crypto while i cling to my little bag of silver [SEP] i realize that crypto has been more successful in the last several years than what i think would be [SEP] and i obviously admit that and people shouldnt take investment',
#  '[CLS] super valid [SEP] worth a podcast someday [SEP]',
#  '[CLS] taylor swift is officially a billionaire',
#  '[CLS] will truth social post a financial bailout for trump',
#  '[CLS] three british aid workers killed in israeli strike in gaza named',
#  "[CLS] tesla 'disaster' with fewest deliveries since 2022",
#  '[CLS] best doge meme wins 69420 trophy like repost this post to participate [SEP] dog upload your meme in the comments [SEP] speech balloon',
#  '[CLS] judges dog',
#  '[CLS] trump sues truth social co founders over alleged mismanagement',
#  '[CLS] ukraine lowers combat call up age to boost numbers',
#  '[CLS] 2024 mlb season how to watch baseball games online for free without cable',
#  "[CLS] congratulations to buid 7952 on being our first winner of the tesla car lucky draw in second installment of futureschallenge party popper don't worry there are 3 weeks left to get your hands on your very own tesla participate now right arrow",
#  '[CLS] tuesday already watch and me play password tonight at 109c on after weakestlink',
#  '[CLS] i went to gagcitydc alone and ended up w the sweetest girl next to me who was also alone so fun and it was her bday loudly crying face loudly crying face loudly crying face loudly crying face pink heart pink heart pink heart it was just a magical and fun night overall [SEP] im so overwhelmed and grateful',
#  '[CLS] r [SEP]i [SEP]p [SEP] michael mcmartin [SEP]',
#  "[CLS] time to look at this month's market insights our research team analyzed the state of the crypto market and provided insights on bitcoin etf inflows ethereum's dencun upgrade solana's dex volumes and more [SEP] check it out down arrow",
#  "[CLS] x is bringing the tip jar to the web app it was an iosandroid feature for years and now it's finally finding its way to the web version here you can see a full list of the supported services",
#  '[CLS] cool cool',
#  '[CLS] israeli government says it will block al jazeera from broadcasting',
#  "[CLS] new senegal president bassirou diomaye faye and his two wives in our african culture divorce is a taboo [SEP] a man isn't allowed to divorce a woman unless she has committed infidelity only that is unforgivable as for a man wanting to divorce a woman because she's no longer young",
#  '[CLS] the deluxe tracks from guts spilled on this weeks billboard hot 100 14 obsessed 58 so american 75 stranger 90 scared of my guitar 99 girl ive always been',
#  '[CLS] janet jackson returns to japan for triumphant together again tour chronicling legendary career',
#  '[CLS] small orange diamond bitcoin has closed over 60000 for 33 days in a row [SEP] consolidation then [SEP] rocket',
#  '[CLS] ohh i gots to have these smiling face with heart eyes smiling face with heart eyes smiling face with heart eyes two hearts',
#  '[CLS] we wear our solar glasses in space [SEP] smiling face with sunglasses while millions of people on earth watch the total solar eclipse on april 8 astronauts aboard the space station will watch from 250 miles above [SEP] theyll have three opportunities to view the ground shadow as they orbit earth',
#  '[CLS] x will soon let you save the trends from the explore tab',
#  '[CLS] very cool',
#  '[CLS] country garden china property giant suspends shares in hong kong',
#  '[CLS] reconhecem o dreamland museu em gramado rio grande do sul inaugurou uma estatua de cera de katy perry [SEP]',
#  '[CLS] just in united states us government sends over 30170 bitcoin worth 2 billion to coinbase using silk road hack funds arkham data shows eyes',
#  '[CLS] struggling to level with vips nows your chance to trade like a vip9 on usdc margined contracts enjoy zero maker fee and only 0017 taker fee for all users read more right arrow',
#  '[CLS]  [SEP]password on now nbc and peacock',
#  '[CLS] bet on the future [SEP] bitcoin',
#  '[CLS] all elite [SEP]',
#  '[CLS] him refusing to speak on the meaning behind boys girls loudly crying face loudly crying face',
#  '[CLS] novo vdeo de katy perry e jared leto durante o iheartradioawards que aconteceu na ltima segunda feira [SEP]',
#  '[CLS] global citizen festival to return to central park in 2024',
#  '[CLS] coneheads its time for u to find out which found heaven song u are',
#  '[CLS] the houston texans are making the moves the dallas cowboys should have if they were really all in [SEP]',
#  '[CLS] person in texas diagnosed with rare bird flu after contact with cattle',
#  '[CLS] im a freak i need it',
#  '[CLS] shut down that hospital please',
#  '[CLS] how michael rubin and his posh parties unite the sports and music worlds',
#  '[CLS] i know dumb ass richy jackson choreo when i see it',
#  '[CLS] whered you go go alley rose idk conan just text the gc',
#  "[CLS] police car light attention katycats and all our friends the industry has always been cruel to katy perry we need to bring this to everyone's attention reply to my tweet withjusticeforkatyperry goal 100 replies",
#  '[CLS] endeavor going private in deal with majority shareholder silver lake',
#  '[CLS] chile woman steals gun from guard and opens fire',
#  '[CLS] nicki concert was literally everything face holding back tears',
#  '[CLS] ive been hearing people ask at what point in a potential downfall should they leave the us [SEP] now i hear the same from canadians and europeans [SEP] the issues with all of this is where will you go we all need to fight to keep our countries in order or there will be nowhere to run [SEP]',
#  '[CLS] hundred points',
#  '[CLS]  [SEP] notches second hot rock alternative songs no [SEP] 1 with too sweet',
#  '[CLS] cigar night qa tonight at 8pm universal tate time [SEP]',
#  '[CLS] stefano cherchi jockey dies two weeks after fall at canberra races',
#  '[CLS] hunter schafer opens up about dating rosala in 2019 shes family no matter what',
#  '[CLS] its everybody tonight with they pink on for mother crying face pink heart heart hands medium skin tone gagcitydc',
#  '[CLS] elon a la benjamin franklin in a tesla my midjourney prompt was benjamin franklin driving a tesla grinning squinting face sparkles',
#  '[CLS] magic wand',
#  "[CLS] why there's a revolution on the way in glass making",
#  '[CLS] firebloodchallenge it taste like orange juice tangerine',
#  '[CLS] g',
#  '[CLS] made in america festival canceled for second consecutive year',
#  '[CLS] its us vol [SEP] 1 4524',
#  "[CLS] world central kitchen founder jos andrs criticises israel over aid workers' deaths",
#  '[CLS] hot 100 first timers allison russell debuts with hozier team up wildflower and barley',
#  '[CLS] the list goes on and on and on',
#  "[CLS] ye and ty dolla ign's vultures listening parties won't go ahead [SEP]",
#  '[CLS] coinbase is now officially integrating the bitcoin lightning network clapping hands coinbase has over 100 million users rocket',
#  '[CLS] grok 1 vs grok 15',
#  '[CLS] big breaking police car light ethereum etf approval police car light sec asks for public comment for grayscale bitwise and fidelity spot ethereum etfs',
#  '[CLS] glorilla recalls the beautiful feeling of visiting the white house i still havent accepted the reality of it',
#  "[CLS] following their first playoff appearance in decades the marlins tried to demote gm kim ng [SEP] she turned that down and left the organization [SEP] the marlins are behind early today and if they lose to the angels they'll be 0 7 to start this season [SEP]",
#  '[CLS] the meaning behinf miss you is so deep fuck',
#  '[CLS] ukraine war deepest ukraine drone attack into russian territory injures 12',
#  '[CLS] harleys in hawaii 500m barreira bloody mary 443m',
#  '[CLS] damn nigga you bought this from god',
#  '[CLS] lizzo clarifies what she meant with i quit statement im going to keep being me',
#  "[CLS] andrew tate's coldest moment in fighting",
#  '[CLS] john summit dom dolla kaskade more to headline desert nights coachella parties',
#  '[CLS] dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote dollar banknote 1000000000 usdt 1000027499 usd minted at tether treasury',
#  '[CLS]  [SEP] marvin winans able tops gospel airplay chart',
#  "[CLS] seeing sht like this back to back at every show puts into perspective who it is nicki minaj is in real life so going back forth with fls on here trying to prove a point is so useless [SEP] nothing negative on here should even phase y'all let them live in their delusion [SEP]",
#  '[CLS] beyonc thanks jack white for inspiring cowboy carter',
#  '[CLS] google to delete records from incognito tracking',
#  '[CLS] we are not slowing down high speed train soccer ball soccer ball soccer ball',
#  '[CLS] we blinked',
#  '[CLS] lady gagas harley quinn speaks listen to the first taste of singers character in joker folie deux',
#  '[CLS] uk surfer laura crane in class of her own at big wave spot nazare',
#  '[CLS] but you did a good job of really fuckin up my day',
#  '[CLS] congrats',
#  '[CLS] julia garner is playing a female silver surfer in fantasticfour',
#  '[CLS] big breaking police car light coinbase goes big on bitcoin coinbase partners with lightspark to integrate bitcoin lightning network [SEP]',
#  '[CLS] i hate pending transactions [SEP] please just take the money [SEP]',
#  '[CLS] pensando en que ya me aprend todas las canciones de las mujeres ya no lloran y ahora tendr que esperar mnimo 7 aos para que shakira saque nuevo lbum [SEP] sad but relieved face',
#  '[CLS] 10010 amazing show smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts smiling face with hearts gagcitybaltimore',
#  '[CLS] top 8 most profitable crypto narratives in 2024 1 [SEP] memecoin 1313 2 [SEP] rwa 286 3 [SEP] ai 222 4 [SEP] defi 99 5 [SEP] depin 81 6 [SEP] layer 1 70 7 [SEP] gaming 64 8 [SEP] layer 2 39',
#  '[CLS] if i was famous id make a fanpage for myself and post rares that literally no one has ever seen because i took them and everyone would be like how does this person always have rare pics crying face bc i am her duh',
#  '[CLS] i cant say nothing every body gets offended over every little thing',
#  '[CLS] i wish gaga would stop bringing her hair makeup friends with her for her movie projects too so we could seehow do i put this nicely',
#  '[CLS] fake nationalist zionist agents not a word from these fake nationalists about the 3 former british military members killed by israel [SEP] israel first',
#  '[CLS] super valid point [SEP]',
#  "[CLS] every dip is just the universe's way of asking do you have the courage to double down on your dreams",
#  '[CLS] raymonte is not wrong [SEP]',
#  '[CLS] nova esttua de cera de katy perry inaugurada no dreamland museu em gramado rio grande do sul [SEP]',
#  '[CLS] i am currently 18h 53m 16s of light travel time from earth 2024 095 000000 1l',
#  '[CLS] conan gray disse no talk shop live que sua msica favorita das que ainda no foram lanadas do found heaven fainted love mas que sua favorita do lbum todo alley rose',
#  '[CLS] no offense bardi its cus i have a dominican parent a black one loudly crying face black heart',
#  '[CLS] what is your most anticipated performance of 2024',
#  '[CLS] race vs ethnicity vs nationality be beating my community ass [SEP]',
#  "[CLS] it's cute when kids say what they want to be when they grow up [SEP] you're gonna write emails on the computer buddy",
#  "[CLS] katyperry's harleys in hawaii has surpassed 500 million streams on spotify [SEP] its her 15th song to reach this milestone flexed biceps motorcycle sun collision keycap 5 keycap 0 keycap 0 circled m multiply keycap 1 keycap 5 musical notes fire crown pink heart",
#  '[CLS] fun fact all of lady gagas lead roles are for films rated r',
#  '[CLS] police car light tenemos nueva colaboracin en camino y es ya inminente',
#  '[CLS] pouria zeraati three accused of tv presenter attack have left uk',
#  '[CLS] starship will be on mars within the decade and i cant wait to help build the booster thatll send it on its way face with steam from nose fire rocket',
#  '[CLS] katy perrys lead single between april and may [SEP] the music video is ready [SEP] xx',
#  '[CLS] joker 2 soundtrack album under gagas label omgg',
#  "[CLS] it's a stormy day at the spaceport what's the weather like for you right arrow curving down",
#  '[CLS] its crazy how it all happened when she was 33 just like jesus',
#  '[CLS] the fact that it never charted on the hot 100 is insane',
#  '[CLS] look how cute we are smiling face with heart eyes face holding back tears pink heart',
#  '[CLS] doja cat says she doesnt care about music leaks theres nothing i can do about it',
#  '[CLS] will you buy a tesla with dogecoin',
#  '[CLS] hundred points',
#  '[CLS] names of three british aid workers killed in israeli strike in gaza are john chapman james henderson and james kirby bbc establishes',
#  '[CLS] live now',
#  '[CLS] are we on the timeline or on the dms we were talking in dms and now youre back on the timeline [SEP] you cant gaslight me and i wont let you confuse people by bringing up things that are irrelevant to the initial discussion [SEP] you say people never called me ghetto [SEP] i responded',
#  '[CLS] all of the barbies are bad it girls and we aint playing tag two hearts star struck gagcitybaltimore',
#  '[CLS] big breaking police car light bitcoin to reach 150k by the end of this year per morgan creek capital management ceo mark yusko',
#  '[CLS] how fox sports resident deadheads brought jam bands to big games',
#  '[CLS] boys girls foi a msica que conan levou mais tempo a fazer no lbum found heaven [SEP]',
#  '[CLS] is winning saluting face',
#  '[CLS] crying [SEP] over [SEP] this [SEP] face holding back tears purple heart we love you',
#  '[CLS] katchatheevu tiny sri lankan island sparks political row in india',
#  "[CLS] when gaga did house of gucci she got dragged for having an accent for joker she's getting dragging for not having one",
#  '[CLS] gaga daily wouldve loved today pleading face broken heart',
#  '[CLS] its time for katycats to move justiceforkatyperry',
#  '[CLS] nicki concert 1010',
#  '[CLS] its been 4 years and youre still a brokie',
#  '[CLS] i reiterate my firm call for an immediate ceasefire in the gaza strip [SEP] i express my deep sorrow for the volunteers who were killed while distributing humanitarian aid in gaza [SEP] i pray for them and their families [SEP]',
#  '[CLS] katy perrys teenage dream album cover is actually a painting',
#  '[CLS] coneheads join cone for a live qa on now star black heart',
#  '[CLS] new shakira collaboration on the way [SEP] xx',
#  '[CLS] just in apple exploring the creation of home robots as next big thing [SEP]',
#  '[CLS] estoy en usa y ha estado ms veces en tendencia que esta semana en twitter [SEP] aunque amo a las dos solo escribo para que vean la relevancia de shakira aqu [SEP]',
#  '[CLS] what if i said house of gucci has the best poster',
#  '[CLS] we need katys documentary about what happened from 2017 2018',
#  '[CLS] new look at moana 2 set 3 years after the first movie [SEP] in theaters on november 27 [SEP]',
#  '[CLS] taylor swift competing with travis kelce for a 2024 webby award full nominations announced',
#  '[CLS] two margaritas deep i heard a song playing called you can go your own way and i was like wow they are really singing their ass off [SEP] looked it up its two band members breaking up i am in tears you can go your own way loudly crying face loudly crying face watched the live performance [SEP] he cant even look at her',
#  '[CLS]  [SEP]s las mujeres ya no lloran hit number one on top latin albums and latin pop albums gem stone',
#  '[CLS] sister ship 1 is 22h 32m 47s of light travel time from earth 2024 094 120000 1l',
#  '[CLS] un fan de karol g pero cuntos streams de spotify tiene selena enraged face',
#  '[CLS] justice for katy perry broken heart crying cat',
#  '[CLS] conans gonna be personally at the gates of the arena asking people if they are in a relationship and if they say yeah hell be like good for you get out [SEP]',
#  "[CLS] usa today attended 's gagcitydc and gave their review of her show for her first u [SEP]s [SEP] run in eight years minaj has crafted her most grandiose productionshe is still the queen of rap for a reason [SEP]",
#  '[CLS] nine milestones beyonc could reach at 2025 grammys',
#  '[CLS] israels pm says its forces unintentionally hit innocent people in gaza after strike on aid workers kills seven follow latest updates',
#  '[CLS] the most sold car on planet earth in 2023 was a tesla',
#  "[CLS] thanks to free media this particular chapter of the genocide in palestine is happening in front of everybody's eyes [SEP] piers rogan trump and other big names are now condemning what is happening [SEP] but on day one was telling piers what would happen [SEP] he knew [SEP]",
#  '[CLS] when barbie touch downn zany face pink heart im ready for you babes [SEP]',
#  '[CLS] beyoncs cowboy carter is galloping to no [SEP] 1 in the u [SEP]k [SEP]',
#  '[CLS] breaking news newspaper police car light bitcoin bull run is coming ox the bitcoin halving is now only about 17 days away [SEP] eyes fire',
#  '[CLS] algum disse voc vem ao brasil [SEP] eu espero que sim mas est fora do meu controle infelizmente [SEP] conan gray ao vivo no talk shop live [SEP]',
#  '[CLS] im here gagcitybaltimore',
#  '[CLS] remembered as a hero family pays tribute to james kirby one of three britons killed in israeli strike on gaza aid convoy',
#  '[CLS] the everything app gets closer every single day [SEP] were building new ways for everyone to find community and connect to one another [SEP]',
#  '[CLS] feid announces joint album with yandel heres what we know',
#  '[CLS] which pussy can mek mi run',
#  '[CLS] mi n di gyaldem',
#  '[CLS] some likkle gyal a stalk mi',
#  "[CLS]  [SEP]'s never really over is now certified diamond in brazil [SEP] brazil",
#  '[CLS] define cultural reset',
#  "[CLS] does conan sell the found heaven necklace separately because i don't collect cds i'm a vinyl girlie",
#  '[CLS] first look at mufasa the lion king [SEP] in theaters on december 20',
#  '[CLS] funimation has officially closed',
#  '[CLS] she sounds exactly like the countess i am screaming',
#  '[CLS] am i the only one that didnt notice conan start singing a song from found heaven by accident during the live the sheer panic in his eyes loudly crying face',
#  '[CLS] what does it mean',
#  '[CLS] just in u [SEP]s [SEP] sec calls for comments on spot eth etfs',
#  '[CLS] i dont give a damn how pretty it is [SEP] australia will never see me',
#  '[CLS] united states las mujeres ya no lloran on us billboard 1 [SEP] top latin albums 1 [SEP] top latin pop albums 2 [SEP] top album sales 2 [SEP] top current album sales 4 [SEP] top vinyl albums 13 [SEP] billboard 200 30 [SEP] top streaming albums',
#  '[CLS] new look at moana 2 out november 27th [SEP]',
#  '[CLS] the sleeper hit of the year this song watches those other hits come and go while it stays smashing on the charts loudly crying face',
#  '[CLS] atta baby flag in hole 40 500 winners money bag money bag radio button repost this video radio button reply saying something nice to somebody radio button put the easiest way to pay you in the post as wellpmslive',
#  '[CLS] high heels on my tippies nail polish medium light skin tone heart with ribbon pinkfridaynails',
#  '[CLS] mediquen a shakmiley por favor [SEP] la pobre ya est en las drogas [SEP]',
#  '[CLS] just in united states us government transfers 30174 bitcoin worth 21 billion seized from silk road to coinbase [SEP]',
#  '[CLS] playstation 5 deals the limited edition spider man 2 console bundle is 110 off at amazon',
#  '[CLS] conan still being in a friend group with his ex oh my god',
#  '[CLS] i dont know how shell top this cover',
#  '[CLS] atta baby flag in hole 40 500 winners money bag money bag radio button repost this video radio button reply saying something nice to somebody radio button put the easiest way to pay you in the post as wellpmslive',
#  '[CLS] i dont give a damn how pretty it is [SEP] australia will never see me',
#  '[CLS] united states las mujeres ya no lloran on us billboard 1 [SEP] top latin albums 1 [SEP] top latin pop albums 2 [SEP] top album sales 2 [SEP] top current album sales 4 [SEP] top vinyl albums 13 [SEP] billboard 200 30 [SEP] top streaming albums',
#  '[CLS] new look at moana 2 out november 27th [SEP]',
#  '[CLS] the sleeper hit of the year this song watches those other hits come and go while it stays smashing on the charts loudly crying face',
#  '[CLS] what does it mean',
#  '[CLS] just in u [SEP]s [SEP] sec calls for comments on spot eth etfs',
#  '[CLS] funimation has officially closed',
#  '[CLS] she sounds exactly like the countess i am screaming',
#  '[CLS] am i the only one that didnt notice conan start singing a song from found heaven by accident during the live the sheer panic in his eyes loudly crying face',
#  '[CLS] first look at mufasa the lion king [SEP] in theaters on december 20',
#  '[CLS] define cultural reset',
#  "[CLS] does conan sell the found heaven necklace separately because i don't collect cds i'm a vinyl girlie",
#  '[CLS] some likkle gyal a stalk mi',
#  "[CLS]  [SEP]'s never really over is now certified diamond in brazil [SEP] brazil",
#  '[CLS] the everything app gets closer every single day [SEP] were building new ways for everyone to find community and connect to one another [SEP]',
#  '[CLS] feid announces joint album with yandel heres what we know',
#  '[CLS] which pussy can mek mi run',
#  '[CLS] mi n di gyaldem',
#  '[CLS] im here gagcitybaltimore',
#  '[CLS] remembered as a hero family pays tribute to james kirby one of three britons killed in israeli strike on gaza aid convoy',
#  '[CLS] breaking news newspaper police car light bitcoin bull run is coming ox the bitcoin halving is now only about 17 days away [SEP] eyes fire',
#  '[CLS] algum disse voc vem ao brasil [SEP] eu espero que sim mas est fora do meu controle infelizmente [SEP] conan gray ao vivo no talk shop live [SEP]',
#  '[CLS] when barbie touch downn zany face pink heart im ready for you babes [SEP]',
#  '[CLS] beyoncs cowboy carter is galloping to no [SEP] 1 in the u [SEP]k [SEP]',
#  '[CLS] the most sold car on planet earth in 2023 was a tesla',
#  "[CLS] thanks to free media this particular chapter of the genocide in palestine is happening in front of everybody's eyes [SEP] piers rogan trump and other big names are now condemning what is happening [SEP] but on day one was telling piers what would happen [SEP] he knew [SEP]",
#  "[CLS] usa today attended 's gagcitydc and gave their review of her show for her first u [SEP]s [SEP] run in eight years minaj has crafted her most grandiose productionshe is still the queen of rap for a reason [SEP]",
#  '[CLS] nine milestones beyonc could reach at 2025 grammys',
#  '[CLS] israels pm says its forces unintentionally hit innocent people in gaza after strike on aid workers kills seven follow latest updates',
#  '[CLS] justice for katy perry broken heart crying cat',
#  '[CLS] conans gonna be personally at the gates of the arena asking people if they are in a relationship and if they say yeah hell be like good for you get out [SEP]',
#  '[CLS] un fan de karol g pero cuntos streams de spotify tiene selena enraged face',
#  '[CLS] taylor swift competing with travis kelce for a 2024 webby award full nominations announced',
#  '[CLS] two margaritas deep i heard a song playing called you can go your own way and i was like wow they are really singing their ass off [SEP] looked it up its two band members breaking up i am in tears you can go your own way loudly crying face loudly crying face watched the live performance [SEP] he cant even look at her',
#  '[CLS]  [SEP]s las mujeres ya no lloran hit number one on top latin albums and latin pop albums gem stone',
#  '[CLS] sister ship 1 is 22h 32m 47s of light travel time from earth 2024 094 120000 1l',
#  '[CLS] new look at moana 2 set 3 years after the first movie [SEP] in theaters on november 27 [SEP]',
#  '[CLS] just in apple exploring the creation of home robots as next big thing [SEP]',
#  '[CLS] estoy en usa y ha estado ms veces en tendencia que esta semana en twitter [SEP] aunque amo a las dos solo escribo para que vean la relevancia de shakira aqu [SEP]',
#  '[CLS] what if i said house of gucci has the best poster',
#  '[CLS] we need katys documentary about what happened from 2017 2018',
#  '[CLS] katy perrys teenage dream album cover is actually a painting',
#  '[CLS] coneheads join cone for a live qa on now star black heart',
#  '[CLS] new shakira collaboration on the way [SEP] xx',
#  '[CLS] nicki concert 1010',
#  '[CLS] its been 4 years and youre still a brokie',
#  '[CLS] i reiterate my firm call for an immediate ceasefire in the gaza strip [SEP] i express my deep sorrow for the volunteers who were killed while distributing humanitarian aid in gaza [SEP] i pray for them and their families [SEP]',
#  '[CLS] its time for katycats to move justiceforkatyperry',
#  '[CLS] katchatheevu tiny sri lankan island sparks political row in india',
#  "[CLS] when gaga did house of gucci she got dragged for having an accent for joker she's getting dragging for not having one",
#  '[CLS] gaga daily wouldve loved today pleading face broken heart',
#  '[CLS] crying [SEP] over [SEP] this [SEP] face holding back tears purple heart we love you',
#  '[CLS] big breaking police car light bitcoin to reach 150k by the end of this year per morgan creek capital management ceo mark yusko',
#  '[CLS] how fox sports resident deadheads brought jam bands to big games',
#  '[CLS] boys girls foi a msica que conan levou mais tempo a fazer no lbum found heaven [SEP]',
#  '[CLS] is winning saluting face',
#  '[CLS] katchatheevu tiny sri lankan island sparks political row in india',
#  "[CLS] when gaga did house of gucci she got dragged for having an accent for joker she's getting dragging for not having one",
#  '[CLS] gaga daily wouldve loved today pleading face broken heart',
#  '[CLS] its time for katycats to move justiceforkatyperry',
#  '[CLS] nicki concert 1010',
#  '[CLS] its been 4 years and youre still a brokie',
#  '[CLS] i reiterate my firm call for an immediate ceasefire in the gaza strip [SEP] i express my deep sorrow for the volunteers who were killed while distributing humanitarian aid in gaza [SEP] i pray for them and their families [SEP]',
#  '[CLS] katy perrys teenage dream album cover is actually a painting',
#  '[CLS] coneheads join cone for a live qa on now star black heart',
#  '[CLS] new shakira collaboration on the way [SEP] xx',
#  '[CLS] just in apple exploring the creation of home robots as next big thing [SEP]',
#  '[CLS] estoy en usa y ha estado ms veces en tendencia que esta semana en twitter [SEP] aunque amo a las dos solo escribo para que vean la relevancia de shakira aqu [SEP]',
#  '[CLS] what if i said house of gucci has the best poster',
#  '[CLS] we need katys documentary about what happened from 2017 2018',
#  '[CLS] new look at moana 2 set 3 years after the first movie [SEP] in theaters on november 27 [SEP]',
#  '[CLS] taylor swift competing with travis kelce for a 2024 webby award full nominations announced',
#  '[CLS] two margaritas deep i heard a song playing called you can go your own way and i was like wow they are really singing their ass off [SEP] looked it up its two band members breaking up i am in tears you can go your own way loudly crying face loudly crying face watched the live performance [SEP] he cant even look at her',
#  '[CLS]  [SEP]s las mujeres ya no lloran hit number one on top latin albums and latin pop albums gem stone',
#  '[CLS] sister ship 1 is 22h 32m 47s of light travel time from earth 2024 094 120000 1l',
#  '[CLS] un fan de karol g pero cuntos streams de spotify tiene selena enraged face',
#  '[CLS] justice for katy perry broken heart crying cat',
#  '[CLS] conans gonna be personally at the gates of the arena asking people if they are in a relationship and if they say yeah hell be like good for you get out [SEP]',
# ...
#  '[CLS] full nudityy and it better be from ga',
#  '[CLS]  [SEP] on new whiskey jypsi release upcoming nashville residency it was important to us that we could be creative',
#  '[CLS] google to delete records from incognito tracking',
#  '[CLS] joker joker 2',
#  '[CLS] venice launches new career assistant tool for artists',
#  '[CLS] this was soo',
#  '[CLS] the 10 member space station crew worked on cargo spacesuits and human research on tuesday as weekend crew departure preps continue [SEP]',
#  "[CLS] the polaris dawn dragon is headed to vacuum chamber testing spacex teams celebrate dragon's departure with and ahead of launching to orbit this summer",
#  '[CLS] the cast of real housewives of potomac are in gag city tonightrhopgagcitydc',
#  '[CLS] kristen wiigs old snl dressing room gets completely taken over in new promo',
#  '[CLS] soca superstar breaks down five favorite tracks from first album in 10 years its time to position ourselves in a global way',
#  '[CLS] bassirou diomaye faye senegal election offers hope to frustrated young africans',
#  '[CLS] there was plenty of drama when ziggy and mackenzie sol entered a sing off on americanidol [SEP]',
#  '[CLS] pink heart folded hands medium skin tone',
#  '[CLS] louis conter last survivor of attack on pearl harbor ship dies aged 102',
#  '[CLS] lizard eliminated after sink or swim experience on the masked singer im not used to losing',
#  '[CLS] at least 29 people now confirmed to have died in fire at istanbul nightclub undergoing renovations',
#  '[CLS] 20 best travel deals to help you get away on a budget',
#  '[CLS] qgtm history in the fng making [SEP] thank you a million times over [SEP] trophy gagcitydc shall go in the gagcity history books [SEP]',
#  '[CLS] michelle obama praises beyoncs cowboy carter while encouraging fans to register to vote we all have power',
#  '[CLS] k pop star karina and actor lee jae wook split shortly after going public',
#  '[CLS] act fast the ipad pro ipad air ipad mini are on sale at amazon save up to 100 off',
#  '[CLS] spotify a pesar del supuesto backlash las mujeres ya no lloran increment sus streams diarios ayer whenever wherever tuvo su mejor da en lo que va del 2024 479768 streams y la tortura recibi ms de 400 mil streams por primera vez 408059',
#  '[CLS] i love this other katy perry accounts [SEP] but i need to make this clear there was no press event was a private preview for some industry people and i wasnt there [SEP] all very positive reactions to batch of songs they heard [SEP] album not 100 percent finished but katy is coming soon',
#  '[CLS] ye has been sued by another former donda academy staffer alleging a sexually abusive environment [SEP] billboardnews',
#  '[CLS] breaking the bills are trading wr stefon diggs to the texans per  [SEP]',
#  '[CLS] adele reschedules 2024 weekends las vegas residency shows postponed by illness',
#  '[CLS] just a few sec of this scene added in the teaser trailer could make me faint',
#  '[CLS] crawler transporter 2 update as we prepare for future missions right arrow curving down',
#  "[CLS] james kirby cousins pay tribute to 'selfless hero'",
#  '[CLS] magic johnson posts heartfelt celebration of living icon beyoncs cowboy carter',
#  '[CLS] jon batiste hopes his work on beyoncs cowboy carter helps dismantle the genre machine',
#  '[CLS] the first amendment [SEP] congress shall make no law respecting an establishment of religion or prohibiting the free exercise thereof or abridging the freedom of speech or of the press or the right of the people peaceably to assemble and to petition the government for a redress',
#  '[CLS] bless ft wvw pre save link',
#  '[CLS] where it all began star',
#  '[CLS] first poster for joker 2 starring joaquin phoenix and lady gaga [SEP]',
#  '[CLS] billie piper says classmate amy winehouse was bullied in school',
#  '[CLS] slipknot avenged sevenfold disturbed to headline 2024 rocklahoma festival',
#  '[CLS] cash cobain speaks out on nyc concert canceled for reasons out of my control',
#  '[CLS] karol g in latin america all the guests on her maana ser bonito tour',
#  '[CLS] bizarrap natanael cano drop explosive two song collaboration bzrp music session 59 stream it here',
#  '[CLS] shakira has surpasses billie eilish to become the 21 1 artist with the most monthly listeners on spotify and 8 female artist [SEP] globe showing americas',
#  "[CLS] two investors plead guilty in insider trading scheme linked to the trump media deal that brought the former president's social media business public",
#  '[CLS] strongest earthquake in 25 years rocks taiwan with tsunami warnings issued for nearby countries',
#  '[CLS] craig gillespie is in talks to direct supergirl [SEP] he has previously directed cruella and i tonya source deadline',
#  '[CLS] do not trust men who are easily afraid [SEP] loyalty requires bravery [SEP] anyone whos easily scared will easily turn [SEP] without balls your sentiment as a man means absolutely zero [SEP] as soon as a weak man has to suffer for the person they are loyal to loyalty disappears [SEP]',
#  '[CLS] kai media company behind k pop label hello82 raises more funding for expansion',
#  '[CLS] finland shooting several injured in vantaa school shooting police',
#  "[CLS] ken griffin says u [SEP]s [SEP] is being 'irresponsible' with national debt and politicians are spending 'at the expense of future generations per fortune [SEP]",
#  '[CLS] we are on [SEP] pink heart party popper party popper party popper party popper birthday cake balloon confetti ball gagcity ticket give away ticket admission tickets may the best barbz win [SEP] trophy',
#  "[CLS] just in china taiwan 30 chinese warplanes and 9 navy vessels have positioned around taiwan according to taiwan's defense ministry [SEP] thinking face",
#  '[CLS] donald trump getting booed in mi today brings joy to my heart [SEP]',
#  '[CLS] fed chairman powell finally told the truth [SEP] last week he finally admitted inflation is winning [SEP] the fed can no longer promise i flation at 2 or that inflation is transitory [SEP] again he finally stopped lying [SEP] congratulations [SEP] the problem is most people have no idea what the',
#  '[CLS] just in hedge fund billionaire steve cohen told cnbc he owns a very little amount of bitcoin eyes',
#  '[CLS] fellas is it antismitic to think that aid workers shouldnt be airstriked',
#  '[CLS] current joker folie deux box office predictions [SEP] with a predicted worldwide box office of just under 800m the film would currently be the 3rd highest grossing r rated movie of all time behind oppenheimer and the original joker [SEP]',
#  '[CLS] there is no future without kids',
#  "[CLS] there have been a few recent articles in the press about 'winning' its proxy contest with nelson peltz based on early election returns that have been leaked to the media [SEP] we don't have an investment in disney but i thought it useful to point out the inappropriateness of",
#  "[CLS] aileen cannon should have been removed from the case a long time ago with her bullshit rulings blatantly causing delays that favor defendant trump [SEP] it's a fucking joke [SEP]",
#  '[CLS] wanna be face with hand over mouth heart on fire 0405',
#  "[CLS] in the movie 'the matrix' neo's passport has an expiration date set to 9112001",
#  "[CLS]  [SEP]'s harleys in hawaii has now surpassed 500 million streams on spotify [SEP]",
#  '[CLS] her mind [SEP] shes sick [SEP]',
#  '[CLS] x premium costs just 23 cents a day when bought annually via web [SEP] united states subscribe to x premium to support this platform [SEP]',
#  '[CLS] is there anything more overrated than a solar eclipse face with tears of joy',
#  "[CLS] loral o'hara one of five currently on the station is returning to earth on april 6 [SEP] she conducted one spacewalk and researched advanced space phenomena during her six and a half month mission [SEP] more [SEP]",
#  "[CLS] it's been 6 years since we became a public company [SEP] its pretty wild to think that by most metrics spotify is now 3x or more on where we were that day [SEP] i am reminded of bill gates quote most people overestimate what they can do in one year and underestimate what they can do",
#  '[CLS] 2  [SEP] 1 of 8 bands in the 2200 to 7300 spectral region then on to a photomultipler tube [SEP] by study of these emission intensity data information on surface texture composition of planets could be obtained along w information [SEP]',
#  '[CLS] joker 2 poster has been seen 14 million times in just 10 hours on one twitter account comparing it to other major releases first poster posts these numbers are incredible [SEP]',
#  '[CLS] police car light police car light police car light police car light police car light police car light police car light police car light police car light police car light 370000000 usdt 370047175 usd transferred from tether treasury to bitfinex',
#  "[CLS] ftc responds to esrb's proposal for an ai powered face scanning 'age estimation' system no",
#  "[CLS] why hasn't judge cannon ruled on the doj reconsideration motion to block the release of witness lists i'm guessing she knows if she releases them smith will go to the 11th circuit [SEP] so she's sitting on it [SEP]",
#  '[CLS] police car light breaking police car light sec asks for public comment for grayscale bitwise and fidelity spot ethereum etfs [SEP] giga bullish fire',
#  '[CLS] this is evil',
#  "[CLS] what's going on here",
#  '[CLS] update on samplingmars i recently collected my 24th sample from an area called bunsen peak named for the landmark [SEP] the rock core is filled with silica and carbonate [SEP]',
#  '[CLS] knowledge is power [SEP] bitcoin',
#  '[CLS] truly mothers daughter',
#  '[CLS] did you know that legacy media have notifications on for',
#  '[CLS] hunter schafer euphoria star says she no longer wants to play trans characters',
#  '[CLS] perfection [SEP]',
#  '[CLS] wonder where she is now loudly crying face',
#  '[CLS] dms are still up running just saying',
#  '[CLS] big breaking police car light coinbase ceo says its bitcoin lightning network integration should be launching soon [SEP] eyes fire',
#  '[CLS] joker folie deux official website [SEP] link',
#  '[CLS] dolce doll pink heart',
#  '[CLS] gagcitybaltimore',
#  '[CLS] katy perry exalando beleza durante as gravaes do american idol no hawaii [SEP]',
#  '[CLS] olivia via instagram stories',
#  "[CLS] katy perry esquecida  [SEP]'s harleys in hawaii has now surpassed 500 million streams on spotify [SEP] 's never really over is now certified diamond in brazil [SEP] gente que fracassada 2 msicas solo do ltimo lbum sendo diamante e 500m de streams do spotify",
#  '[CLS] katy perry x american idol brown heart sparkles',
#  '[CLS] joker 2 trailer is really coming to break the internet [SEP] were talking hundreds of millions of views across all platforms [SEP] a global event [SEP]',
#  '[CLS] shakira is set to appear on hot ones tomorrow april 4 heart on fire',
#  '[CLS] started stan twitter started the concept of eras started the whole mother and fanbase relationship like im so serious',
#  "[CLS] lavar ball blames the nba training staffs and puma's 'raggedy' shoes for his sons' injuries the reason they hurt is because they got away from me [SEP] and they start doing these rooty toot workouts [SEP] because if you keep running them hills you're going to keep that power and that",
#  '[CLS] former observer huffpost journalist claims katy perrys career decline was planned by some people similar to how christina aguileras career was sabotaged [SEP] they then alleged writers trashed katy to generate clicks more money [SEP] last year former pitchfork writers alleged',
#  '[CLS] lady gaga photographed by steven klein [SEP]',
#  '[CLS] breaking the sec requested public comment on major ethereum spot etfs',
#  '[CLS] btc bitcoin is holding that weekly range low 65600 as support for nowbtc crypto bitcoin',
#  '[CLS] what other payment options do you think should be added to the tip jar',
#  '[CLS] doge',
#  '[CLS] harry potter said what loudly crying face',
#  '[CLS] im glad gaga is keeping her og voice nobody wants to hear that squeaky ass over exaggerated voice',
#  '[CLS] were 5 days away from the eclipse check out my eclipse guide linked in bio for some tips on how to see it [SEP] remember the difference between 99 100 is one that will literally change your life [SEP] the eclipse i saw in 2017 ignited a passion to pursue astrophotography [SEP]',
#  "[CLS] fans from selected countries can now watch shakira's videos on spotify go and stream",
#  "[CLS] why are cities dominated by highways and cars it's partly because of one of the most influential people you've never heard of norman bel geddes [SEP] in 1939 he created futurama a huge exhibition that tried to predict the future and ended up changing the world [SEP]",
#  '[CLS] breaking coinbase is working with lightspark to integrate the bitcoin lightning network for all its customers high voltage',
#  '[CLS] from these 4 accounts alone nearly 31 million views in 24 hours [SEP]',
#  '[CLS] finally restocked lady gaga the fame monster picture disc [SEP] will be included in our friday drop as well',
#  "[CLS] rumor aparentemente houve uma listening sessions de algumas msicas do kp6 e um jornalista que estava presente comentou sobre o novo lbum de katy perry [SEP] katy est prestes a realizar o maior retorno musical desde mariah carey com 'the emancipation of mimi' [SEP] seu novo lbum",
#  '[CLS] breaking the guy that rammed his car into the fbi field office in atlanta the other day has social media accounts associated with q anon anti vaxx stuff election denialism sidney powell and donald trump [SEP] super shocked source',
#  '[CLS] a warner bros [SEP] divulgou todas as fotos de joker folie deux que sairam sem cortes [SEP] joker2 clapper board joker',
#  "[CLS] spotify top songs 0402 streams hips don't lie 1138286 tqg 1038174 puntera 961461 entre parntesis 846840 cohete 603393 bzrp music sessions vol [SEP] 53 570837 whenever wherever 479768 chantaje 422502 la tortura 408059 dia de enero 403425",
#  '[CLS] mxico puerto rico repblica dominicana costa rica panam el lugar podra dejarlos por fuera colombia brasil ecuador per bolivia chile argentina paraguay uruguay gem stone gem stone gem stone gem stone gem stone gem stone',
#  "[CLS] what if i tell you that there's more adult content on threadz instagram than on onlyfans [SEP] eyes",
#  '[CLS] keityn feid carlos vives and yng lvcas talk major wins at 2024 latin ascap awards',
#  '[CLS] ferrari sf90 palm tree',
#  '[CLS] anya taylor joy confirms she secretly got married to malcolm mcrae in 2022',
#  '[CLS] thank you baby kiss mark',
#  '[CLS] tonights tank top says w star men at gutsworldtourboston',
#  '[CLS] up green circle facebook down red circle instagram down red circle whatsapp down red circle',
#  '[CLS] we all remember where we were',
#  '[CLS] just in united states blackrock and fidelity now own a combined 399741 btc worth 262 billion for their spot bitcoin etfs [SEP]',
#  '[CLS] united states shakira is the female artist with the most songs currently on the us itunes top 100 latin songs totaling 8 songs [SEP]',
#  "[CLS] shakira's amazing 12th studio album 'las mujeres ya no lloran' scores the 3rd highest new entry on the united world album chart landing at 6 flexed biceps 3rd place medal top arrow new button collision keycap 6 globe showing americas chart increasing crown heart on fire 'las mujeres ya no lloran' featuring cardib rauwalejandro manuelturizo grupofrontera ozuna karolg",
#  '[CLS] news tesla overtook mercedes as the second largest seller of imported vehicles in korea last month [SEP] it marked the first time for tesla to beat mercedes benz in korea in terms of sales [SEP]',
#  '[CLS] the ultimate guide to festivals celebrating latin music in 2024',
#  '[CLS] lady gaga is a fucking movie star',
#  '[CLS] te har salir volando como un cohete rocket collision ill make you fly like a rocket lmynl',
#  '[CLS] hawl awn is that',
#  '[CLS] youre invited see you in rogueport on may 23 in papermariothethousandyeardoor coming to nintendoswitch',
#  '[CLS] alien mothers']

# %% [markdown]
# ## Tokenization and Input Formatting

# %%
# Load pre-trained model tokenizer (vocabulary)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize all the processed results
tokenized_results = [tokenizer.tokenize(sentence) for sentence in processed_results]
tokenized_results

# Convert tokens to their respective IDs in the BERT vocabulary
indexed_tokens_list = [tokenizer.convert_tokens_to_ids(tokens) for tokens in tokenized_results]
indexed_tokens_list

# %% [markdown]
# Tokenize the preprocessed text and convert the tokens into indices that correspond to BERT's vocabulary.

# %% [markdown]
# ## Prepare Model Inputs

# %% [markdown]
# ### Create Segment IDs and Attention Masks

# %%
# Initialize lists for segment IDs and attention masks
token_type_list = []
attention_mask_list = []

# Generate segment IDs and attention masks for each sentence
for indexed_sentence in indexed_tokens_list:
    # For each sentence, all tokens belong to the same segment, so use 0
    segment_ids = [0] * len(indexed_sentence)
    token_type_list.append(segment_ids)
    
    # If you're not padding, all tokens are real, so the attention mask is all 1s
    attention_mask = [1] * len(indexed_sentence)
    attention_mask_list.append(attention_mask)

# %% [markdown]
# Segment IDs indicate to the model different segments of the input, while attention masks allow the model to ignore padding during processing.

# %% [markdown]
# ### Add Padding

# %%
# Initialize padded lists
padded_input_ids = []
padded_attention_mask = []

# Find the maximum sequence length in your batch
max_length = max(len(tokens) for tokens in indexed_tokens_list)

for tokens in indexed_tokens_list:
    # Calculate the number of padding tokens needed
    num_padding_tokens = max_length - len(tokens)
    
    # Pad the input IDs with zeros (assuming 0 is your padding token)
    padded_tokens = tokens + [0] * num_padding_tokens
    padded_input_ids.append(padded_tokens)
    
    # Pad the attention mask where actual tokens are marked with 1 and padding tokens with 0
    padded_mask = [1] * len(tokens) + [0] * num_padding_tokens
    padded_attention_mask.append(padded_mask)

# %% [markdown]
# Uniform input length is crucial for batch processing in neural networks. This step pads shorter sequences with zeros.

# %% [markdown]
# ### Extract Contextual Embeddings

# %% [markdown]
# This section describes loading the pre-trained BERT model, converting data into tensors, and running the model to extract contextual embeddings.

# %%
# Load the BERT model
model = BertModel.from_pretrained('bert-base-uncased', output_hidden_states=True)
model.eval()  # Set the model to evaluation mode

# Convert the lists of integers into tensors
input_ids_tensor = torch.tensor(padded_input_ids)
attention_mask_tensor = torch.tensor(padded_attention_mask)

# Run the model and get the outputs
with torch.no_grad():
    outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
    hidden_states = outputs[2]  # Hidden states from all BERT layers
    word_embeddings = outputs.last_hidden_state  # The last layer's output
word_embeddings

# %%
# write the embeddings to a file
import numpy as np
np.save('word_embeddings.npy', word_embeddings)

# %%
# read the embeddings from a file
word_embeddings = np.load('word_embeddings.npy')
word_embeddings
