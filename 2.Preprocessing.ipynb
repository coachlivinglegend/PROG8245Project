# %% [markdown]
# ### Read Data

# %%
# !pip install langdetect

# %%
import pandas as pd
from langdetect import detect, LangDetectException

# %%
## language detection
#def detect_lang(text):
#    try:
#        return detect(text)
#    except LangDetectException:
#        return None
#
#df_texts_orig = pd.read_csv('data/labeled_texts_1000.csv', encoding='utf-8-sig')
#df_texts_orig.dropna(inplace=True)
#
## detect language and add a new column
#df_texts_orig['lang'] = df_texts_orig['Content'].apply(detect_lang)
#
## select only English texts
#df_eng = df_texts_orig[df_texts_orig['lang'] == 'en'].reset_index(drop=True)
#
#df_eng.to_csv('data/labeled_texts_eng.csv', index=False)

# %% [markdown]
# ### Load Data

# %%
df_eng_loaded = pd.read_csv('data/labeled_texts_eng.csv')

df_labels = df_eng_loaded['label']
df_labels.to_pickle('data/labels.pkl')

df_texts = df_eng_loaded['Content']

texts = [text for text in df_texts]
print(texts)
len(texts)
# Out:
# ['The #Binance towel comes everywhere with me...\r\n\r\nIncluding breakfast 🍳', 'Drop your $SOL address below and\r\nmake sure you are following me\r\n\r\nDon’t ask why 👇🏼', 'It only takes one good altcoin to change the world. ✨', 'disrespectful is one of my top 3 fav', 'Some Congressional Republicans call the Affordable Connectivity Program wasteful.\r\n\r\nI call it necessary.\r\n\r\nIt’s time Congress extended it so the 23 million households across America that rely on the program can stay connected.', 'Donald Trump won’t do what an American president must do.\r\n\r\nHe refuses to denounce political violence. \r\n\r\nI’ll say what Trump won’t: Political violence is never, ever acceptable in America.', 'There is a massive #Bitcoin breakout coming.\r\n\r\nAre you ready?', 'Ok so the vote is in. I’ll do a 25 tkt giveaway on station head in 10 mins. \r\n\r\nIf I feel like it I’ll come on spaces & give out another 5-10 after that. \r\n\r\nThe Generous Queen 👸🏽', 'My whole heart', 'I’m tired of people using me as their punching bag… LEAVE ME TF ALONE!! It’s my day off', 'April 03, 2024 @ 09:21 AM (UTC)\r\nCurrent Price of Bitcoin\r\n\r\n(BTC-USD):        $66,484.80\r\n(BTC-EUR):        €61,757.73', 'HOW is Pitbull not in the big 3?????????', "$35 a month insulin for seniors.\r\n$35 inhalers for asthma.\r\n$2,000 a year cap on prescription drugs for seniors starting next year.\r\n\r\nWith Senator Sanders' help, we’re showing how health care should be a right – not a privilege – in America.", 'Cryptoooo', 'The world is a stage. Joker: Folie à Deux trailer coming April 9. 🃏', 'Video shows abducted US girl fatally shot by police', 'https://share.stationhead.com/kgXBpFtPyx8MAY THE BEST BRAVEST BADDEST BARBZ WIN', 'Bitcoin is going to $100,000\r\n\r\nETH is going to $10,000\r\n\r\nAltcoins will pump 10x \r\n\r\nHalving in 15 days. \r\n\r\nYou are not bullish enough.', 'what conan lyric feels like this', 'The more Tether prints, the higher #Bitcoin goes.', 'Which of these artists is the biggest hit-maker ?', '#Bitcoin: Navigating the High Seas of Finance, Steering the Ship of Economic Evolution. ⛵💰🌊', 'album moments🌀I hear you… feeling optimistic about this week https://dualipa.lnk.to/radicaloptimism', "Not in the path of totality for the total solar #eclipse? On April 8, we'll bring totality to you by broadcasting from several locations along its trajectory, including @NASAGlenn—our only center in the eclipse’s path.\r\n\r\nHow to watch: http://go.nasa.gov/3vAvTbo", "It's a tough gig being the Binance intern.\r\n\r\n(gm)", 'There is no bigger red flag in an adult than lack of children. \r\n\r\nIf you’re 46 and not yet bored of weed and alcohol - you’re immature and soulless. \r\n\r\nHow can you be trusted to vote?\r\n\r\nYou have a warped world view with zero vested interest in the future. \r\n\r\nThe poorest people alive…', '1 whole bitcoin hodlers are becoming RARE', 'Dogecoin as Tipping Option? 👀', 'Introducing a new Simple Earn Flexible Products promotion!\r\n\r\nSubscribe to either SUI or USDT Simple Earn Flexible Products to grab your share of 20,000 SUI while also earning bonus APR.\r\n\r\nGet started today ⤵️', '$69,416.50#Bitcoin  #BTC  $BTC $USD', 'Through laws I wrote and signed, I enacted tax credits that save an average of $800 per person per year, reducing health care premiums for millions of families.\r\n\r\nThose credits expire next year.\r\n\r\nCongress, make that $800 expanded affordable health care tax credit permanent.', 'You already made your statement, Donald.', 'Tag a light mode user 👇', 'Coinbase & BlackRock will pump crypto higher!', 'Pitbull, Chingy, and Baby Bash', 'My station head seems to not be working guys. What a shocker', 'If I say I’m 25 then I’m 25 the fuk', 'Psalm 📷 by Saint', 'The next #Bitcoin halving is just 2 weeks out.\r\n\r\nAnd historically, the most gains are always realized after the halving.\r\n\r\nAre you prepared?', 'Moment Taiwan maternity staff rush to keep babies safe during earthquake ...
# 839

# %% [markdown]
# ### Text Preprocessing

# %%
#emoji and emoticons detection package for Python
# !pip install emot

# %%
#emoji package for Python
# !pip install emoji

# %%
#tweet preprocessing package for Python
# !pip install tweet-preprocessor

# %%
#replace keywords in sentences
# !pip install flashtext

# %%
# necessary for BERT tokenizer
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (4.39.2)
# Requirement already satisfied: filelock in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: colorama in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\flag8\work\cscn8010\venv\cscn8010_classic_ml\lib\site-packages (from requests->transformers) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# importing the needed libraries
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import re 
import string
import preprocessor as p
import emoji
from emot.emo_unicode import EMOTICONS_EMO
from flashtext import KeywordProcessor
from transformers import BertTokenizer

# %%
def get_wordnet_tag(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    elif tag.startswith('V'):
        return 'v'
    else:
        return None

# %%
def convert_emoticons(text):
    ## formatting
    all_emoji_emoticons = {**EMOTICONS_EMO}
    all_emoji_emoticons = {k:v.replace(":","").replace("_"," ").strip() for k,v in all_emoji_emoticons.items()}

    kp_all_emoji_emoticons = KeywordProcessor()
    for k,v in all_emoji_emoticons.items():
        kp_all_emoji_emoticons.add_keyword(k, v)
    output = kp_all_emoji_emoticons.replace_keywords(text)

    return output

# %%
def normalize_text(text):
    # handle abbreviations
    normalized_text = re.sub(r'\bfav\b', "favorite", text)
    normalized_text = re.sub(r'\btkt\b', "ticket", normalized_text)
    normalized_text = re.sub(r'\(gm\)', 'good morning', normalized_text)
    
    # remove unnecessary information
    normalized_text = re.sub(r'\([^)]*(via|h/t)[^)]*\)', '', normalized_text)

    # reduce repeated characters
    normalized_text = re.sub(r'([a-zA-Z])\1{2,}', r'\1\1', normalized_text)
    
    return normalized_text

# %%
def clean_characters(text):
    # Replacing special characters with space
    sentence_cleaned = re.sub(r'[-_:]', ' ', text)

    # Removing any character which is not a space, letter or a number
    regular_expression_num_letters = r"[^a-zA-Z0-9 ']"
    sentence_cleaned = re.sub(regular_expression_num_letters, '', sentence_cleaned)

    # Removing any extra spaces
    sentence_cleaned = re.sub(r'\s+', ' ', sentence_cleaned)
    
    return sentence_cleaned

# %%
def clean_tweet(tweet, mode='default'):
    # remove URLs, mentions, reserved words (RT, FAV)
    p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.RESERVED)
    cleaned_tweet = p.clean(tweet)

    # remove emojis
    cleaned_tweet = emoji.demojize(cleaned_tweet)
    
    # convert emoticons to words
    cleaned_tweet = convert_emoticons(cleaned_tweet)

    # handle abbreviations
    normalized_text = normalize_text(cleaned_tweet.lower())

    # BERT Tokenizer
    if mode == 'bert':
        tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        encoded_input = tokenizer.encode(normalized_text, add_special_tokens=True)
        tokens = tokenizer.convert_ids_to_tokens(encoded_input)
        return tokens

    # clean characters
    sentence_cleaned = clean_characters(normalized_text)

    # Tokenize the tweet
    tokens = word_tokenize(sentence_cleaned)
    
    # POS tagging
    pos_tagged = pos_tag(tokens)

    # Remove Stopwords
    stop_words_removed = [word for word in pos_tagged if word[0] not in stopwords.words('english')]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = [word if get_wordnet_tag(tag) is None else lemmatizer.lemmatize(word, get_wordnet_tag(tag)) for word, tag in stop_words_removed]
    
    return lemmatized_sentence

# %%
def get_cleaned_tweets(tweets, mode='default'):
    if mode == 'bert':
        result = []
        for tweet in tweets:
            tokens = clean_tweet(tweet, mode)
            if len(tokens) <= 512:
                result.append(tokens)

        return result

    return [clean_tweet(tweet, mode) for tweet in tweets]

# %%
result = get_cleaned_tweets(texts)
result
# Out:
# [['binance', 'towel', 'come', 'everywhere', 'include', 'breakfast', 'cooking'],
#  ['drop',
#   'sol',
#   'address',
#   'make',
#   'sure',
#   'follow',
#   'dont',
#   'ask',
#   'backhand',
#   'index',
#   'point',
#   'medium',
#   'light',
#   'skin',
#   'tone'],
#  ['take', 'one', 'good', 'altcoin', 'change', 'world', 'sparkle'],
#  ['disrespectful', 'one', 'top', '3', 'favorite'],
#  ['congressional',
#   'republican',
#   'call',
#   'affordable',
#   'connectivity',
#   'program',
#   'wasteful',
#   'call',
#   'necessary',
#   'time',
#   'congress',
#   'extend',
#   '23',
#   'million',
#   'household',
#   'across',
#   'america',
#   'rely',
#   'program',
#   'stay',
#   'connect'],
#  ['donald',
#   'trump',
#   'wont',
#   'american',
#   'president',
#   'must',
#   'refuse',
#   'denounce',
#   'political',
#   'violence',
#   'ill',
#   'say',
#   'trump',
#   'wont',
#   'political',
#   'violence',
#   'never',
#   'ever',
#   'acceptable',
#   'america'],
#  ['massive', 'bitcoin', 'breakout', 'come', 'ready'],
#  ['ok',
#   'vote',
#   'ill',
#   '25',
#   'ticket',
#   'giveaway',
#   'station',
#   'head',
#   '10',
#   'min',
#   'feel',
#   'like',
#   'ill',
#   'come',
#   'space',
#   'give',
#   'another',
#   '5',
#   '10',
#   'generous',
#   'queen',
#   'princess',
#   'medium',
#   'skin',
#   'tone'],
#  ['whole', 'heart'],
#  ['im',
#   'tire',
#   'people',
#   'use',
#   'punching',
#   'bag',
#   'leave',
#   'tf',
#   'alone',
#   'day'],
#  ['april',
#   '03',
#   '2024',
#   '09',
#   '21',
#   'utc',
#   'current',
#   'price',
#   'bitcoin',
#   'btc',
#   'usd',
#   '6648480',
#   'btc',
#   'eur',
#   '6175773'],
#  ['pitbull', 'big', '3'],
#  ['35',
#   'month',
#   'insulin',
#   'senior',
#   '35',
#   'inhaler',
#   'asthma',
#   '2000',
#   'year',
#   'cap',
#   'prescription',
#   'drug',
#   'senior',
#   'start',
#   'next',
#   'year',
#   'senator',
#   'sander',
#   "'",
#   'help',
#   'show',
#   'health',
#   'care',
#   'right',
#   'privilege',
#   'america'],
#  ['cryptoo'],
#  ['world',
#   'stage',
#   'joker',
#   'folie',
#   'deux',
#   'trailer',
#   'come',
#   'april',
#   '9',
#   'joker'],
#  ['video', 'show', 'abduct', 'us', 'girl', 'fatally', 'shoot', 'police'],
#  ['best', 'bravest', 'baddest', 'barbz', 'win'],
#  ['bitcoin',
#   'go',
#   '100000',
#   'eth',
#   'go',
#   '10000',
#   'altcoins',
#   'pump',
#   '10x',
#   'halve',
#   '15',
#   'day',
#   'bullish',
#   'enough'],
#  ['conan', 'lyric', 'feel', 'like'],
#  ['tether', 'print', 'high', 'bitcoin', 'go'],
#  ['artist', 'big', 'hit', 'maker'],
#  ['bitcoin',
#   'navigate',
#   'high',
#   'sea',
#   'finance',
#   'steer',
#   'ship',
#   'economic',
#   'evolution',
#   'sailboat',
#   'money',
#   'bag',
#   'water',
#   'wave'],
#  ['album', 'moment', 'cyclone', 'hear', 'feeling', 'optimistic', 'week'],
#  ['path',
#   'totality',
#   'total',
#   'solar',
#   'eclipse',
#   'april',
#   '8',
#   "'ll",
#   'bring',
#   'totality',
#   'broadcast',
#   'several',
#   'location',
#   'along',
#   'trajectory',
#   'include',
#   'center',
#   'eclipse',
#   'path',
#   'watch'],
#  ["'s", 'tough', 'gig', 'binance', 'intern', 'good', 'morning'],
#  ['big',
#   'red',
#   'flag',
#   'adult',
#   'lack',
#   'child',
#   'youre',
#   '46',
#   'yet',
#   'bore',
#   'weed',
#   'alcohol',
#   'youre',
#   'immature',
#   'soulless',
#   'trust',
#   'vote',
#   'warped',
#   'world',
#   'view',
#   'zero',
#   'vested',
#   'interest',
#   'future',
#   'poor',
#   'people',
#   'alive'],
#  ['1', 'whole', 'bitcoin', 'hodlers', 'become', 'rare'],
#  ['dogecoin', 'tip', 'option', 'eye'],
#  ['introduce',
#   'new',
#   'simple',
#   'earn',
#   'flexible',
#   'product',
#   'promotion',
#   'subscribe',
#   'either',
#   'sui',
#   'usdt',
#   'simple',
#   'earn',
#   'flexible',
#   'product',
#   'grab',
#   'share',
#   '20000',
#   'sui',
#   'also',
#   'earn',
#   'bonus',
#   'apr',
#   'get',
#   'start',
#   'today',
#   'right',
#   'arrow',
#   'curve'],
#  ['6941650bitcoin', 'btc', 'btc', 'usd'],
#  ['law',
#   'write',
#   'sign',
#   'enact',
#   'tax',
#   'credit',
#   'save',
#   'average',
#   '800',
#   'per',
#   'person',
#   'per',
#   'year',
#   'reduce',
#   'health',
#   'care',
#   'premium',
#   'million',
#   'family',
#   'credit',
#   'expire',
#   'next',
#   'year',
#   'congress',
#   'make',
#   '800',
#   'expand',
#   'affordable',
#   'health',
#   'care',
#   'tax',
#   'credit',
#   'permanent'],
#  ['already', 'make', 'statement', 'donald'],
#  ['tag', 'light', 'mode', 'user', 'backhand', 'index', 'point'],
#  ['coinbase', 'blackrock', 'pump', 'crypto', 'high'],
#  ['pitbull', 'chingy', 'baby', 'bash'],
#  ['station', 'head', 'seem', 'work', 'guy', 'shocker'],
#  ['say', 'im', '25', 'im', '25', 'fuk'],
#  ['psalm', 'camera', 'saint'],
#  ['next',
#   'bitcoin',
#   'halving',
#   '2',
#   'week',
#   'historically',
#   'gain',
#   'always',
#   'realize',
#   'halving',
#   'prepared'],
#  ['moment',
#   'taiwan',
#   'maternity',
#   'staff',
#   'rush',
#   'keep',
#   'baby',
#   'safe',
#   'earthquake'],
#  ['13900',
#   'egg',
#   '200000',
#   'reward',
#   '1',
#   'bitcoin',
#   'get',
#   'start',
#   'binance',
#   'egg',
#   'drop',
#   'backhand',
#   'index',
#   'point'],
#  ['congratulation',
#   'select',
#   'move',
#   'forward',
#   'develop',
#   'artemis',
#   'lunar',
#   'terrain',
#   'vehicle',
#   'moon',
#   'rover',
#   'allow',
#   'future',
#   'astronaut',
#   'travel',
#   'far',
#   'lunar',
#   'surface'],
#  ['outrage',
#   'heartbroken',
#   'death',
#   'seven',
#   'humanitarian',
#   'worker',
#   'world',
#   'central',
#   'kitchen',
#   'include',
#   'one',
#   'american',
#   'gaza',
#   'yesterday',
#   'incident',
#   'like',
#   'yesterday',
#   'simply',
#   'happen',
#   'full',
#   'statement'],
#  ['bitcoin',
#   'symbol',
#   'digital',
#   'revolution',
#   'financial',
#   'freedom',
#   'light',
#   'bulb',
#   'globe',
#   'meridian',
#   'money',
#   'wing'],
#  ['miss', 'shanel', 'must', 'do'],
#  ['whale',
#   'watch',
#   'bucket',
#   'list',
#   "'ll",
#   'glad',
#   'know',
#   "n't",
#   'travel',
#   'well',
#   'crypto',
#   'whale',
#   'watch',
#   'anyway'],
#  ['want',
#   'honest',
#   'criticism',
#   'ai',
#   'portfolio',
#   '25',
#   'btc15',
#   'tao15',
#   'rndr10',
#   'grt10',
#   'akt5',
#   'ait5',
#   'paal5'],
#  ['still', 'argentina', 'star', 'star', 'star', 'gutsworldtour'],
#  ['kamala',
#   'continue',
#   'call',
#   'congress',
#   'restore',
#   'protection',
#   'roe',
#   'every',
#   'state',
#   'majority',
#   'american',
#   'support',
#   'woman',
#   "'s",
#   'right',
#   'choose',
#   'include',
#   'florida',
#   'voter',
#   'opportunity',
#   'support',
#   'reproductive',
#   'freedom',
#   'ballot',
#   'initiative',
#   'fall'],
#  ['category', 'album', 'deserve', 'way', 'success'],
#  ['white', 'house', 'want', 'moon', 'time', 'zone'],
#  ['introduce',
#   'binanceclubhouse',
#   'global',
#   'hub',
#   'binance',
#   'user',
#   'connect',
#   'work',
#   'talk',
#   'thing',
#   'crypto',
#   'stay',
#   'tune',
#   'info',
#   'come',
#   'handshake'],
#  ['yesterday',
#   'extreme',
#   'florida',
#   'supreme',
#   'court',
#   'decision',
#   'put',
#   'desperately',
#   'need',
#   'medical',
#   'care',
#   'even',
#   'reach',
#   'million',
#   'woman',
#   'florida',
#   'across',
#   'south',
#   'outrageousand',
#   'make',
#   'possible',
#   'trump',
#   'end',
#   'roe',
#   'v',
#   'wade'],
#  ['5198706bitcoin', 'btc', 'btc', 'gbp'],
#  ['ready',
#   'rock',
#   'april',
#   '8',
#   'eclipse',
#   'submit',
#   'favorite',
#   'solar',
#   'theme',
#   'song',
#   'add',
#   'sun',
#   'moon',
#   'eye',
#   'playlist'],
#  ['baby', 'step', 'sir', 'weary', 'face', 'grin', 'face', 'sweat'],
#  ['search', 'antidote', 'debut', '3', 'top', 'album', 'sale', 'chart'],
#  ['3',
#   'sleep',
#   'till',
#   'wrestlemania',
#   '40',
#   'talk',
#   'show',
#   'tonight',
#   'finalboss',
#   'tribalchief'],
#  ['one', 'crypto', 'show', 'monster', 'god', 'candle', 'summer'],
#  ['deadly',
#   'air',
#   'strike',
#   'show',
#   'system',
#   'protect',
#   'aid',
#   'worker',
#   'crisis',
#   'agency',
#   'say'],
#  ['binance',
#   'list',
#   'wormhole',
#   'w',
#   'seed',
#   'tag',
#   'apply',
#   'right',
#   'arrow'],
#  ['happy',
#   '90th',
#   'birthday',
#   'please',
#   'give',
#   'regard',
#   'mr',
#   'h',
#   'janeat90',
#   'goodallday'],
#  ['gaza', 'aid', 'convoy', 'strike', 'know'],
#  ['thank', 'ny', 'night', 'remember'],
#  ['watch',
#   'tomorrow',
#   'x',
#   'together',
#   'bring',
#   'deja',
#   'vu',
#   'kelly',
#   'clarkson',
#   'show'],
#  ['one', 'tell'],
#  ['prior',
#   'administration',
#   'extreme',
#   'republican',
#   'congress',
#   'succeed',
#   'gutting',
#   'aca',
#   '45',
#   'million',
#   'people',
#   'nationwide',
#   'would',
#   'lose',
#   'health',
#   'insurance'],
#  ['helloo', 'ever', 'see'],
#  ['album', 'make', 'noise', 'friday'],
#  ['barbz',
#   'since',
#   'yall',
#   'like',
#   'yappyity',
#   'yapping',
#   'take',
#   'screenshots',
#   'yall',
#   'ass',
#   'report',
#   'station',
#   'head',
#   'im',
#   'gagcity',
#   'giveaway',
#   'right',
#   '10',
#   'min',
#   'wan',
#   'na',
#   'win',
#   'ticket',
#   'ticket',
#   'admission',
#   'ticket',
#   'let',
#   'go',
#   'give',
#   'away',
#   '50',
#   'ticket',
#   '25',
#   'winner',
#   'get',
#   'plus',
#   '1'],
#  ['cake', 'think', 'conan', 'would', 'proud', 'smile', 'face', 'heart'],
#  ['remember',
#   'remember',
#   'withdraw',
#   'tournament',
#   '6',
#   'year',
#   'old',
#   'beat',
#   'first',
#   'two',
#   'adult',
#   'lose',
#   '3',
#   'row',
#   'ask',
#   'able',
#   'beat',
#   'chess',
#   'im',
#   'grow',
#   'reply',
#   'son',
#   'youre',
#   'grow',
#   'youll',
#   'beat',
#   'anyone',
#   'anything'],
#  ['bitcoin', 'halving', '17', 'day', 'away', 'eye'],
#  ['eye',
#   'sky',
#   'april',
#   '8',
#   'total',
#   'solar',
#   'eclipse',
#   'know',
#   'help',
#   'us',
#   'experience',
#   'big',
#   'event',
#   'listen',
#   'scientist',
#   'episode',
#   'curious',
#   'universe',
#   'podcast'],
#  ['rip', 'gale', 'sparrow'],
#  ['bitcoin', 'hit', '100000', 'next', '3', 'month', 'delete', 'x', 'account'],
#  ['trading', 'live', 'ena', 'binance', 'right', 'arrow'],
#  ['vechains', 'importance', 'isnt', 'talk', 'enough', 'vet'],
#  ['inhaler',
#   'cost',
#   'less',
#   '5',
#   'make',
#   'drug',
#   'company',
#   'charge',
#   'americans',
#   '600',
#   'increase',
#   'profit',
#   'administration',
#   'crack',
#   'big',
#   'pharma',
#   'three',
#   'four',
#   'large',
#   'inhaler',
#   'manufacturer',
#   'cap',
#   'pocket',
#   'cost',
#   '35'],
#  ['category', 'controversial', 'music', 'video'],
#  ['poll',
#   'open',
#   'state',
#   'across',
#   'country',
#   'head',
#   'confirm',
#   'poll',
#   'place'],
#  ['final', 'deadline', '7', 'spot', 'ethereum', 'etf', '50', 'day'],
#  ['guy', 'give', 'rundown', 'everything', 'say', 'unreleased', 'track'],
#  ['google', 'look', 'ai', 'paywall', 'option', 'report'],
#  ['solar', 'eclipse', '2024', 'watch', 'stream', 'live', 'anywhere'],
#  ['gagcity',
#   'everything',
#   'nicki',
#   'monica',
#   '50',
#   'cent',
#   'need',
#   'do',
#   'two',
#   'heart',
#   'gagcitydc'],
#  ['live',
#   'future',
#   'astronaut',
#   'drive',
#   'across',
#   'surface',
#   'moon',
#   "'re",
#   'announce',
#   'company',
#   'advance',
#   'capability',
#   'lunar',
#   'terrain',
#   'vehicle',
#   'rover',
#   'exploration',
#   'artemis',
#   'v',
#   'mission',
#   'beyond'],
#  ['time',
#   'supply',
#   'crypto',
#   'knowledge',
#   'literally',
#   'maximum',
#   'total',
#   'circulate',
#   'supply',
#   'explain',
#   'backhand',
#   'index',
#   'point'],
#  ['anyone',
#   'receive',
#   'checkmark',
#   'today',
#   'earn',
#   'money',
#   'stuff',
#   "'re",
#   'already',
#   'post',
#   'extra',
#   'effort',
#   'require',
#   'apply',
#   'monetize',
#   'setting',
#   'monetization'],
#  ['explore',
#   'new',
#   'taker',
#   'fee',
#   'promotion',
#   'binance',
#   'trade',
#   'usdc',
#   'spot',
#   'margin',
#   'trading',
#   'pair',
#   'enjoy',
#   'discount',
#   'taker',
#   'fee',
#   '10',
#   'april',
#   '2024',
#   'learn',
#   'right',
#   'arrow',
#   'curve'],
#  ['tune', 'deliver', 'remark', 'lower', 'health', 'care', 'cost', 'american'],
#  ['oh', 'extremely', 'gaggy', 'babe'],
#  ['like'],
#  ['truck', 'crash', 'spill', 'live', 'salmon', 'wrong', 'oregon', 'river'],
#  ['celebrate',
#   'upcoming',
#   'bitcoin',
#   'halve',
#   'binance',
#   'future',
#   'ultimate',
#   'challenge',
#   'join',
#   'daily',
#   'price',
#   'prediction',
#   'weekly',
#   'task',
#   'challenge',
#   'chance',
#   'win',
#   'btc',
#   'reward',
#   'tesla',
#   'model',
#   'join',
#   'right',
#   'arrow'],
#  ['police',
#   'car',
#   'light',
#   'break',
#   'police',
#   'car',
#   'light',
#   'grayscale',
#   'transfer',
#   '1983',
#   'btc',
#   'worth',
#   '1314',
#   'million',
#   'coinbase'],
#  ['bitcoin',
#   'always',
#   'pumps',
#   'halve',
#   '1st',
#   'halving',
#   '8000',
#   '2nd',
#   'halve',
#   '3000',
#   '3rd',
#   'halve',
#   '800',
#   '15',
#   'day',
#   '4th',
#   'halving',
#   'mentally',
#   'prepare'],
#  ['today',
#   'candid',
#   'conversation',
#   'president',
#   'xi',
#   'jinping',
#   'people',
#   'republic',
#   'china',
#   'range',
#   'issue',
#   'include',
#   'area',
#   'cooperation',
#   'area',
#   'difference',
#   'emphasize',
#   'importance',
#   'maintain',
#   'peace',
#   'stability',
#   'across',
#   'taiwan',
#   'strait',
#   'south'],
#  ['reason',
#   'felt',
#   'comfortable',
#   'call',
#   'mexican',
#   'im',
#   'dominican',
#   'ask',
#   'feel',
#   'comfortable',
#   'call',
#   'mexican',
#   'ice',
#   'jharell',
#   'jerome',
#   'zoe',
#   'saldana',
#   'dominican',
#   'dont',
#   'know',
#   'thats',
#   'people',
#   'use'],
#  ['gagcitybaltimore',
#   'take',
#   'dmv',
#   'miss',
#   'youuyall',
#   'dont',
#   'know',
#   'man',
#   'weary',
#   'face',
#   'fly',
#   'saucer',
#   'cityscape',
#   'thank',
#   'idk',
#   'say',
#   'best',
#   'night',
#   'ive',
#   'ever',
#   'earth',
#   'gagcity',
#   'may',
#   'god',
#   'bless',
#   'every',
#   'one',
#   'ill',
#   'never',
#   'forget',
#   'heavyonit'],
#  ['binance',
#   'respectfully',
#   'request',
#   'tigran',
#   'gambaryan',
#   'decision',
#   'make',
#   'power',
#   'company',
#   'hold',
#   'responsible',
#   'current',
#   'discussion',
#   'ongoing',
#   'binance',
#   'nigerian',
#   'government',
#   'officialsbringtigranhomeread',
#   'backhand',
#   'index',
#   'point'],
#  ['204',
#   'day',
#   '3264',
#   'orbit',
#   'dozen',
#   'experiment',
#   'space',
#   'head',
#   'home',
#   'undocking',
#   'return',
#   'coverage',
#   'nasa',
#   'platform',
#   'begin',
#   '8pm',
#   'et',
#   'friday',
#   'april',
#   '5',
#   '0000',
#   'utc',
#   'april',
#   '6'],
#  ["n't", 'buy', 'bitcoin', 'first', 'name', 'buy', 'bitcoin', 'last', 'name'],
#  ['billie',
#   'eilish',
#   'pearl',
#   'jam',
#   'nicki',
#   'minaj',
#   'among',
#   '200',
#   'artist',
#   'call',
#   'responsible',
#   'ai',
#   'music',
#   'practice'],
#  ['school', 'shoot', 'brings', 'tough', 'question', 'finland'],
#  ['instead',
#   'senior',
#   'diabetes',
#   'pay',
#   'much',
#   '400',
#   'month',
#   'insulin',
#   'badly',
#   'need',
#   'pay',
#   '35',
#   'month',
#   'period',
#   'want',
#   'extend',
#   'saving',
#   'everyone',
#   'need',
#   'lifesaving',
#   'insulin',
#   'whether',
#   'youre',
#   'senior'],
#  ['trade',
#   'responsibly',
#   'employ',
#   'risk',
#   'management',
#   'strategy',
#   'important',
#   'step',
#   'reduce',
#   'portfolio',
#   "'s",
#   'risk',
#   "'ve",
#   'list',
#   '5',
#   'strategy',
#   'find',
#   'right',
#   'backhand',
#   'index',
#   'point'],
#  ['binance',
#   'expand',
#   'portfolio',
#   'margin',
#   'non',
#   'vip',
#   'user',
#   'optimise',
#   'portfolio',
#   'enhanced',
#   'capital',
#   'efficiency',
#   'risk',
#   'management',
#   'trading',
#   'strategy',
#   'make',
#   'accessible',
#   'learn',
#   'backhand',
#   'index',
#   'point'],
#  ['collision',
#   'break',
#   'spot',
#   'bitcoin',
#   'etf',
#   'positive',
#   'inflow',
#   '40300000',
#   'yesterday'],
#  ['binance',
#   'charity',
#   'partner',
#   'child',
#   'hero',
#   'foundation',
#   'collaboration',
#   'launch',
#   'da',
#   'vinci',
#   '12',
#   'day',
#   'therapeutic',
#   'camp',
#   'support',
#   'child',
#   'lose',
#   'parent',
#   'war',
#   'read',
#   'right',
#   'arrow',
#   'curve'],
#  ['florida',
#   'ban',
#   'law',
#   'like',
#   'state',
#   'across',
#   'america',
#   'put',
#   'health',
#   'life',
#   'million',
#   'woman',
#   'risk',
#   'take',
#   'away',
#   'woman',
#   'freedom',
#   'make',
#   'health',
#   'care',
#   'decision',
#   'threaten',
#   'physician',
#   'provide',
#   'care',
#   'train',
#   'provide'],
#  ["n't", 'panic', 'salute', 'face'],
#  ["'ve",
#   'officially',
#   'hit',
#   '1m',
#   'post',
#   'binance',
#   'square',
#   'thank',
#   'share',
#   'content',
#   'feed',
#   'spread',
#   'crypto',
#   'knowledge',
#   'worldwide',
#   'handshake',
#   'keep',
#   'building',
#   'right',
#   'arrow'],
#  ['thats',
#   'say',
#   'say',
#   'nobody',
#   'call',
#   'ghetto',
#   'move',
#   'goal',
#   'post',
#   'know',
#   'im',
#   'im',
#   'right',
#   'take',
#   'no',
#   'recognize',
#   'change',
#   'change',
#   'way',
#   'talk',
#   'way',
#   'act',
#   'way',
#   'respond'],
#  ['honestly',
#   'great',
#   'product',
#   'feel',
#   'energized',
#   'strong',
#   'ever',
#   'since',
#   'ive',
#   'take'],
#  ['lizzo',
#   'clarifies',
#   'quit',
#   'music',
#   'industry',
#   "'negative",
#   'energy',
#   "'"],
#  ['olivia',
#   'rodrigo',
#   'kiss',
#   'chappell',
#   'roan',
#   'gut',
#   'world',
#   'tour',
#   'boston',
#   'stop'],
#  ['yesterday',
#   'floridas',
#   'supreme',
#   'court',
#   'uphold',
#   'state',
#   'abortion',
#   'ban',
#   'likely',
#   'trigger',
#   'governor',
#   "'s",
#   'extreme',
#   'law',
#   'eliminate',
#   'access',
#   'many',
#   'even',
#   'know',
#   "'re",
#   'pregnant',
#   'outrageous',
#   'remain',
#   'committed',
#   'protect',
#   'reproductive',
#   'freedom',
#   'florida',
#   'across',
#   'us'],
#  ['ukraine', 'give', 'award', 'foreign', 'vigilante', 'hack', 'russia'],
#  ['get',
#   '45',
#   'min',
#   'give',
#   'away',
#   'personal',
#   'tkts',
#   'soldoutminaj',
#   'show',
#   'guy',
#   'im',
#   'station',
#   'head',
#   'nanabooboo',
#   'barbz',
#   'dont',
#   'start',
#   'miss',
#   'face',
#   'hand',
#   'mouth'],
#  ['fly',
#   'new',
#   'class',
#   'officially',
#   'graduate',
#   'basic',
#   'training',
#   'last',
#   'monthand',
#   "'s",
#   'graduation',
#   'without',
#   'superlative',
#   'want',
#   'join',
#   'next',
#   'astronaut',
#   'class',
#   'application',
#   'still',
#   'open',
#   'get',
#   'april',
#   '16'],
#  ['coinbase',
#   'ceo',
#   'say',
#   'bitcoin',
#   'lightning',
#   'network',
#   'integration',
#   'launch',
#   'soon',
#   'high',
#   'voltage',
#   'eye'],
#  ['dont', 'pinch', 'please'],
#  ['rashee',
#   'rice',
#   'super',
#   'bowl',
#   'champion',
#   'admit',
#   'role',
#   'texas',
#   'hit',
#   'run'],
#  ['week',
#   'america',
#   'lose',
#   'hero',
#   'lou',
#   'conter',
#   'pass',
#   'away',
#   'age',
#   '102',
#   'america',
#   'say',
#   'farewell',
#   'last',
#   'known',
#   'survivor',
#   'us',
#   'arizona',
#   'station',
#   'battleship',
#   'row',
#   'pearl',
#   'harbor',
#   'december',
#   '7',
#   '1941',
#   'today',
#   'heart',
#   'know'],
#  ['think',
#   'might',
#   'confusion',
#   'say',
#   'ask',
#   'feel',
#   'comfortable',
#   'call',
#   'mexican',
#   'mexican',
#   'parent',
#   'mom',
#   'trini',
#   'come',
#   'whole',
#   'black',
#   'woman',
#   'father',
#   'dominicanim',
#   'dominican',
#   'like',
#   'also',
#   'use',
#   'dominican'],
#  ['want',
#   'give',
#   'fan',
#   'album',
#   'tour',
#   'touch',
#   'every',
#   'way',
#   'remind',
#   'fell',
#   'love',
#   '1st',
#   'place',
#   'give',
#   'tour',
#   'never',
#   'know',
#   'need',
#   'prove',
#   'much',
#   'value',
#   'much',
#   'value',
#   'art',
#   'pink',
#   'heart'],
#  ['beyonc',
#   'jennifer',
#   'hudson',
#   'host',
#   'mini',
#   'dreamgirls',
#   'reunion',
#   '2024',
#   'iheartradio',
#   'music',
#   'award'],
#  ['amateur', 'scientist', 'measure', 'snowfall', '50', 'year'],
#  ['happy',
#   'tip',
#   'tuesday',
#   'shibes',
#   'tip',
#   'dogecoin',
#   'dog',
#   'dog',
#   'face',
#   'money',
#   'wing'],
#  ['doge', 'og', 'tipping', 'currency', 'internet'],
#  ['april',
#   'big',
#   'month',
#   'sky',
#   'gaze',
#   'star',
#   'strike',
#   'big',
#   'planet',
#   'jupiter',
#   'visible',
#   'month',
#   'mar',
#   'saturn',
#   'rise',
#   'together',
#   'april',
#   '10',
#   '11',
#   'big',
#   'eclipse',
#   'april',
#   '8',
#   'catch',
#   'last',
#   'total',
#   'solar',
#   'eclipse',
#   'us',
#   '20',
#   'year',
#   'big',
#   'moon',
#   'catch',
#   'full',
#   'moon',
#   'april',
#   '23'],
#  ['irish',
#   'basketball',
#   'team',
#   'order',
#   'replay',
#   'last',
#   '03',
#   'second',
#   'quarter',
#   'final',
#   'tie'],
#  ['beyonc', 'finally', 'win', 'album', 'year', 'grammy', 'cowboy', 'carter'],
#  ['bad',
#   'migraine',
#   'ever',
#   'like',
#   '3',
#   'week',
#   'skull',
#   'wont',
#   'thing',
#   'go',
#   'away',
#   'try',
#   'everything',
#   'secret'],
#  ['tennessee',
#   'pass',
#   "'chemtrail",
#   "'",
#   'bill',
#   'ban',
#   'airborne',
#   'chemical'],
#  ['here',
#   'advice',
#   'raymonte',
#   'take',
#   'time',
#   'right',
#   'get',
#   'brand',
#   'deal',
#   '5',
#   'million',
#   'campaign',
#   'get',
#   'social',
#   'medium',
#   'famous',
#   '2014my',
#   'first',
#   'brand',
#   'deal',
#   'fashion',
#   'nova',
#   '2016',
#   '200',
#   'post',
#   'could',
#   'reach',
#   'height',
#   'matter',
#   'ghetto'],
#  ['something', 'cook', 'eye'],
#  ['mysterious',
#   'streak',
#   'light',
#   'see',
#   'across',
#   'southern',
#   'california',
#   'sky'],
#  ['performer', 'presenter', '2024', 'cmt', 'music', 'award'],
#  ['botswana', 'offer', 'send', '20000', 'elephant', 'germany'],
#  ['two', 'letter', 'dc', 'gagcitydc'],
#  ['french', 'couple', 'keep', '159', 'cat', 'ban', 'keep', 'pet'],
#  ['police',
#   'car',
#   'light',
#   'break',
#   'police',
#   'car',
#   'light',
#   '1000000000',
#   'usdt',
#   'get',
#   'mint',
#   'tether',
#   'treasury',
#   'yesterday',
#   'also',
#   '1',
#   'billion',
#   'usdt',
#   'mint',
#   'whale',
#   'prepare',
#   'huge',
#   'bitcoin',
#   'pump'],
#  ['rebel', 'wilson', 'book', 'release', 'put', 'back', 'uk', 'australia'],
#  ['world',
#   'central',
#   'kitchen',
#   'founder',
#   'jos',
#   'andrs',
#   'say',
#   'israel',
#   'targeted',
#   'staff',
#   'gaza',
#   "'car",
#   'car',
#   "'"],
#  ['seven', 'aid', 'worker', 'kill', 'gaza'],
#  ['listen',
#   'lot',
#   'friend',
#   'make',
#   'ton',
#   'ton',
#   'money',
#   'crypto',
#   'cling',
#   'little',
#   'bag',
#   'silver',
#   'realize',
#   'crypto',
#   'successful',
#   'last',
#   'several',
#   'year',
#   'think',
#   'would',
#   'obviously',
#   'admit',
#   'people',
#   'shouldnt',
#   'take',
#   'investment'],
#  ['super', 'valid', 'worth', 'podcast', 'someday'],
#  ['taylor', 'swift', 'officially', 'billionaire'],
#  ['truth', 'social', 'post', 'financial', 'bailout', 'trump'],
#  ['three',
#   'british',
#   'aid',
#   'worker',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'name'],
#  ['tesla', "'disaster", "'", 'few', 'delivery', 'since', '2022'],
#  ['best',
#   'doge',
#   'meme',
#   'win',
#   '69420',
#   'trophy',
#   'like',
#   'repost',
#   'post',
#   'participate',
#   'dog',
#   'upload',
#   'meme',
#   'comment',
#   'speech',
#   'balloon'],
#  ['trump',
#   'sue',
#   'truth',
#   'social',
#   'co',
#   'founder',
#   'alleged',
#   'mismanagement'],
#  ['ukraine', 'lower', 'combat', 'call', 'age', 'boost', 'number'],
#  ['2024',
#   'mlb',
#   'season',
#   'watch',
#   'baseball',
#   'game',
#   'online',
#   'free',
#   'without',
#   'cable'],
#  ['congratulation',
#   'buid',
#   '7952',
#   'first',
#   'winner',
#   'tesla',
#   'car',
#   'lucky',
#   'draw',
#   'second',
#   'installment',
#   'futureschallenge',
#   'party',
#   'popper',
#   "n't",
#   'worry',
#   '3',
#   'week',
#   'leave',
#   'get',
#   'hand',
#   'tesla',
#   'participate',
#   'right',
#   'arrow'],
#  ['tuesday',
#   'already',
#   'watch',
#   'play',
#   'password',
#   'tonight',
#   '109c',
#   'weakestlink'],
#  ['go',
#   'gagcitydc',
#   'alone',
#   'end',
#   'w',
#   'sweet',
#   'girl',
#   'next',
#   'also',
#   'alone',
#   'fun',
#   'bday',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'pink',
#   'heart',
#   'pink',
#   'heart',
#   'pink',
#   'heart',
#   'magical',
#   'fun',
#   'night',
#   'overall',
#   'im',
#   'overwhelmed',
#   'grateful'],
#  ['rip', 'michael', 'mcmartin'],
#  ['time',
#   'look',
#   'month',
#   "'s",
#   'market',
#   'insights',
#   'research',
#   'team',
#   'analyze',
#   'state',
#   'crypto',
#   'market',
#   'provide',
#   'insight',
#   'bitcoin',
#   'etf',
#   'inflows',
#   'ethereum',
#   "'s",
#   'dencun',
#   'upgrade',
#   'solana',
#   "'s",
#   'dex',
#   'volume',
#   'check',
#   'arrow'],
#  ['x',
#   'bring',
#   'tip',
#   'jar',
#   'web',
#   'app',
#   'iosandroid',
#   'feature',
#   'year',
#   "'s",
#   'finally',
#   'find',
#   'way',
#   'web',
#   'version',
#   'see',
#   'full',
#   'list',
#   'supported',
#   'service'],
#  ['cool', 'cool'],
#  ['israeli', 'government', 'say', 'block', 'al', 'jazeera', 'broadcast'],
#  ['new',
#   'senegal',
#   'president',
#   'bassirou',
#   'diomaye',
#   'faye',
#   'two',
#   'wife',
#   'african',
#   'culture',
#   'divorce',
#   'taboo',
#   'man',
#   "n't",
#   'allow',
#   'divorce',
#   'woman',
#   'unless',
#   'commit',
#   'infidelity',
#   'unforgivable',
#   'man',
#   'want',
#   'divorce',
#   'woman',
#   "'s",
#   'longer',
#   'young'],
#  ['deluxe',
#   'track',
#   'gut',
#   'spill',
#   'week',
#   'billboard',
#   'hot',
#   '100',
#   '14',
#   'obsess',
#   '58',
#   'american',
#   '75',
#   'stranger',
#   '90',
#   'scared',
#   'guitar',
#   '99',
#   'girl',
#   'ive',
#   'always'],
#  ['janet',
#   'jackson',
#   'return',
#   'japan',
#   'triumphant',
#   'together',
#   'tour',
#   'chronicle',
#   'legendary',
#   'career'],
#  ['small',
#   'orange',
#   'diamond',
#   'bitcoin',
#   'close',
#   '60000',
#   '33',
#   'day',
#   'row',
#   'consolidation',
#   'rocket'],
#  ['ohh',
#   'gots',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'two',
#   'heart'],
#  ['wear',
#   'solar',
#   'glass',
#   'space',
#   'smile',
#   'face',
#   'sunglass',
#   'million',
#   'people',
#   'earth',
#   'watch',
#   'total',
#   'solar',
#   'eclipse',
#   'april',
#   '8',
#   'astronaut',
#   'aboard',
#   'space',
#   'station',
#   'watch',
#   '250',
#   'mile',
#   'theyll',
#   'three',
#   'opportunity',
#   'view',
#   'ground',
#   'shadow',
#   'orbit',
#   'earth'],
#  ['x', 'soon', 'let', 'save', 'trend', 'explore', 'tab'],
#  ['cool'],
#  ['country',
#   'garden',
#   'china',
#   'property',
#   'giant',
#   'suspend',
#   'share',
#   'hong',
#   'kong'],
#  ['united',
#   'state',
#   'us',
#   'government',
#   'send',
#   '30170',
#   'bitcoin',
#   'worth',
#   '2',
#   'billion',
#   'coinbase',
#   'use',
#   'silk',
#   'road',
#   'hack',
#   'fund',
#   'arkham',
#   'data',
#   'show',
#   'eye'],
#  ['struggle',
#   'level',
#   'vip',
#   'now',
#   'chance',
#   'trade',
#   'like',
#   'vip9',
#   'usdc',
#   'margined',
#   'contract',
#   'enjoy',
#   'zero',
#   'maker',
#   'fee',
#   '0017',
#   'taker',
#   'fee',
#   'user',
#   'read',
#   'right',
#   'arrow'],
#  ['password', 'nbc', 'peacock'],
#  ['bet', 'future', 'bitcoin'],
#  ['refuse',
#   'speak',
#   'meaning',
#   'behind',
#   'boys',
#   'girl',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face'],
#  ['global', 'citizen', 'festival', 'return', 'central', 'park', '2024'],
#  ['coneheads', 'time', 'u', 'find', 'find', 'heaven', 'song', 'u'],
#  ['houston', 'texan', 'make', 'move', 'dallas', 'cowboy', 'really'],
#  ['person', 'texas', 'diagnose', 'rare', 'bird', 'flu', 'contact', 'cattle'],
#  ['im', 'freak', 'need'],
#  ['shut', 'hospital', 'please'],
#  ['michael', 'rubin', 'posh', 'party', 'unite', 'sport', 'music', 'world'],
#  ['know', 'dumb', 'as', 'richy', 'jackson', 'choreo', 'see'],
#  ['whered', 'go', 'go', 'alley', 'rise', 'idk', 'conan', 'text', 'gc'],
#  ['police',
#   'car',
#   'light',
#   'attention',
#   'katycats',
#   'friend',
#   'industry',
#   'always',
#   'cruel',
#   'katy',
#   'perry',
#   'need',
#   'bring',
#   'everyone',
#   "'s",
#   'attention',
#   'reply',
#   'tweet',
#   'withjusticeforkatyperry',
#   'goal',
#   '100',
#   'reply'],
#  ['endeavor',
#   'go',
#   'private',
#   'deal',
#   'majority',
#   'shareholder',
#   'silver',
#   'lake'],
#  ['chile', 'woman', 'steal', 'gun', 'guard', 'open', 'fire'],
#  ['nicki',
#   'concert',
#   'literally',
#   'everything',
#   'face',
#   'hold',
#   'back',
#   'tear'],
#  ['ive',
#   'hear',
#   'people',
#   'ask',
#   'point',
#   'potential',
#   'downfall',
#   'leave',
#   'us',
#   'hear',
#   'canadian',
#   'europeans',
#   'issue',
#   'go',
#   'need',
#   'fight',
#   'keep',
#   'country',
#   'order',
#   'nowhere',
#   'run'],
#  ['notch', 'second', 'hot', 'rock', 'alternative', 'songs', '1', 'sweet'],
#  ['cigar', 'night', 'qa', 'tonight', '8pm', 'universal', 'tate', 'time'],
#  ['stefano',
#   'cherchi',
#   'jockey',
#   'dy',
#   'two',
#   'week',
#   'fall',
#   'canberra',
#   'race'],
#  ['hunter',
#   'schafer',
#   'open',
#   'date',
#   'rosala',
#   '2019',
#   'shes',
#   'family',
#   'matter'],
#  ['everybody',
#   'tonight',
#   'pink',
#   'mother',
#   'cry',
#   'face',
#   'pink',
#   'heart',
#   'heart',
#   'hand',
#   'medium',
#   'skin',
#   'tone',
#   'gagcitydc'],
#  ['elon',
#   'la',
#   'benjamin',
#   'franklin',
#   'tesla',
#   'midjourney',
#   'prompt',
#   'benjamin',
#   'franklin',
#   'drive',
#   'tesla',
#   'grin',
#   'squint',
#   'face',
#   'sparkle'],
#  ["'s", 'revolution', 'way', 'glass', 'making'],
#  ['firebloodchallenge', 'taste', 'like', 'orange', 'juice', 'tangerine'],
#  ['make', 'america', 'festival', 'cancel', 'second', 'consecutive', 'year'],
#  ['world',
#   'central',
#   'kitchen',
#   'founder',
#   'jos',
#   'andrs',
#   'criticises',
#   'israel',
#   'aid',
#   'worker',
#   "'",
#   'death'],
#  ['hot',
#   '100',
#   'first',
#   'timer',
#   'allison',
#   'russell',
#   'debut',
#   'hozier',
#   'team',
#   'wildflower',
#   'barley'],
#  ['list', 'go'],
#  ['ye',
#   'ty',
#   'dolla',
#   'ign',
#   "'s",
#   'vulture',
#   'listen',
#   'party',
#   'wo',
#   "n't",
#   'go',
#   'ahead'],
#  ['coinbase',
#   'officially',
#   'integrate',
#   'bitcoin',
#   'lightning',
#   'network',
#   'clap',
#   'hand',
#   'coinbase',
#   '100',
#   'million',
#   'user',
#   'rocket'],
#  ['big',
#   'breaking',
#   'police',
#   'car',
#   'light',
#   'ethereum',
#   'etf',
#   'approval',
#   'police',
#   'car',
#   'light',
#   'sec',
#   'ask',
#   'public',
#   'comment',
#   'grayscale',
#   'bitwise',
#   'fidelity',
#   'spot',
#   'ethereum',
#   'etf'],
#  ['glorilla',
#   'recall',
#   'beautiful',
#   'feeling',
#   'visit',
#   'white',
#   'house',
#   'still',
#   'havent',
#   'accept',
#   'reality'],
#  ['follow',
#   'first',
#   'playoff',
#   'appearance',
#   'decade',
#   'marlin',
#   'try',
#   'demote',
#   'gm',
#   'kim',
#   'ng',
#   'turn',
#   'leave',
#   'organization',
#   'marlin',
#   'behind',
#   'early',
#   'today',
#   'lose',
#   'angel',
#   "'ll",
#   '0',
#   '7',
#   'start',
#   'season'],
#  ['ukraine',
#   'war',
#   'deep',
#   'ukraine',
#   'drone',
#   'attack',
#   'russian',
#   'territory',
#   'injures',
#   '12'],
#  ['damn', 'nigga', 'buy', 'god'],
#  ['lizzo', 'clarifies', 'mean', 'quit', 'statement', 'im', 'go', 'keep'],
#  ['andrew', 'tate', "'s", 'cold', 'moment', 'fight'],
#  ['john',
#   'summit',
#   'dom',
#   'dolla',
#   'kaskade',
#   'headline',
#   'desert',
#   'night',
#   'coachella',
#   'party'],
#  ['dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   'dollar',
#   'banknote',
#   '1000000000',
#   'usdt',
#   '1000027499',
#   'usd',
#   'mint',
#   'tether',
#   'treasury'],
#  ['marvin', 'winans', 'able', 'top', 'gospel', 'airplay', 'chart'],
#  ['see',
#   'sht',
#   'like',
#   'back',
#   'back',
#   'every',
#   'show',
#   'put',
#   'perspective',
#   'nicki',
#   'minaj',
#   'real',
#   'life',
#   'go',
#   'back',
#   'forth',
#   'fl',
#   'try',
#   'prove',
#   'point',
#   'useless',
#   'nothing',
#   'negative',
#   'even',
#   'phase',
#   "y'all",
#   'let',
#   'live',
#   'delusion'],
#  ['beyonc', 'thanks', 'jack', 'white', 'inspire', 'cowboy', 'carter'],
#  ['slow',
#   'high',
#   'speed',
#   'train',
#   'soccer',
#   'ball',
#   'soccer',
#   'ball',
#   'soccer',
#   'ball'],
#  ['lady',
#   'gagas',
#   'harley',
#   'quinn',
#   'speak',
#   'listen',
#   'first',
#   'taste',
#   'singer',
#   'character',
#   'joker',
#   'folie',
#   'deux'],
#  ['uk', 'surfer', 'laura', 'crane', 'class', 'big', 'wave', 'spot', 'nazare'],
#  ['congrats'],
#  ['julia', 'garner', 'play', 'female', 'silver', 'surfer', 'fantasticfour'],
#  ['big',
#   'breaking',
#   'police',
#   'car',
#   'light',
#   'coinbase',
#   'go',
#   'big',
#   'bitcoin',
#   'coinbase',
#   'partner',
#   'lightspark',
#   'integrate',
#   'bitcoin',
#   'lightning',
#   'network'],
#  ['hate', 'pending', 'transaction', 'please', 'take', 'money'],
#  ['10010',
#   'amazing',
#   'show',
#   'smile',
#   'face',
#   'heart',
#   'smile',
#   'face',
#   'heart',
#   'smile',
#   'face',
#   'heart',
#   'smile',
#   'face',
#   'heart',
#   'smile',
#   'face',
#   'heart',
#   'smile',
#   'face',
#   'heart',
#   'smile',
#   'face',
#   'heart',
#   'gagcitybaltimore'],
#  ['top',
#   '8',
#   'profitable',
#   'crypto',
#   'narrative',
#   '2024',
#   '1',
#   'memecoin',
#   '1313',
#   '2',
#   'rwa',
#   '286',
#   '3',
#   'ai',
#   '222',
#   '4',
#   'defi',
#   '99',
#   '5',
#   'depin',
#   '81',
#   '6',
#   'layer',
#   '1',
#   '70',
#   '7',
#   'game',
#   '64',
#   '8',
#   'layer',
#   '2',
#   '39'],
#  ['famous',
#   'id',
#   'make',
#   'fanpage',
#   'post',
#   'rares',
#   'literally',
#   'one',
#   'ever',
#   'see',
#   'take',
#   'everyone',
#   'would',
#   'like',
#   'person',
#   'always',
#   'rare',
#   'pic',
#   'cry',
#   'face',
#   'bc',
#   'duh'],
#  ['cant',
#   'say',
#   'nothing',
#   'every',
#   'body',
#   'get',
#   'offend',
#   'every',
#   'little',
#   'thing'],
#  ['wish',
#   'gaga',
#   'would',
#   'stop',
#   'bring',
#   'hair',
#   'makeup',
#   'friend',
#   'movie',
#   'project',
#   'could',
#   'seehow',
#   'put',
#   'nicely'],
#  ['fake',
#   'nationalist',
#   'zionist',
#   'agent',
#   'word',
#   'fake',
#   'nationalist',
#   '3',
#   'former',
#   'british',
#   'military',
#   'member',
#   'kill',
#   'israel',
#   'israel',
#   'first'],
#  ['every',
#   'dip',
#   'universe',
#   "'s",
#   'way',
#   'ask',
#   'courage',
#   'double',
#   'dream'],
#  ['raymonte', 'wrong'],
#  ['currently',
#   '18h',
#   '53m',
#   '16s',
#   'light',
#   'travel',
#   'time',
#   'earth',
#   '2024',
#   '095',
#   '000000',
#   '1l'],
#  ['offense',
#   'bardi',
#   'cu',
#   'dominican',
#   'parent',
#   'black',
#   'one',
#   'loudly',
#   'cry',
#   'face',
#   'black',
#   'heart'],
#  ['anticipated', 'performance', '2024'],
#  ['race', 'v', 'ethnicity', 'v', 'nationality', 'beat', 'community', 'as'],
#  ["'s",
#   'cute',
#   'kid',
#   'say',
#   'want',
#   'grow',
#   "'re",
#   'gon',
#   'na',
#   'write',
#   'email',
#   'computer',
#   'buddy'],
#  ['katyperry',
#   "'s",
#   'harleys',
#   'hawaii',
#   'surpass',
#   '500',
#   'million',
#   'stream',
#   'spotify',
#   '15th',
#   'song',
#   'reach',
#   'milestone',
#   'flex',
#   'biceps',
#   'motorcycle',
#   'sun',
#   'collision',
#   'keycap',
#   '5',
#   'keycap',
#   '0',
#   'keycap',
#   '0',
#   'circle',
#   'multiply',
#   'keycap',
#   '1',
#   'keycap',
#   '5',
#   'musical',
#   'note',
#   'fire',
#   'crown',
#   'pink',
#   'heart'],
#  ['fun', 'fact', 'lady', 'gagas', 'lead', 'role', 'film', 'rat', 'r'],
#  ['pouria',
#   'zeraati',
#   'three',
#   'accuse',
#   'tv',
#   'presenter',
#   'attack',
#   'leave',
#   'uk'],
#  ['starship',
#   'mar',
#   'within',
#   'decade',
#   'cant',
#   'wait',
#   'help',
#   'build',
#   'booster',
#   'thatll',
#   'send',
#   'way',
#   'face',
#   'steam',
#   'nose',
#   'fire',
#   'rocket'],
#  ['katy',
#   'perry',
#   'lead',
#   'single',
#   'april',
#   'may',
#   'music',
#   'video',
#   'ready',
#   'xx'],
#  ["'s",
#   'stormy',
#   'day',
#   'spaceport',
#   "'s",
#   'weather',
#   'like',
#   'right',
#   'arrow',
#   'curve'],
#  ['crazy', 'happen', '33', 'like', 'jesus'],
#  ['fact', 'never', 'chart', 'hot', '100', 'insane'],
#  ['look',
#   'cute',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'face',
#   'hold',
#   'back',
#   'tear',
#   'pink',
#   'heart'],
#  ['doja',
#   'cat',
#   'say',
#   'doesnt',
#   'care',
#   'music',
#   'leak',
#   'theres',
#   'nothing'],
#  ['buy', 'tesla', 'dogecoin'],
#  ['name',
#   'three',
#   'british',
#   'aid',
#   'worker',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'john',
#   'chapman',
#   'james',
#   'henderson',
#   'james',
#   'kirby',
#   'bbc',
#   'establishes'],
#  ['timeline',
#   'dm',
#   'talk',
#   'dm',
#   'youre',
#   'back',
#   'timeline',
#   'cant',
#   'gaslight',
#   'wont',
#   'let',
#   'confuse',
#   'people',
#   'bring',
#   'thing',
#   'irrelevant',
#   'initial',
#   'discussion',
#   'say',
#   'people',
#   'never',
#   'call',
#   'ghetto',
#   'respond'],
#  ['barbies',
#   'bad',
#   'girls',
#   'aint',
#   'play',
#   'tag',
#   'two',
#   'heart',
#   'star',
#   'strike',
#   'gagcitybaltimore'],
#  ['big',
#   'breaking',
#   'police',
#   'car',
#   'light',
#   'bitcoin',
#   'reach',
#   '150k',
#   'end',
#   'year',
#   'per',
#   'morgan',
#   'creek',
#   'capital',
#   'management',
#   'ceo',
#   'mark',
#   'yusko'],
#  ['fox',
#   'sport',
#   'resident',
#   'deadhead',
#   'bring',
#   'jam',
#   'band',
#   'big',
#   'game'],
#  ['win', 'salute', 'face'],
#  ['cry', 'face', 'hold', 'back', 'tear', 'purple', 'heart', 'love'],
#  ['katchatheevu',
#   'tiny',
#   'sri',
#   'lankan',
#   'island',
#   'spark',
#   'political',
#   'row',
#   'india'],
#  ['gaga',
#   'house',
#   'gucci',
#   'get',
#   'drag',
#   'accent',
#   'joker',
#   "'s",
#   'get',
#   'drag',
#   'one'],
#  ['gaga',
#   'daily',
#   'wouldve',
#   'love',
#   'today',
#   'plead',
#   'face',
#   'broken',
#   'heart'],
#  ['time', 'katycats', 'move', 'justiceforkatyperry'],
#  ['4', 'year', 'youre', 'still', 'brokie'],
#  ['reiterate',
#   'firm',
#   'call',
#   'immediate',
#   'ceasefire',
#   'gaza',
#   'strip',
#   'express',
#   'deep',
#   'sorrow',
#   'volunteer',
#   'kill',
#   'distribute',
#   'humanitarian',
#   'aid',
#   'gaza',
#   'pray',
#   'family'],
#  ['katy',
#   'perry',
#   'teenage',
#   'dream',
#   'album',
#   'cover',
#   'actually',
#   'painting'],
#  ['coneheads', 'join', 'cone', 'live', 'qa', 'star', 'black', 'heart'],
#  ['new', 'shakira', 'collaboration', 'way', 'xx'],
#  ['apple', 'explore', 'creation', 'home', 'robot', 'next', 'big', 'thing'],
#  ['say', 'house', 'gucci', 'best', 'poster'],
#  ['need', 'katys', 'documentary', 'happen', '2017', '2018'],
#  ['new',
#   'look',
#   'moana',
#   '2',
#   'set',
#   '3',
#   'year',
#   'first',
#   'movie',
#   'theater',
#   'november',
#   '27'],
#  ['taylor',
#   'swift',
#   'compete',
#   'travis',
#   'kelce',
#   '2024',
#   'webby',
#   'award',
#   'full',
#   'nomination',
#   'announce'],
#  ['two',
#   'margarita',
#   'deep',
#   'hear',
#   'song',
#   'playing',
#   'call',
#   'go',
#   'way',
#   'like',
#   'wow',
#   'really',
#   'sing',
#   'as',
#   'look',
#   'two',
#   'band',
#   'member',
#   'break',
#   'tear',
#   'go',
#   'way',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'watch',
#   'live',
#   'performance',
#   'cant',
#   'even',
#   'look'],
#  ['la',
#   'mujeres',
#   'ya',
#   'lloran',
#   'hit',
#   'number',
#   'one',
#   'top',
#   'latin',
#   'album',
#   'latin',
#   'pop',
#   'album',
#   'gem',
#   'stone'],
#  ['sister',
#   'ship',
#   '1',
#   '22h',
#   '32m',
#   '47s',
#   'light',
#   'travel',
#   'time',
#   'earth',
#   '2024',
#   '094',
#   '120000',
#   '1l'],
#  ['justice', 'katy', 'perry', 'broken', 'heart', 'cry', 'cat'],
#  ['conans',
#   'gon',
#   'na',
#   'personally',
#   'gate',
#   'arena',
#   'ask',
#   'people',
#   'relationship',
#   'say',
#   'yeah',
#   'hell',
#   'like',
#   'good',
#   'get'],
#  ['usa',
#   'today',
#   'attend',
#   "'s",
#   'gagcitydc',
#   'give',
#   'review',
#   'show',
#   'first',
#   'us',
#   'run',
#   'eight',
#   'year',
#   'minaj',
#   'craft',
#   'grandiose',
#   'productionshe',
#   'still',
#   'queen',
#   'rap',
#   'reason'],
#  ['nine', 'milestone', 'beyonc', 'could', 'reach', '2025', 'grammys'],
#  ['israel',
#   'pm',
#   'say',
#   'force',
#   'unintentionally',
#   'hit',
#   'innocent',
#   'people',
#   'gaza',
#   'strike',
#   'aid',
#   'worker',
#   'kill',
#   'seven',
#   'follow',
#   'late',
#   'update'],
#  ['sold', 'car', 'planet', 'earth', '2023', 'tesla'],
#  ['thanks',
#   'free',
#   'medium',
#   'particular',
#   'chapter',
#   'genocide',
#   'palestine',
#   'happen',
#   'front',
#   'everybody',
#   "'s",
#   'eye',
#   'pier',
#   'rogan',
#   'trump',
#   'big',
#   'name',
#   'condemn',
#   'happen',
#   'day',
#   'one',
#   'tell',
#   'pier',
#   'would',
#   'happen',
#   'know'],
#  ['barbie',
#   'touch',
#   'downn',
#   'zany',
#   'face',
#   'pink',
#   'heart',
#   'im',
#   'ready',
#   'babes'],
#  ['beyoncs', 'cowboy', 'carter', 'gallop', '1', 'uk'],
#  ['im', 'gagcitybaltimore'],
#  ['remember',
#   'hero',
#   'family',
#   'pay',
#   'tribute',
#   'james',
#   'kirby',
#   'one',
#   'three',
#   'briton',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'aid',
#   'convoy'],
#  ['everything',
#   'app',
#   'get',
#   'close',
#   'every',
#   'single',
#   'day',
#   'build',
#   'new',
#   'way',
#   'everyone',
#   'find',
#   'community',
#   'connect',
#   'one',
#   'another'],
#  ['feid', 'announces', 'joint', 'album', 'yandel', 'here', 'know'],
#  ['pussy', 'mek', 'mi', 'run'],
#  ["'s", 'never', 'really', 'certified', 'diamond', 'brazil', 'brazil'],
#  ['conan',
#   'sell',
#   'found',
#   'heaven',
#   'necklace',
#   'separately',
#   "n't",
#   'collect',
#   'cd',
#   "'m",
#   'vinyl',
#   'girlie'],
#  ['first', 'look', 'mufasa', 'lion', 'king', 'theater', 'december', '20'],
#  ['funimation', 'officially', 'close'],
#  ['sound', 'exactly', 'like', 'countess', 'scream'],
#  ['one',
#   'didnt',
#   'notice',
#   'conan',
#   'start',
#   'sing',
#   'song',
#   'find',
#   'heaven',
#   'accident',
#   'live',
#   'sheer',
#   'panic',
#   'eye',
#   'loudly',
#   'cry',
#   'face'],
#  ['mean'],
#  ['us', 'sec', 'call', 'comment', 'spot', 'eth', 'etf'],
#  ['dont', 'give', 'damn', 'pretty', 'australia', 'never', 'see'],
#  ['united',
#   'state',
#   'las',
#   'mujeres',
#   'ya',
#   'lloran',
#   'us',
#   'billboard',
#   '1',
#   'top',
#   'latin',
#   'albums',
#   '1',
#   'top',
#   'latin',
#   'pop',
#   'album',
#   '2',
#   'top',
#   'album',
#   'sale',
#   '2',
#   'top',
#   'current',
#   'album',
#   'sale',
#   '4',
#   'top',
#   'vinyl',
#   'album',
#   '13',
#   'billboard',
#   '200',
#   '30',
#   'top',
#   'streaming',
#   'album'],
#  ['new', 'look', 'moana', '2', 'november', '27th'],
#  ['sleeper',
#   'hit',
#   'year',
#   'song',
#   'watch',
#   'hit',
#   'come',
#   'go',
#   'stay',
#   'smash',
#   'chart',
#   'loudly',
#   'cry',
#   'face'],
#  ['atta',
#   'baby',
#   'flag',
#   'hole',
#   '40',
#   '500',
#   'winner',
#   'money',
#   'bag',
#   'money',
#   'bag',
#   'radio',
#   'button',
#   'repost',
#   'video',
#   'radio',
#   'button',
#   'reply',
#   'say',
#   'something',
#   'nice',
#   'somebody',
#   'radio',
#   'button',
#   'put',
#   'easy',
#   'way',
#   'pay',
#   'post',
#   'wellpmslive'],
#  ['high',
#   'heel',
#   'tippies',
#   'nail',
#   'polish',
#   'medium',
#   'light',
#   'skin',
#   'tone',
#   'heart',
#   'ribbon',
#   'pinkfridaynails'],
#  ['united',
#   'state',
#   'us',
#   'government',
#   'transfer',
#   '30174',
#   'bitcoin',
#   'worth',
#   '21',
#   'billion',
#   'seize',
#   'silk',
#   'road',
#   'coinbase'],
#  ['playstation',
#   '5',
#   'deal',
#   'limited',
#   'edition',
#   'spider',
#   'man',
#   '2',
#   'console',
#   'bundle',
#   '110',
#   'amazon'],
#  ['conan', 'still', 'friend', 'group', 'ex', 'oh', 'god'],
#  ['dont', 'know', 'shell', 'top', 'cover'],
#  ['atta',
#   'baby',
#   'flag',
#   'hole',
#   '40',
#   '500',
#   'winner',
#   'money',
#   'bag',
#   'money',
#   'bag',
#   'radio',
#   'button',
#   'repost',
#   'video',
#   'radio',
#   'button',
#   'reply',
#   'say',
#   'something',
#   'nice',
#   'somebody',
#   'radio',
#   'button',
#   'put',
#   'easy',
#   'way',
#   'pay',
#   'post',
#   'wellpmslive'],
#  ['dont', 'give', 'damn', 'pretty', 'australia', 'never', 'see'],
#  ['united',
#   'state',
#   'las',
#   'mujeres',
#   'ya',
#   'lloran',
#   'us',
#   'billboard',
#   '1',
#   'top',
#   'latin',
#   'albums',
#   '1',
#   'top',
#   'latin',
#   'pop',
#   'album',
#   '2',
#   'top',
#   'album',
#   'sale',
#   '2',
#   'top',
#   'current',
#   'album',
#   'sale',
#   '4',
#   'top',
#   'vinyl',
#   'album',
#   '13',
#   'billboard',
#   '200',
#   '30',
#   'top',
#   'streaming',
#   'album'],
#  ['new', 'look', 'moana', '2', 'november', '27th'],
#  ['sleeper',
#   'hit',
#   'year',
#   'song',
#   'watch',
#   'hit',
#   'come',
#   'go',
#   'stay',
#   'smash',
#   'chart',
#   'loudly',
#   'cry',
#   'face'],
#  ['mean'],
#  ['us', 'sec', 'call', 'comment', 'spot', 'eth', 'etf'],
#  ['funimation', 'officially', 'close'],
#  ['sound', 'exactly', 'like', 'countess', 'scream'],
#  ['one',
#   'didnt',
#   'notice',
#   'conan',
#   'start',
#   'sing',
#   'song',
#   'find',
#   'heaven',
#   'accident',
#   'live',
#   'sheer',
#   'panic',
#   'eye',
#   'loudly',
#   'cry',
#   'face'],
#  ['first', 'look', 'mufasa', 'lion', 'king', 'theater', 'december', '20'],
#  ['conan',
#   'sell',
#   'found',
#   'heaven',
#   'necklace',
#   'separately',
#   "n't",
#   'collect',
#   'cd',
#   "'m",
#   'vinyl',
#   'girlie'],
#  ["'s", 'never', 'really', 'certified', 'diamond', 'brazil', 'brazil'],
#  ['everything',
#   'app',
#   'get',
#   'close',
#   'every',
#   'single',
#   'day',
#   'build',
#   'new',
#   'way',
#   'everyone',
#   'find',
#   'community',
#   'connect',
#   'one',
#   'another'],
#  ['feid', 'announces', 'joint', 'album', 'yandel', 'here', 'know'],
#  ['im', 'gagcitybaltimore'],
#  ['remember',
#   'hero',
#   'family',
#   'pay',
#   'tribute',
#   'james',
#   'kirby',
#   'one',
#   'three',
#   'briton',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'aid',
#   'convoy'],
#  ['barbie',
#   'touch',
#   'downn',
#   'zany',
#   'face',
#   'pink',
#   'heart',
#   'im',
#   'ready',
#   'babes'],
#  ['beyoncs', 'cowboy', 'carter', 'gallop', '1', 'uk'],
#  ['sold', 'car', 'planet', 'earth', '2023', 'tesla'],
#  ['thanks',
#   'free',
#   'medium',
#   'particular',
#   'chapter',
#   'genocide',
#   'palestine',
#   'happen',
#   'front',
#   'everybody',
#   "'s",
#   'eye',
#   'pier',
#   'rogan',
#   'trump',
#   'big',
#   'name',
#   'condemn',
#   'happen',
#   'day',
#   'one',
#   'tell',
#   'pier',
#   'would',
#   'happen',
#   'know'],
#  ['usa',
#   'today',
#   'attend',
#   "'s",
#   'gagcitydc',
#   'give',
#   'review',
#   'show',
#   'first',
#   'us',
#   'run',
#   'eight',
#   'year',
#   'minaj',
#   'craft',
#   'grandiose',
#   'productionshe',
#   'still',
#   'queen',
#   'rap',
#   'reason'],
#  ['nine', 'milestone', 'beyonc', 'could', 'reach', '2025', 'grammys'],
#  ['israel',
#   'pm',
#   'say',
#   'force',
#   'unintentionally',
#   'hit',
#   'innocent',
#   'people',
#   'gaza',
#   'strike',
#   'aid',
#   'worker',
#   'kill',
#   'seven',
#   'follow',
#   'late',
#   'update'],
#  ['justice', 'katy', 'perry', 'broken', 'heart', 'cry', 'cat'],
#  ['conans',
#   'gon',
#   'na',
#   'personally',
#   'gate',
#   'arena',
#   'ask',
#   'people',
#   'relationship',
#   'say',
#   'yeah',
#   'hell',
#   'like',
#   'good',
#   'get'],
#  ['taylor',
#   'swift',
#   'compete',
#   'travis',
#   'kelce',
#   '2024',
#   'webby',
#   'award',
#   'full',
#   'nomination',
#   'announce'],
#  ['two',
#   'margarita',
#   'deep',
#   'hear',
#   'song',
#   'playing',
#   'call',
#   'go',
#   'way',
#   'like',
#   'wow',
#   'really',
#   'sing',
#   'as',
#   'look',
#   'two',
#   'band',
#   'member',
#   'break',
#   'tear',
#   'go',
#   'way',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'watch',
#   'live',
#   'performance',
#   'cant',
#   'even',
#   'look'],
#  ['la',
#   'mujeres',
#   'ya',
#   'lloran',
#   'hit',
#   'number',
#   'one',
#   'top',
#   'latin',
#   'album',
#   'latin',
#   'pop',
#   'album',
#   'gem',
#   'stone'],
#  ['sister',
#   'ship',
#   '1',
#   '22h',
#   '32m',
#   '47s',
#   'light',
#   'travel',
#   'time',
#   'earth',
#   '2024',
#   '094',
#   '120000',
#   '1l'],
#  ['new',
#   'look',
#   'moana',
#   '2',
#   'set',
#   '3',
#   'year',
#   'first',
#   'movie',
#   'theater',
#   'november',
#   '27'],
#  ['apple', 'explore', 'creation', 'home', 'robot', 'next', 'big', 'thing'],
#  ['say', 'house', 'gucci', 'best', 'poster'],
#  ['need', 'katys', 'documentary', 'happen', '2017', '2018'],
#  ['katy',
#   'perry',
#   'teenage',
#   'dream',
#   'album',
#   'cover',
#   'actually',
#   'painting'],
#  ['coneheads', 'join', 'cone', 'live', 'qa', 'star', 'black', 'heart'],
#  ['new', 'shakira', 'collaboration', 'way', 'xx'],
#  ['4', 'year', 'youre', 'still', 'brokie'],
#  ['reiterate',
#   'firm',
#   'call',
#   'immediate',
#   'ceasefire',
#   'gaza',
#   'strip',
#   'express',
#   'deep',
#   'sorrow',
#   'volunteer',
#   'kill',
#   'distribute',
#   'humanitarian',
#   'aid',
#   'gaza',
#   'pray',
#   'family'],
#  ['time', 'katycats', 'move', 'justiceforkatyperry'],
#  ['katchatheevu',
#   'tiny',
#   'sri',
#   'lankan',
#   'island',
#   'spark',
#   'political',
#   'row',
#   'india'],
#  ['gaga',
#   'house',
#   'gucci',
#   'get',
#   'drag',
#   'accent',
#   'joker',
#   "'s",
#   'get',
#   'drag',
#   'one'],
#  ['gaga',
#   'daily',
#   'wouldve',
#   'love',
#   'today',
#   'plead',
#   'face',
#   'broken',
#   'heart'],
#  ['cry', 'face', 'hold', 'back', 'tear', 'purple', 'heart', 'love'],
#  ['big',
#   'breaking',
#   'police',
#   'car',
#   'light',
#   'bitcoin',
#   'reach',
#   '150k',
#   'end',
#   'year',
#   'per',
#   'morgan',
#   'creek',
#   'capital',
#   'management',
#   'ceo',
#   'mark',
#   'yusko'],
#  ['fox',
#   'sport',
#   'resident',
#   'deadhead',
#   'bring',
#   'jam',
#   'band',
#   'big',
#   'game'],
#  ['win', 'salute', 'face'],
#  ['katchatheevu',
#   'tiny',
#   'sri',
#   'lankan',
#   'island',
#   'spark',
#   'political',
#   'row',
#   'india'],
#  ['gaga',
#   'house',
#   'gucci',
#   'get',
#   'drag',
#   'accent',
#   'joker',
#   "'s",
#   'get',
#   'drag',
#   'one'],
#  ['gaga',
#   'daily',
#   'wouldve',
#   'love',
#   'today',
#   'plead',
#   'face',
#   'broken',
#   'heart'],
#  ['time', 'katycats', 'move', 'justiceforkatyperry'],
#  ['4', 'year', 'youre', 'still', 'brokie'],
#  ['reiterate',
#   'firm',
#   'call',
#   'immediate',
#   'ceasefire',
#   'gaza',
#   'strip',
#   'express',
#   'deep',
#   'sorrow',
#   'volunteer',
#   'kill',
#   'distribute',
#   'humanitarian',
#   'aid',
#   'gaza',
#   'pray',
#   'family'],
#  ['katy',
#   'perry',
#   'teenage',
#   'dream',
#   'album',
#   'cover',
#   'actually',
#   'painting'],
#  ['coneheads', 'join', 'cone', 'live', 'qa', 'star', 'black', 'heart'],
#  ['new', 'shakira', 'collaboration', 'way', 'xx'],
#  ['apple', 'explore', 'creation', 'home', 'robot', 'next', 'big', 'thing'],
#  ['say', 'house', 'gucci', 'best', 'poster'],
#  ['need', 'katys', 'documentary', 'happen', '2017', '2018'],
#  ['new',
#   'look',
#   'moana',
#   '2',
#   'set',
#   '3',
#   'year',
#   'first',
#   'movie',
#   'theater',
#   'november',
#   '27'],
#  ['taylor',
#   'swift',
#   'compete',
#   'travis',
#   'kelce',
#   '2024',
#   'webby',
#   'award',
#   'full',
#   'nomination',
#   'announce'],
#  ['two',
#   'margarita',
#   'deep',
#   'hear',
#   'song',
#   'playing',
#   'call',
#   'go',
#   'way',
#   'like',
#   'wow',
#   'really',
#   'sing',
#   'as',
#   'look',
#   'two',
#   'band',
#   'member',
#   'break',
#   'tear',
#   'go',
#   'way',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'watch',
#   'live',
#   'performance',
#   'cant',
#   'even',
#   'look'],
#  ['la',
#   'mujeres',
#   'ya',
#   'lloran',
#   'hit',
#   'number',
#   'one',
#   'top',
#   'latin',
#   'album',
#   'latin',
#   'pop',
# ...
#  ['soo'],
#  ['10',
#   'member',
#   'space',
#   'station',
#   'crew',
#   'work',
#   'cargo',
#   'spacesuit',
#   'human',
#   'research',
#   'tuesday',
#   'weekend',
#   'crew',
#   'departure',
#   'prep',
#   'continue'],
#  ['polaris',
#   'dawn',
#   'dragon',
#   'head',
#   'vacuum',
#   'chamber',
#   'test',
#   'spacex',
#   'team',
#   'celebrate',
#   'dragon',
#   "'s",
#   'departure',
#   'ahead',
#   'launch',
#   'orbit',
#   'summer'],
#  ['cast',
#   'real',
#   'housewife',
#   'potomac',
#   'gag',
#   'city',
#   'tonightrhopgagcitydc'],
#  ['kristen',
#   'wiigs',
#   'old',
#   'snl',
#   'dressing',
#   'room',
#   'get',
#   'completely',
#   'take',
#   'new',
#   'promo'],
#  ['soca',
#   'superstar',
#   'break',
#   'five',
#   'favorite',
#   'track',
#   'first',
#   'album',
#   '10',
#   'year',
#   'time',
#   'position',
#   'global',
#   'way'],
#  ['bassirou',
#   'diomaye',
#   'faye',
#   'senegal',
#   'election',
#   'offer',
#   'hope',
#   'frustrate',
#   'young',
#   'african'],
#  ['plenty',
#   'drama',
#   'ziggy',
#   'mackenzie',
#   'sol',
#   'enter',
#   'sing',
#   'americanidol'],
#  ['louis',
#   'conter',
#   'last',
#   'survivor',
#   'attack',
#   'pearl',
#   'harbor',
#   'ship',
#   'die',
#   'age',
#   '102'],
#  ['lizard',
#   'eliminate',
#   'sink',
#   'swim',
#   'experience',
#   'masked',
#   'singer',
#   'im',
#   'use',
#   'lose'],
#  ['least',
#   '29',
#   'people',
#   'confirm',
#   'die',
#   'fire',
#   'istanbul',
#   'nightclub',
#   'undergoing',
#   'renovation'],
#  ['20', 'best', 'travel', 'deal', 'help', 'get', 'away', 'budget'],
#  ['qgtm',
#   'history',
#   'fng',
#   'make',
#   'thank',
#   'million',
#   'time',
#   'trophy',
#   'gagcitydc',
#   'shall',
#   'go',
#   'gagcity',
#   'history',
#   'book'],
#  ['michelle',
#   'obama',
#   'praise',
#   'beyoncs',
#   'cowboy',
#   'carter',
#   'encourage',
#   'fan',
#   'register',
#   'vote',
#   'power'],
#  ['k',
#   'pop',
#   'star',
#   'karina',
#   'actor',
#   'lee',
#   'jae',
#   'wook',
#   'split',
#   'shortly',
#   'go',
#   'public'],
#  ['act',
#   'fast',
#   'ipad',
#   'pro',
#   'ipad',
#   'air',
#   'ipad',
#   'mini',
#   'sale',
#   'amazon',
#   'save',
#   '100'],
#  ['love',
#   'katy',
#   'perry',
#   'account',
#   'need',
#   'make',
#   'clear',
#   'press',
#   'event',
#   'private',
#   'preview',
#   'industry',
#   'people',
#   'wasnt',
#   'positive',
#   'reaction',
#   'batch',
#   'song',
#   'hear',
#   'album',
#   '100',
#   'percent',
#   'finish',
#   'katy',
#   'come',
#   'soon'],
#  ['ye',
#   'sue',
#   'another',
#   'former',
#   'donda',
#   'academy',
#   'staffer',
#   'allege',
#   'sexually',
#   'abusive',
#   'environment',
#   'billboardnews'],
#  ['break', 'bill', 'trade', 'wr', 'stefon', 'diggs', 'texan', 'per'],
#  ['adele',
#   'reschedules',
#   '2024',
#   'weekend',
#   'las',
#   'vega',
#   'residency',
#   'show',
#   'postpone',
#   'illness'],
#  ['sec', 'scene', 'add', 'teaser', 'trailer', 'could', 'make', 'faint'],
#  ['crawler',
#   'transporter',
#   '2',
#   'update',
#   'prepare',
#   'future',
#   'mission',
#   'right',
#   'arrow',
#   'curve'],
#  ['james', 'kirby', 'cousin', 'pay', 'tribute', "'selfless", 'hero', "'"],
#  ['magic',
#   'johnson',
#   'post',
#   'heartfelt',
#   'celebration',
#   'live',
#   'icon',
#   'beyoncs',
#   'cowboy',
#   'carter'],
#  ['jon',
#   'batiste',
#   'hop',
#   'work',
#   'beyoncs',
#   'cowboy',
#   'carter',
#   'help',
#   'dismantle',
#   'genre',
#   'machine'],
#  ['first',
#   'amendment',
#   'congress',
#   'shall',
#   'make',
#   'law',
#   'respect',
#   'establishment',
#   'religion',
#   'prohibit',
#   'free',
#   'exercise',
#   'thereof',
#   'abridge',
#   'freedom',
#   'speech',
#   'press',
#   'right',
#   'people',
#   'peaceably',
#   'assemble',
#   'petition',
#   'government',
#   'redress'],
#  ['bless', 'ft', 'wvw', 'pre', 'save', 'link'],
#  ['begin', 'star'],
#  ['first',
#   'poster',
#   'joker',
#   '2',
#   'star',
#   'joaquin',
#   'phoenix',
#   'lady',
#   'gaga'],
#  ['billie',
#   'piper',
#   'say',
#   'classmate',
#   'amy',
#   'winehouse',
#   'bully',
#   'school'],
#  ['slipknot',
#   'avenge',
#   'sevenfold',
#   'disturb',
#   'headline',
#   '2024',
#   'rocklahoma',
#   'festival'],
#  ['cash', 'cobain', 'speak', 'nyc', 'concert', 'cancel', 'reason', 'control'],
#  ['karol', 'g', 'latin', 'america', 'guest', 'maana', 'ser', 'bonito', 'tour'],
#  ['bizarrap',
#   'natanael',
#   'cano',
#   'drop',
#   'explosive',
#   'two',
#   'song',
#   'collaboration',
#   'bzrp',
#   'music',
#   'session',
#   '59',
#   'stream'],
#  ['shakira',
#   'surpasses',
#   'billie',
#   'eilish',
#   'become',
#   '21',
#   '1',
#   'artist',
#   'monthly',
#   'listener',
#   'spotify',
#   '8',
#   'female',
#   'artist',
#   'globe',
#   'show',
#   'america'],
#  ['two',
#   'investor',
#   'plead',
#   'guilty',
#   'insider',
#   'trading',
#   'scheme',
#   'link',
#   'trump',
#   'medium',
#   'deal',
#   'bring',
#   'former',
#   'president',
#   "'s",
#   'social',
#   'medium',
#   'business',
#   'public'],
#  ['strong',
#   'earthquake',
#   '25',
#   'year',
#   'rock',
#   'taiwan',
#   'tsunami',
#   'warning',
#   'issue',
#   'nearby',
#   'country'],
#  ['craig',
#   'gillespie',
#   'talk',
#   'direct',
#   'supergirl',
#   'previously',
#   'direct',
#   'cruella',
#   'tonya',
#   'source',
#   'deadline'],
#  ['trust',
#   'men',
#   'easily',
#   'afraid',
#   'loyalty',
#   'require',
#   'bravery',
#   'anyone',
#   'who',
#   'easily',
#   'scar',
#   'easily',
#   'turn',
#   'without',
#   'ball',
#   'sentiment',
#   'man',
#   'mean',
#   'absolutely',
#   'zero',
#   'soon',
#   'weak',
#   'man',
#   'suffer',
#   'person',
#   'loyal',
#   'loyalty',
#   'disappears'],
#  ['kai',
#   'medium',
#   'company',
#   'behind',
#   'k',
#   'pop',
#   'label',
#   'hello82',
#   'raise',
#   'funding',
#   'expansion'],
#  ['finland',
#   'shoot',
#   'several',
#   'injure',
#   'vantaa',
#   'school',
#   'shoot',
#   'police'],
#  ['ken',
#   'griffin',
#   'say',
#   'us',
#   "'irresponsible",
#   "'",
#   'national',
#   'debt',
#   'politician',
#   'spend',
#   "'at",
#   'expense',
#   'future',
#   'generation',
#   'per',
#   'fortune'],
#  ['china',
#   'taiwan',
#   '30',
#   'chinese',
#   'warplane',
#   '9',
#   'navy',
#   'vessel',
#   'position',
#   'around',
#   'taiwan',
#   'accord',
#   'taiwan',
#   "'s",
#   'defense',
#   'ministry',
#   'think',
#   'face'],
#  ['donald', 'trump', 'get', 'boo', 'mi', 'today', 'bring', 'joy', 'heart'],
#  ['feed',
#   'chairman',
#   'powell',
#   'finally',
#   'tell',
#   'truth',
#   'last',
#   'week',
#   'finally',
#   'admit',
#   'inflation',
#   'win',
#   'fed',
#   'longer',
#   'promise',
#   'flation',
#   '2',
#   'inflation',
#   'transitory',
#   'finally',
#   'stop',
#   'lie',
#   'congratulation',
#   'problem',
#   'people',
#   'idea'],
#  ['hedge',
#   'fund',
#   'billionaire',
#   'steve',
#   'cohen',
#   'tell',
#   'cnbc',
#   'own',
#   'little',
#   'amount',
#   'bitcoin',
#   'eye'],
#  ['fella', 'antismitic', 'think', 'aid', 'worker', 'shouldnt', 'airstriked'],
#  ['current',
#   'joker',
#   'folie',
#   'deux',
#   'box',
#   'office',
#   'prediction',
#   'predicted',
#   'worldwide',
#   'box',
#   'office',
#   '800m',
#   'film',
#   'would',
#   'currently',
#   '3rd',
#   'high',
#   'gross',
#   'r',
#   'rat',
#   'movie',
#   'time',
#   'behind',
#   'oppenheimer',
#   'original',
#   'joker'],
#  ['future', 'without', 'kid'],
#  ['recent',
#   'article',
#   'press',
#   "'winning",
#   "'",
#   'proxy',
#   'contest',
#   'nelson',
#   'peltz',
#   'base',
#   'early',
#   'election',
#   'return',
#   'leak',
#   'medium',
#   "n't",
#   'investment',
#   'disney',
#   'think',
#   'useful',
#   'point',
#   'inappropriateness'],
#  ['aileen',
#   'cannon',
#   'remove',
#   'case',
#   'long',
#   'time',
#   'ago',
#   'bullshit',
#   'ruling',
#   'blatantly',
#   'cause',
#   'delay',
#   'favor',
#   'defendant',
#   'trump',
#   "'s",
#   'fucking',
#   'joke'],
#  ['movie',
#   "'the",
#   'matrix',
#   "'",
#   'neo',
#   "'s",
#   'passport',
#   'expiration',
#   'date',
#   'set',
#   '9112001'],
#  ["'s", 'harleys', 'hawaii', 'surpass', '500', 'million', 'stream', 'spotify'],
#  ['x',
#   'premium',
#   'cost',
#   '23',
#   'cent',
#   'day',
#   'buy',
#   'annually',
#   'via',
#   'web',
#   'united',
#   'state',
#   'subscribe',
#   'x',
#   'premium',
#   'support',
#   'platform'],
#  ['anything', 'overrated', 'solar', 'eclipse', 'face', 'tear', 'joy'],
#  ['loral',
#   "o'hara",
#   'one',
#   'five',
#   'currently',
#   'station',
#   'return',
#   'earth',
#   'april',
#   '6',
#   'conduct',
#   'one',
#   'spacewalk',
#   'research',
#   'advanced',
#   'space',
#   'phenomenon',
#   'six',
#   'half',
#   'month',
#   'mission'],
#  ["'s",
#   '6',
#   'year',
#   'since',
#   'become',
#   'public',
#   'company',
#   'pretty',
#   'wild',
#   'think',
#   'metric',
#   'spotify',
#   '3x',
#   'day',
#   'remind',
#   'bill',
#   'gate',
#   'quote',
#   'people',
#   'overestimate',
#   'one',
#   'year',
#   'underestimate'],
#  ['2',
#   '1',
#   '8',
#   'band',
#   '2200',
#   '7300',
#   'spectral',
#   'region',
#   'photomultipler',
#   'tube',
#   'study',
#   'emission',
#   'intensity',
#   'data',
#   'information',
#   'surface',
#   'texture',
#   'composition',
#   'planet',
#   'could',
#   'obtain',
#   'along',
#   'w',
#   'information'],
#  ['joker',
#   '2',
#   'poster',
#   'see',
#   '14',
#   'million',
#   'time',
#   '10',
#   'hour',
#   'one',
#   'twitter',
#   'account',
#   'compare',
#   'major',
#   'release',
#   'first',
#   'poster',
#   'post',
#   'number',
#   'incredible'],
#  ['police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   '370000000',
#   'usdt',
#   '370047175',
#   'usd',
#   'transfer',
#   'tether',
#   'treasury',
#   'bitfinex'],
#  ['ftc',
#   'responds',
#   'esrb',
#   "'s",
#   'proposal',
#   'ai',
#   'power',
#   'face',
#   'scan',
#   "'age",
#   'estimation',
#   "'",
#   'system'],
#  ["n't",
#   'judge',
#   'cannon',
#   'rule',
#   'doj',
#   'reconsideration',
#   'motion',
#   'block',
#   'release',
#   'witness',
#   'list',
#   "'m",
#   'guess',
#   'know',
#   'release',
#   'smith',
#   'go',
#   '11th',
#   'circuit',
#   "'s",
#   'sit'],
#  ['evil'],
#  ["'s", 'go'],
#  ['update',
#   'samplingmars',
#   'recently',
#   'collect',
#   '24th',
#   'sample',
#   'area',
#   'call',
#   'bunsen',
#   'peak',
#   'name',
#   'landmark',
#   'rock',
#   'core',
#   'fill',
#   'silica',
#   'carbonate'],
#  ['knowledge', 'power', 'bitcoin'],
#  ['truly', 'mother', 'daughter'],
#  ['know', 'legacy', 'medium', 'notification'],
#  ['hunter',
#   'schafer',
#   'euphoria',
#   'star',
#   'say',
#   'longer',
#   'want',
#   'play',
#   'trans',
#   'character'],
#  ['perfection'],
#  ['wonder', 'loudly', 'cry', 'face'],
#  ['gagcitybaltimore'],
#  ['katy',
#   'perry',
#   'esquecida',
#   "'s",
#   'harleys',
#   'hawaii',
#   'surpass',
#   '500',
#   'million',
#   'stream',
#   'spotify',
#   "'s",
#   'never',
#   'really',
#   'certified',
#   'diamond',
#   'brazil',
#   'gente',
#   'que',
#   'fracassada',
#   '2',
#   'msicas',
#   'solo',
#   'ltimo',
#   'lbum',
#   'sendo',
#   'diamante',
#   'e',
#   '500m',
#   'de',
#   'streams',
#   'spotify'],
#  ['katy', 'perry', 'x', 'american', 'idol', 'brown', 'heart', 'sparkle'],
#  ['joker',
#   '2',
#   'trailer',
#   'really',
#   'come',
#   'break',
#   'internet',
#   'talk',
#   'hundred',
#   'million',
#   'view',
#   'across',
#   'platform',
#   'global',
#   'event'],
#  ['shakira',
#   'set',
#   'appear',
#   'hot',
#   'one',
#   'tomorrow',
#   'april',
#   '4',
#   'heart',
#   'fire'],
#  ['start',
#   'stan',
#   'twitter',
#   'start',
#   'concept',
#   'era',
#   'start',
#   'whole',
#   'mother',
#   'fanbase',
#   'relationship',
#   'like',
#   'im',
#   'serious'],
#  ['lavar',
#   'ball',
#   'blame',
#   'nba',
#   'training',
#   'staff',
#   'puma',
#   "'s",
#   "'raggedy",
#   "'",
#   'shoe',
#   'son',
#   "'",
#   'injury',
#   'reason',
#   'hurt',
#   'get',
#   'away',
#   'start',
#   'rooty',
#   'toot',
#   'workout',
#   'keep',
#   'run',
#   'hill',
#   "'re",
#   'go',
#   'keep',
#   'power'],
#  ['former',
#   'observer',
#   'huffpost',
#   'journalist',
#   'claim',
#   'katy',
#   'perrys',
#   'career',
#   'decline',
#   'plan',
#   'people',
#   'similar',
#   'christina',
#   'aguileras',
#   'career',
#   'sabotage',
#   'allege',
#   'writer',
#   'trash',
#   'katy',
#   'generate',
#   'click',
#   'money',
#   'last',
#   'year',
#   'former',
#   'pitchfork',
#   'writer',
#   'allege'],
#  ['lady', 'gaga', 'photograph', 'steven', 'klein'],
#  ['break',
#   'sec',
#   'request',
#   'public',
#   'comment',
#   'major',
#   'ethereum',
#   'spot',
#   'etf'],
#  ['btc',
#   'bitcoin',
#   'hold',
#   'weekly',
#   'range',
#   'low',
#   '65600',
#   'support',
#   'nowbtc',
#   'crypto',
#   'bitcoin'],
#  ['payment', 'option', 'think', 'add', 'tip', 'jar'],
#  ['harry', 'potter', 'say', 'loudly', 'cry', 'face'],
#  ['im',
#   'glad',
#   'gaga',
#   'keep',
#   'og',
#   'voice',
#   'nobody',
#   'want',
#   'hear',
#   'squeaky',
#   'as',
#   'exaggerated',
#   'voice'],
#  ['5',
#   'day',
#   'away',
#   'eclipse',
#   'check',
#   'eclipse',
#   'guide',
#   'link',
#   'bio',
#   'tip',
#   'see',
#   'remember',
#   'difference',
#   '99',
#   '100',
#   'one',
#   'literally',
#   'change',
#   'life',
#   'eclipse',
#   'saw',
#   '2017',
#   'ignite',
#   'passion',
#   'pursue',
#   'astrophotography'],
#  ['fan',
#   'select',
#   'country',
#   'watch',
#   'shakira',
#   "'s",
#   'video',
#   'spotify',
#   'go',
#   'stream'],
#  ['city',
#   'dominate',
#   'highway',
#   'car',
#   "'s",
#   'partly',
#   'one',
#   'influential',
#   'people',
#   "'ve",
#   'never',
#   'hear',
#   'norman',
#   'bel',
#   'geddes',
#   '1939',
#   'create',
#   'futurama',
#   'huge',
#   'exhibition',
#   'try',
#   'predict',
#   'future',
#   'end',
#   'change',
#   'world'],
#  ['break',
#   'coinbase',
#   'work',
#   'lightspark',
#   'integrate',
#   'bitcoin',
#   'lightning',
#   'network',
#   'customer',
#   'high',
#   'voltage'],
#  ['4', 'account', 'alone', 'nearly', '31', 'million', 'view', '24', 'hour'],
#  ['finally',
#   'restock',
#   'lady',
#   'gaga',
#   'fame',
#   'monster',
#   'picture',
#   'disc',
#   'include',
#   'friday',
#   'drop',
#   'well'],
#  ['break',
#   'guy',
#   'ram',
#   'car',
#   'fbi',
#   'field',
#   'office',
#   'atlanta',
#   'day',
#   'social',
#   'medium',
#   'account',
#   'associate',
#   'q',
#   'anon',
#   'anti',
#   'vaxx',
#   'stuff',
#   'election',
#   'denialism',
#   'sidney',
#   'powell',
#   'donald',
#   'trump',
#   'super',
#   'shock',
#   'source'],
#  ['spotify',
#   'top',
#   'song',
#   '0402',
#   'stream',
#   'hip',
#   "n't",
#   'lie',
#   '1138286',
#   'tqg',
#   '1038174',
#   'puntera',
#   '961461',
#   'entre',
#   'parntesis',
#   '846840',
#   'cohete',
#   '603393',
#   'bzrp',
#   'music',
#   'session',
#   'vol',
#   '53',
#   '570837',
#   'whenever',
#   'wherever',
#   '479768',
#   'chantaje',
#   '422502',
#   'la',
#   'tortura',
#   '408059',
#   'dia',
#   'de',
#   'enero',
#   '403425'],
#  ['tell', "'s", 'adult', 'content', 'threadz', 'instagram', 'onlyfans', 'eye'],
#  ['keityn',
#   'feid',
#   'carlos',
#   'vives',
#   'yng',
#   'lvcas',
#   'talk',
#   'major',
#   'win',
#   '2024',
#   'latin',
#   'ascap',
#   'award'],
#  ['anya',
#   'taylor',
#   'joy',
#   'confirm',
#   'secretly',
#   'get',
#   'marry',
#   'malcolm',
#   'mcrae',
#   '2022'],
#  ['tonight', 'tank', 'top', 'say', 'w', 'star', 'men', 'gutsworldtourboston'],
#  ['green',
#   'circle',
#   'facebook',
#   'red',
#   'circle',
#   'instagram',
#   'red',
#   'circle',
#   'whatsapp',
#   'red',
#   'circle'],
#  ['remember'],
#  ['united',
#   'state',
#   'blackrock',
#   'fidelity',
#   'combined',
#   '399741',
#   'btc',
#   'worth',
#   '262',
#   'billion',
#   'spot',
#   'bitcoin',
#   'etf'],
#  ['united',
#   'state',
#   'shakira',
#   'female',
#   'artist',
#   'song',
#   'currently',
#   'us',
#   'itunes',
#   'top',
#   '100',
#   'latin',
#   'song',
#   'total',
#   '8',
#   'song'],
#  ['shakira',
#   "'s",
#   'amazing',
#   '12th',
#   'studio',
#   'album',
#   "'las",
#   'mujeres',
#   'ya',
#   'lloran',
#   "'",
#   'score',
#   '3rd',
#   'high',
#   'new',
#   'entry',
#   'united',
#   'world',
#   'album',
#   'chart',
#   'land',
#   '6',
#   'flexed',
#   'biceps',
#   '3rd',
#   'place',
#   'medal',
#   'top',
#   'arrow',
#   'new',
#   'button',
#   'collision',
#   'keycap',
#   '6',
#   'globe',
#   'show',
#   'americas',
#   'chart',
#   'increase',
#   'crown',
#   'heart',
#   'fire',
#   "'las",
#   'mujeres',
#   'ya',
#   'lloran',
#   "'",
#   'feature',
#   'cardib',
#   'rauwalejandro',
#   'manuelturizo',
#   'grupofrontera',
#   'ozuna',
#   'karolg'],
#  ['news',
#   'tesla',
#   'overtook',
#   'mercedes',
#   'second',
#   'large',
#   'seller',
#   'imported',
#   'vehicle',
#   'korea',
#   'last',
#   'month',
#   'mark',
#   'first',
#   'time',
#   'tesla',
#   'beat',
#   'mercedes',
#   'benz',
#   'korea',
#   'term',
#   'sale'],
#  ['ultimate', 'guide', 'festival', 'celebrate', 'latin', 'music', '2024'],
#  ['lady', 'gaga', 'fucking', 'movie', 'star'],
#  ['te',
#   'har',
#   'salir',
#   'volando',
#   'como',
#   'un',
#   'cohete',
#   'rocket',
#   'collision',
#   'ill',
#   'make',
#   'fly',
#   'like',
#   'rocket',
#   'lmynl'],
#  ['youre',
#   'invite',
#   'see',
#   'rogueport',
#   'may',
#   '23',
#   'papermariothethousandyeardoor',
#   'come',
#   'nintendoswitch'],
#  ['alien', 'mother']]

# %%
result_bert = get_cleaned_tweets(texts, mode='bert')
result_bert
# Out:
# [['[CLS]',
#   'the',
#   '#',
#   'bin',
#   '##ance',
#   'towel',
#   'comes',
#   'everywhere',
#   'with',
#   'me',
#   '.',
#   '.',
#   '.',
#   'including',
#   'breakfast',
#   ':',
#   'cooking',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'drop',
#   'your',
#   '$',
#   'sol',
#   'address',
#   'below',
#   'and',
#   'make',
#   'sure',
#   'you',
#   'are',
#   'following',
#   'me',
#   'don',
#   '’',
#   't',
#   'ask',
#   'why',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   '_',
#   'medium',
#   '-',
#   'light',
#   '_',
#   'skin',
#   '_',
#   'tone',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'it',
#   'only',
#   'takes',
#   'one',
#   'good',
#   'alt',
#   '##co',
#   '##in',
#   'to',
#   'change',
#   'the',
#   'world',
#   '.',
#   ':',
#   'sparkle',
#   '##s',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'di',
#   '##sr',
#   '##es',
#   '##pe',
#   '##ct',
#   '##ful',
#   'is',
#   'one',
#   'of',
#   'my',
#   'top',
#   '3',
#   'favorite',
#   '[SEP]'],
#  ['[CLS]',
#   'some',
#   'congressional',
#   'republicans',
#   'call',
#   'the',
#   'affordable',
#   'connectivity',
#   'program',
#   'waste',
#   '##ful',
#   '.',
#   'i',
#   'call',
#   'it',
#   'necessary',
#   '.',
#   'it',
#   '’',
#   's',
#   'time',
#   'congress',
#   'extended',
#   'it',
#   'so',
#   'the',
#   '23',
#   'million',
#   'households',
#   'across',
#   'america',
#   'that',
#   'rely',
#   'on',
#   'the',
#   'program',
#   'can',
#   'stay',
#   'connected',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'donald',
#   'trump',
#   'won',
#   '’',
#   't',
#   'do',
#   'what',
#   'an',
#   'american',
#   'president',
#   'must',
#   'do',
#   '.',
#   'he',
#   'refuses',
#   'to',
#   'den',
#   '##oun',
#   '##ce',
#   'political',
#   'violence',
#   '.',
#   'i',
#   '’',
#   'll',
#   'say',
#   'what',
#   'trump',
#   'won',
#   '’',
#   't',
#   ':',
#   'political',
#   'violence',
#   'is',
#   'never',
#   ',',
#   'ever',
#   'acceptable',
#   'in',
#   'america',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'there',
#   'is',
#   'a',
#   'massive',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'breakout',
#   'coming',
#   '.',
#   'are',
#   'you',
#   'ready',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'ok',
#   'so',
#   'the',
#   'vote',
#   'is',
#   'in',
#   '.',
#   'i',
#   '’',
#   'll',
#   'do',
#   'a',
#   '25',
#   'ticket',
#   'give',
#   '##away',
#   'on',
#   'station',
#   'head',
#   'in',
#   '10',
#   'min',
#   '##s',
#   '.',
#   'if',
#   'i',
#   'feel',
#   'like',
#   'it',
#   'i',
#   '’',
#   'll',
#   'come',
#   'on',
#   'spaces',
#   '&',
#   'give',
#   'out',
#   'another',
#   '5',
#   '-',
#   '10',
#   'after',
#   'that',
#   '.',
#   'the',
#   'generous',
#   'queen',
#   ':',
#   'princess',
#   '_',
#   'medium',
#   '_',
#   'skin',
#   '_',
#   'tone',
#   ':',
#   '[SEP]'],
#  ['[CLS]', 'my', 'whole', 'heart', '[SEP]'],
#  ['[CLS]',
#   'i',
#   '’',
#   'm',
#   'tired',
#   'of',
#   'people',
#   'using',
#   'me',
#   'as',
#   'their',
#   'punching',
#   'bag',
#   '…',
#   'leave',
#   'me',
#   't',
#   '##f',
#   'alone',
#   '!',
#   '!',
#   'it',
#   '’',
#   's',
#   'my',
#   'day',
#   'off',
#   '[SEP]'],
#  ['[CLS]',
#   'april',
#   '03',
#   ',',
#   '202',
#   '##4',
#   '09',
#   ':',
#   '21',
#   'am',
#   '(',
#   'utc',
#   ')',
#   'current',
#   'price',
#   'of',
#   'bit',
#   '##co',
#   '##in',
#   '(',
#   'bt',
#   '##c',
#   '-',
#   'usd',
#   ')',
#   ':',
#   '$',
#   '66',
#   ',',
#   '48',
#   '##4',
#   '.',
#   '80',
#   '(',
#   'bt',
#   '##c',
#   '-',
#   'eu',
#   '##r',
#   ')',
#   ':',
#   '€',
#   '##6',
#   '##1',
#   ',',
#   '75',
#   '##7',
#   '.',
#   '73',
#   '[SEP]'],
#  ['[CLS]',
#   'how',
#   'is',
#   'pit',
#   '##bu',
#   '##ll',
#   'not',
#   'in',
#   'the',
#   'big',
#   '3',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   '$',
#   '35',
#   'a',
#   'month',
#   'insulin',
#   'for',
#   'seniors',
#   '.',
#   '$',
#   '35',
#   'in',
#   '##hale',
#   '##rs',
#   'for',
#   'asthma',
#   '.',
#   '$',
#   '2',
#   ',',
#   '000',
#   'a',
#   'year',
#   'cap',
#   'on',
#   'prescription',
#   'drugs',
#   'for',
#   'seniors',
#   'starting',
#   'next',
#   'year',
#   '.',
#   'with',
#   'senator',
#   'sanders',
#   "'",
#   'help',
#   ',',
#   'we',
#   '’',
#   're',
#   'showing',
#   'how',
#   'health',
#   'care',
#   'should',
#   'be',
#   'a',
#   'right',
#   '–',
#   'not',
#   'a',
#   'privilege',
#   '–',
#   'in',
#   'america',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'crypt', '##oo', '[SEP]'],
#  ['[CLS]',
#   'the',
#   'world',
#   'is',
#   'a',
#   'stage',
#   '.',
#   'joker',
#   ':',
#   'f',
#   '##oli',
#   '##e',
#   'a',
#   'deux',
#   'trailer',
#   'coming',
#   'april',
#   '9',
#   '.',
#   ':',
#   'joker',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'video',
#   'shows',
#   'abducted',
#   'us',
#   'girl',
#   'fatally',
#   'shot',
#   'by',
#   'police',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'best',
#   'braves',
#   '##t',
#   'bad',
#   '##des',
#   '##t',
#   'bar',
#   '##b',
#   '##z',
#   'win',
#   '[SEP]'],
#  ['[CLS]',
#   'bit',
#   '##co',
#   '##in',
#   'is',
#   'going',
#   'to',
#   '$',
#   '100',
#   ',',
#   '000',
#   'et',
#   '##h',
#   'is',
#   'going',
#   'to',
#   '$',
#   '10',
#   ',',
#   '000',
#   'alt',
#   '##co',
#   '##ins',
#   'will',
#   'pump',
#   '10',
#   '##x',
#   'hal',
#   '##ving',
#   'in',
#   '15',
#   'days',
#   '.',
#   'you',
#   'are',
#   'not',
#   'bull',
#   '##ish',
#   'enough',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'what', 'conan', 'lyric', 'feels', 'like', 'this', '[SEP]'],
#  ['[CLS]',
#   'the',
#   'more',
#   'te',
#   '##ther',
#   'prints',
#   ',',
#   'the',
#   'higher',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'goes',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'which',
#   'of',
#   'these',
#   'artists',
#   'is',
#   'the',
#   'biggest',
#   'hit',
#   '-',
#   'maker',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   ':',
#   'na',
#   '##vi',
#   '##gating',
#   'the',
#   'high',
#   'seas',
#   'of',
#   'finance',
#   ',',
#   'steering',
#   'the',
#   'ship',
#   'of',
#   'economic',
#   'evolution',
#   '.',
#   ':',
#   'sail',
#   '##boat',
#   ':',
#   ':',
#   'money',
#   '_',
#   'bag',
#   ':',
#   ':',
#   'water',
#   '_',
#   'wave',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'album',
#   'moments',
#   ':',
#   'cyclone',
#   ':',
#   'i',
#   'hear',
#   'you',
#   '…',
#   'feeling',
#   'optimistic',
#   'about',
#   'this',
#   'week',
#   '[SEP]'],
#  ['[CLS]',
#   'not',
#   'in',
#   'the',
#   'path',
#   'of',
#   'total',
#   '##ity',
#   'for',
#   'the',
#   'total',
#   'solar',
#   '#',
#   'eclipse',
#   '?',
#   'on',
#   'april',
#   '8',
#   ',',
#   'we',
#   "'",
#   'll',
#   'bring',
#   'total',
#   '##ity',
#   'to',
#   'you',
#   'by',
#   'broadcasting',
#   'from',
#   'several',
#   'locations',
#   'along',
#   'its',
#   'trajectory',
#   ',',
#   'including',
#   '—',
#   'our',
#   'only',
#   'center',
#   'in',
#   'the',
#   'eclipse',
#   '’',
#   's',
#   'path',
#   '.',
#   'how',
#   'to',
#   'watch',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'it',
#   "'",
#   's',
#   'a',
#   'tough',
#   'gig',
#   'being',
#   'the',
#   'bin',
#   '##ance',
#   'intern',
#   '.',
#   'good',
#   'morning',
#   '[SEP]'],
#  ['[CLS]',
#   'there',
#   'is',
#   'no',
#   'bigger',
#   'red',
#   'flag',
#   'in',
#   'an',
#   'adult',
#   'than',
#   'lack',
#   'of',
#   'children',
#   '.',
#   'if',
#   'you',
#   '’',
#   're',
#   '46',
#   'and',
#   'not',
#   'yet',
#   'bored',
#   'of',
#   'weed',
#   'and',
#   'alcohol',
#   '-',
#   'you',
#   '’',
#   're',
#   'immature',
#   'and',
#   'soul',
#   '##less',
#   '.',
#   'how',
#   'can',
#   'you',
#   'be',
#   'trusted',
#   'to',
#   'vote',
#   '?',
#   'you',
#   'have',
#   'a',
#   'warped',
#   'world',
#   'view',
#   'with',
#   'zero',
#   'vested',
#   'interest',
#   'in',
#   'the',
#   'future',
#   '.',
#   'the',
#   'poor',
#   '##est',
#   'people',
#   'alive',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   '1',
#   'whole',
#   'bit',
#   '##co',
#   '##in',
#   'ho',
#   '##dler',
#   '##s',
#   'are',
#   'becoming',
#   'rare',
#   '[SEP]'],
#  ['[CLS]',
#   'dog',
#   '##ec',
#   '##oin',
#   'as',
#   'tipping',
#   'option',
#   '?',
#   ':',
#   'eyes',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'introducing',
#   'a',
#   'new',
#   'simple',
#   'earn',
#   'flexible',
#   'products',
#   'promotion',
#   '!',
#   'sub',
#   '##scribe',
#   'to',
#   'either',
#   'sui',
#   'or',
#   'usd',
#   '##t',
#   'simple',
#   'earn',
#   'flexible',
#   'products',
#   'to',
#   'grab',
#   'your',
#   'share',
#   'of',
#   '20',
#   ',',
#   '000',
#   'sui',
#   'while',
#   'also',
#   'earning',
#   'bonus',
#   'apr',
#   '.',
#   'get',
#   'started',
#   'today',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   '_',
#   'curving',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   '$',
#   '69',
#   ',',
#   '41',
#   '##6',
#   '.',
#   '50',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   '#',
#   'bt',
#   '##c',
#   '$',
#   'bt',
#   '##c',
#   '$',
#   'usd',
#   '[SEP]'],
#  ['[CLS]',
#   'through',
#   'laws',
#   'i',
#   'wrote',
#   'and',
#   'signed',
#   ',',
#   'i',
#   'enacted',
#   'tax',
#   'credits',
#   'that',
#   'save',
#   'an',
#   'average',
#   'of',
#   '$',
#   '800',
#   'per',
#   'person',
#   'per',
#   'year',
#   ',',
#   'reducing',
#   'health',
#   'care',
#   'premium',
#   '##s',
#   'for',
#   'millions',
#   'of',
#   'families',
#   '.',
#   'those',
#   'credits',
#   'ex',
#   '##pire',
#   'next',
#   'year',
#   '.',
#   'congress',
#   ',',
#   'make',
#   'that',
#   '$',
#   '800',
#   'expanded',
#   'affordable',
#   'health',
#   'care',
#   'tax',
#   'credit',
#   'permanent',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'you',
#   'already',
#   'made',
#   'your',
#   'statement',
#   ',',
#   'donald',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'tag',
#   'a',
#   'light',
#   'mode',
#   'user',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'coin',
#   '##base',
#   '&',
#   'black',
#   '##rock',
#   'will',
#   'pump',
#   'crypt',
#   '##o',
#   'higher',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'pit',
#   '##bu',
#   '##ll',
#   ',',
#   'ching',
#   '##y',
#   ',',
#   'and',
#   'baby',
#   'bash',
#   '[SEP]'],
#  ['[CLS]',
#   'my',
#   'station',
#   'head',
#   'seems',
#   'to',
#   'not',
#   'be',
#   'working',
#   'guys',
#   '.',
#   'what',
#   'a',
#   'shock',
#   '##er',
#   '[SEP]'],
#  ['[CLS]',
#   'if',
#   'i',
#   'say',
#   'i',
#   '’',
#   'm',
#   '25',
#   'then',
#   'i',
#   '’',
#   'm',
#   '25',
#   'the',
#   'fu',
#   '##k',
#   '[SEP]'],
#  ['[CLS]', 'psalm', ':', 'camera', ':', 'by', 'saint', '[SEP]'],
#  ['[CLS]',
#   'the',
#   'next',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'hal',
#   '##ving',
#   'is',
#   'just',
#   '2',
#   'weeks',
#   'out',
#   '.',
#   'and',
#   'historically',
#   ',',
#   'the',
#   'most',
#   'gains',
#   'are',
#   'always',
#   'realized',
#   'after',
#   'the',
#   'hal',
#   '##ving',
#   '.',
#   'are',
#   'you',
#   'prepared',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'moment',
#   'taiwan',
#   'maternity',
#   'staff',
#   'rush',
#   'to',
#   'keep',
#   'babies',
#   'safe',
#   'during',
#   'earthquake',
#   '[SEP]'],
#  ['[CLS]',
#   '13',
#   ',',
#   '900',
#   'eggs',
#   '.',
#   '$',
#   '200',
#   ',',
#   '000',
#   'in',
#   'rewards',
#   '.',
#   '1',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   '.',
#   'get',
#   'started',
#   'with',
#   'the',
#   '#',
#   'bin',
#   '##ance',
#   'egg',
#   'drop',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'congratulations',
#   'to',
#   ',',
#   ',',
#   'and',
#   'for',
#   'being',
#   'selected',
#   'to',
#   'move',
#   'forward',
#   'in',
#   'developing',
#   'the',
#   '#',
#   'artemis',
#   'lunar',
#   'terrain',
#   'vehicle',
#   '!',
#   'this',
#   'moon',
#   'rover',
#   'will',
#   'allow',
#   'future',
#   'astronauts',
#   'to',
#   'travel',
#   'far',
#   'on',
#   'the',
#   'lunar',
#   'surface',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'am',
#   'outraged',
#   'and',
#   'heart',
#   '##broken',
#   'by',
#   'the',
#   'deaths',
#   'of',
#   'seven',
#   'humanitarian',
#   'workers',
#   'from',
#   'world',
#   'central',
#   'kitchen',
#   ',',
#   'including',
#   'one',
#   'american',
#   ',',
#   'in',
#   'gaza',
#   'yesterday',
#   '.',
#   'incidents',
#   'like',
#   'yesterday',
#   '’',
#   's',
#   'simply',
#   'should',
#   'not',
#   'happen',
#   '.',
#   'here',
#   'is',
#   'my',
#   'full',
#   'statement',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'is',
#   'a',
#   'symbol',
#   'of',
#   'digital',
#   'revolution',
#   'and',
#   'financial',
#   'freedom',
#   '.',
#   ':',
#   'light',
#   '_',
#   'bulb',
#   ':',
#   ':',
#   'globe',
#   '_',
#   'with',
#   '_',
#   'meridian',
#   '##s',
#   ':',
#   ':',
#   'money',
#   '_',
#   'with',
#   '_',
#   'wings',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'miss',
#   'shane',
#   '##l',
#   'does',
#   'what',
#   'must',
#   'be',
#   'done',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'is',
#   'whale',
#   'watching',
#   'on',
#   'your',
#   'bucket',
#   'list',
#   '?',
#   'if',
#   'so',
#   ',',
#   'you',
#   "'",
#   'll',
#   'be',
#   'glad',
#   'to',
#   'know',
#   'that',
#   'you',
#   'don',
#   "'",
#   't',
#   'have',
#   'to',
#   'travel',
#   'to',
#   'do',
#   'it',
#   '.',
#   'well',
#   ',',
#   'not',
#   'for',
#   'crypt',
#   '##o',
#   'whale',
#   'watching',
#   'anyway',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'want',
#   'honest',
#   'criticism',
#   'on',
#   'this',
#   'ai',
#   'portfolio',
#   ':',
#   '25',
#   '%',
#   '$',
#   'bt',
#   '##c',
#   '##15',
#   '%',
#   '$',
#   'tao',
#   '##15',
#   '%',
#   '$',
#   'rn',
#   '##dr',
#   '##10',
#   '%',
#   '$',
#   'gr',
#   '##t',
#   '##10',
#   '%',
#   '%',
#   '$',
#   'ak',
#   '##t',
#   '##5',
#   '%',
#   '$',
#   'ai',
#   '##t',
#   '##5',
#   '%',
#   '$',
#   'pa',
#   '##al',
#   '##5',
#   '%',
#   '[SEP]'],
#  ['[CLS]',
#   'are',
#   'you',
#   'still',
#   'with',
#   'me',
#   ',',
#   ':',
#   'argentina',
#   ':',
#   '?',
#   ':',
#   'star',
#   ':',
#   ':',
#   'star',
#   ':',
#   ':',
#   'star',
#   ':',
#   '#',
#   'guts',
#   '##world',
#   '##tour',
#   '[SEP]'],
#  ['[CLS]',
#   'kamal',
#   '##a',
#   'and',
#   'i',
#   'continue',
#   'to',
#   'call',
#   'on',
#   'congress',
#   'to',
#   'restore',
#   'the',
#   'protections',
#   'of',
#   'roe',
#   'in',
#   'every',
#   'state',
#   '.',
#   'the',
#   'majority',
#   'of',
#   'americans',
#   'support',
#   'a',
#   'woman',
#   "'",
#   's',
#   'right',
#   'to',
#   'choose',
#   '–',
#   'including',
#   'in',
#   'florida',
#   'where',
#   'voters',
#   'will',
#   'have',
#   'the',
#   'opportunity',
#   'to',
#   'support',
#   'a',
#   'reproductive',
#   'freedom',
#   'ballot',
#   'initiative',
#   'this',
#   'fall',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'category',
#   'is',
#   ':',
#   'albums',
#   'that',
#   'deserved',
#   'way',
#   'more',
#   'success',
#   '[SEP]'],
#  ['[CLS]',
#   'white',
#   'house',
#   'wants',
#   'moon',
#   'to',
#   'have',
#   'its',
#   'own',
#   'time',
#   'zone',
#   '[SEP]'],
#  ['[CLS]',
#   'introducing',
#   'the',
#   '#',
#   'bin',
#   '##ance',
#   '##cl',
#   '##ub',
#   '##house',
#   '!',
#   'a',
#   'global',
#   'hub',
#   'for',
#   'all',
#   'bin',
#   '##ance',
#   'users',
#   'to',
#   'connect',
#   ',',
#   'work',
#   ',',
#   'and',
#   'talk',
#   'all',
#   'things',
#   'crypt',
#   '##o',
#   '.',
#   'stay',
#   'tuned',
#   'for',
#   'more',
#   'info',
#   'to',
#   'come',
#   ':',
#   'hands',
#   '##hak',
#   '##e',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'yesterday',
#   '’',
#   's',
#   'extreme',
#   'florida',
#   'supreme',
#   'court',
#   'decision',
#   'puts',
#   'desperately',
#   'needed',
#   'medical',
#   'care',
#   'even',
#   'further',
#   'out',
#   'of',
#   'reach',
#   'for',
#   'millions',
#   'of',
#   'women',
#   'in',
#   'florida',
#   'and',
#   'across',
#   'the',
#   'south',
#   '.',
#   'it',
#   '’',
#   's',
#   'outrageous',
#   '—',
#   'and',
#   'it',
#   'was',
#   'made',
#   'possible',
#   'by',
#   'trump',
#   'ending',
#   'roe',
#   'v',
#   '.',
#   'wade',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '£5',
#   '##1',
#   ',',
#   '98',
#   '##7',
#   '.',
#   '06',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   '#',
#   'bt',
#   '##c',
#   '$',
#   'bt',
#   '##c',
#   '$',
#   'gb',
#   '##p',
#   '[SEP]'],
#  ['[CLS]',
#   'ready',
#   'to',
#   'rock',
#   'with',
#   'for',
#   'the',
#   'april',
#   '8',
#   '#',
#   'eclipse',
#   '?',
#   'submit',
#   'your',
#   'favorite',
#   'solar',
#   '-',
#   'themed',
#   'songs',
#   'to',
#   'be',
#   'added',
#   'to',
#   'a',
#   'sun',
#   ',',
#   'moon',
#   'and',
#   '"',
#   'eyes',
#   '"',
#   'play',
#   '##list',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'baby',
#   'steps',
#   ',',
#   'sir',
#   ':',
#   'weary',
#   '_',
#   'face',
#   ':',
#   ':',
#   'grinning',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'sweat',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   '.',
#   '’',
#   's',
#   '‘',
#   'in',
#   'search',
#   'of',
#   'the',
#   'anti',
#   '##dote',
#   '’',
#   'debuts',
#   'at',
#   'no',
#   '.',
#   '3',
#   'on',
#   'top',
#   'album',
#   'sales',
#   'chart',
#   '[SEP]'],
#  ['[CLS]',
#   'only',
#   '3',
#   'more',
#   'sleeps',
#   'till',
#   '#',
#   'wrestlemania',
#   '40',
#   '.',
#   'talking',
#   'to',
#   'and',
#   'on',
#   'the',
#   'show',
#   'tonight',
#   '.',
#   '#',
#   'final',
#   '##bos',
#   '##s',
#   '#',
#   'tribal',
#   '##chi',
#   '##ef',
#   '[SEP]'],
#  ['[CLS]',
#   'one',
#   '#',
#   'crypt',
#   '##o',
#   'that',
#   'will',
#   'show',
#   'a',
#   'monster',
#   'god',
#   'candle',
#   'this',
#   'summer',
#   '[SEP]'],
#  ['[CLS]',
#   'deadly',
#   'air',
#   'strike',
#   'shows',
#   'system',
#   'to',
#   'protect',
#   'aid',
#   'workers',
#   'in',
#   'crisis',
#   ',',
#   'agencies',
#   'say',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bin',
#   '##ance',
#   'will',
#   'list',
#   'worm',
#   '##hole',
#   '$',
#   'w',
#   'with',
#   'seed',
#   'tag',
#   'applied',
#   '.',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'happy',
#   '90',
#   '##th',
#   'birthday',
#   '!',
#   'and',
#   'please',
#   'give',
#   'my',
#   'regards',
#   'to',
#   'mr',
#   '.',
#   'h',
#   '.',
#   '#',
#   'jane',
#   '##at',
#   '##90',
#   '#',
#   'good',
#   '##all',
#   '##day',
#   '[SEP]'],
#  ['[CLS]',
#   'gaza',
#   'aid',
#   'convoy',
#   'strike',
#   ':',
#   'what',
#   'do',
#   'we',
#   'know',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'thank',
#   'you',
#   'ny',
#   'for',
#   'a',
#   'night',
#   'to',
#   'remember',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'watch',
#   'tomorrow',
#   'x',
#   'together',
#   'bring',
#   '‘',
#   'de',
#   '##ja',
#   'vu',
#   '’',
#   'to',
#   '‘',
#   'kelly',
#   'clarkson',
#   'show',
#   '’',
#   '[SEP]'],
#  ['[CLS]',
#   'it',
#   '’',
#   's',
#   'not',
#   'that',
#   'no',
#   'one',
#   'told',
#   'you',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'if',
#   'the',
#   'prior',
#   'administration',
#   'and',
#   'extreme',
#   'republicans',
#   'in',
#   'congress',
#   'had',
#   'succeeded',
#   'in',
#   'gut',
#   '##ting',
#   'the',
#   'ac',
#   '##a',
#   ',',
#   '45',
#   'million',
#   'people',
#   'nationwide',
#   'would',
#   'have',
#   'lost',
#   'their',
#   'health',
#   'insurance',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'hello', '##o', 'have', 'we', 'ever', 'seen', 'this', '?', '[SEP]'],
#  ['[CLS]',
#   'which',
#   'album',
#   'is',
#   'making',
#   'more',
#   'noise',
#   'this',
#   'friday',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'bar',
#   '##b',
#   '##z',
#   'since',
#   'ya',
#   '##ll',
#   'like',
#   'ya',
#   '##ppy',
#   '##ity',
#   'ya',
#   '##pping',
#   'i',
#   'took',
#   'screens',
#   '##hot',
#   '##s',
#   'of',
#   'who',
#   'been',
#   'on',
#   'here',
#   '.',
#   'ya',
#   '##ll',
#   'ass',
#   '##es',
#   'report',
#   'to',
#   'station',
#   'head',
#   'i',
#   '’',
#   'm',
#   'doing',
#   'a',
#   '#',
#   'gag',
#   '##city',
#   'give',
#   '##away',
#   'right',
#   'now',
#   '.',
#   'in',
#   '10',
#   'min',
#   '##s',
#   '.',
#   'who',
#   'wanna',
#   'win',
#   'tickets',
#   '?',
#   '!',
#   '?',
#   '!',
#   '!',
#   '!',
#   ':',
#   'ticket',
#   ':',
#   ':',
#   'admission',
#   '_',
#   'tickets',
#   ':',
#   'let',
#   '’',
#   's',
#   'go',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'should',
#   'i',
#   'give',
#   'away',
#   '50',
#   'tickets',
#   'or',
#   '25',
#   'winners',
#   'get',
#   'a',
#   'plus',
#   '1',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'so',
#   'about',
#   'the',
#   'cake',
#   '!',
#   'do',
#   'we',
#   'think',
#   'conan',
#   'would',
#   'be',
#   'proud',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'hearts',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'remember',
#   'this',
#   '.',
#   'i',
#   'remember',
#   'him',
#   'withdrawing',
#   'me',
#   'from',
#   'the',
#   'tournament',
#   'when',
#   'i',
#   'was',
#   '6',
#   'years',
#   'old',
#   '.',
#   'i',
#   'beat',
#   'the',
#   'first',
#   'two',
#   'adults',
#   ',',
#   'then',
#   'lost',
#   '3',
#   'in',
#   'a',
#   'row',
#   '.',
#   'i',
#   'asked',
#   ':',
#   'will',
#   'i',
#   'be',
#   'able',
#   'to',
#   'beat',
#   'them',
#   'at',
#   'chess',
#   'when',
#   'im',
#   'grown',
#   'up',
#   '?',
#   'he',
#   'replied',
#   ':',
#   'son',
#   ',',
#   'once',
#   'your',
#   '##e',
#   'grown',
#   'up',
#   ',',
#   'you',
#   '##ll',
#   'beat',
#   'anyone',
#   'at',
#   'anything',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'hal',
#   '##ving',
#   'is',
#   'now',
#   'only',
#   'about',
#   '17',
#   'days',
#   'away',
#   ':',
#   'eyes',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'all',
#   'eyes',
#   'are',
#   'on',
#   'the',
#   'sky',
#   'on',
#   'april',
#   '8',
#   'for',
#   'the',
#   'total',
#   'solar',
#   '#',
#   'eclipse',
#   '!',
#   'did',
#   'you',
#   'know',
#   'you',
#   'can',
#   'help',
#   'us',
#   'while',
#   'experiencing',
#   'the',
#   'big',
#   'event',
#   '?',
#   'listen',
#   'in',
#   'from',
#   'scientists',
#   'in',
#   'this',
#   'episode',
#   'of',
#   'our',
#   'curious',
#   'universe',
#   'podcast',
#   ':',
#   '[SEP]'],
#  ['[CLS]', 'r', '.', 'i', '.', 'p', '.', 'gale', 'sparrow', '.', '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'will',
#   'hit',
#   '$',
#   '100',
#   ',',
#   '000',
#   'in',
#   'next',
#   '3',
#   'months',
#   'or',
#   'i',
#   'am',
#   'del',
#   '##eti',
#   '##ng',
#   'my',
#   '"',
#   'x',
#   '"',
#   'account',
#   '[SEP]'],
#  ['[CLS]',
#   'trading',
#   'is',
#   'now',
#   'live',
#   'for',
#   '$',
#   'en',
#   '##a',
#   'on',
#   '#',
#   'bin',
#   '##ance',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   've',
#   '##chai',
#   '##n',
#   '’',
#   's',
#   'importance',
#   'isn',
#   '’',
#   't',
#   'talked',
#   'about',
#   'enough',
#   '.',
#   '$',
#   'vet',
#   '[SEP]'],
#  ['[CLS]',
#   'in',
#   '##hale',
#   '##rs',
#   'cost',
#   'less',
#   'than',
#   '$',
#   '5',
#   'to',
#   'make',
#   '.',
#   'but',
#   'drug',
#   'companies',
#   'charge',
#   'americans',
#   'up',
#   'to',
#   '$',
#   '600',
#   'to',
#   'increase',
#   'their',
#   'profits',
#   '.',
#   'my',
#   'administration',
#   'has',
#   'been',
#   'cracking',
#   'down',
#   'on',
#   'big',
#   'ph',
#   '##arm',
#   '##a',
#   '–',
#   'and',
#   'now',
#   ',',
#   'three',
#   'of',
#   'the',
#   'four',
#   'largest',
#   'in',
#   '##hale',
#   '##r',
#   'manufacturers',
#   'are',
#   'cap',
#   '##ping',
#   'out',
#   '-',
#   'of',
#   '-',
#   'pocket',
#   'costs',
#   'at',
#   '$',
#   '35',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'category',
#   'is',
#   ':',
#   'most',
#   'controversial',
#   'music',
#   'videos',
#   '[SEP]'],
#  ['[CLS]',
#   'polls',
#   'are',
#   'opening',
#   'up',
#   'in',
#   'states',
#   'across',
#   'the',
#   'country',
#   '.',
#   'head',
#   'to',
#   'to',
#   'confirm',
#   'your',
#   'polling',
#   'place',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'final',
#   'deadline',
#   'for',
#   '7',
#   'spot',
#   '#',
#   'ether',
#   '##eum',
#   'et',
#   '##fs',
#   'is',
#   'in',
#   '50',
#   'days',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'can',
#   'you',
#   'guys',
#   'give',
#   'me',
#   'a',
#   'run',
#   '##down',
#   'on',
#   'everything',
#   'he',
#   'said',
#   'about',
#   'the',
#   'unreleased',
#   'tracks',
#   '[SEP]'],
#  ['[CLS]',
#   'google',
#   'looks',
#   'to',
#   'ai',
#   'pay',
#   '##wall',
#   'option',
#   '-',
#   'report',
#   '[SEP]'],
#  ['[CLS]',
#   'solar',
#   'eclipse',
#   '202',
#   '##4',
#   ':',
#   'how',
#   'to',
#   'watch',
#   '&',
#   'stream',
#   'live',
#   'from',
#   'anywhere',
#   '[SEP]'],
#  ['[CLS]',
#   'gag',
#   '##city',
#   'was',
#   'everything',
#   '!',
#   '!',
#   '!',
#   'nick',
#   '##i',
#   ',',
#   'monica',
#   ',',
#   'and',
#   '50',
#   'cent',
#   'did',
#   'what',
#   'needed',
#   'to',
#   'be',
#   'done',
#   '!',
#   '!',
#   '!',
#   ':',
#   'two',
#   '_',
#   'hearts',
#   ':',
#   '#',
#   'gag',
#   '##city',
#   '##dc',
#   '[SEP]'],
#  ['[CLS]',
#   'live',
#   'now',
#   ':',
#   'how',
#   'will',
#   'future',
#   'astronauts',
#   'drive',
#   'across',
#   'the',
#   'surface',
#   'of',
#   'the',
#   'moon',
#   '?',
#   'we',
#   "'",
#   're',
#   'announcing',
#   'the',
#   'companies',
#   'that',
#   'will',
#   'advance',
#   'the',
#   'capabilities',
#   'of',
#   'the',
#   'lunar',
#   'terrain',
#   'vehicle',
#   ',',
#   'a',
#   'rover',
#   'for',
#   'exploration',
#   'during',
#   'the',
#   '#',
#   'artemis',
#   'v',
#   'missions',
#   'and',
#   'beyond',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'time',
#   'to',
#   'supply',
#   'you',
#   'with',
#   'some',
#   'crypt',
#   '##o',
#   'knowledge',
#   '.',
#   'literally',
#   '.',
#   'maximum',
#   ',',
#   'total',
#   ',',
#   'and',
#   'circulating',
#   'supply',
#   'explained',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'for',
#   'anyone',
#   'who',
#   'received',
#   'a',
#   'check',
#   '##mark',
#   'today',
#   ',',
#   'you',
#   'can',
#   'earn',
#   'money',
#   'for',
#   'the',
#   'stuff',
#   'you',
#   "'",
#   're',
#   'already',
#   'posting',
#   '.',
#   'no',
#   'extra',
#   'effort',
#   'required',
#   '.',
#   'apply',
#   'to',
#   'be',
#   'mon',
#   '##eti',
#   '##zed',
#   'in',
#   'settings',
#   '>',
#   'mon',
#   '##eti',
#   '##zation',
#   '[SEP]'],
#  ['[CLS]',
#   'explore',
#   'new',
#   'take',
#   '##r',
#   'fee',
#   'promotions',
#   'on',
#   '#',
#   'bin',
#   '##ance',
#   '!',
#   'you',
#   'can',
#   'now',
#   'trade',
#   '$',
#   'usd',
#   '##c',
#   'spot',
#   'and',
#   'margin',
#   'trading',
#   'pairs',
#   'to',
#   'enjoy',
#   'discount',
#   '##ed',
#   'take',
#   '##r',
#   'fees',
#   'from',
#   '10',
#   'april',
#   ',',
#   '202',
#   '##4',
#   '.',
#   'learn',
#   'more',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   '_',
#   'curving',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'tune',
#   'in',
#   'as',
#   'i',
#   'deliver',
#   'remarks',
#   'on',
#   'lowering',
#   'health',
#   'care',
#   'costs',
#   'for',
#   'americans',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'oh', 'this', 'is', 'extremely', 'gag', '##gy', 'babe', '[SEP]'],
#  ['[CLS]', 'like', 'what', '?', '[SEP]'],
#  ['[CLS]',
#   'truck',
#   'crash',
#   'spill',
#   '##s',
#   'live',
#   'salmon',
#   'into',
#   'wrong',
#   'oregon',
#   'river',
#   '[SEP]'],
#  ['[CLS]',
#   'celebrate',
#   'the',
#   'upcoming',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'hal',
#   '##ving',
#   'with',
#   'the',
#   '#',
#   'bin',
#   '##ance',
#   'futures',
#   'ultimate',
#   'challenge',
#   '.',
#   'join',
#   'the',
#   'daily',
#   'price',
#   'prediction',
#   'and',
#   'weekly',
#   'task',
#   'challenges',
#   'for',
#   'a',
#   'chance',
#   'to',
#   'win',
#   '#',
#   'bt',
#   '##c',
#   'rewards',
#   'and',
#   'a',
#   'tesla',
#   'model',
#   'y',
#   '!',
#   'join',
#   'now',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   'breaking',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   'gray',
#   '##sca',
#   '##le',
#   'has',
#   'transferred',
#   '1983',
#   'bt',
#   '##c',
#   'worth',
#   '$',
#   '131',
#   '.',
#   '4',
#   'million',
#   'to',
#   'coin',
#   '##base',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'always',
#   'pumps',
#   'after',
#   'the',
#   'hal',
#   '##ving',
#   '.',
#   '-',
#   '1st',
#   'hal',
#   '##ving',
#   ':',
#   '+',
#   '8',
#   ',',
#   '000',
#   '%',
#   '-',
#   '2nd',
#   'hal',
#   '##ving',
#   ':',
#   '+',
#   '3',
#   ',',
#   '000',
#   '%',
#   '-',
#   '3rd',
#   'hal',
#   '##ving',
#   ':',
#   '+',
#   '800',
#   '%',
#   'in',
#   '15',
#   'days',
#   ',',
#   'the',
#   '4th',
#   'hal',
#   '##ving',
#   'is',
#   'here',
#   '.',
#   'are',
#   'you',
#   'mentally',
#   'prepared',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'today',
#   ',',
#   'i',
#   'had',
#   'a',
#   'candi',
#   '##d',
#   'conversation',
#   'with',
#   'president',
#   'xi',
#   'jin',
#   '##ping',
#   'of',
#   'the',
#   'people',
#   '’',
#   's',
#   'republic',
#   'of',
#   'china',
#   'on',
#   'a',
#   'range',
#   'of',
#   'issues',
#   ',',
#   'including',
#   'areas',
#   'of',
#   'cooperation',
#   'and',
#   'areas',
#   'of',
#   'difference',
#   '.',
#   'i',
#   'emphasized',
#   'the',
#   'importance',
#   'of',
#   'maintaining',
#   'peace',
#   'and',
#   'stability',
#   'across',
#   'the',
#   'taiwan',
#   'strait',
#   'and',
#   'in',
#   'the',
#   'south',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'same',
#   'reason',
#   'why',
#   'you',
#   'felt',
#   'comfortable',
#   'calling',
#   'me',
#   'a',
#   'mexican',
#   'when',
#   'i',
#   '’',
#   'm',
#   'dominican',
#   'and',
#   'i',
#   'asked',
#   'you',
#   'why',
#   'you',
#   'feel',
#   'comfortable',
#   'calling',
#   'me',
#   'a',
#   'mexican',
#   'when',
#   'ice',
#   'and',
#   'j',
#   '##har',
#   '##ell',
#   'jerome',
#   'zoe',
#   'sal',
#   '##dana',
#   'are',
#   'dominican',
#   '##s',
#   'and',
#   'you',
#   'don',
#   '’',
#   't',
#   'do',
#   'that',
#   'to',
#   'them',
#   '.',
#   'you',
#   'do',
#   'it',
#   'to',
#   'me',
#   'because',
#   'you',
#   'know',
#   'that',
#   '’',
#   's',
#   'what',
#   'people',
#   'use',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'gag',
#   '##city',
#   '##bal',
#   '##ti',
#   '##more',
#   'is',
#   'taking',
#   'it',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'd',
#   '##m',
#   '##v',
#   'i',
#   'missed',
#   'you',
#   '##u',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'ya',
#   '##ll',
#   'don',
#   '##t',
#   'know',
#   'man',
#   '.',
#   ':',
#   'weary',
#   '_',
#   'face',
#   ':',
#   ':',
#   'flying',
#   '_',
#   'sauce',
#   '##r',
#   ':',
#   ':',
#   'city',
#   '##sca',
#   '##pe',
#   ':',
#   'thank',
#   'you',
#   '.',
#   'id',
#   '##k',
#   'what',
#   'to',
#   'say',
#   '.',
#   'the',
#   'best',
#   'night',
#   'i',
#   '’',
#   've',
#   'ever',
#   'had',
#   'on',
#   'earth',
#   'and',
#   '#',
#   'gag',
#   '##city',
#   '.',
#   'may',
#   'god',
#   'bless',
#   'each',
#   '&',
#   'every',
#   'one',
#   'of',
#   'you',
#   '.',
#   'i',
#   '’',
#   'll',
#   'never',
#   'forget',
#   'you',
#   '.',
#   '#',
#   'heavy',
#   '##oni',
#   '##t',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bin',
#   '##ance',
#   'respectful',
#   '##ly',
#   'requests',
#   'that',
#   'ti',
#   '##gra',
#   '##n',
#   'ga',
#   '##mba',
#   '##rya',
#   '##n',
#   ',',
#   'who',
#   'has',
#   'no',
#   'decision',
#   '-',
#   'making',
#   'power',
#   'in',
#   'the',
#   'company',
#   ',',
#   'is',
#   'not',
#   'held',
#   'responsible',
#   'while',
#   'current',
#   'discussions',
#   'are',
#   'ongoing',
#   'between',
#   'bin',
#   '##ance',
#   'and',
#   'nigerian',
#   'government',
#   'officials',
#   '.',
#   '#',
#   'bring',
#   '##ti',
#   '##gra',
#   '##nh',
#   '##ome',
#   '##rea',
#   '##d',
#   'more',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'after',
#   '204',
#   'days',
#   ',',
#   '3',
#   ',',
#   '264',
#   'orbits',
#   ',',
#   'and',
#   'dozens',
#   'of',
#   'experiments',
#   'in',
#   'space',
#   ',',
#   'is',
#   'heading',
#   'home',
#   '.',
#   'undo',
#   '##cking',
#   'and',
#   'return',
#   'coverage',
#   '(',
#   'on',
#   'nasa',
#   '+',
#   'and',
#   'other',
#   'platforms',
#   ')',
#   'begins',
#   'at',
#   '8',
#   '##pm',
#   'et',
#   ',',
#   'friday',
#   ',',
#   'april',
#   '5',
#   '(',
#   '000',
#   '##0',
#   'utc',
#   'april',
#   '6',
#   ')',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'don',
#   "'",
#   't',
#   'buy',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'for',
#   'your',
#   'first',
#   'name',
#   '.',
#   'buy',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'for',
#   'your',
#   'last',
#   'name',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'billie',
#   'e',
#   '##ilis',
#   '##h',
#   ',',
#   'pearl',
#   'jam',
#   ',',
#   'nick',
#   '##i',
#   'mina',
#   '##j',
#   'among',
#   '200',
#   'artists',
#   'calling',
#   'for',
#   'responsible',
#   'ai',
#   'music',
#   'practices',
#   '[SEP]'],
#  ['[CLS]',
#   'school',
#   'shooting',
#   'brings',
#   'up',
#   'tough',
#   'questions',
#   'for',
#   'finland',
#   '[SEP]'],
#  ['[CLS]',
#   'instead',
#   'of',
#   'seniors',
#   'with',
#   'diabetes',
#   'paying',
#   'as',
#   'much',
#   'as',
#   '$',
#   '400',
#   'a',
#   'month',
#   'for',
#   'their',
#   'insulin',
#   'they',
#   'so',
#   'badly',
#   'need',
#   ',',
#   'they',
#   'now',
#   'only',
#   'have',
#   'to',
#   'pay',
#   '$',
#   '35',
#   'a',
#   'month',
#   '.',
#   'period',
#   '.',
#   'i',
#   'want',
#   'to',
#   'extend',
#   'those',
#   'savings',
#   'to',
#   'everyone',
#   'who',
#   'needs',
#   'life',
#   '##sa',
#   '##ving',
#   'insulin',
#   ',',
#   'whether',
#   'you',
#   '’',
#   're',
#   'a',
#   'senior',
#   'or',
#   'not',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'trade',
#   'res',
#   '##pon',
#   '##si',
#   '##bly',
#   '.',
#   'employing',
#   'risk',
#   'management',
#   'strategies',
#   'is',
#   'an',
#   'important',
#   'step',
#   'to',
#   'reducing',
#   'your',
#   'portfolio',
#   "'",
#   's',
#   'risk',
#   '.',
#   'so',
#   'we',
#   "'",
#   've',
#   'listed',
#   'out',
#   '5',
#   'strategies',
#   ',',
#   'which',
#   'you',
#   'can',
#   'find',
#   'right',
#   'here',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bin',
#   '##ance',
#   'has',
#   'expanded',
#   'portfolio',
#   'margin',
#   'to',
#   'non',
#   '-',
#   'vip',
#   'users',
#   '!',
#   'opt',
#   '##imi',
#   '##se',
#   'your',
#   'portfolio',
#   'with',
#   'enhanced',
#   'capital',
#   'efficiency',
#   ',',
#   'risk',
#   'management',
#   ',',
#   'and',
#   'trading',
#   'strategies',
#   'made',
#   'more',
#   'accessible',
#   '.',
#   'learn',
#   'more',
#   ':',
#   'back',
#   '##hand',
#   '_',
#   'index',
#   '_',
#   'pointing',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   ':',
#   'collision',
#   ':',
#   'breaking',
#   ':',
#   'the',
#   'spot',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'et',
#   '##f',
#   'had',
#   'positive',
#   'in',
#   '##flow',
#   'of',
#   ':',
#   '+',
#   '$',
#   '40',
#   ',',
#   '300',
#   ',',
#   '000',
#   'yesterday',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bin',
#   '##ance',
#   'charity',
#   'partners',
#   'with',
#   'the',
#   'children',
#   'of',
#   'heroes',
#   'foundation',
#   '!',
#   'this',
#   'collaboration',
#   'will',
#   'launch',
#   '“',
#   'i',
#   'am',
#   'da',
#   'vinci',
#   '”',
#   ',',
#   'a',
#   '12',
#   '-',
#   'day',
#   'therapeutic',
#   'camp',
#   ',',
#   'to',
#   'support',
#   'children',
#   'who',
#   'have',
#   'lost',
#   'their',
#   'parents',
#   'in',
#   'the',
#   'war',
#   '.',
#   'read',
#   'more',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   '_',
#   'curving',
#   '_',
#   'down',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'florida',
#   '’',
#   's',
#   'ban',
#   '##s',
#   '–',
#   'and',
#   'laws',
#   'like',
#   'them',
#   'in',
#   'states',
#   'across',
#   'america',
#   '–',
#   'are',
#   'putting',
#   'the',
#   'health',
#   'and',
#   'lives',
#   'of',
#   'millions',
#   'of',
#   'women',
#   'at',
#   'risk',
#   '.',
#   'they',
#   'take',
#   'away',
#   'women',
#   '’',
#   's',
#   'freedom',
#   'to',
#   'make',
#   'their',
#   'own',
#   'health',
#   'care',
#   'decisions',
#   'and',
#   'threaten',
#   'physicians',
#   'for',
#   'providing',
#   'the',
#   'care',
#   'they',
#   'were',
#   'trained',
#   'to',
#   'provide',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'don',
#   "'",
#   't',
#   'panic',
#   ':',
#   'sal',
#   '##uting',
#   '_',
#   'face',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'we',
#   "'",
#   've',
#   'officially',
#   'hit',
#   '1',
#   '##m',
#   'posts',
#   'on',
#   '#',
#   'bin',
#   '##ance',
#   'square',
#   '!',
#   'thank',
#   'you',
#   'for',
#   'sharing',
#   'content',
#   'on',
#   'your',
#   'feeds',
#   ',',
#   'and',
#   'spreading',
#   'crypt',
#   '##o',
#   'knowledge',
#   'worldwide',
#   ':',
#   'hands',
#   '##hak',
#   '##e',
#   ':',
#   'keep',
#   'building',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'that',
#   '’',
#   's',
#   'not',
#   'what',
#   'you',
#   'said',
#   '.',
#   'you',
#   'said',
#   'nobody',
#   'called',
#   'me',
#   'ghetto',
#   'and',
#   'now',
#   'you',
#   'moving',
#   'the',
#   'goal',
#   'post',
#   '…',
#   'you',
#   'know',
#   'why',
#   'i',
#   '’',
#   'm',
#   'at',
#   'where',
#   'i',
#   '’',
#   'm',
#   'at',
#   'right',
#   'now',
#   '?',
#   'because',
#   'i',
#   'took',
#   'all',
#   'those',
#   'no',
#   '’',
#   's',
#   'and',
#   'recognized',
#   'what',
#   'i',
#   'had',
#   'to',
#   'change',
#   '.',
#   'i',
#   'had',
#   'to',
#   'change',
#   'the',
#   'way',
#   'i',
#   'talk',
#   ',',
#   'the',
#   'way',
#   'i',
#   'act',
#   'and',
#   'the',
#   'way',
#   'i',
#   'respond',
#   'and',
#   'how',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'honestly',
#   'a',
#   'great',
#   'product',
#   '!',
#   'feel',
#   'more',
#   'en',
#   '##er',
#   '##gi',
#   '##zed',
#   'and',
#   'stronger',
#   'ever',
#   'since',
#   'i',
#   '’',
#   've',
#   'taken',
#   'it',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'liz',
#   '##zo',
#   'cl',
#   '##ari',
#   '##fies',
#   'she',
#   'is',
#   'not',
#   'quit',
#   '##ting',
#   'music',
#   'industry',
#   ',',
#   'just',
#   "'",
#   'negative',
#   'energy',
#   "'",
#   '[SEP]'],
#  ['[CLS]',
#   'olivia',
#   'rodrigo',
#   'kisses',
#   'cha',
#   '##ppel',
#   '##l',
#   'ro',
#   '##an',
#   'during',
#   'guts',
#   'world',
#   'tour',
#   '’',
#   's',
#   'boston',
#   'stop',
#   '[SEP]'],
#  ['[CLS]',
#   'yesterday',
#   ',',
#   'florida',
#   '’',
#   's',
#   'supreme',
#   'court',
#   'upheld',
#   'a',
#   'state',
#   'abortion',
#   'ban',
#   ',',
#   'likely',
#   'triggering',
#   'the',
#   'governor',
#   "'",
#   's',
#   'more',
#   'extreme',
#   'law',
#   'eliminating',
#   'access',
#   'before',
#   'many',
#   'even',
#   'know',
#   'they',
#   "'",
#   're',
#   'pregnant',
#   '.',
#   'outrageous',
#   '.',
#   'and',
#   'i',
#   'remain',
#   'committed',
#   'to',
#   'protecting',
#   'reproductive',
#   'freedom',
#   'in',
#   'florida',
#   'and',
#   'across',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'ukraine',
#   'gives',
#   'award',
#   'to',
#   'foreign',
#   'vi',
#   '##gil',
#   '##antes',
#   'for',
#   'hack',
#   '##s',
#   'on',
#   'russia',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'got',
#   '45',
#   'min',
#   '##s',
#   'to',
#   'give',
#   'away',
#   'my',
#   'own',
#   'personal',
#   't',
#   '##kt',
#   '##s',
#   'to',
#   '#',
#   'sold',
#   '##out',
#   '##mina',
#   '##j',
#   'shows',
#   'guys',
#   '.',
#   'but',
#   'i',
#   '’',
#   'm',
#   'doing',
#   'it',
#   'on',
#   'station',
#   'head',
#   'so',
#   'nana',
#   '##bo',
#   '##ob',
#   '##oo',
#   'bar',
#   '##b',
#   '##z',
#   'don',
#   '’',
#   't',
#   'start',
#   '.',
#   'i',
#   'miss',
#   'you',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'hand',
#   '_',
#   'over',
#   '_',
#   'mouth',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   '"',
#   'the',
#   'flies',
#   ',',
#   '"',
#   'our',
#   'newest',
#   'class',
#   'of',
#   ',',
#   'officially',
#   'graduated',
#   'basic',
#   'training',
#   'last',
#   'month',
#   '—',
#   'and',
#   'what',
#   "'",
#   's',
#   'a',
#   'graduation',
#   'without',
#   'a',
#   'few',
#   'super',
#   '##lative',
#   '##s',
#   '?',
#   'if',
#   'you',
#   'want',
#   'to',
#   'join',
#   'the',
#   'next',
#   'astronaut',
#   'class',
#   ',',
#   'our',
#   'applications',
#   'are',
#   'still',
#   'open',
#   '!',
#   'get',
#   'yours',
#   'in',
#   'by',
#   'april',
#   '16',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'just',
#   'in',
#   ':',
#   'coin',
#   '##base',
#   'ceo',
#   'says',
#   'its',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'lightning',
#   'network',
#   'integration',
#   '"',
#   'should',
#   'be',
#   'launching',
#   'soon',
#   '"',
#   ':',
#   'high',
#   '_',
#   'voltage',
#   ':',
#   ':',
#   'eyes',
#   ':',
#   '[SEP]'],
#  ['[CLS]', 'don', '’', 't', 'pinch', 'me', 'please', '[SEP]'],
#  ['[CLS]',
#   'rash',
#   '##ee',
#   'rice',
#   ':',
#   'super',
#   'bowl',
#   'champion',
#   'admits',
#   'role',
#   'in',
#   'texas',
#   'hit',
#   '-',
#   'and',
#   '-',
#   'run',
#   '[SEP]'],
#  ['[CLS]',
#   'this',
#   'week',
#   ',',
#   'america',
#   'lost',
#   'a',
#   'hero',
#   '.',
#   'when',
#   'lou',
#   'con',
#   '##ter',
#   'passed',
#   'away',
#   'at',
#   'the',
#   'age',
#   'of',
#   '102',
#   ',',
#   'america',
#   'said',
#   'farewell',
#   'to',
#   'the',
#   'last',
#   'known',
#   'survivor',
#   'of',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   's',
#   '.',
#   'arizona',
#   ',',
#   'which',
#   'was',
#   'stationed',
#   'on',
#   'battleship',
#   'row',
#   'at',
#   'pearl',
#   'harbor',
#   'on',
#   'december',
#   '7',
#   ',',
#   '1941',
#   '.',
#   'today',
#   ',',
#   'our',
#   'hearts',
#   'are',
#   'with',
#   'those',
#   'who',
#   'knew',
#   'him',
#   'and',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'think',
#   'there',
#   'might',
#   'be',
#   'some',
#   'confusion',
#   'on',
#   'what',
#   'was',
#   'said',
#   '.',
#   'i',
#   'asked',
#   'why',
#   'he',
#   'feels',
#   'so',
#   'comfortable',
#   'calling',
#   'me',
#   'mexican',
#   '?',
#   'i',
#   'have',
#   'no',
#   'mexican',
#   'parents',
#   '.',
#   'my',
#   'mom',
#   'is',
#   'tri',
#   '##ni',
#   '.',
#   '.',
#   'she',
#   'came',
#   'out',
#   'of',
#   'a',
#   'whole',
#   'black',
#   'woman',
#   '.',
#   'my',
#   'father',
#   'is',
#   'dominican',
#   '…',
#   'i',
#   '’',
#   'm',
#   'dominican',
#   'just',
#   'like',
#   'you',
#   '.',
#   'i',
#   'also',
#   'used',
#   'other',
#   'dominican',
#   '##s',
#   'as',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'all',
#   'i',
#   'wanted',
#   '…',
#   'to',
#   'give',
#   'my',
#   'fans',
#   'an',
#   'album',
#   '&',
#   'tour',
#   'that',
#   'touched',
#   'them',
#   'in',
#   'every',
#   'way',
#   '&',
#   'reminded',
#   'them',
#   'of',
#   'why',
#   '&',
#   'how',
#   'we',
#   'fell',
#   'in',
#   'love',
#   'in',
#   'the',
#   '1st',
#   'place',
#   '.',
#   'to',
#   'give',
#   'them',
#   'the',
#   'tour',
#   'that',
#   'they',
#   'never',
#   'knew',
#   'they',
#   'needed',
#   '-',
#   'prove',
#   'to',
#   'them',
#   'how',
#   'much',
#   'i',
#   'value',
#   'them',
#   '&',
#   'how',
#   'much',
#   'i',
#   'value',
#   'the',
#   'arts',
#   ':',
#   'pink',
#   '_',
#   'heart',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'beyonce',
#   '&',
#   'jennifer',
#   'hudson',
#   'host',
#   'mini',
#   '‘',
#   'dream',
#   '##girl',
#   '##s',
#   '’',
#   'reunion',
#   'at',
#   '202',
#   '##4',
#   'i',
#   '##heart',
#   '##rad',
#   '##io',
#   'music',
#   'awards',
#   '[SEP]'],
#  ['[CLS]',
#   'why',
#   'this',
#   'amateur',
#   'scientist',
#   'measured',
#   'snowfall',
#   'for',
#   '50',
#   'years',
#   '[SEP]'],
#  ['[CLS]',
#   'happy',
#   'tipping',
#   'tuesday',
#   'shi',
#   '##bes',
#   '!',
#   'tip',
#   'in',
#   'dog',
#   '##ec',
#   '##oin',
#   ':',
#   'dog',
#   ':',
#   ':',
#   'dog',
#   '_',
#   'face',
#   ':',
#   ':',
#   'money',
#   '_',
#   'with',
#   '_',
#   'wings',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'dog',
#   '##e',
#   'is',
#   'the',
#   'og',
#   'tipping',
#   'currency',
#   'of',
#   'the',
#   'internet',
#   '[SEP]'],
#  ['[CLS]',
#   'april',
#   'is',
#   'a',
#   'big',
#   'month',
#   'for',
#   'sky',
#   'gazing',
#   ':',
#   'star',
#   '-',
#   'struck',
#   ':',
#   'big',
#   'planets',
#   ':',
#   'jupiter',
#   'will',
#   'be',
#   'visible',
#   'all',
#   'month',
#   ';',
#   'mars',
#   'and',
#   'saturn',
#   'will',
#   'rise',
#   'together',
#   'on',
#   'april',
#   '10',
#   '&',
#   '11',
#   'big',
#   'eclipse',
#   ':',
#   'on',
#   'april',
#   '8',
#   ',',
#   'catch',
#   'the',
#   'last',
#   'total',
#   'solar',
#   'eclipse',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'for',
#   '20',
#   'years',
#   'big',
#   'moon',
#   ':',
#   'catch',
#   'a',
#   'full',
#   'moon',
#   'on',
#   'april',
#   '23',
#   '[SEP]'],
#  ['[CLS]',
#   'irish',
#   'basketball',
#   'teams',
#   'ordered',
#   'to',
#   'replay',
#   'last',
#   '0',
#   '.',
#   '3',
#   'seconds',
#   'of',
#   'quarter',
#   '-',
#   'final',
#   'tie',
#   '[SEP]'],
#  ['[CLS]',
#   'will',
#   'beyonce',
#   'finally',
#   'win',
#   'album',
#   'of',
#   'the',
#   'year',
#   'grammy',
#   'with',
#   '‘',
#   'cowboy',
#   'carter',
#   '’',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'worst',
#   'mig',
#   '##raine',
#   '##s',
#   'ever',
#   'for',
#   'like',
#   '3',
#   'weeks',
#   'now',
#   '.',
#   ':',
#   'skull',
#   ':',
#   'why',
#   'won',
#   '’',
#   't',
#   'these',
#   'things',
#   'go',
#   'away',
#   '?',
#   'i',
#   'have',
#   'tried',
#   'everything',
#   '.',
#   'what',
#   'is',
#   'your',
#   'secret',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'tennessee',
#   'passes',
#   "'",
#   'che',
#   '##mt',
#   '##rail',
#   "'",
#   'bill',
#   'banning',
#   'airborne',
#   'chemicals',
#   '[SEP]'],
#  ['[CLS]',
#   'here',
#   '’',
#   's',
#   'my',
#   'advice',
#   'to',
#   'you',
#   'ray',
#   '##mont',
#   '##e',
#   '…',
#   'it',
#   'takes',
#   'time',
#   '!',
#   '!',
#   '!',
#   'right',
#   'now',
#   'i',
#   'get',
#   'brand',
#   'deals',
#   'for',
#   'over',
#   '$',
#   '5',
#   'million',
#   'for',
#   'a',
#   'campaign',
#   '…',
#   'i',
#   'got',
#   'social',
#   'media',
#   'famous',
#   'in',
#   '2014',
#   '…',
#   'my',
#   'first',
#   'brand',
#   'deal',
#   'from',
#   'fashion',
#   'nova',
#   'was',
#   'in',
#   '2016',
#   'and',
#   '$',
#   '200',
#   'a',
#   'post',
#   '.',
#   'you',
#   'could',
#   'reach',
#   'any',
#   'height',
#   'no',
#   'matter',
#   'how',
#   'ghetto',
#   'or',
#   'where',
#   'you',
#   '…',
#   '[SEP]'],
#  ['[CLS]', 'something', 'is', 'cooking', 'at', ':', 'eyes', ':', '[SEP]'],
#  ['[CLS]',
#   'mysterious',
#   'streak',
#   'of',
#   'light',
#   'seen',
#   'across',
#   'southern',
#   'california',
#   'sky',
#   '[SEP]'],
#  ['[CLS]',
#   'here',
#   'are',
#   'the',
#   'performers',
#   'and',
#   'presenters',
#   'for',
#   '202',
#   '##4',
#   'cm',
#   '##t',
#   'music',
#   'awards',
#   '[SEP]'],
#  ['[CLS]',
#   'botswana',
#   'offers',
#   'to',
#   'send',
#   '20',
#   ',',
#   '000',
#   'elephants',
#   'to',
#   'germany',
#   '[SEP]'],
#  ['[CLS]',
#   'two',
#   'letters',
#   ':',
#   'dc',
#   '>',
#   '>',
#   '>',
#   '>',
#   '#',
#   'gag',
#   '##city',
#   '##dc',
#   '[SEP]'],
#  ['[CLS]',
#   'french',
#   'couple',
#   'who',
#   'kept',
#   '159',
#   'cats',
#   'banned',
#   'from',
#   'keeping',
#   'pets',
#   '[SEP]'],
#  ['[CLS]',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   'breaking',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   '1',
#   ',',
#   '000',
#   ',',
#   '000',
#   ',',
#   '000',
#   'usd',
#   '##t',
#   'just',
#   'got',
#   'mint',
#   '##ed',
#   'at',
#   'te',
#   '##ther',
#   'treasury',
#   'yesterday',
#   'also',
#   '$',
#   '1',
#   'billion',
#   'usd',
#   '##t',
#   'was',
#   'mint',
#   '##ed',
#   '.',
#   'are',
#   'whales',
#   'preparing',
#   'for',
#   'a',
#   'huge',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'pump',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'rebel',
#   'wilson',
#   'book',
#   'release',
#   'put',
#   'back',
#   'in',
#   'uk',
#   'and',
#   'australia',
#   '[SEP]'],
#  ['[CLS]',
#   'world',
#   'central',
#   'kitchen',
#   'founder',
#   'jose',
#   'andres',
#   'says',
#   'israel',
#   'targeted',
#   'staff',
#   'in',
#   'gaza',
#   "'",
#   'car',
#   'by',
#   'car',
#   "'",
#   '[SEP]'],
#  ['[CLS]',
#   'who',
#   'were',
#   'the',
#   'seven',
#   'aid',
#   'workers',
#   'killed',
#   'in',
#   'gaza',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'listen',
#   ',',
#   'lots',
#   'of',
#   'my',
#   'friends',
#   'have',
#   'made',
#   'tons',
#   'and',
#   'tons',
#   'of',
#   'money',
#   'on',
#   'crypt',
#   '##o',
#   'while',
#   'i',
#   'cl',
#   '##ing',
#   'to',
#   'my',
#   'little',
#   'bag',
#   'of',
#   'silver',
#   '.',
#   'i',
#   'realize',
#   'that',
#   'crypt',
#   '##o',
#   'has',
#   'been',
#   'more',
#   'successful',
#   'in',
#   'the',
#   'last',
#   'several',
#   'years',
#   'than',
#   'what',
#   'i',
#   'think',
#   'would',
#   'be',
#   '.',
#   'and',
#   'i',
#   'obviously',
#   'admit',
#   'that',
#   'and',
#   'people',
#   'shouldn',
#   '’',
#   't',
#   'take',
#   'investment',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'super',
#   'valid',
#   '.',
#   'worth',
#   'a',
#   'podcast',
#   'someday',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'taylor', 'swift', 'is', 'officially', 'a', 'billionaire', '[SEP]'],
#  ['[CLS]',
#   'will',
#   'truth',
#   'social',
#   'post',
#   'a',
#   'financial',
#   'bail',
#   '##out',
#   'for',
#   'trump',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'three',
#   'british',
#   'aid',
#   'workers',
#   'killed',
#   'in',
#   'israeli',
#   'strike',
#   'in',
#   'gaza',
#   'named',
#   '[SEP]'],
#  ['[CLS]',
#   'tesla',
#   "'",
#   'disaster',
#   "'",
#   'with',
#   'few',
#   '##est',
#   'deliveries',
#   'since',
#   '202',
#   '##2',
#   '[SEP]'],
#  ['[CLS]',
#   'best',
#   'dog',
#   '##e',
#   'me',
#   '##me',
#   'wins',
#   'đ',
#   '##6',
#   '##9',
#   '.',
#   '420',
#   '!',
#   ':',
#   'trophy',
#   ':',
#   'like',
#   '&',
#   'rep',
#   '##ost',
#   'this',
#   'post',
#   'to',
#   'participate',
#   '.',
#   ':',
#   'dog',
#   ':',
#   'up',
#   '##load',
#   'your',
#   'me',
#   '##me',
#   'in',
#   'the',
#   'comments',
#   '.',
#   ':',
#   'speech',
#   '_',
#   'balloon',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'trump',
#   'sue',
#   '##s',
#   'truth',
#   'social',
#   'co',
#   '-',
#   'founders',
#   'over',
#   'alleged',
#   'mis',
#   '##mana',
#   '##gement',
#   '[SEP]'],
#  ['[CLS]',
#   'ukraine',
#   'lowers',
#   'combat',
#   'call',
#   '-',
#   'up',
#   'age',
#   'to',
#   'boost',
#   'numbers',
#   '[SEP]'],
#  ['[CLS]',
#   '202',
#   '##4',
#   'mlb',
#   'season',
#   ':',
#   'how',
#   'to',
#   'watch',
#   'baseball',
#   'games',
#   'online',
#   'for',
#   'free',
#   'without',
#   'cable',
#   '[SEP]'],
#  ['[CLS]',
#   'congratulations',
#   'to',
#   'bu',
#   '##id',
#   ':',
#   '79',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '52',
#   'on',
#   'being',
#   'our',
#   'first',
#   'winner',
#   'of',
#   'the',
#   'tesla',
#   'car',
#   'lucky',
#   'draw',
#   'in',
#   'second',
#   'installment',
#   'of',
#   '#',
#   'futures',
#   '##chal',
#   '##len',
#   '##ge',
#   ':',
#   'party',
#   '_',
#   'pop',
#   '##per',
#   ':',
#   'don',
#   "'",
#   't',
#   'worry',
#   ',',
#   'there',
#   'are',
#   '3',
#   'weeks',
#   'left',
#   'to',
#   'get',
#   'your',
#   'hands',
#   'on',
#   'your',
#   'very',
#   'own',
#   'tesla',
#   '!',
#   'participate',
#   'now',
#   ':',
#   'right',
#   '_',
#   'arrow',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'tuesday',
#   'already',
#   '?',
#   'watch',
#   'and',
#   'me',
#   'play',
#   '#',
#   'password',
#   'tonight',
#   'at',
#   '10',
#   '/',
#   '9',
#   '##c',
#   'on',
#   'after',
#   '#',
#   'weak',
#   '##est',
#   '##link',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   'went',
#   'to',
#   '#',
#   'gag',
#   '##city',
#   '##dc',
#   'alone',
#   'and',
#   'ended',
#   'up',
#   'w',
#   'the',
#   'sweet',
#   '##est',
#   'girl',
#   'next',
#   'to',
#   'me',
#   'who',
#   'was',
#   'also',
#   'alone',
#   '&',
#   'so',
#   'fun',
#   'and',
#   'it',
#   'was',
#   'her',
#   'b',
#   '##day',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ':',
#   'pink',
#   '_',
#   'heart',
#   ':',
#   ':',
#   'pink',
#   '_',
#   'heart',
#   ':',
#   ':',
#   'pink',
#   '_',
#   'heart',
#   ':',
#   'it',
#   'was',
#   'just',
#   'a',
#   'magical',
#   'and',
#   'fun',
#   'night',
#   'overall',
#   '.',
#   'i',
#   '’',
#   'm',
#   'so',
#   'overwhelmed',
#   'and',
#   'grateful',
#   '[SEP]'],
#  ['[CLS]',
#   'r',
#   '.',
#   'i',
#   '.',
#   'p',
#   '.',
#   'michael',
#   'mc',
#   '##mart',
#   '##in',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'time',
#   'to',
#   'look',
#   'at',
#   'this',
#   'month',
#   "'",
#   's',
#   'market',
#   'insights',
#   '!',
#   'our',
#   'research',
#   'team',
#   'analyzed',
#   'the',
#   'state',
#   'of',
#   'the',
#   'crypt',
#   '##o',
#   'market',
#   'and',
#   'provided',
#   'insights',
#   'on',
#   'bit',
#   '##co',
#   '##in',
#   'et',
#   '##f',
#   'in',
#   '##flow',
#   '##s',
#   ',',
#   'ether',
#   '##eum',
#   "'",
#   's',
#   'den',
#   '##cu',
#   '##n',
#   'upgrade',
#   ',',
#   'sol',
#   '##ana',
#   "'",
#   's',
#   'dex',
#   'volumes',
#   ',',
#   'and',
#   'more',
#   '.',
#   'check',
#   'it',
#   'out',
#   ':',
#   'down',
#   '_',
#   'arrow',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'x',
#   'is',
#   'bringing',
#   'the',
#   'tip',
# ...
#   'emission',
#   'intensity',
#   'data',
#   ',',
#   'information',
#   'on',
#   'surface',
#   'texture',
#   '&',
#   'composition',
#   'of',
#   'planets',
#   'could',
#   'be',
#   'obtained',
#   ',',
#   'along',
#   'w',
#   'information',
#   '.',
#   '.',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'joker',
#   '2',
#   'poster',
#   'has',
#   'been',
#   'seen',
#   '14',
#   'million',
#   'times',
#   'in',
#   'just',
#   '10',
#   'hours',
#   'on',
#   'one',
#   'twitter',
#   'account',
#   ',',
#   'comparing',
#   'it',
#   'to',
#   'other',
#   'major',
#   'releases',
#   'first',
#   'poster',
#   'posts',
#   ',',
#   'these',
#   'numbers',
#   'are',
#   'incredible',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   ':',
#   'police',
#   '_',
#   'car',
#   '_',
#   'light',
#   ':',
#   '370',
#   ',',
#   '000',
#   ',',
#   '000',
#   '#',
#   'usd',
#   '##t',
#   '(',
#   '370',
#   ',',
#   '04',
#   '##7',
#   ',',
#   '175',
#   'usd',
#   ')',
#   'transferred',
#   'from',
#   'te',
#   '##ther',
#   'treasury',
#   'to',
#   '#',
#   'bit',
#   '##fine',
#   '##x',
#   '[SEP]'],
#  ['[CLS]',
#   'ft',
#   '##c',
#   'responds',
#   'to',
#   'es',
#   '##rb',
#   "'",
#   's',
#   'proposal',
#   'for',
#   'an',
#   'ai',
#   '-',
#   'powered',
#   'face',
#   '-',
#   'scanning',
#   "'",
#   'age',
#   'estimation',
#   "'",
#   'system',
#   '"',
#   'no',
#   '"',
#   '[SEP]'],
#  ['[CLS]',
#   'why',
#   'hasn',
#   "'",
#   't',
#   'judge',
#   'cannon',
#   'ruled',
#   'on',
#   'the',
#   'do',
#   '##j',
#   'rec',
#   '##ons',
#   '##ider',
#   '##ation',
#   'motion',
#   'to',
#   'block',
#   'the',
#   'release',
#   'of',
#   'witness',
#   'lists',
#   '?',
#   'i',
#   "'",
#   'm',
#   'guessing',
#   'she',
#   'knows',
#   'if',
#   'she',
#   'releases',
#   'them',
#   ',',
#   'smith',
#   'will',
#   'go',
#   'to',
#   'the',
#   '11th',
#   'circuit',
#   '.',
#   'so',
#   'she',
#   "'",
#   's',
#   'sitting',
#   'on',
#   'it',
#   '.',
#   '[SEP]'],
#  ['[CLS]', 'this', 'is', 'evil', '[SEP]'],
#  ['[CLS]', 'what', "'", 's', 'going', 'on', 'here', '[SEP]'],
#  ['[CLS]',
#   'update',
#   'on',
#   '#',
#   'sampling',
#   '##mar',
#   '##s',
#   ':',
#   'i',
#   'recently',
#   'collected',
#   'my',
#   '24th',
#   'sample',
#   'from',
#   'an',
#   'area',
#   'called',
#   '"',
#   'bun',
#   '##sen',
#   'peak',
#   '"',
#   '(',
#   'named',
#   'for',
#   'the',
#   'landmark',
#   ')',
#   '.',
#   'the',
#   'rock',
#   'core',
#   'is',
#   'filled',
#   'with',
#   'si',
#   '##lica',
#   'and',
#   'carbonate',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'knowledge',
#   'is',
#   'power',
#   '.',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   '[SEP]'],
#  ['[CLS]', 'truly', 'mother', '’', 's', 'daughter', '[SEP]'],
#  ['[CLS]',
#   'did',
#   'you',
#   'know',
#   'that',
#   'legacy',
#   'media',
#   'have',
#   'notification',
#   '##s',
#   'on',
#   'for',
#   '[UNK]',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'hunter',
#   'sc',
#   '##ha',
#   '##fer',
#   ':',
#   'eu',
#   '##ph',
#   '##oria',
#   'star',
#   'says',
#   'she',
#   'no',
#   'longer',
#   'wants',
#   'to',
#   'play',
#   'trans',
#   'characters',
#   '[SEP]'],
#  ['[CLS]', 'perfection', '.', '[SEP]'],
#  ['[CLS]',
#   'wonder',
#   'where',
#   'she',
#   'is',
#   'now',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   '[SEP]'],
#  ['[CLS]', '#', 'gag', '##city', '##bal', '##ti', '##more', '[SEP]'],
#  ['[CLS]',
#   '"',
#   'katy',
#   'perry',
#   'esq',
#   '##ue',
#   '##ci',
#   '##da',
#   '"',
#   '.',
#   "'",
#   's',
#   '"',
#   'harley',
#   '##s',
#   'in',
#   'hawaii',
#   '"',
#   'has',
#   'now',
#   'surpassed',
#   '500',
#   'million',
#   'streams',
#   'on',
#   'spot',
#   '##ify',
#   '.',
#   '.',
#   "'",
#   's',
#   '"',
#   'never',
#   'really',
#   'over',
#   '"',
#   'is',
#   'now',
#   'certified',
#   'diamond',
#   'in',
#   'brazil',
#   '.',
#   'gen',
#   '##te',
#   '?',
#   'que',
#   'fra',
#   '##cas',
#   '##sa',
#   '##da',
#   ',',
#   '2',
#   'musica',
#   '##s',
#   'solo',
#   'do',
#   'ul',
#   '##ti',
#   '##mo',
#   'album',
#   'send',
#   '##o',
#   'dia',
#   '##man',
#   '##te',
#   'e',
#   '+',
#   '500',
#   '##m',
#   'de',
#   'streams',
#   'do',
#   'spot',
#   '##ify',
#   '[SEP]'],
#  ['[CLS]',
#   'katy',
#   'perry',
#   'x',
#   'american',
#   'idol',
#   '!',
#   ':',
#   'brown',
#   '_',
#   'heart',
#   ':',
#   ':',
#   'sparkle',
#   '##s',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'joker',
#   '2',
#   'trailer',
#   'is',
#   'really',
#   'coming',
#   'to',
#   'break',
#   'the',
#   'internet',
#   '.',
#   'we',
#   '’',
#   're',
#   'talking',
#   'hundreds',
#   'of',
#   'millions',
#   'of',
#   'views',
#   'across',
#   'all',
#   'platforms',
#   '.',
#   'a',
#   'global',
#   'event',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'sha',
#   '##kir',
#   '##a',
#   'is',
#   'set',
#   'to',
#   'appear',
#   'on',
#   '‘',
#   'hot',
#   'ones',
#   '’',
#   'tomorrow',
#   ',',
#   'april',
#   '4',
#   '!',
#   ':',
#   'heart',
#   '_',
#   'on',
#   '_',
#   'fire',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'started',
#   'stan',
#   'twitter',
#   ',',
#   'started',
#   'the',
#   'concept',
#   'of',
#   '"',
#   'eras',
#   '"',
#   ',',
#   'started',
#   'the',
#   'whole',
#   '"',
#   'mother',
#   'and',
#   'fan',
#   '##base',
#   '"',
#   'relationship',
#   'like',
#   'im',
#   'so',
#   'serious',
#   '[SEP]'],
#  ['[CLS]',
#   'lava',
#   '##r',
#   'ball',
#   'blame',
#   '##s',
#   'the',
#   'nba',
#   'training',
#   'staff',
#   '##s',
#   'and',
#   'pu',
#   '##ma',
#   "'",
#   's',
#   "'",
#   'ragged',
#   '##y',
#   "'",
#   'shoes',
#   'for',
#   'his',
#   'sons',
#   "'",
#   'injuries',
#   '“',
#   'the',
#   'reason',
#   'they',
#   'hurt',
#   'is',
#   'because',
#   'they',
#   'got',
#   'away',
#   'from',
#   'me',
#   '.',
#   'and',
#   'they',
#   'start',
#   'doing',
#   'these',
#   'root',
#   '##y',
#   '-',
#   'too',
#   '##t',
#   'workout',
#   '##s',
#   '.',
#   'because',
#   'if',
#   'you',
#   'keep',
#   'running',
#   'them',
#   'hills',
#   ',',
#   'you',
#   "'",
#   're',
#   'going',
#   'to',
#   'keep',
#   'that',
#   'power',
#   'and',
#   'that',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'former',
#   'observer',
#   '&',
#   'huff',
#   '##post',
#   'journalist',
#   'claims',
#   'katy',
#   'perry',
#   '’',
#   's',
#   'career',
#   'decline',
#   'was',
#   'planned',
#   'by',
#   '“',
#   'some',
#   'people',
#   ',',
#   '”',
#   'similar',
#   'to',
#   'how',
#   'christina',
#   'ag',
#   '##uil',
#   '##era',
#   '’',
#   's',
#   'career',
#   'was',
#   'sabotage',
#   '##d',
#   '.',
#   'they',
#   'then',
#   'alleged',
#   'writers',
#   '“',
#   'trash',
#   '##ed',
#   '”',
#   'katy',
#   'to',
#   'generate',
#   'clicks',
#   ',',
#   'more',
#   'money',
#   '.',
#   'last',
#   'year',
#   ',',
#   'former',
#   'pitchfork',
#   'writers',
#   'alleged',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'lady',
#   'gaga',
#   'photographed',
#   'by',
#   'steven',
#   'klein',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'breaking',
#   ':',
#   'the',
#   'sec',
#   'requested',
#   'public',
#   'comment',
#   'on',
#   'major',
#   'ether',
#   '##eum',
#   'spot',
#   'et',
#   '##fs',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'bt',
#   '##c',
#   'bit',
#   '##co',
#   '##in',
#   'is',
#   'holding',
#   'that',
#   'weekly',
#   'range',
#   'low',
#   '(',
#   '~',
#   '65',
#   '##60',
#   '##0',
#   ')',
#   'as',
#   'support',
#   'for',
#   'now',
#   '$',
#   'bt',
#   '##c',
#   '#',
#   'crypt',
#   '##o',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   '[SEP]'],
#  ['[CLS]',
#   'what',
#   'other',
#   'payment',
#   'options',
#   'do',
#   'you',
#   'think',
#   'should',
#   'be',
#   'added',
#   'to',
#   'the',
#   'tip',
#   'jar',
#   '?',
#   '[SEP]'],
#  ['[CLS]',
#   'harry',
#   'potter',
#   'said',
#   'what',
#   '?',
#   '!',
#   '?',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'i',
#   '’',
#   'm',
#   'glad',
#   'gaga',
#   'is',
#   'keeping',
#   'her',
#   'og',
#   'voice',
#   'nobody',
#   'wants',
#   'to',
#   'hear',
#   'that',
#   'squeak',
#   '##y',
#   'ass',
#   'over',
#   '-',
#   'exaggerated',
#   'voice',
#   '[SEP]'],
#  ['[CLS]',
#   'we',
#   '’',
#   're',
#   '5',
#   'days',
#   'away',
#   'from',
#   'the',
#   'eclipse',
#   '!',
#   '!',
#   '!',
#   'check',
#   'out',
#   'my',
#   'eclipse',
#   'guide',
#   '(',
#   'linked',
#   'in',
#   'bio',
#   ')',
#   'for',
#   'some',
#   'tips',
#   'on',
#   'how',
#   'to',
#   'see',
#   'it',
#   '.',
#   'remember',
#   '-',
#   'the',
#   'difference',
#   'between',
#   '99',
#   '%',
#   '&',
#   '100',
#   '%',
#   'is',
#   'one',
#   'that',
#   'will',
#   'literally',
#   'change',
#   'your',
#   'life',
#   '.',
#   'the',
#   'eclipse',
#   'i',
#   'saw',
#   'in',
#   '2017',
#   'ignited',
#   'a',
#   'passion',
#   'to',
#   'pursue',
#   'astro',
#   '##ph',
#   '##oto',
#   '##graphy',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'fans',
#   'from',
#   'selected',
#   'countries',
#   'can',
#   'now',
#   'watch',
#   'sha',
#   '##kir',
#   '##a',
#   "'",
#   's',
#   'videos',
#   'on',
#   'spot',
#   '##ify',
#   '!',
#   'go',
#   'and',
#   'stream',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'why',
#   'are',
#   'cities',
#   'dominated',
#   'by',
#   'highways',
#   'and',
#   'cars',
#   '?',
#   'it',
#   "'",
#   's',
#   'partly',
#   'because',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'influential',
#   'people',
#   'you',
#   "'",
#   've',
#   'never',
#   'heard',
#   'of',
#   ':',
#   'norman',
#   'bel',
#   'ge',
#   '##dd',
#   '##es',
#   '.',
#   'in',
#   '1939',
#   'he',
#   'created',
#   '"',
#   'fu',
#   '##tura',
#   '##ma',
#   '"',
#   ',',
#   'a',
#   'huge',
#   'exhibition',
#   'that',
#   'tried',
#   'to',
#   'predict',
#   'the',
#   'future',
#   '—',
#   'and',
#   'ended',
#   'up',
#   'changing',
#   'the',
#   'world',
#   '.',
#   '.',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'breaking',
#   ':',
#   'coin',
#   '##base',
#   'is',
#   'working',
#   'with',
#   'lights',
#   '##park',
#   'to',
#   'integrate',
#   'the',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'lightning',
#   'network',
#   'for',
#   'all',
#   'its',
#   'customers',
#   ':',
#   'high',
#   '_',
#   'voltage',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'from',
#   'these',
#   '4',
#   'accounts',
#   'alone',
#   ',',
#   'nearly',
#   '31',
#   'million',
#   'views',
#   'in',
#   '24',
#   'hours',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'finally',
#   'rest',
#   '##ock',
#   '##ed',
#   ':',
#   'lady',
#   'gaga',
#   '-',
#   'the',
#   'fame',
#   'monster',
#   'picture',
#   'disc',
#   '.',
#   'will',
#   'be',
#   'included',
#   'in',
#   'our',
#   'friday',
#   'drop',
#   'as',
#   'well',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   'breaking',
#   ':',
#   'the',
#   'guy',
#   'that',
#   'rammed',
#   'his',
#   'car',
#   'into',
#   'the',
#   'fbi',
#   'field',
#   'office',
#   'in',
#   'atlanta',
#   'the',
#   'other',
#   'day',
#   'has',
#   'social',
#   'media',
#   'accounts',
#   'associated',
#   'with',
#   'q',
#   'an',
#   '##on',
#   ',',
#   'anti',
#   '-',
#   'va',
#   '##xx',
#   'stuff',
#   ',',
#   'election',
#   'denial',
#   '##ism',
#   ',',
#   'sidney',
#   'powell',
#   ',',
#   'and',
#   'donald',
#   'trump',
#   '.',
#   'super',
#   'shocked',
#   'source',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'spot',
#   '##ify',
#   '|',
#   'top',
#   'songs',
#   '(',
#   '04',
#   '/',
#   '02',
#   ')',
#   '[',
#   'streams',
#   ']',
#   'hips',
#   'don',
#   "'",
#   't',
#   'lie',
#   '—',
#   '1',
#   ',',
#   '138',
#   ',',
#   '286',
#   'tq',
#   '##g',
#   '—',
#   '1',
#   ',',
#   '03',
#   '##8',
#   ',',
#   '174',
#   'punt',
#   '##eria',
#   '—',
#   '96',
#   '##1',
#   ',',
#   '46',
#   '##1',
#   '(',
#   'en',
#   '##tre',
#   'parent',
#   '##esis',
#   ')',
#   '—',
#   '84',
#   '##6',
#   ',',
#   '840',
#   'co',
#   '##het',
#   '##e',
#   '—',
#   '60',
#   '##3',
#   ',',
#   '39',
#   '##3',
#   'b',
#   '##z',
#   '##rp',
#   'music',
#   'sessions',
#   ',',
#   'vol',
#   '.',
#   '53',
#   '—',
#   '570',
#   ',',
#   '83',
#   '##7',
#   'whenever',
#   ',',
#   'wherever',
#   '—',
#   '47',
#   '##9',
#   ',',
#   '76',
#   '##8',
#   'chant',
#   '##aj',
#   '##e',
#   '—',
#   '422',
#   ',',
#   '50',
#   '##2',
#   'la',
#   'tor',
#   '##tura',
#   '—',
#   '40',
#   '##8',
#   ',',
#   '05',
#   '##9',
#   'dia',
#   'de',
#   'en',
#   '##ero',
#   '—',
#   '403',
#   ',',
#   '425',
#   '[SEP]'],
#  ['[CLS]',
#   'what',
#   'if',
#   'i',
#   'tell',
#   'you',
#   'that',
#   'there',
#   "'",
#   's',
#   'more',
#   'adult',
#   'content',
#   'on',
#   'thread',
#   '##z',
#   '&',
#   'ins',
#   '##tagram',
#   'than',
#   'on',
#   'only',
#   '##fan',
#   '##s',
#   '.',
#   ':',
#   'eyes',
#   ':',
#   '[SEP]'],
#  ['[CLS]',
#   'kei',
#   '##tyn',
#   ',',
#   'fei',
#   '##d',
#   ',',
#   'carlos',
#   'vi',
#   '##ves',
#   'and',
#   'y',
#   '##ng',
#   'l',
#   '##vc',
#   '##as',
#   'talk',
#   'major',
#   'wins',
#   'at',
#   '202',
#   '##4',
#   'latin',
#   'as',
#   '##cap',
#   'awards',
#   '[SEP]'],
#  ['[CLS]',
#   'anya',
#   'taylor',
#   '-',
#   'joy',
#   'confirms',
#   'she',
#   'secretly',
#   'got',
#   'married',
#   'to',
#   'malcolm',
#   'mc',
#   '##rae',
#   'in',
#   '202',
#   '##2',
#   '[SEP]'],
#  ['[CLS]',
#   'tonight',
#   '’',
#   's',
#   'tank',
#   'top',
#   'says',
#   '‘',
#   'w',
#   ':',
#   'star',
#   ':',
#   'men',
#   '’',
#   'at',
#   '#',
#   'guts',
#   '##world',
#   '##tour',
#   '##bos',
#   '##ton',
#   '!',
#   '[SEP]'],
#  ['[CLS]',
#   '[UNK]',
#   '=',
#   'up',
#   ':',
#   'green',
#   '_',
#   'circle',
#   ':',
#   'facebook',
#   '=',
#   'down',
#   ':',
#   'red',
#   '_',
#   'circle',
#   ':',
#   'ins',
#   '##tagram',
#   '=',
#   'down',
#   ':',
#   'red',
#   '_',
#   'circle',
#   ':',
#   'what',
#   '##sa',
#   '##pp',
#   '=',
#   'down',
#   ':',
#   'red',
#   '_',
#   'circle',
#   ':',
#   '[SEP]'],
#  ['[CLS]', 'we', 'all', 'remember', 'where', 'we', 'were', '[SEP]'],
#  ['[CLS]',
#   'just',
#   'in',
#   ':',
#   ':',
#   'united',
#   '_',
#   'states',
#   ':',
#   'black',
#   '##rock',
#   'and',
#   'fidelity',
#   'now',
#   'own',
#   'a',
#   'combined',
#   '39',
#   '##9',
#   ',',
#   '74',
#   '##1',
#   '#',
#   'bt',
#   '##c',
#   'worth',
#   '$',
#   '26',
#   '.',
#   '2',
#   'billion',
#   'for',
#   'their',
#   'spot',
#   '#',
#   'bit',
#   '##co',
#   '##in',
#   'et',
#   '##fs',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   ':',
#   'united',
#   '_',
#   'states',
#   ':',
#   '|',
#   'sha',
#   '##kir',
#   '##a',
#   'is',
#   'the',
#   'female',
#   'artist',
#   'with',
#   'the',
#   'most',
#   'songs',
#   'currently',
#   'on',
#   'the',
#   'us',
#   'itunes',
#   'top',
#   '100',
#   'latin',
#   'songs',
#   ',',
#   'totaling',
#   '8',
#   'songs',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   '#',
#   'sha',
#   '##kir',
#   '##a',
#   "'",
#   's',
#   'amazing',
#   '12th',
#   'studio',
#   'album',
#   "'",
#   'las',
#   'mu',
#   '##jer',
#   '##es',
#   'ya',
#   'no',
#   'll',
#   '##oran',
#   "'",
#   'scores',
#   'the',
#   '3rd',
#   'highest',
#   'new',
#   'entry',
#   'on',
#   'the',
#   'united',
#   'world',
#   'album',
#   'chart',
#   ',',
#   'landing',
#   'at',
#   '#',
#   '6',
#   '!',
#   ':',
#   'flexed',
#   '_',
#   'biceps',
#   ':',
#   ':',
#   '3rd',
#   '_',
#   'place',
#   '_',
#   'medal',
#   ':',
#   ':',
#   'top',
#   '_',
#   'arrow',
#   ':',
#   ':',
#   'new',
#   '_',
#   'button',
#   ':',
#   ':',
#   'collision',
#   ':',
#   ':',
#   'key',
#   '##cap',
#   '_',
#   '6',
#   ':',
#   ':',
#   'globe',
#   '_',
#   'showing',
#   '_',
#   'americas',
#   ':',
#   ':',
#   'chart',
#   '_',
#   'increasing',
#   ':',
#   ':',
#   'crown',
#   ':',
#   ':',
#   'heart',
#   '_',
#   'on',
#   '_',
#   'fire',
#   ':',
#   "'",
#   'las',
#   'mu',
#   '##jer',
#   '##es',
#   'ya',
#   'no',
#   'll',
#   '##oran',
#   "'",
#   'featuring',
#   '#',
#   'card',
#   '##ib',
#   ',',
#   '#',
#   'ra',
#   '##uw',
#   '##ale',
#   '##jan',
#   '##dro',
#   ',',
#   '#',
#   'manuel',
#   '##tur',
#   '##iz',
#   '##o',
#   ',',
#   '#',
#   'grupo',
#   '##front',
#   '##era',
#   ',',
#   '#',
#   'oz',
#   '##una',
#   ',',
#   '#',
#   'ka',
#   '##rol',
#   '##g',
#   '&',
#   '…',
#   '[SEP]'],
#  ['[CLS]',
#   'news',
#   ':',
#   'tesla',
#   'overtook',
#   'mercedes',
#   'as',
#   'the',
#   'second',
#   '-',
#   'largest',
#   'seller',
#   'of',
#   'imported',
#   'vehicles',
#   'in',
#   'korea',
#   'last',
#   'month',
#   '.',
#   'it',
#   'marked',
#   'the',
#   'first',
#   'time',
#   'for',
#   'tesla',
#   'to',
#   'beat',
#   'mercedes',
#   '-',
#   'benz',
#   'in',
#   'korea',
#   'in',
#   'terms',
#   'of',
#   'sales',
#   '.',
#   '[SEP]'],
#  ['[CLS]',
#   'the',
#   'ultimate',
#   'guide',
#   'to',
#   'festivals',
#   'celebrating',
#   'latin',
#   'music',
#   'in',
#   '202',
#   '##4',
#   '[SEP]'],
#  ['[CLS]', 'lady', 'gaga', 'is', 'a', 'fucking', 'movie', 'star', '[SEP]'],
#  ['[CLS]',
#   'te',
#   'hare',
#   'sal',
#   '##ir',
#   'vol',
#   '##ando',
#   'como',
#   'un',
#   'co',
#   '##het',
#   '##e',
#   '!',
#   ':',
#   'rocket',
#   ':',
#   ':',
#   'collision',
#   ':',
#   'i',
#   '’',
#   'll',
#   'make',
#   'you',
#   'fly',
#   'like',
#   'a',
#   'rocket',
#   '!',
#   '#',
#   'l',
#   '##my',
#   '##nl',
#   '→',
#   '[SEP]'],
#  ['[CLS]',
#   'you',
#   '’',
#   're',
#   'invited',
#   '!',
#   'see',
#   'you',
#   'in',
#   'rogue',
#   '##port',
#   'on',
#   'may',
#   '23',
#   'in',
#   '#',
#   'paper',
#   '##mar',
#   '##iot',
#   '##het',
#   '##ho',
#   '##usa',
#   '##nd',
#   '##year',
#   '##door',
#   ',',
#   'coming',
#   'to',
#   '#',
#   'nintendo',
#   '##sw',
#   '##itch',
#   '!',
#   '[SEP]'],
#  ['[CLS]', 'alien', 'mothers', '[SEP]']]

# %% [markdown]
# ### Save Output

# %%
import pickle

# %%
# Save the list of tokens to a file using Pickle
with open('data/preprocessing_output.pkl', 'wb') as file:
    pickle.dump(result, file)

# save dataframe as a CSV file
preprocessed_data = [' '.join(document) for document in result]
df_data = pd.DataFrame(preprocessed_data, columns=['Content'])
df_data['Label'] = df_labels
df_data.to_csv('data/preprocessed_data.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Save Output for BERT

# %%
# Save the list of tokens to a file using Pickle
with open('data/preprocessing_output_bert.pkl', 'wb') as file:
    pickle.dump(result_bert, file)

# save dataframe as a CSV file
preprocessed_data_bert = [' '.join(document) for document in result_bert]
df_data = pd.DataFrame(preprocessed_data_bert, columns=['Content'])
df_data['Label'] = df_labels
df_data.to_csv('data/preprocessed_data_bert.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Load Output

# %%
# to read the pkl file:
with open('data/preprocessing_output.pkl', 'rb') as file:
    loaded_list = pickle.load(file)
    
# Print the dictionary
print(loaded_list)
print(len(loaded_list))

# print the labels
df_labels_loaded = pd.read_pickle('data/labels.pkl')
print(df_labels_loaded)
print(len(df_labels_loaded))

# read the CSV file
df_data_loaded = pd.read_csv('data/preprocessed_data.csv', encoding='utf-8-sig')
print(df_data_loaded)
# Out:
# [['binance', 'towel', 'come', 'everywhere', 'include', 'breakfast', 'cooking'], ['drop', 'sol', 'address', 'make', 'sure', 'follow', 'dont', 'ask', 'backhand', 'index', 'point', 'medium', 'light', 'skin', 'tone'], ['take', 'one', 'good', 'altcoin', 'change', 'world', 'sparkle'], ['disrespectful', 'one', 'top', '3', 'favorite'], ['congressional', 'republican', 'call', 'affordable', 'connectivity', 'program', 'wasteful', 'call', 'necessary', 'time', 'congress', 'extend', '23', 'million', 'household', 'across', 'america', 'rely', 'program', 'stay', 'connect'], ['donald', 'trump', 'wont', 'american', 'president', 'must', 'refuse', 'denounce', 'political', 'violence', 'ill', 'say', 'trump', 'wont', 'political', 'violence', 'never', 'ever', 'acceptable', 'america'], ['massive', 'bitcoin', 'breakout', 'come', 'ready'], ['ok', 'vote', 'ill', '25', 'ticket', 'giveaway', 'station', 'head', '10', 'min', 'feel', 'like', 'ill', 'come', 'space', 'give', 'another', '5', '10', 'generous', 'queen', 'princess', 'medium', 'skin', 'tone'], ['whole', 'heart'], ['im', 'tire', 'people', 'use', 'punching', 'bag', 'leave', 'tf', 'alone', 'day'], ['april', '03', '2024', '09', '21', 'utc', 'current', 'price', 'bitcoin', 'btc', 'usd', '6648480', 'btc', 'eur', '6175773'], ['pitbull', 'big', '3'], ['35', 'month', 'insulin', 'senior', '35', 'inhaler', 'asthma', '2000', 'year', 'cap', 'prescription', 'drug', 'senior', 'start', 'next', 'year', 'senator', 'sander', "'", 'help', 'show', 'health', 'care', 'right', 'privilege', 'america'], ['cryptoo'], ['world', 'stage', 'joker', 'folie', 'deux', 'trailer', 'come', 'april', '9', 'joker'], ['video', 'show', 'abduct', 'us', 'girl', 'fatally', 'shoot', 'police'], ['best', 'bravest', 'baddest', 'barbz', 'win'], ['bitcoin', 'go', '100000', 'eth', 'go', '10000', 'altcoins', 'pump', '10x', 'halve', '15', 'day', 'bullish', 'enough'], ['conan', 'lyric', 'feel', 'like'], ['tether', 'print', 'high', 'bitcoin', 'go'], ['artist', 'big', 'hit', 'maker'], ['bitcoin', 'navigate', 'high', 'sea', 'finance', 'steer', 'ship', 'economic', 'evolution', 'sailboat', 'money', 'bag', 'water', 'wave'], ['album', 'moment', 'cyclone', 'hear', 'feeling', 'optimistic', 'week'], ['path', 'totality', 'total', 'solar', 'eclipse', 'april', '8', "'ll", 'bring', 'totality', 'broadcast', 'several', 'location', 'along', 'trajectory', 'include', 'center', 'eclipse', 'path', 'watch'], ["'s", 'tough', 'gig', 'binance', 'intern', 'good', 'morning'], ['big', 'red', 'flag', 'adult', 'lack', 'child', 'youre', '46', 'yet', 'bore', 'weed', 'alcohol', 'youre', 'immature', 'soulless', 'trust', 'vote', 'warped', 'world', 'view', 'zero', 'vested', 'interest', 'future', 'poor', 'people', 'alive'], ['1', 'whole', 'bitcoin', 'hodlers', 'become', 'rare'], ['dogecoin', 'tip', 'option', 'eye'], ['introduce', 'new', 'simple', 'earn', 'flexible', 'product', 'promotion', 'subscribe', 'either', 'sui', 'usdt', 'simple', 'earn', 'flexible', 'product', 'grab', 'share', '20000', 'sui', 'also', 'earn', 'bonus', 'apr', 'get', 'start', 'today', 'right', 'arrow', 'curve'], ['6941650bitcoin', 'btc', 'btc', 'usd'], ['law', 'write', 'sign', 'enact', 'tax', 'credit', 'save', 'average', '800', 'per', 'person', 'per', 'year', 'reduce', 'health', 'care', 'premium', 'million', 'family', 'credit', 'expire', 'next', 'year', 'congress', 'make', '800', 'expand', 'affordable', 'health', 'care', 'tax', 'credit', 'permanent'], ['already', 'make', 'statement', 'donald'], ['tag', 'light', 'mode', 'user', 'backhand', 'index', 'point'], ['coinbase', 'blackrock', 'pump', 'crypto', 'high'], ['pitbull', 'chingy', 'baby', 'bash'], ['station', 'head', 'seem', 'work', 'guy', 'shocker'], ['say', 'im', '25', 'im', '25', 'fuk'], ['psalm', 'camera', 'saint'], ['next', 'bitcoin', 'halving', '2', 'week', 'historically', 'gain', 'always', 'realize', 'halving', 'prepared'], ['moment', 'taiwan', 'maternity', 'staff', 'rush', 'keep', 'baby', 'safe', 'earthquake'], ['13900', 'egg', '200000', 'reward', '1', 'bitcoin', ...
# 839
# 0      1
# 1      1
# 2      2
# 3      2
# 4      1
#       ..
# 834    1
# 835    0
# 836    2
# 837    2
# 838    0
# Name: label, Length: 839, dtype: int64
# 839
#                                                Content  Label
# 0    binance towel come everywhere include breakfas...      1
# 1    drop sol address make sure follow dont ask bac...      1
# 2           take one good altcoin change world sparkle      2
# 3                     disrespectful one top 3 favorite      2
# 4    congressional republican call affordable conne...      1
# ..                                                 ...    ...
# 834  ultimate guide festival celebrate latin music ...      1
# 835                       lady gaga fucking movie star      0
# 836  te har salir volando como un cohete rocket col...      2
# 837  youre invite see rogueport may 23 papermarioth...      2
# 838                                       alien mother      0
#
# [839 rows x 2 columns]

# %%
# read the CSV file
df_data_loaded_bert = pd.read_csv('data/preprocessed_data_bert.csv', encoding='utf-8-sig')
print(df_data_loaded_bert)
# Out:
#                                                Content  Label
# 0    [CLS] the # bin ##ance towel comes everywhere ...      1
# 1    [CLS] drop your $ sol address below and make s...      1
# 2    [CLS] it only takes one good alt ##co ##in to ...      2
# 3    [CLS] di ##sr ##es ##pe ##ct ##ful is one of m...      2
# 4    [CLS] some congressional republicans call the ...      1
# ..                                                 ...    ...
# 834  [CLS] the ultimate guide to festivals celebrat...      1
# 835      [CLS] lady gaga is a fucking movie star [SEP]      0
# 836  [CLS] te hare sal ##ir vol ##ando como un co #...      2
# 837  [CLS] you ’ re invited ! see you in rogue ##po...      2
# 838                          [CLS] alien mothers [SEP]      0
#
# [839 rows x 2 columns]
