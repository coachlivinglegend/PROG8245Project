# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Gathering the Data

# %% [markdown]
# For the data collection process,

# %%
import pandas as pd

df = pd.read_csv("./data/texts.csv")
df.head()
# Out:
#                    Name           Handle                 Timestamp  Verified  \
# 0  GamaNoticias Ecuador  @GamaNoticiasEc  2024-03-30T15:04:05.000Z     False
# 1         Historic Vids  @historyinmemes  2024-03-29T15:44:00.000Z      True
# 2           Fascinating       @fasc1nate  2024-03-30T06:00:13.000Z      True
# 3                  kira    @kirawontmiss  2024-03-30T17:06:11.000Z      True
# 4                  ryan      @scubaryan_  2024-03-29T22:20:35.000Z      True
#
#                                              Content Comments Retweets Likes  \
# 0  #Internacionales | La policía registra la casa...       29       29   292
# 1  In 2013, this dude on YouTube begged everyone ...       2K      11K  142K
# 2  Christopher Nolan planted 500 acres of corn fo...      178      574   13K
# 3  the one who was the last survivor of genocide ...      340       3K   53K
# 4  Kai Cenat room setup for his 50+ hour Red Dead...      481     4.5K  104K
#
# ...

# %% [markdown]
# ### talk about the nature of the data here.
