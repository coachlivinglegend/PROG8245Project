# %%
import pickle
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read preprocessed data

# %%
df_sentences = pd.read_csv('data/preprocessed_data.csv')
df_sentences
# Out:
#                                                Content  Label
# 0    binance towel come everywhere include breakfas...      1
# 1    drop sol address make sure follow dont ask bac...      1
# 2           take one good altcoin change world sparkle      2
# 3                     disrespectful one top 3 favorite      2
# 4    congressional republican call affordable conne...      1
# ..                                                 ...    ...
# 838  shakira 's amazing 12th studio album 'las muje...      2
# 839  news tesla overtook mercedes second large sell...      2
# 840  ultimate guide festival celebrate latin music ...      1
# 841  youre invite see rogueport may 23 papermarioth...      2
# 842                                       alien mother      0
#
# [843 rows x 2 columns]

# %% [markdown]
# ### Split data into train and test set

# %%
train, test = train_test_split(df_sentences, test_size=0.2, random_state=42)
train['Label'].value_counts()
# Out:
# Label
# 1    351
# 2    181
# 0    142
# Name: count, dtype: int64

# %% [markdown]
# ### Split into tokens

# %%
train_tokenized = [[word for word in sentence.split()] for sentence in train['Content']]
test_tokenized = [[word for word in sentence.split()] for sentence in test['Content']]
train_tokenized
# Out:
# [['there',
#   'extended',
#   'episode',
#   'vanderpump',
#   'rule',
#   'online',
#   'heres',
#   'watch',
#   'stream',
#   'show',
#   'without',
#   'cable'],
#  ['recent',
#   'article',
#   'press',
#   "'winning",
#   "'",
#   'proxy',
#   'contest',
#   'nelson',
#   'peltz',
#   'base',
#   'early',
#   'election',
#   'return',
#   'leak',
#   'medium',
#   "n't",
#   'investment',
#   'disney',
#   'think',
#   'useful',
#   'point',
#   'inappropriateness'],
#  ['sunlight', 'best', 'disinfectant'],
#  ['katy',
#   'perry',
#   'teenage',
#   'dream',
#   'album',
#   'cover',
#   'actually',
#   'painting'],
#  ['cry', 'face', 'hold', 'back', 'tear', 'purple', 'heart', 'love'],
#  ['know', 'legacy', 'medium', 'notification'],
#  ['entre',
#   'parntesis',
#   'shakira',
#   'grupo',
#   'frontera',
#   'reach',
#   '10',
#   'million',
#   'view',
#   'youtube',
#   'deserve',
#   'waayy',
#   'cowboy',
#   'hat',
#   'face',
#   'watch'],
#  ['city',
#   'dominate',
#   'highway',
#   'car',
#   "'s",
#   'partly',
#   'one',
#   'influential',
#   'people',
#   "'ve",
#   'never',
#   'hear',
#   'norman',
#   'bel',
#   'geddes',
#   '1939',
#   'create',
#   'futurama',
#   'huge',
#   'exhibition',
#   'try',
#   'predict',
#   'future',
#   'end',
#   'change',
#   'world'],
#  ['kanye',
#   'west',
#   'sue',
#   'ex',
#   'donda',
#   'academy',
#   'staffer',
#   'say',
#   'rapper',
#   'threaten',
#   'lock',
#   'student',
#   'cage'],
#  ['lulu', "n't", 'speak', '12', 'noon', "'m", 'lie'],
#  ['seven', 'aid', 'worker', 'kill', 'gaza'],
#  ['tomorrow',
#   'find',
#   'heaven',
#   'release',
#   'flashback',
#   'beginning',
#   'current',
#   'era',
#   'drop',
#   'cause',
#   'life',
#   'change',
#   'day'],
#  ['two',
#   'heart',
#   'gagcitydc',
#   'def',
#   'one',
#   'one',
#   'right',
#   'clothing',
#   'etc'],
#  ['barbie',
#   'touch',
#   'downn',
#   'zany',
#   'face',
#   'pink',
#   'heart',
#   'im',
#   'ready',
#   'babes'],
#  ['coneheads', 'join', 'cone', 'live', 'qa', 'star', 'black', 'heart'],
#  ['coinbase',
#   'officially',
#   'integrate',
#   'bitcoin',
#   'lightning',
#   'network',
#   'clap',
#   'hand',
#   'coinbase',
#   '100',
#   'million',
#   'user',
#   'rocket'],
#  ['jean',
#   'paul',
#   'vignon',
#   'stylish',
#   'french',
#   'vocalist',
#   'actor',
#   'die',
#   '89'],
#  ['police',
#   'car',
#   'light',
#   'conan',
#   'gray',
#   'upcoming',
#   'album',
#   'find',
#   'heaven',
#   '36',
#   '42',
#   'minute',
#   'long',
#   '13',
#   'track',
#   'album',
#   'include',
#   '5',
#   'earlier',
#   'release',
#   'song',
#   'red',
#   'exclamation',
#   'mark',
#   'album',
#   'come',
#   'tomorrow'],
#  ['april',
#   'big',
#   'month',
#   'sky',
#   'gaze',
#   'star',
#   'strike',
#   'big',
#   'planet',
#   'jupiter',
#   'visible',
#   'month',
#   'mar',
#   'saturn',
#   'rise',
#   'together',
#   'april',
#   '10',
#   '11',
#   'big',
#   'eclipse',
#   'april',
#   '8',
#   'catch',
#   'last',
#   'total',
#   'solar',
#   'eclipse',
#   'us',
#   '20',
#   'year',
#   'big',
#   'moon',
#   'catch',
#   'full',
#   'moon',
#   'april',
#   '23'],
#  ['pf2',
#   'tour',
#   'fit',
#   'definitely',
#   'permanently',
#   'sign',
#   'contract',
#   'resident',
#   'gag',
#   'city',
#   'amazing',
#   'show'],
#  ['harry', 'potter', 'say', 'loudly', 'cry', 'face'],
#  ['save',
#   'date',
#   'billboardlatinweek',
#   'return',
#   'miami',
#   'october',
#   'smile',
#   'face',
#   'sunglass',
#   'palm',
#   'tree'],
#  ['baby', 'step', 'sir', 'weary', 'face', 'grin', 'face', 'sweat'],
#  ['microsoft', 'split', 'team', 'office', 'globally'],
#  ['24',
#   'shakira',
#   'create',
#   'worldwide',
#   'hit',
#   'everybody',
#   'remembers',
#   'day',
#   'age',
#   'even',
#   'old',
#   'drag',
#   'internet',
#   'one',
#   'remember',
#   'face',
#   'blow',
#   'kiss'],
#  ['youre', 'right', 'lot', 'wrong', 'crypto'],
#  ['united',
#   'state',
#   'las',
#   'mujeres',
#   'ya',
#   'lloran',
#   'us',
#   'billboard',
#   '1',
#   'top',
#   'latin',
#   'albums',
#   '1',
#   'top',
#   'latin',
#   'pop',
#   'album',
#   '2',
#   'top',
#   'album',
#   'sale',
#   '2',
#   'top',
#   'current',
#   'album',
#   'sale',
#   '4',
#   'top',
#   'vinyl',
#   'album',
#   '13',
#   'billboard',
#   '200',
#   '30',
#   'top',
#   'streaming',
#   'album'],
#  ['break',
#   'coinbase',
#   'work',
#   'lightspark',
#   'integrate',
#   'bitcoin',
#   'lightning',
#   'network',
#   'customer',
#   'high',
#   'voltage'],
#  ['news',
#   'police',
#   'car',
#   'light',
#   'nasa',
#   "'s",
#   'parker',
#   'solar',
#   'probe',
#   'make',
#   '1st',
#   'kind',
#   'observation',
#   'within',
#   'coronal',
#   'mass',
#   'ejection'],
#  ['jordan',
#   'davis',
#   'morgan',
#   'wallen',
#   'big',
#   'loud',
#   'publishing',
#   'lead',
#   '2024',
#   'aimp',
#   'nashville',
#   'country',
#   'award',
#   'honoree'],
#  ['conan', 'still', 'friend', 'group', 'ex', 'oh', 'god'],
#  ['sound', 'exactly', 'like', 'countess', 'scream'],
#  ['joker',
#   'folie',
#   'deux',
#   'feature',
#   'joaquin',
#   'phoenix',
#   'lady',
#   'gaga',
#   'give',
#   'r',
#   'rating',
#   'due',
#   'occasional',
#   'instance',
#   'strong',
#   'violence',
#   'frequent',
#   'use',
#   'explicit',
#   'language',
#   'depiction',
#   'sexuality',
#   'brief',
#   'scene',
#   'full',
#   'nudity'],
#  ['binance',
#   'list',
#   'wormhole',
#   'w',
#   'seed',
#   'tag',
#   'apply',
#   'right',
#   'arrow'],
#  ['everybody',
#   'tonight',
#   'pink',
#   'mother',
#   'cry',
#   'face',
#   'pink',
#   'heart',
#   'heart',
#   'hand',
#   'medium',
#   'skin',
#   'tone',
#   'gagcitydc'],
#  ['kp6',
#   '500k',
#   'copy',
#   'sell',
#   'first',
#   'week',
#   '5',
#   'deluxe',
#   'version',
#   'alternate',
#   'cover',
#   'fraudulent',
#   'radio',
#   'play',
#   'streams',
#   'satanic',
#   'accusation',
#   '6',
#   'tv',
#   'performance',
#   '4',
#   'viral',
#   'song',
#   '3',
#   '1',
#   'hit',
#   'stream',
#   'farm'],
#  ['dont', 'know', 'shell', 'top', 'cover'],
#  ['glorilla',
#   'recall',
#   'beautiful',
#   'feeling',
#   'visit',
#   'white',
#   'house',
#   'still',
#   'havent',
#   'accept',
#   'reality'],
#  ['reiterate',
#   'firm',
#   'call',
#   'immediate',
#   'ceasefire',
#   'gaza',
#   'strip',
#   'express',
#   'deep',
#   'sorrow',
#   'volunteer',
#   'kill',
#   'distribute',
#   'humanitarian',
#   'aid',
#   'gaza',
#   'pray',
#   'family'],
#  ['nicki', 'arrive', 'stage', 'gagcitydc'],
#  ['billboard',
#   'bubble',
#   'hot',
#   '100',
#   '20new',
#   'entre',
#   'parntesis',
#   'grupo',
#   'frontera'],
#  ['sleeper',
#   'hit',
#   'year',
#   'song',
#   'watch',
#   'hit',
#   'come',
#   'go',
#   'stay',
#   'smash',
#   'chart',
#   'loudly',
#   'cry',
#   'face'],
#  ['result', 'find', 'heaven', 'quiz'],
#  ['musician',
#   'vote',
#   'ratify',
#   'new',
#   'contract',
#   'film',
#   'studio',
#   'include',
#   'stream',
#   'residual'],
#  ['wan',
#   'na',
#   'laugh',
#   'remember',
#   'man',
#   'cucked',
#   'buy',
#   'gift',
#   'used',
#   'non',
#   'virgin',
#   'woman',
#   'he',
#   'date',
#   'valentine',
#   'day'],
#  ['magic',
#   'johnson',
#   'post',
#   'heartfelt',
#   'celebration',
#   'live',
#   'icon',
#   'beyoncs',
#   'cowboy',
#   'carter'],
#  ['anyone',
#   'receive',
#   'checkmark',
#   'today',
#   'earn',
#   'money',
#   'stuff',
#   "'re",
#   'already',
#   'post',
#   'extra',
#   'effort',
#   'require',
#   'apply',
#   'monetize',
#   'setting',
#   'monetization'],
#  ['anything', 'overrated', 'solar', 'eclipse', 'face', 'tear', 'joy'],
#  ['global', 'citizen', 'festival', 'return', 'central', 'park', '2024'],
#  ['clothes',
#   'french',
#   'toddler',
#   'emile',
#   'soleil',
#   'find',
#   'near',
#   'remains',
#   'french',
#   'alp'],
#  ['wait', 'final', 'flight'],
#  ["'s", 'never', 'really', 'certified', 'diamond', 'brazil', 'brazil'],
#  ['2024',
#   'mlb',
#   'season',
#   'watch',
#   'baseball',
#   'game',
#   'online',
#   'free',
#   'without',
#   'cable'],
#  ['barbz',
#   'since',
#   'yall',
#   'like',
#   'yappyity',
#   'yapping',
#   'take',
#   'screenshots',
#   'yall',
#   'ass',
#   'report',
#   'station',
#   'head',
#   'im',
#   'gagcity',
#   'giveaway',
#   'right',
#   '10',
#   'min',
#   'wan',
#   'na',
#   'win',
#   'ticket',
#   'ticket',
#   'admission',
#   'ticket',
#   'let',
#   'go',
#   'give',
#   'away',
#   '50',
#   'ticket',
#   '25',
#   'winner',
#   'get',
#   'plus',
#   '1'],
#  ['latin',
#   'music',
#   'week',
#   'return',
#   'miami',
#   'october',
#   '2024',
#   'palm',
#   'tree',
#   'latinmusicweek'],
#  ['happy',
#   'tip',
#   'tuesday',
#   'shibes',
#   'tip',
#   'dogecoin',
#   'dog',
#   'dog',
#   'face',
#   'money',
#   'wing'],
#  ['miss', 'shanel', 'must', 'do'],
#  ['medium',
#   'demand',
#   'tesla',
#   'product',
#   'fade',
#   'reality',
#   'tesla',
#   'model',
#   'best',
#   'selling',
#   'car',
#   'earth',
#   '2023'],
#  ['cake', 'think', 'conan', 'would', 'proud', 'smile', 'face', 'heart'],
#  ['win', 'salute', 'face'],
#  ['beyoncs', 'cowboy', 'carter', 'gallop', '1', 'uk'],
#  ['conans',
#   'gon',
#   'na',
#   'personally',
#   'gate',
#   'arena',
#   'ask',
#   'people',
#   'relationship',
#   'say',
#   'yeah',
#   'hell',
#   'like',
#   'good',
#   'get'],
#  ['one',
#   'didnt',
#   'notice',
#   'conan',
#   'start',
#   'sing',
#   'song',
#   'find',
#   'heaven',
#   'accident',
#   'live',
#   'sheer',
#   'panic',
#   'eye',
#   'loudly',
#   'cry',
#   'face'],
#  ['beyonc', 'finally', 'win', 'album', 'year', 'grammy', 'cowboy', 'carter'],
#  ['poll',
#   'open',
#   'state',
#   'across',
#   'country',
#   'head',
#   'confirm',
#   'poll',
#   'place'],
#  ['cool', 'cool'],
#  ['x',
#   'bring',
#   'tip',
#   'jar',
#   'web',
#   'app',
#   'iosandroid',
#   'feature',
#   'year',
#   "'s",
#   'finally',
#   'find',
#   'way',
#   'web',
#   'version',
#   'see',
#   'full',
#   'list',
#   'supported',
#   'service'],
#  ['introduce',
#   'new',
#   'simple',
#   'earn',
#   'flexible',
#   'product',
#   'promotion',
#   'subscribe',
#   'either',
#   'sui',
#   'usdt',
#   'simple',
#   'earn',
#   'flexible',
#   'product',
#   'grab',
#   'share',
#   '20000',
#   'sui',
#   'also',
#   'earn',
#   'bonus',
#   'apr',
#   'get',
#   'start',
#   'today',
#   'right',
#   'arrow',
#   'curve'],
#  ['big', 'first', 'week', 'beyonc', 'lasso', 'cowboy', 'carter'],
#  ['nicki',
#   'concert',
#   'literally',
#   'everything',
#   'face',
#   'hold',
#   'back',
#   'tear'],
#  ['politician', 'condemn', 'disorder', 'derry', 'parade'],
#  ['father',
#   'crash',
#   'victim',
#   'tell',
#   'funeral',
#   'world',
#   "'now",
#   'empty',
#   "'"],
#  ['conan',
#   'fan',
#   'remember',
#   'conan',
#   'male',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face'],
#  ['bad',
#   'migraine',
#   'ever',
#   'like',
#   '3',
#   'week',
#   'skull',
#   'wont',
#   'thing',
#   'go',
#   'away',
#   'try',
#   'everything',
#   'secret'],
#  ['theyre', 'trouble'],
#  ['justice', 'katy', 'perry', 'broken', 'heart', 'cry', 'cat'],
#  ['mysterious',
#   'streak',
#   'light',
#   'see',
#   'across',
#   'southern',
#   'california',
#   'sky'],
#  ['yup',
#   'im',
#   'journalist',
#   'huffpost',
#   'observer',
#   'fantastic',
#   'news',
#   'outlet',
#   'condemnation',
#   'generate',
#   'hate',
#   'click',
#   'perry',
#   'former',
#   'self',
#   'great',
#   'news',
#   'outlet'],
#  ['massive', 'bitcoin', 'breakout', 'come', 'ready'],
#  ['first',
#   'person',
#   'benefit',
#   'act',
#   'charity',
#   'benefactor',
#   'see',
#   'change',
#   'manner',
#   'find',
#   'peace',
#   'watch',
#   'smile',
#   'form',
#   'lip',
#   'another',
#   'person'],
#  ['lecture',
#   'son',
#   'misplace',
#   'glass',
#   'anxiously',
#   'look',
#   'say',
#   'mommy',
#   'youre',
#   'make',
#   'nervous',
#   'talk',
#   'afterwards',
#   'good',
#   'wrong',
#   'aid',
#   'dysregulation',
#   'mess'],
#  ['every',
#   'dip',
#   'universe',
#   "'s",
#   'way',
#   'ask',
#   'courage',
#   'double',
#   'dream'],
#  ['nine', 'milestone', 'beyonc', 'could', 'reach', '2025', 'grammys'],
#  ['eye',
#   'sky',
#   'april',
#   '8',
#   'total',
#   'solar',
#   'eclipse',
#   'know',
#   'help',
#   'us',
#   'experience',
#   'big',
#   'event',
#   'listen',
#   'scientist',
#   'episode',
#   'curious',
#   'universe',
#   'podcast'],
#  ['beyoncs', 'texas', 'hold', 'em', 'rebound', 'uk'],
#  ['israel',
#   'pm',
#   'say',
#   'force',
#   'unintentionally',
#   'hit',
#   'innocent',
#   'people',
#   'gaza',
#   'strike',
#   'aid',
#   'worker',
#   'kill',
#   'seven',
#   'follow',
#   'late',
#   'update'],
#  ['begin', 'star'],
#  ['police',
#   'car',
#   'light',
#   'break',
#   'police',
#   'car',
#   'light',
#   '1000000000',
#   'usdt',
#   'get',
#   'mint',
#   'tether',
#   'treasury',
#   'yesterday',
#   'also',
#   '1',
#   'billion',
#   'usdt',
#   'mint',
#   'whale',
#   'prepare',
#   'huge',
#   'bitcoin',
#   'pump'],
#  ['fake',
#   'nationalist',
#   'zionist',
#   'agent',
#   'word',
#   'fake',
#   'nationalist',
#   '3',
#   'former',
#   'british',
#   'military',
#   'member',
#   'kill',
#   'israel',
#   'israel',
#   'first'],
#  ['see',
#   'sht',
#   'like',
#   'back',
#   'back',
#   'every',
#   'show',
#   'put',
#   'perspective',
#   'nicki',
#   'minaj',
#   'real',
#   'life',
#   'go',
#   'back',
#   'forth',
#   'fl',
#   'try',
#   'prove',
#   'point',
#   'useless',
#   'nothing',
#   'negative',
#   'even',
#   'phase',
#   "y'all",
#   'let',
#   'live',
#   'delusion'],
#  ['alert',
#   'new',
#   'york',
#   'judge',
#   'juan',
#   'merchan',
#   'deny',
#   'trump',
#   'claim',
#   'presidential',
#   'immunity',
#   'ny',
#   'criminal',
#   'case',
#   'judge',
#   'say',
#   'among',
#   'thing',
#   'trump',
#   'myriad',
#   'opportunity',
#   'raise',
#   'claim',
#   'presidential',
#   'immunity',
#   'well',
#   'march',
#   '7'],
#  ['beyoncs',
#   'cowboy',
#   'carter',
#   'songwriting',
#   'credit',
#   'here',
#   'write',
#   'song'],
#  ['doge', 'og', 'tipping', 'currency', 'internet'],
#  ['left', 'dumb', 'keep', 'win', 'important', 'election'],
#  ['watch', 'full', 'tate', 'confidential', 'episode', 'exclusively', 'rumble'],
#  ['keityn',
#   'feid',
#   'carlos',
#   'vives',
#   'yng',
#   'lvcas',
#   'talk',
#   'major',
#   'win',
#   '2024',
#   'latin',
#   'ascap',
#   'award'],
#  ['congratulation',
#   'select',
#   'move',
#   'forward',
#   'develop',
#   'artemis',
#   'lunar',
#   'terrain',
#   'vehicle',
#   'moon',
#   'rover',
#   'allow',
#   'future',
#   'astronaut',
#   'travel',
#   'far',
#   'lunar',
#   'surface'],
#  ['florida',
#   "'s",
#   'top',
#   'court',
#   'usher',
#   'six',
#   'week',
#   'abortion',
#   'ban',
#   'voter',
#   'say'],
#  ['trade',
#   'responsibly',
#   'employ',
#   'risk',
#   'management',
#   'strategy',
#   'important',
#   'step',
#   'reduce',
#   'portfolio',
#   "'s",
#   'risk',
#   "'ve",
#   'list',
#   '5',
#   'strategy',
#   'find',
#   'right',
#   'backhand',
#   'index',
#   'point'],
#  ['rod',
#   'wave',
#   'arrest',
#   'weapon',
#   'charge',
#   'police',
#   'accuse',
#   'tie',
#   'florida',
#   'gang',
#   'shoot'],
#  ['search', 'antidote', 'debut', '3', 'top', 'album', 'sale', 'chart'],
#  ['interest', 'think', 'face', 'whats', 'go', 'engineering'],
#  ['new', 'look', 'moana', '2', 'november', '27th'],
#  ["'s",
#   '6',
#   'year',
#   'since',
#   'become',
#   'public',
#   'company',
#   'pretty',
#   'wild',
#   'think',
#   'metric',
#   'spotify',
#   '3x',
#   'day',
#   'remind',
#   'bill',
#   'gate',
#   'quote',
#   'people',
#   'overestimate',
#   'one',
#   'year',
#   'underestimate'],
#  ["'s", 'tough', 'gig', 'binance', 'intern', 'good', 'morning'],
#  ['ive',
#   'see',
#   'twice',
#   'tonight',
#   'bmore',
#   'last',
#   'night',
#   'dc',
#   'say',
#   'unequivocally',
#   'must',
#   'see',
#   'front',
#   'row',
#   'forever',
#   'remember',
#   'past',
#   'two',
#   'night',
#   'shes',
#   'undeniable',
#   'queen',
#   'rap',
#   'fanbase',
#   'unmatched',
#   'im',
#   'hook'],
#  ['israel',
#   'pm',
#   'say',
#   'force',
#   'unintentionally',
#   'hit',
#   'innocent',
#   'people',
#   'gaza',
#   'strike',
#   'aid',
#   'worker',
#   'kill',
#   'seven',
#   'follow',
#   'late',
#   'update'],
#  ['im', 'gagcitybaltimore'],
#  ['introduce',
#   'binanceclubhouse',
#   'global',
#   'hub',
#   'binance',
#   'user',
#   'connect',
#   'work',
#   'talk',
#   'thing',
#   'crypto',
#   'stay',
#   'tune',
#   'info',
#   'come',
#   'handshake'],
#  ['apple', 'explore', 'creation', 'home', 'robot', 'next', 'big', 'thing'],
#  ['craig',
#   'gillespie',
#   'talk',
#   'direct',
#   'supergirl',
#   'previously',
#   'direct',
#   'cruella',
#   'tonya',
#   'source',
#   'deadline'],
#  ['4', 'year', 'youre', 'still', 'brokie'],
#  ['richard', 'say', 'go', 'retire', 'soon', 'season', '1'],
#  ['new', 'promotional', 'photo', 'hibiscus'],
#  ['song', 'hat', 'fandom', "'s", 'fuking', 'masterpiece'],
#  ['pharrell',
#   'face',
#   'neptune',
#   'dispute',
#   'lucian',
#   'grainge',
#   'blast',
#   'diddy',
#   'claim',
#   'top',
#   'music',
#   'law',
#   'news'],
#  ['conan', 'lyric', 'feel', 'like'],
#  ['jon',
#   'bernthal',
#   'share',
#   'new',
#   'daredevil',
#   'bear',
#   'bts',
#   'photo',
#   'charlie',
#   'cox',
#   'deborah',
#   'ann',
#   'woll'],
#  ['conan',
#   'sell',
#   'found',
#   'heaven',
#   'necklace',
#   'separately',
#   "n't",
#   'collect',
#   'cd',
#   "'m",
#   'vinyl',
#   'girlie'],
#  ['final', 'deadline', '7', 'spot', 'ethereum', 'etf', '50', 'day'],
#  ['happy',
#   '90th',
#   'birthday',
#   'please',
#   'give',
#   'regard',
#   'mr',
#   'h',
#   'janeat90',
#   'goodallday'],
#  ['usher',
#   'reveal',
#   'super',
#   'bowl',
#   'strategy',
#   'halftime',
#   'veteran',
#   'give',
#   'note'],
#  ['beyoncs', 'cowboy', 'carter', 'gallop', '1', 'uk'],
#  ['new', 'look', 'moana', '2', 'november', '27th'],
#  ['best',
#   'concert',
#   'ever',
#   'cry',
#   'dance',
#   'unicorn',
#   'unicorn',
#   'unicorn',
#   'gagcitybaltimore'],
#  ['say', 'conments', 'boys', 'girl', 'bruh', 'wtf'],
#  ['coneheads', 'time', 'u', 'find', 'find', 'heaven', 'song', 'u'],
#  ['two',
#   'margarita',
#   'deep',
#   'hear',
#   'song',
#   'playing',
#   'call',
#   'go',
#   'way',
#   'like',
#   'wow',
#   'really',
#   'sing',
#   'as',
#   'look',
#   'two',
#   'band',
#   'member',
#   'break',
#   'tear',
#   'go',
#   'way',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'watch',
#   'live',
#   'performance',
#   'cant',
#   'even',
#   'look'],
#  ['man', 'charge', 'murder', 'irish', 'woman', 'new', 'york'],
#  ['slow',
#   'high',
#   'speed',
#   'train',
#   'soccer',
#   'ball',
#   'soccer',
#   'ball',
#   'soccer',
#   'ball'],
#  ['fact',
#   'tony',
#   'keep',
#   'card',
#   'gaga',
#   'im',
#   'emo',
#   'loudly',
#   'cry',
#   'face'],
#  ['police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   '370000000',
#   'usdt',
#   '370047175',
#   'usd',
#   'transfer',
#   'tether',
#   'treasury',
#   'bitfinex'],
#  ['need', 'katys', 'documentary', 'happen', '2017', '2018'],
#  ['tonight', 'tank', 'top', 'say', 'w', 'star', 'men', 'gutsworldtourboston'],
#  ['notable',
#   'add',
#   'us',
#   'rhythmic',
#   'radio',
#   'week',
#   'enough',
#   'miami',
#   '3',
#   'get',
#   'sexyy',
#   '3',
#   'punteria',
#   'ft',
#   '3',
#   'spaghettii',
#   'ft',
#   'lindamartell',
#   '1',
#   'tyrant',
#   'ft',
#   '1',
#   'ya',
#   'ya',
#   '1'],
#  ['dua',
#   'lipa',
#   'tease',
#   'snippet',
#   'new',
#   'album',
#   'radical',
#   'optimism',
#   'beauty',
#   'chaos'],
#  ['united',
#   'state',
#   'us',
#   'government',
#   'send',
#   '30170',
#   'bitcoin',
#   'worth',
#   '2',
#   'billion',
#   'coinbase',
#   'use',
#   'silk',
#   'road',
#   'hack',
#   'fund',
#   'arkham',
#   'data',
#   'show',
#   'eye'],
#  ['julia',
#   'garner',
#   'cast',
#   'female',
#   'silver',
#   'surfer',
#   'fantastic',
#   'four',
#   'source',
#   'deadline'],
#  ['karol', 'g', 'latin', 'america', 'guest', 'maana', 'ser', 'bonito', 'tour'],
#  ['time',
#   'look',
#   'month',
#   "'s",
#   'market',
#   'insights',
#   'research',
#   'team',
#   'analyze',
#   'state',
#   'crypto',
#   'market',
#   'provide',
#   'insight',
#   'bitcoin',
#   'etf',
#   'inflows',
#   'ethereum',
#   "'s",
#   'dencun',
#   'upgrade',
#   'solana',
#   "'s",
#   'dex',
#   'volume',
#   'check',
#   'arrow'],
#  ['crazy', 'happen', '33', 'like', 'jesus'],
#  ['make', 'fall', 'loudly', 'cry', 'face'],
#  ['lizard',
#   'eliminate',
#   'sink',
#   'swim',
#   'experience',
#   'masked',
#   'singer',
#   'im',
#   'use',
#   'lose'],
#  ['rip', 'gale', 'sparrow'],
#  ['kai',
#   'medium',
#   'company',
#   'behind',
#   'k',
#   'pop',
#   'label',
#   'hello82',
#   'raise',
#   'funding',
#   'expansion'],
#  ['think',
#   'conan',
#   'start',
#   'sing',
#   'one',
#   'song',
#   'cause',
#   'start',
#   'sing',
#   'make',
#   'wide',
#   'eye',
#   'stop',
#   'lmfao'],
#  ['today',
#   'year',
#   'old',
#   'find',
#   'ethiopia',
#   '8',
#   'year',
#   'behind',
#   'everyone',
#   'else',
#   "'s",
#   'currently',
#   '2016',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face'],
#  ["n't", 'buy', 'bitcoin', 'first', 'name', 'buy', 'bitcoin', 'last', 'name'],
#  ["'ve",
#   'officially',
#   'hit',
#   '1m',
#   'post',
#   'binance',
#   'square',
#   'thank',
#   'share',
#   'content',
#   'feed',
#   'spread',
#   'crypto',
#   'knowledge',
#   'worldwide',
#   'handshake',
#   'keep',
#   'building',
#   'right',
#   'arrow'],
#  ['roof', 'blow', 'away', 'tree', 'uproot', 'us', 'storm'],
#  ['tune', 'deliver', 'remark', 'lower', 'health', 'care', 'cost', 'american'],
#  ['lady', 'gagas', 'liked', 'instagram', 'post', 'far', 'year'],
#  ['time',
#   'supply',
#   'crypto',
#   'knowledge',
#   'literally',
#   'maximum',
#   'total',
#   'circulate',
#   'supply',
#   'explain',
#   'backhand',
#   'index',
#   'point'],
#  ['marc',
#   'brys',
#   'appointment',
#   'new',
#   'cameroon',
#   'bos',
#   'surprise',
#   'country',
#   "'s",
#   'fa'],
#  ['trust',
#   'men',
#   'easily',
#   'afraid',
#   'loyalty',
#   'require',
#   'bravery',
#   'anyone',
#   'who',
#   'easily',
#   'scar',
#   'easily',
#   'turn',
#   'without',
#   'ball',
#   'sentiment',
#   'man',
#   'mean',
#   'absolutely',
#   'zero',
#   'soon',
#   'weak',
#   'man',
#   'suffer',
#   'person',
#   'loyal',
#   'loyalty',
#   'disappears'],
#  ['future', 'without', 'kid'],
#  ['silver',
#   '8',
#   'week',
#   'video',
#   'genius',
#   'inventor',
#   'ethereum',
#   'call',
#   'crazy',
#   'im',
#   'sticking',
#   'store',
#   'wealth',
#   'back',
#   'far',
#   'time',
#   'mental',
#   'illness',
#   'wasnt',
#   'praise',
#   'virtue'],
#  ['go', 'station', 'head', 'give', 'tkts'],
#  ['like'],
#  ['pitbull', 'big', '3'],
#  ['plenty',
#   'drama',
#   'ziggy',
#   'mackenzie',
#   'sol',
#   'enter',
#   'sing',
#   'americanidol'],
#  ['bitcoin',
#   'symbol',
#   'digital',
#   'revolution',
#   'financial',
#   'freedom',
#   'light',
#   'bulb',
#   'globe',
#   'meridian',
#   'money',
#   'wing'],
#  ['outrage',
#   'heartbroken',
#   'death',
#   'seven',
#   'humanitarian',
#   'worker',
#   'world',
#   'central',
#   'kitchen',
#   'include',
#   'one',
#   'american',
#   'gaza',
#   'yesterday',
#   'incident',
#   'like',
#   'yesterday',
#   'simply',
#   'happen',
#   'full',
#   'statement'],
#  ['thanks',
#   'free',
#   'medium',
#   'particular',
#   'chapter',
#   'genocide',
#   'palestine',
#   'happen',
#   'front',
#   'everybody',
#   "'s",
#   'eye',
#   'pier',
#   'rogan',
#   'trump',
#   'big',
#   'name',
#   'condemn',
#   'happen',
#   'day',
#   'one',
#   'tell',
#   'pier',
#   'would',
#   'happen',
#   'know'],
#  ['new',
#   'senegal',
#   'president',
#   'bassirou',
#   'diomaye',
#   'faye',
#   'two',
#   'wife',
#   'african',
#   'culture',
#   'divorce',
#   'taboo',
#   'man',
#   "n't",
#   'allow',
#   'divorce',
#   'woman',
#   'unless',
#   'commit',
#   'infidelity',
#   'unforgivable',
#   'man',
#   'want',
#   'divorce',
#   'woman',
#   "'s",
#   'longer',
#   'young'],
#  ['polaris',
#   'dawn',
#   'dragon',
#   'head',
#   'vacuum',
#   'chamber',
#   'test',
#   'spacex',
#   'team',
#   'celebrate',
#   'dragon',
#   "'s",
#   'departure',
#   'ahead',
#   'launch',
#   'orbit',
#   'summer'],
#  ['china',
#   'property',
#   'giant',
#   'country',
#   'garden',
#   'suspend',
#   'share',
#   'hong',
#   'kong'],
#  ['travis',
#   'read',
#   'happy',
#   'belated',
#   'independence',
#   'day',
#   'local',
#   'neighborhood',
#   'independent',
#   'girlies',
#   'smile',
#   'face',
#   'sunglass',
#   'see',
#   'tonight',
#   'kansa',
#   'cityy'],
#  ['20',
#   'million',
#   'view',
#   'poster',
#   'one',
#   'twitter',
#   'account',
#   '24',
#   'hour',
#   'actually',
#   'insane',
#   'think'],
#  ['password', 'nbc', 'peacock'],
#  ['sabrina',
#   'carpenter',
#   'channel',
#   '90s',
#   'skim',
#   'sultry',
#   'underwear',
#   'campaign'],
#  ['thank',
#   'hot',
#   'girl',
#   'tip',
#   'day',
#   'face',
#   'tear',
#   'joy',
#   'pink',
#   'heart',
#   'iheartawards2024'],
#  ['struggle',
#   'level',
#   'vip',
#   'now',
#   'chance',
#   'trade',
#   'like',
#   'vip9',
#   'usdc',
#   'margined',
#   'contract',
#   'enjoy',
#   'zero',
#   'maker',
#   'fee',
#   '0017',
#   'taker',
#   'fee',
#   'user',
#   'read',
#   'right',
#   'arrow'],
#  ['love', 'support', 'elon', 'smile', 'face', 'open', 'hand'],
#  ['eminem', 'prank', 'fan', 'april', 'fool', 'day', 'album', 'announcement'],
#  ['al',
#   'hilal',
#   'sudanese',
#   'champion',
#   'play',
#   "'to",
#   'distract',
#   'people',
#   'war',
#   "'"],
#  ['fox',
#   'sport',
#   'resident',
#   'deadhead',
#   'bring',
#   'jam',
#   'band',
#   'big',
#   'game'],
#  ['god',
#   'demonstrate',
#   'soul',
#   'choose',
#   'god',
#   'show',
#   'youre',
#   'heartless',
#   'monster',
#   'gods',
#   'intention',
#   'entire',
#   'world',
#   'disgust',
#   'action'],
#  ['taylor',
#   'swift',
#   'compete',
#   'travis',
#   'kelce',
#   '2024',
#   'webby',
#   'award',
#   'full',
#   'nomination',
#   'announce'],
#  ['neither',
#   'two',
#   'ever',
#   'sign',
#   'normal',
#   'movie',
#   'gon',
#   'na',
#   'heart',
#   'wrench',
#   'love',
#   'story',
#   'time',
#   'trust',
#   'believe'],
#  ['video', 'show', 'abduct', 'us', 'girl', 'fatally', 'shoot', 'police'],
#  ['disrespectful', 'one', 'top', '3', 'favorite'],
#  ['4', 'year', 'youre', 'still', 'brokie'],
#  ['big',
#   'breaking',
#   'police',
#   'car',
#   'light',
#   'bitcoin',
#   'reach',
#   '150k',
#   'end',
#   'year',
#   'per',
#   'morgan',
#   'creek',
#   'capital',
#   'management',
#   'ceo',
#   'mark',
#   'yusko'],
#  ['billionaire', 'gut', 'stand', 'woke', 'mob', 'anybody', 'else'],
#  ['would', 'never', 'recommend', 'client', 'sort', 'business', 'pique'],
#  ['coneheads', 'join', 'cone', 'live', 'qa', 'star', 'black', 'heart'],
#  ['google', 'delete', 'record', 'incognito', 'track'],
#  ['two',
#   'investor',
#   'plead',
#   'guilty',
#   'insider',
#   'trading',
#   'scheme',
#   'link',
#   'trump',
#   'medium',
#   'deal',
#   'bring',
#   'former',
#   'president',
#   "'s",
#   'social',
#   'medium',
#   'business',
#   'public'],
#  ['billie',
#   'eilish',
#   'nicki',
#   'minaj',
#   'want',
#   'stop',
#   "'predatory",
#   "'",
#   'music',
#   'ai'],
#  ['burgerdiseases',
#   'anything',
#   'like',
#   'affluenza',
#   'im',
#   'gon',
#   'na',
#   'scream'],
#  ['im', 'gagcitybaltimore'],
#  ['bassirou',
#   'diomaye',
#   'faye',
#   'senegal',
#   'election',
#   'offer',
#   'hope',
#   'frustrate',
#   'young',
#   'african'],
#  ['im',
#   'tire',
#   'people',
#   'use',
#   'punching',
#   'bag',
#   'leave',
#   'tf',
#   'alone',
#   'day'],
#  ['fact', 'never', 'chart', 'hot', '100', 'insane'],
#  ['album', 'moment', 'cyclone', 'hear', 'feeling', 'optimistic', 'week'],
#  ['katchatheevu',
#   'tiny',
#   'sri',
#   'lankan',
#   'island',
#   'spark',
#   'political',
#   'row',
#   'india'],
#  ['beyonc', 'thanks', 'jack', 'white', 'inspire', 'cowboy', 'carter'],
#  ['watch', 'taiwan', 'earthquake', 'shake', 'man', 'rooftop', 'pool'],
#  ['remember', 'friday', 'wont', 'new', 'music', 'year'],
#  ['break',
#   'guy',
#   'ram',
#   'car',
#   'fbi',
#   'field',
#   'office',
#   'atlanta',
#   'day',
#   'social',
#   'medium',
#   'account',
#   'associate',
#   'q',
#   'anon',
#   'anti',
#   'vaxx',
#   'stuff',
#   'election',
#   'denialism',
#   'sidney',
#   'powell',
#   'donald',
#   'trump',
#   'super',
#   'shock',
#   'source'],
#  ['katy', 'perry', 'next', 'episode', 'american', 'idol'],
#  ['apple', 'explore', 'creation', 'home', 'robot', 'next', 'big', 'thing'],
#  ['queen', 'lil', 'jon', 'sport', 'anthem', 'bear'],
#  ['make', 'america', 'festival', 'cancel', 'second', 'consecutive', 'year'],
#  ['currently',
#   '18h',
#   '53m',
#   '16s',
#   'light',
#   'travel',
#   'time',
#   'earth',
#   '2024',
#   '095',
#   '000000',
#   '1l'],
#  ['oh', 'extremely', 'gaggy', 'babe'],
#  ['fuck'],
#  ['conan',
#   'sell',
#   'found',
#   'heaven',
#   'necklace',
#   'separately',
#   "n't",
#   'collect',
#   'cd',
#   "'m",
#   'vinyl',
#   'girlie'],
#  ['police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   'police',
#   'car',
#   'light',
#   '4824',
#   'btc',
#   '317962687',
#   'usd',
#   'transfer',
#   'unknown',
#   'wallet',
#   'coinbase',
#   'institutional'],
#  ['barbie',
#   'touch',
#   'downn',
#   'zany',
#   'face',
#   'pink',
#   'heart',
#   'im',
#   'ready',
#   'babes'],
#  ['person', 'texas', 'diagnose', 'rare', 'bird', 'flu', 'contact', 'cattle'],
#  ['three',
#   'seven',
#   'aid',
#   'worker',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'british',
#   'charity',
#   'world',
#   'central',
#   'kitchen',
#   'confirms'],
#  ['never', '2763', 'bitcoin'],
#  ['three',
#   'british',
#   'aid',
#   'worker',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'name'],
#  ['bitcoin', 'hit', '100000', 'next', '3', 'month', 'delete', 'x', 'account'],
#  ['look',
#   'like',
#   'lg7',
#   'process',
#   'go',
#   'reverse',
#   'record',
#   'january',
#   'mastering',
#   'february',
#   'write',
#   'march',
#   'gaga',
#   "'s",
#   'happen'],
#  ['battle',
#   'future',
#   'civilization',
#   'free',
#   'speech',
#   'lose',
#   'even',
#   'america',
#   'tyranny',
#   'lie',
#   'ahead'],
#  ['justice', 'katy', 'perry', 'broken', 'heart', 'cry', 'cat'],
#  ['album', 'make', 'noise', 'friday'],
#  ['final',
#   'fight',
#   'wish',
#   'one',
#   'say',
#   'last',
#   'thing',
#   'relationship',
#   'end',
#   'guess',
#   'thats',
#   'short',
#   'imagine',
#   'like',
#   'back',
#   'forth',
#   'end',
#   'abruptly',
#   'cuz',
#   'didnt',
#   'get',
#   'last',
#   'word',
#   'listen'],
#  ['know', 'dumb', 'as', 'richy', 'jackson', 'choreo', 'see'],
#  ['need', 'katys', 'documentary', 'happen', '2017', '2018'],
#  ['news',
#   'cathie',
#   'wood',
#   'say',
#   'still',
#   '2000',
#   'price',
#   'target',
#   'tsla',
#   'share',
#   'time',
#   'run',
#   'hill',
#   'say',
#   'cnbc'],
#  ['whenever',
#   'wherever',
#   'big',
#   'stream',
#   'day',
#   '2024',
#   'spotify',
#   'yesterday',
#   '479768',
#   'stream',
#   'la',
#   'tortura',
#   'big',
#   'streaming',
#   'day',
#   'ever',
#   'platform',
#   '408059',
#   'source'],
#  ['raymonte', 'wrong'],
#  ['live',
#   'future',
#   'astronaut',
#   'drive',
#   'across',
#   'surface',
#   'moon',
#   "'re",
#   'announce',
#   'company',
#   'advance',
#   'capability',
#   'lunar',
#   'terrain',
#   'vehicle',
#   'rover',
#   'exploration',
#   'artemis',
#   'v',
#   'mission',
#   'beyond'],
#  ['talk',
#   'beyoncs',
#   'cowboy',
#   'carter',
#   'compare',
#   'new',
#   'album',
#   'beatles',
#   'white',
#   'album',
#   'shes',
#   'get',
#   'gut'],
#  ['lizzo',
#   'clarifies',
#   'quit',
#   'music',
#   'industry',
#   "'negative",
#   'energy',
#   "'"],
#  ['rashee',
#   'rice',
#   'super',
#   'bowl',
#   'champion',
#   'admit',
#   'role',
#   'texas',
#   'hit',
#   'run'],
#  ['joker',
#   'folie',
#   'deux',
#   'star',
#   'joaquin',
#   'phoenix',
#   'lady',
#   'gaga',
#   'rat',
#   'r',
#   'strong',
#   'violence',
#   'language',
#   'throughout',
#   'sexuality',
#   'brief',
#   'full',
#   'nudity'],
#  ['feid', 'announces', 'joint', 'album', 'yandel', 'here', 'know'],
#  ['offense',
#   'bardi',
#   'cu',
#   'dominican',
#   'parent',
#   'black',
#   'one',
#   'loudly',
#   'cry',
#   'face',
#   'black',
#   'heart'],
#  ['binance', 'towel', 'come', 'everywhere', 'include', 'breakfast', 'cooking'],
#  ['green',
#   'circle',
#   'facebook',
#   'red',
#   'circle',
#   'instagram',
#   'red',
#   'circle',
#   'whatsapp',
#   'red',
#   'circle'],
#  ['wonder',
#   'canonical',
#   'explanation',
#   'gagas',
#   'harley',
#   'blonde',
#   'brunette',
#   'root',
#   'harley',
#   'happen',
#   'like',
#   'bleach',
#   'hair',
#   'like',
#   'stefani',
#   'change',
#   'hair',
#   'arthur',
#   'blonde'],
#  ['venice', 'launch', 'new', 'career', 'assistant', 'tool', 'artist'],
#  ['dont', 'give', 'damn', 'pretty', 'australia', 'never', 'see'],
#  ['oh', 'bitch', 'eat', 'time', '10', 'tonight', 'baltimore'],
#  ['harleys',
#   'hawaii',
#   'de',
#   'katy',
#   'perry',
#   'ultrapassou',
#   'marca',
#   'de',
#   '500',
#   'milhes',
#   'de',
#   'streams',
#   'spotify',
#   'hibiscus'],
#  ['conans',
#   'gon',
#   'na',
#   'personally',
#   'gate',
#   'arena',
#   'ask',
#   'people',
#   'relationship',
#   'say',
#   'yeah',
#   'hell',
#   'like',
#   'good',
#   'get'],
#  ['bizarraps', 'best', 'music', 'session', 'rank', 'critic', 'pick'],
#  ['honestly',
#   'great',
#   'product',
#   'feel',
#   'energized',
#   'strong',
#   'ever',
#   'since',
#   'ive',
#   'take'],
#  ['hate', 'pending', 'transaction', 'please', 'take', 'money'],
#  ['tip',
#   'jar',
#   'soon',
#   'available',
#   'web',
#   'significantly',
#   'benefit',
#   'creator',
#   'platform',
#   'via'],
#  ['highkey', 'need', 'gaga', 'comedy', 'joker', '2', 'cycle'],
#  ['wrong',
#   'netanyahu',
#   'try',
#   'prevent',
#   'israeli',
#   'see',
#   'reality',
#   'ground',
#   'gaza',
#   'thats',
#   'autocrat',
#   'democratic',
#   'leader'],
#  ['two',
#   'margarita',
#   'deep',
#   'hear',
#   'song',
#   'playing',
#   'call',
#   'go',
#   'way',
#   'like',
#   'wow',
#   'really',
#   'sing',
#   'as',
#   'look',
#   'two',
#   'band',
#   'member',
#   'break',
#   'tear',
#   'go',
#   'way',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'watch',
#   'live',
#   'performance',
#   'cant',
#   'even',
#   'look'],
#  ['first', 'look', 'mufasa', 'lion', 'king', 'theater', 'december', '20'],
#  ['hunter',
#   'schafer',
#   'euphoria',
#   'star',
#   'say',
#   'longer',
#   'want',
#   'play',
#   'trans',
#   'character'],
#  ['french', 'couple', 'keep', '159', 'cat', 'ban', 'keep', 'pet'],
#  ['still',
#   'cant',
#   'believe',
#   'truly',
#   'one',
#   'memorable',
#   'night',
#   'love',
#   'every',
#   'second',
#   'every',
#   'moment',
#   'thank',
#   'barb',
#   'whove',
#   'supportive',
#   'true',
#   'best',
#   'love',
#   'guy',
#   'cloud',
#   'pink',
#   'heart',
#   'gagcitydc',
#   'gagcitydmv'],
#  ['kirsten',
#   'dunst',
#   'jonathan',
#   'glazer',
#   'oscars',
#   'speech',
#   'interpretation',
#   'say',
#   'genocide',
#   'bad'],
#  ['slipknot',
#   'avenge',
#   'sevenfold',
#   'disturb',
#   'headline',
#   '2024',
#   'rocklahoma',
#   'festival'],
#  ['yo', 'ive', 'never', 'see', 'bad', 'customer', 'service', 'life'],
#  ['taylor',
#   'swift',
#   'compete',
#   'travis',
#   'kelce',
#   '2024',
#   'webby',
#   'award',
#   'full',
#   'nomination',
#   'announce'],
#  ['new', 'shakira', 'collaboration', 'way', 'xx'],
#  ['company', 'want', 'recycle', 'instrument', 'string', 'across', 'globe'],
#  ['dont', 'know', 'shell', 'top', 'cover'],
#  ['boy', 'girl', 'song', 'take', 'long', 'write'],
#  ['united',
#   'state',
#   'las',
#   'mujeres',
#   'ya',
#   'lloran',
#   'us',
#   'billboard',
#   '1',
#   'top',
#   'latin',
#   'albums',
#   '1',
#   'top',
#   'latin',
#   'pop',
#   'album',
#   '2',
#   'top',
#   'album',
#   'sale',
#   '2',
#   'top',
#   'current',
#   'album',
#   'sale',
#   '4',
#   'top',
#   'vinyl',
#   'album',
#   '13',
#   'billboard',
#   '200',
#   '30',
#   'top',
#   'streaming',
#   'album'],
#  ['mental',
#   'fragility',
#   'promote',
#   'every',
#   'opportunity',
#   'people',
#   'wonder',
#   'depression',
#   'increase',
#   'taboo',
#   'tell',
#   'people',
#   'think',
#   'strong',
#   'strong',
#   'act',
#   'strong',
#   'tell',
#   'cave',
#   'instantly',
#   'emotion',
#   'time',
#   'dangerous'],
#  ['want',
#   'honest',
#   'criticism',
#   'ai',
#   'portfolio',
#   '25',
#   'btc15',
#   'tao15',
#   'rndr10',
#   'grt10',
#   'akt5',
#   'ait5',
#   'paal5'],
#  ['katchatheevu',
#   'tiny',
#   'sri',
#   'lankan',
#   'island',
#   'spark',
#   'political',
#   'row',
#   'india'],
#  ['la',
#   'mujeres',
#   'ya',
#   'lloran',
#   'hit',
#   'number',
#   'one',
#   'top',
#   'latin',
#   'album',
#   'latin',
#   'pop',
#   'album',
#   'gem',
#   'stone'],
#  ['start', 'sink', 'conan', 'album', 'soon', 'guys', 'oh', 'word'],
#  ['gaga',
#   'house',
#   'gucci',
#   'get',
#   'drag',
#   'accent',
#   'joker',
#   "'s",
#   'get',
#   'drag',
#   'one'],
#  ['notch', 'second', 'hot', 'rock', 'alternative', 'songs', '1', 'sweet'],
#  ['alien', 'mother'],
#  ['special', 'announcement', 'week', 'guest', 'fire'],
#  ['instead',
#   'senior',
#   'diabetes',
#   'pay',
#   'much',
#   '400',
#   'month',
#   'insulin',
#   'badly',
#   'need',
#   'pay',
#   '35',
#   'month',
#   'period',
#   'want',
#   'extend',
#   'saving',
#   'everyone',
#   'need',
#   'lifesaving',
#   'insulin',
#   'whether',
#   'youre',
#   'senior'],
#  ['deadly',
#   'air',
#   'strike',
#   'show',
#   'system',
#   'protect',
#   'aid',
#   'worker',
#   'crisis',
#   'agency',
#   'say'],
#  ['cant', 'believe', 'era', 'little', 'monster', 'abandon'],
#  ['incredible', 'team', 'engineer', 'build', 'app', 'change', 'everything'],
#  ['reason',
#   'felt',
#   'comfortable',
#   'call',
#   'mexican',
#   'im',
#   'dominican',
#   'ask',
#   'feel',
#   'comfortable',
#   'call',
#   'mexican',
#   'ice',
#   'jharell',
#   'jerome',
#   'zoe',
#   'saldana',
#   'dominican',
#   'dont',
#   'know',
#   'thats',
#   'people',
#   'use'],
#  ['katy', 'perry', 'x', 'american', 'idol'],
#  ['man',
#   'go',
#   'viral',
#   'say',
#   'soulja',
#   'boy',
#   'rap',
#   'legend',
#   'nipsey',
#   'hussle'],
#  ['crawler',
#   'transporter',
#   '2',
#   'update',
#   'prepare',
#   'future',
#   'mission',
#   'right',
#   'arrow',
#   'curve'],
#  ['dead', 'wife', 'beginning', 'movie'],
#  ['break',
#   'president',
#   'trump',
#   'say',
#   'win',
#   'tax',
#   'cut',
#   'economic',
#   'boom'],
#  ['bet', 'future', 'bitcoin'],
#  ['united',
#   'state',
#   'us',
#   'government',
#   'transfer',
#   '30174',
#   'bitcoin',
#   'worth',
#   '21',
#   'billion',
#   'seize',
#   'silk',
#   'road',
#   'coinbase'],
#  ['nicole',
#   'richie',
#   'joel',
#   'maddens',
#   'kid',
#   'parent',
#   'lookalikes',
#   'red',
#   'carpet',
#   'debut'],
#  ['3',
#   'sleep',
#   'till',
#   'wrestlemania',
#   '40',
#   'talk',
#   'show',
#   'tonight',
#   'finalboss',
#   'tribalchief'],
#  ['start',
#   'stan',
#   'twitter',
#   'start',
#   'concept',
#   'era',
#   'start',
#   'whole',
#   'mother',
#   'fanbase',
#   'relationship',
#   'like',
#   'im',
#   'serious'],
#  ['listen',
#   'lot',
#   'friend',
#   'make',
#   'ton',
#   'ton',
#   'money',
#   'crypto',
#   'cling',
#   'little',
#   'bag',
#   'silver',
#   'realize',
#   'crypto',
#   'successful',
#   'last',
#   'several',
#   'year',
#   'think',
#   'would',
#   'obviously',
#   'admit',
#   'people',
#   'shouldnt',
#   'take',
#   'investment'],
#  ['dont', 'pinch', 'please'],
#  ['insufferable',
#   'literally',
#   'keep',
#   'legit',
#   'could',
#   'never',
#   'go',
#   'eat',
#   'around',
#   'someone',
#   'like',
#   'dont',
#   'care',
#   'disordered',
#   'relationship',
#   'food',
#   'shut'],
#  ['full', 'nudityy', 'good', 'ga'],
#  ['im', 'freak', 'need'],
#  ['equal', 'treatment', 'equal', 'outcome', 'pick', 'one'],
#  ['white', 'house', 'want', 'moon', 'time', 'zone'],
#  ['yg', 'entertainment', 'name', 'yang', 'min', 'seok', 'sole', 'ceo'],
#  ['minnie',
#   'take',
#   'awf',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   "y'all",
#   'see',
#   'minussy',
#   'like'],
#  ['thank', 'baby', 'kiss', 'mark'],
#  ['lady', 'gaga', 'desperate', 'oscar', 'meanwhile', 'lady', 'gaga'],
#  ['everything',
#   'app',
#   'get',
#   'close',
#   'every',
#   'single',
#   'day',
#   'build',
#   'new',
#   'way',
#   'everyone',
#   'find',
#   'community',
#   'connect',
#   'one',
#   'another'],
#  ['big',
#   'breaking',
#   'police',
#   'car',
#   'light',
#   'bitcoin',
#   'reach',
#   '150k',
#   'end',
#   'year',
#   'per',
#   'morgan',
#   'creek',
#   'capital',
#   'management',
#   'ceo',
#   'mark',
#   'yusko'],
#  ['donald', 'trump', 'get', 'boo', 'mi', 'today', 'bring', 'joy', 'heart'],
#  ['botswana', 'offer', 'send', '20000', 'elephant', 'germany'],
#  ['two',
#   'margarita',
#   'deep',
#   'hear',
#   'song',
#   'playing',
#   'call',
#   'go',
#   'way',
#   'like',
#   'wow',
#   'really',
#   'sing',
#   'as',
#   'look',
#   'two',
#   'band',
#   'member',
#   'break',
#   'tear',
#   'go',
#   'way',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'watch',
#   'live',
#   'performance',
#   'cant',
#   'even',
#   'look'],
#  ["'s",
#   'las',
#   'mujeres',
#   'ya',
#   'lloran',
#   'storm',
#   '1',
#   'top',
#   'latin',
#   'album',
#   'latin',
#   'pop',
#   'album'],
#  ['performer', 'presenter', '2024', 'cmt', 'music', 'award'],
#  ['atta',
#   'baby',
#   'flag',
#   'hole',
#   '40',
#   '500',
#   'winner',
#   'money',
#   'bag',
#   'money',
#   'bag',
#   'radio',
#   'button',
#   'repost',
#   'video',
#   'radio',
#   'button',
#   'reply',
#   'say',
#   'something',
#   'nice',
#   'somebody',
#   'radio',
#   'button',
#   'put',
#   'easy',
#   'way',
#   'pay',
#   'post',
#   'wellpmslive'],
#  ['time', 'katycats', 'move', 'justiceforkatyperry'],
#  ["'s", 'never', 'really', 'certified', 'diamond', 'brazil', 'brazil'],
#  ['tether', 'print', 'high', 'bitcoin', 'go'],
#  ['wear',
#   'solar',
#   'glass',
#   'space',
#   'smile',
#   'face',
#   'sunglass',
#   'million',
#   'people',
#   'earth',
#   'watch',
#   'total',
#   'solar',
#   'eclipse',
#   'april',
#   '8',
#   'astronaut',
#   'aboard',
#   'space',
#   'station',
#   'watch',
#   '250',
#   'mile',
#   'theyll',
#   'three',
#   'opportunity',
#   'view',
#   'ground',
#   'shadow',
#   'orbit',
#   'earth'],
#  ["'s", 'go'],
#  ['sleeper',
#   'hit',
#   'year',
#   'song',
#   'watch',
#   'hit',
#   'come',
#   'go',
#   'stay',
#   'smash',
#   'chart',
#   'loudly',
#   'cry',
#   'face'],
#  ['funimation', 'officially', 'close'],
#  ['aileen',
#   'cannon',
#   'remove',
#   'case',
#   'long',
#   'time',
#   'ago',
#   'bullshit',
#   'ruling',
#   'blatantly',
#   'cause',
#   'delay',
#   'favor',
#   'defendant',
#   'trump',
#   "'s",
#   'fucking',
#   'joke'],
#  ['35',
#   'month',
#   'insulin',
#   'senior',
#   '35',
#   'inhaler',
#   'asthma',
#   '2000',
#   'year',
#   'cap',
#   'prescription',
#   'drug',
#   'senior',
#   'start',
#   'next',
#   'year',
#   'senator',
#   'sander',
#   "'",
#   'help',
#   'show',
#   'health',
#   'care',
#   'right',
#   'privilege',
#   'america'],
#  ['one',
#   'child',
#   'dead',
#   'two',
#   'seriously',
#   'wound',
#   'finland',
#   'school',
#   'shooting',
#   'pupil',
#   '12',
#   'open',
#   'fire',
#   'police',
#   'say'],
#  ['community', 'note', 'active', 'india'],
#  ['playstation',
#   '5',
#   'deal',
#   'limited',
#   'edition',
#   'spider',
#   'man',
#   '2',
#   'console',
#   'bundle',
#   '110',
#   'amazon'],
#  ['fox',
#   'sport',
#   'resident',
#   'deadhead',
#   'bring',
#   'jam',
#   'band',
#   'big',
#   'game'],
#  ['big',
#   'red',
#   'flag',
#   'adult',
#   'lack',
#   'child',
#   'youre',
#   '46',
#   'yet',
#   'bore',
#   'weed',
#   'alcohol',
#   'youre',
#   'immature',
#   'soulless',
#   'trust',
#   'vote',
#   'warped',
#   'world',
#   'view',
#   'zero',
#   'vested',
#   'interest',
#   'future',
#   'poor',
#   'people',
#   'alive'],
#  ['please',
#   'pray',
#   'xavier',
#   'he',
#   'surgery',
#   'right',
#   'remove',
#   'neuroblastoma',
#   'cancer',
#   'chest',
#   'spine',
#   'thank',
#   'love',
#   'boyxaviersfight',
#   'purple',
#   'heart',
#   'reminder',
#   'ribbon',
#   'yellow',
#   'heart'],
#  ['janet',
#   'jackson',
#   'return',
#   'japan',
#   'triumphant',
#   'together',
#   'tour',
#   'chronicle',
#   'legendary',
#   'career'],
#  ['could', 'ethiopian', 'emperor', 'steal', 'clothes', 'find', 'manchester'],
#  ['next',
#   'bitcoin',
#   'halving',
#   '2',
#   'week',
#   'historically',
#   'gain',
#   'always',
#   'realize',
#   'halving',
#   'prepared'],
#  ['country',
#   'garden',
#   'china',
#   'property',
#   'giant',
#   'suspend',
#   'share',
#   'hong',
#   'kong'],
#  ['starship',
#   'mar',
#   'within',
#   'decade',
#   'cant',
#   'wait',
#   'help',
#   'build',
#   'booster',
#   'thatll',
#   'send',
#   'way',
#   'face',
#   'steam',
#   'nose',
#   'fire',
#   'rocket'],
#  ['dont', 'give', 'damn', 'pretty', 'australia', 'never', 'see'],
#  ['first',
#   'poster',
#   'joker',
#   '2',
#   'star',
#   'joaquin',
#   'phoenix',
#   'lady',
#   'gaga'],
#  ['analysis',
#   'putin',
#   'interview',
#   'street',
#   'smart',
#   'ive',
#   'never',
#   'profess',
#   'anything',
#   'else',
#   'street',
#   'smart',
#   'take',
#   'high',
#   'echelon',
#   'finance',
#   'fame',
#   'without',
#   'sell',
#   'soul',
#   'leave',
#   'pit',
#   'mortal',
#   'battle',
#   'matrix'],
#  ['red', 'clay', 'stray', 'set', 'european', 'concert', 'date'],
#  ['new',
#   'look',
#   'moana',
#   '2',
#   'set',
#   '3',
#   'year',
#   'first',
#   'movie',
#   'theater',
#   'november',
#   '27'],
#  ['think',
#   'bourgeoisie',
#   'suppose',
#   'mashup',
#   'word',
#   'bourgeoisie',
#   'diseases',
#   'kinda',
#   'like',
#   'affluenza',
#   'mix',
#   'affluence',
#   'influenza'],
#  ['obsess',
#   'photo',
#   'series',
#   'call',
#   'window',
#   'masahisa',
#   'fukase',
#   'take',
#   'photo',
#   'wife',
#   'apartment',
#   'window',
#   'almost',
#   'everyday',
#   'leave',
#   'face',
#   'hold',
#   'back',
#   'tear'],
#  ['harleys',
#   'hawaii',
#   'katy',
#   'perry',
#   'reach',
#   '500',
#   'million',
#   'stream',
#   'spotify',
#   '15th',
#   'song',
#   'achieve'],
#  ['tesla', "'disaster", "'", 'few', 'delivery', 'since', '2022'],
#  ['week',
#   'america',
#   'lose',
#   'hero',
#   'lou',
#   'conter',
#   'pass',
#   'away',
#   'age',
#   '102',
#   'america',
#   'say',
#   'farewell',
#   'last',
#   'known',
#   'survivor',
#   'us',
#   'arizona',
#   'station',
#   'battleship',
#   'row',
#   'pearl',
#   'harbor',
#   'december',
#   '7',
#   '1941',
#   'today',
#   'heart',
#   'know'],
#  ['joker',
#   'trailer',
#   'didnt',
#   'release',
#   'yet',
#   'even',
#   'close',
#   'october',
#   'already',
#   'defend',
#   'gaga',
#   'harley',
#   'role',
#   'weve',
#   'get',
#   'big',
#   'storm',
#   'come'],
#  ['finallyy', 'messy', 'highlight', 'wayy'],
#  ['say', 'house', 'gucci', 'best', 'poster'],
#  ['jimmy', 'butler', 'update'],
#  ['remember',
#   'hero',
#   'family',
#   'pay',
#   'tribute',
#   'james',
#   'kirby',
#   'one',
#   'three',
#   'briton',
#   'kill',
#   'israeli',
#   'strike',
#   'gaza',
#   'aid',
#   'convoy'],
#  ["n't", 'panic', 'salute', 'face'],
#  ['playlist',
#   'design',
#   'give',
#   'power',
#   'fire',
#   'blood',
#   'badmann',
#   'riddims',
#   'power',
#   'guarantee',
#   'use',
#   'power',
#   'playlist',
#   'hold',
#   'exact',
#   'riddims',
#   'listen',
#   'ascent',
#   '4x',
#   'world',
#   'champion',
#   'hold',
#   'music',
#   'power'],
#  ['x', 'soon', 'let', 'save', 'trend', 'explore', 'tab'],
#  ['time', 'katycats', 'move', 'justiceforkatyperry'],
#  ['casey', 'wasserman', 'music', 'sport', 'false', 'theory', 'star'],
#  ['bitcoin',
#   'go',
#   '100000',
#   'eth',
#   'go',
#   '10000',
#   'altcoins',
#   'pump',
#   '10x',
#   'halve',
#   '15',
#   'day',
#   'bullish',
#   'enough'],
#  ['think',
#   'might',
#   'confusion',
#   'say',
#   'ask',
#   'feel',
#   'comfortable',
#   'call',
#   'mexican',
#   'mexican',
#   'parent',
#   'mom',
#   'trini',
#   'come',
#   'whole',
#   'black',
#   'woman',
#   'father',
#   'dominicanim',
#   'dominican',
#   'like',
#   'also',
#   'use',
#   'dominican'],
#  ['feid', 'announces', 'joint', 'album', 'yandel', 'here', 'know'],
#  ['barbies',
#   'bad',
#   'girls',
#   'aint',
#   'play',
#   'tag',
#   'two',
#   'heart',
#   'star',
#   'strike',
#   'gagcitybaltimore'],
#  ['hedge',
#   'fund',
#   'billionaire',
#   'steve',
#   'cohen',
#   'tell',
#   'cnbc',
#   'own',
#   'little',
#   'amount',
#   'bitcoin',
#   'eye'],
#  ['joker',
#   '2',
#   'trailer',
#   'really',
#   'come',
#   'break',
#   'internet',
#   'talk',
#   'hundred',
#   'million',
#   'view',
#   'across',
#   'platform',
#   'global',
#   'event'],
#  ['police',
#   'car',
#   'light',
#   'attention',
#   'katycats',
#   'friend',
#   'industry',
#   'always',
#   'cruel',
#   'katy',
#   'perry',
#   'need',
#   'bring',
#   'everyone',
#   "'s",
#   'attention',
#   'reply',
#   'tweet',
#   'withjusticeforkatyperry',
#   'goal',
#   '100',
#   'reply'],
#  ['thats',
#   'say',
#   'say',
#   'nobody',
#   'call',
#   'ghetto',
#   'move',
#   'goal',
#   'post',
#   'know',
#   'im',
#   'im',
#   'right',
#   'take',
#   'no',
#   'recognize',
#   'change',
#   'change',
#   'way',
#   'talk',
#   'way',
#   'act',
#   'way',
#   'respond'],
#  ['baltimore',
#   'big',
#   'one',
#   'barbie',
#   'dangerous',
#   'lemon',
#   'drop',
#   'loudly',
#   'cry',
#   'face',
#   'gagcitybaltimore'],
#  ['refuse',
#   'speak',
#   'meaning',
#   'behind',
#   'boys',
#   'girl',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face'],
#  ['sleeper',
#   'hit',
#   'year',
#   'song',
#   'watch',
#   'hit',
#   'come',
#   'go',
#   'stay',
#   'smash',
#   'chart',
#   'loudly',
#   'cry',
#   'face'],
#  ['google', 'delete', 'record', 'incognito', 'track'],
#  ['remember'],
#  ['three',
#   'station',
#   'crew',
#   'member',
#   'include',
#   'astronaut',
#   'loral',
#   "o'hara",
#   'schedule',
#   'begin',
#   'return',
#   'earth',
#   'friday',
#   'april',
#   '5',
#   'nasa',
#   'tv',
#   'provide',
#   'live',
#   'coverage',
#   'departure',
#   'landing'],
#  ['like', 'eat', 'gagcitybaltimore', 'nicki', 'love'],
#  ['nothing', 'make', 'happy', 'kid', 'elon', 'musk'],
#  ['way', 'guy', 'use', 'mexican', 'insult', 'fuck', 'weird'],
#  ['spotify',
#   'top',
#   'song',
#   '0402',
#   'stream',
#   'hip',
#   "n't",
#   'lie',
#   '1138286',
#   'tqg',
#   '1038174',
#   'puntera',
#   '961461',
#   'entre',
#   'parntesis',
#   '846840',
#   'cohete',
#   '603393',
#   'bzrp',
#   'music',
#   'session',
#   'vol',
#   '53',
#   '570837',
#   'whenever',
#   'wherever',
#   '479768',
#   'chantaje',
#   '422502',
#   'la',
#   'tortura',
#   '408059',
#   'dia',
#   'de',
#   'enero',
#   '403425'],
#  ['whale',
#   'watch',
#   'bucket',
#   'list',
#   "'ll",
#   'glad',
#   'know',
#   "n't",
#   'travel',
#   'well',
#   'crypto',
#   'whale',
#   'watch',
#   'anyway'],
#  ['billie',
#   'piper',
#   'say',
#   'classmate',
#   'amy',
#   'winehouse',
#   'bully',
#   'school'],
#  ['ukraine', 'lower', 'combat', 'call', 'age', 'boost', 'number'],
#  ['swifties',
#   'hate',
#   'kanye',
#   'bc',
#   'taylor',
#   'hate',
#   'bc',
#   'he',
#   'vile',
#   'human',
#   'taylor',
#   'reflection'],
#  ['ohh',
#   'gots',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'smile',
#   'face',
#   'heart',
#   'eye',
#   'two',
#   'heart'],
#  ['best', 'bravest', 'baddest', 'barbz', 'win'],
#  ['shakira',
#   'drag',
#   'north',
#   'american',
#   'uncultured',
#   'ass',
#   'loudly',
#   'cry',
#   'face'],
#  ['kamala',
#   'continue',
#   'call',
#   'congress',
#   'restore',
#   'protection',
#   'roe',
#   'every',
#   'state',
#   'majority',
#   'american',
#   'support',
#   'woman',
#   "'s",
#   'right',
#   'choose',
#   'include',
#   'florida',
#   'voter',
#   'opportunity',
#   'support',
#   'reproductive',
#   'freedom',
#   'ballot',
#   'initiative',
#   'fall'],
#  ['break',
#   'sec',
#   'request',
#   'public',
#   'comment',
#   'major',
#   'ethereum',
#   'spot',
#   'etf'],
# ...
#   'attack',
#   'world',
#   'trade',
#   'center',
#   'tunnel',
#   'close',
#   'traffic',
#   'flee',
#   'manhattan',
#   'via',
#   'bridge',
#   'reach',
#   'standstill',
#   'many',
#   'civilian',
#   'especially',
#   'neighborhood',
#   'closest',
#   'attack',
#   'desperate',
#   'escape',
#   'island',
#   'way'],
#  ['chance',
#   'rapper',
#   'wife',
#   'kirsten',
#   'corley',
#   'announce',
#   'divorce',
#   '5',
#   'year',
#   'marriage'],
#  ['shakira', 'set', 'appear', 'hot', 'one', 'thursday'],
#  ['still', 'argentina', 'star', 'star', 'star', 'gutsworldtour'],
#  ['tag', 'light', 'mode', 'user', 'backhand', 'index', 'point'],
#  ['elon',
#   'la',
#   'benjamin',
#   'franklin',
#   'tesla',
#   'midjourney',
#   'prompt',
#   'benjamin',
#   'franklin',
#   'drive',
#   'tesla',
#   'grin',
#   'squint',
#   'face',
#   'sparkle'],
#  ['irish',
#   'basketball',
#   'team',
#   'order',
#   'replay',
#   'last',
#   '03',
#   'second',
#   'quarter',
#   'final',
#   'tie'],
#  ['dogecoin', 'tip', 'option', 'eye'],
#  ['soca',
#   'superstar',
#   'break',
#   'five',
#   'favorite',
#   'track',
#   'first',
#   'album',
#   '10',
#   'year',
#   'time',
#   'position',
#   'global',
#   'way'],
#  ['top',
#   '8',
#   'profitable',
#   'crypto',
#   'narrative',
#   '2024',
#   '1',
#   'memecoin',
#   '1313',
#   '2',
#   'rwa',
#   '286',
#   '3',
#   'ai',
#   '222',
#   '4',
#   'defi',
#   '99',
#   '5',
#   'depin',
#   '81',
#   '6',
#   'layer',
#   '1',
#   '70',
#   '7',
#   'game',
#   '64',
#   '8',
#   'layer',
#   '2',
#   '39'],
#  ['dont',
#   'believe',
#   'presidential',
#   'poll',
#   'partly',
#   'ive',
#   'personally',
#   'never',
#   'poll',
#   'entire',
#   'life',
#   'even',
#   'ever',
#   'poll',
#   'support',
#   'president',
#   'think',
#   'face'],
#  ['sold', 'car', 'planet', 'earth', '2023', 'tesla'],
#  ['everything',
#   'app',
#   'get',
#   'close',
#   'every',
#   'single',
#   'day',
#   'build',
#   'new',
#   'way',
#   'everyone',
#   'find',
#   'community',
#   'connect',
#   'one',
#   'another'],
#  ['coinbase',
#   'partner',
#   'lightspark',
#   'integrate',
#   'bitcoin',
#   'lightning',
#   'network'],
#  ['say', 'whole', 'discography'],
#  ['sound', 'exactly', 'like', 'countess', 'scream'],
#  ['nicki',
#   'minaj',
#   'bring',
#   'artist',
#   'tate',
#   'kobang',
#   'perform',
#   'rnb',
#   'bankroll',
#   'hometown',
#   'baltimore',
#   'fire'],
#  ['kirsten', 'dunst', "'", "n't", 'even', 'think', 'ask', 'equal', 'pay', "'"],
#  ['here',
#   'advice',
#   'raymonte',
#   'take',
#   'time',
#   'right',
#   'get',
#   'brand',
#   'deal',
#   '5',
#   'million',
#   'campaign',
#   'get',
#   'social',
#   'medium',
#   'famous',
#   '2014my',
#   'first',
#   'brand',
#   'deal',
#   'fashion',
#   'nova',
#   '2016',
#   '200',
#   'post',
#   'could',
#   'reach',
#   'height',
#   'matter',
#   'ghetto'],
#  ['gaza', 'aid', 'convoy', 'strike', 'know'],
#  ['gagcitybaltimore',
#   'gagcity',
#   'smile',
#   'face',
#   'heart',
#   'pink',
#   'heart',
#   'love',
#   'nickiminaj'],
#  ['solar', 'eclipse', 'path', 'guide', 'watch', 'north', 'america'],
#  ['want',
#   'give',
#   'fan',
#   'album',
#   'tour',
#   'touch',
#   'every',
#   'way',
#   'remind',
#   'fell',
#   'love',
#   '1st',
#   'place',
#   'give',
#   'tour',
#   'never',
#   'know',
#   'need',
#   'prove',
#   'much',
#   'value',
#   'much',
#   'value',
#   'art',
#   'pink',
#   'heart'],
#  ['5',
#   'day',
#   'away',
#   'eclipse',
#   'check',
#   'eclipse',
#   'guide',
#   'link',
#   'bio',
#   'tip',
#   'see',
#   'remember',
#   'difference',
#   '99',
#   '100',
#   'one',
#   'literally',
#   'change',
#   'life',
#   'eclipse',
#   'saw',
#   '2017',
#   'ignite',
#   'passion',
#   'pursue',
#   'astrophotography'],
#  ['upcoming',
#   'cheech',
#   'chong',
#   'mw3',
#   'warzone',
#   'operator',
#   'bundle',
#   'weapon',
#   'tracer',
#   'turn',
#   'enemy',
#   'joint'],
#  ['watch',
#   'tomorrow',
#   'x',
#   'together',
#   'bring',
#   'deja',
#   'vu',
#   'kelly',
#   'clarkson',
#   'show'],
#  ['world',
#   'stage',
#   'joker',
#   'folie',
#   'deux',
#   'trailer',
#   'come',
#   'april',
#   '9',
#   'joker'],
#  ['trump',
#   'sue',
#   'truth',
#   'social',
#   'co',
#   'founder',
#   'alleged',
#   'mismanagement'],
#  ['13900',
#   'egg',
#   '200000',
#   'reward',
#   '1',
#   'bitcoin',
#   'get',
#   'start',
#   'binance',
#   'egg',
#   'drop',
#   'backhand',
#   'index',
#   'point'],
#  ['must', 'makeup', '9', 'new', 'beauty', 'product', 'buy', 'spring', '2024'],
#  ['thanks',
#   'free',
#   'medium',
#   'particular',
#   'chapter',
#   'genocide',
#   'palestine',
#   'happen',
#   'front',
#   'everybody',
#   "'s",
#   'eye',
#   'pier',
#   'rogan',
#   'trump',
#   'big',
#   'name',
#   'condemn',
#   'happen',
#   'day',
#   'one',
#   'tell',
#   'pier',
#   'would',
#   'happen',
#   'know'],
#  ['michael', 'rubin', 'posh', 'party', 'unite', 'sport', 'music', 'world'],
#  ['andrew', 'tate', "'s", 'cold', 'moment', 'fight'],
#  ['yesterday',
#   'extreme',
#   'florida',
#   'supreme',
#   'court',
#   'decision',
#   'put',
#   'desperately',
#   'need',
#   'medical',
#   'care',
#   'even',
#   'reach',
#   'million',
#   'woman',
#   'florida',
#   'across',
#   'south',
#   'outrageousand',
#   'make',
#   'possible',
#   'trump',
#   'end',
#   'roe',
#   'v',
#   'wade'],
#  ['la',
#   'mujeres',
#   'ya',
#   'lloran',
#   'hit',
#   'number',
#   'one',
#   'top',
#   'latin',
#   'album',
#   'latin',
#   'pop',
#   'album',
#   'gem',
#   'stone'],
#  ['qgtm',
#   'history',
#   'fng',
#   'make',
#   'thank',
#   'million',
#   'time',
#   'trophy',
#   'gagcitydc',
#   'shall',
#   'go',
#   'gagcity',
#   'history',
#   'book'],
#  ['ukraine',
#   'war',
#   'deep',
#   'ukraine',
#   'drone',
#   'attack',
#   'russian',
#   'territory',
#   'injures',
#   '12'],
#  ['open', 'yellowstone', 'theme', 'album', 'stellaria', 'mental', 'health'],
#  ['sound', 'exactly', 'like', 'countess', 'scream'],
#  ['ahh', 'bourgeousieses', 'affluenza', 'pt2', 'confirm'],
#  ['doja',
#   'cat',
#   'say',
#   'doesnt',
#   'care',
#   'music',
#   'leak',
#   'theres',
#   'nothing'],
#  ['new',
#   'bitcoin',
#   'etf',
#   'saw',
#   'record',
#   'volume',
#   '111',
#   'billion',
#   'march',
#   "'s",
#   'triple',
#   'inflow',
#   'february',
#   'explode',
#   'head'],
#  ['star',
#   'bear',
#   'house',
#   'gucci',
#   'joker',
#   'ii',
#   'lady',
#   'gaga',
#   'conquer',
#   'hollywood',
#   'insane',
#   'loudly',
#   'cry',
#   'face'],
#  ['katy', 'perry', 'jojo', 'siwa', 'loudly', 'cry', 'face'],
#  ['ultimate', 'guide', 'festival', 'celebrate', 'latin', 'music', '2024'],
#  ['apple', 'explore', 'creation', 'home', 'robot', 'next', 'big', 'thing'],
#  ["'s", 'revolution', 'way', 'glass', 'making'],
#  ['go',
#   'gagcitydc',
#   'alone',
#   'end',
#   'w',
#   'sweet',
#   'girl',
#   'next',
#   'also',
#   'alone',
#   'fun',
#   'bday',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'loudly',
#   'cry',
#   'face',
#   'pink',
#   'heart',
#   'pink',
#   'heart',
#   'pink',
#   'heart',
#   'magical',
#   'fun',
#   'night',
#   'overall',
#   'im',
#   'overwhelmed',
#   'grateful'],
#  ['josh',
#   'allen',
#   'get',
#   'chance',
#   'prove',
#   'doesnt',
#   'need',
#   'stefon',
#   'diggs',
#   'anymore',
#   'like',
#   'patrick',
#   'mahomes',
#   'prove',
#   'didnt',
#   'need',
#   'tyreek',
#   'hill'],
#  ['major',
#   'plan',
#   '2024',
#   'eye',
#   'tease',
#   'next',
#   'album',
#   'go',
#   'tour',
#   'dive',
#   'act',
#   'billboardnews',
#   'watch',
#   'full',
#   'interview'],
#  ['united',
#   'state',
#   'us',
#   'government',
#   'transfer',
#   '30174',
#   'bitcoin',
#   'worth',
#   '21',
#   'billion',
#   'seize',
#   'silk',
#   'road',
#   'coinbase'],
#  ['frank', 'ocean', 'lose', 'hit', '1', 'billion', 'spotify', 'stream'],
#  ['inside',
#   'evolution',
#   'record',
#   'label',
#   'radio',
#   'staff',
#   'layoff',
#   'hit',
#   'promotion',
#   'department',
#   'hard'],
#  ['billie',
#   'eilish',
#   'pearl',
#   'jam',
#   'nicki',
#   'minaj',
#   'among',
#   '200',
#   'artist',
#   'call',
#   'responsible',
#   'ai',
#   'music',
#   'practice'],
#  ['retrospect',
#   'call',
#   'never',
#   'end',
#   'song',
#   'grocery',
#   'store',
#   'food',
#   'heaven',
#   'insane'],
#  ['first', 'look', 'mufasa', 'lion', 'king', 'theater', 'december', '20'],
#  ['drop',
#   'sol',
#   'address',
#   'make',
#   'sure',
#   'follow',
#   'dont',
#   'ask',
#   'backhand',
#   'index',
#   'point',
#   'medium',
#   'light',
#   'skin',
#   'tone'],
#  ["'s", 'harleys', 'hawaii', 'surpass', '500', 'million', 'stream', 'spotify'],
#  ['olive',
#   'garden',
#   'longhorn',
#   'steakhouse',
#   'report',
#   'last',
#   'week',
#   'households',
#   'income',
#   '150000',
#   'transaction',
#   'restaurant',
#   'recent',
#   'quarter',
#   'year',
#   'ago',
#   'whereas',
#   'transaction',
#   'among',
#   'make',
#   'less',
#   '50000',
#   'fell',
#   'per',
#   'axios'],
#  ['guy',
#   'answer',
#   'question',
#   'im',
#   'gon',
#   'na',
#   'cryy',
#   'love',
#   'man',
#   'much'],
#  ['hot',
#   '100',
#   'first',
#   'timer',
#   'allison',
#   'russell',
#   'debut',
#   'hozier',
#   'team',
#   'wildflower',
#   'barley'],
#  ['pitbull', 'chingy', 'baby', 'bash'],
#  ['previous',
#   'version',
#   'fsd',
#   'hard',
#   'time',
#   'deal',
#   'kind',
#   'stuff',
#   'fsd',
#   '12',
#   'nail'],
#  ['instagram',
#   'whatsapp',
#   'katy',
#   'perry',
#   'still',
#   'stand',
#   'raise',
#   'hand',
#   'light',
#   'skin',
#   'tone'],
#  ['former',
#   'president',
#   'paypal',
#   'help',
#   'large',
#   'us',
#   'bitcoin',
#   'exchange',
#   'integrate',
#   'lightning',
#   'network',
#   'high',
#   'voltage',
#   'bullish',
#   'rocket'],
#  ['say', 'house', 'gucci', 'best', 'poster'],
#  ['explore',
#   'new',
#   'taker',
#   'fee',
#   'promotion',
#   'binance',
#   'trade',
#   'usdc',
#   'spot',
#   'margin',
#   'trading',
#   'pair',
#   'enjoy',
#   'discount',
#   'taker',
#   'fee',
#   '10',
#   'april',
#   '2024',
#   'learn',
#   'right',
#   'arrow',
#   'curve'],
#  ['new',
#   'look',
#   'moana',
#   '2',
#   'set',
#   '3',
#   'year',
#   'first',
#   'movie',
#   'theater',
#   'november',
#   '27'],
#  ['one',
#   'know',
#   'could',
#   'find',
#   'unsolicited',
#   'advice',
#   'preferably',
#   'people',
#   'weird',
#   'personality',
#   'disorder',
#   'dont',
#   'know',
#   'anything'],
#  ['new', 'shakira', 'collaboration', 'way', 'xx'],
#  ['finland',
#   'shoot',
#   'several',
#   'injure',
#   'vantaa',
#   'school',
#   'shoot',
#   'police'],
#  ["'s",
#   'cute',
#   'kid',
#   'say',
#   'want',
#   'grow',
#   "'re",
#   'gon',
#   'na',
#   'write',
#   'email',
#   'computer',
#   'buddy'],
#  ['cryptoo'],
#  ['funimation', 'officially', 'close'],
#  ['miley', 'cyrus', 'post', 'malone', 'rumor', 'collaboration', 'work'],
#  ["'s", 'never', 'really', 'certified', 'diamond', 'brazil', 'brazil'],
#  ['taylor',
#   'swift',
#   'compete',
#   'travis',
#   'kelce',
#   '2024',
#   'webby',
#   'award',
#   'full',
#   'nomination',
#   'announce'],
#  ['israeli', 'government', 'say', 'block', 'al', 'jazeera', 'broadcast'],
#  ['united',
#   'state',
#   'blackrock',
#   'fidelity',
#   'combined',
#   '399741',
#   'btc',
#   'worth',
#   '262',
#   'billion',
#   'spot',
#   'bitcoin',
#   'etf'],
#  ['rebel',
#   'wilson',
#   'believe',
#   'adele',
#   'hat',
#   'fat',
#   'amy',
#   'comparison',
#   'people',
#   'would',
#   'confuse',
#   'us'],
#  ['actually', 'nuts', 'lmao'],
#  ['4', 'account', 'alone', 'nearly', '31', 'million', 'view', '24', 'hour'],
#  ["'s", 'never', 'really', 'certified', 'diamond', 'brazil'],
#  ['fun', 'fact', 'lady', 'gagas', 'lead', 'role', 'film', 'rat', 'r'],
#  ['fun',
#   'fact',
#   'movie',
#   'matrix',
#   'neo',
#   "'s",
#   'passport',
#   'expiration',
#   'date',
#   'set',
#   '9112001'],
#  ['consistency', 'incredibly', 'valuable'],
#  ['spotify', 'plan', 'price', 'increase', '2024', 'report'],
#  ['whered', 'go', 'go', 'alley', 'rise', 'idk', 'conan', 'text', 'gc'],
#  ['fella', 'antismitic', 'think', 'aid', 'worker', 'shouldnt', 'airstriked'],
#  ['civilization', "n't", 'grow', 'nothing', 'else', 'matter'],
#  ['juda',
#   'receive',
#   '492957',
#   'stream',
#   'tuesday',
#   'glow',
#   'star',
#   'black',
#   'heart'],
#  ['17',
#   'sell',
#   'show',
#   'ribbon',
#   'unicorn',
#   'come',
#   'thru',
#   'gagcitybaltimore',
#   'pinkfriday2tour',
#   'pinkfriday2',
#   'nickiminaj',
#   'nicki',
#   'yo',
#   'world',
#   'globe',
#   'show',
#   'americas',
#   'aint',
#   'heart',
#   'arrow',
#   'unicorn'],
#  ['united',
#   'state',
#   'feed',
#   'chair',
#   'jerome',
#   'powell',
#   'say',
#   "n't",
#   'expect',
#   'interest',
#   'rate',
#   'cut',
#   'confidence',
#   'inflation'],
#  ['one', 'crypto', 'show', 'monster', 'god', 'candle', 'summer'],
#  ['hello', '14b', 'people', 'welcome'],
#  ['lady', 'gaga', 'update', 'bio', 'instagram'],
#  ['20', 'best', 'travel', 'deal', 'help', 'get', 'away', 'budget'],
#  ['buy', 'tesla', 'dogecoin'],
#  ['bitcoin',
#   'navigate',
#   'high',
#   'sea',
#   'finance',
#   'steer',
#   'ship',
#   'economic',
#   'evolution',
#   'sailboat',
#   'money',
#   'bag',
#   'water',
#   'wave'],
#  ['mean'],
#  ['love', 'one', 'actually', 'look', 'mentally', 'ill'],
#  ['tuesday',
#   'already',
#   'watch',
#   'play',
#   'password',
#   'tonight',
#   '109c',
#   'weakestlink'],
#  ['sister',
#   'ship',
#   '1',
#   '22h',
#   '32m',
#   '47s',
#   'light',
#   'travel',
#   'time',
#   'earth',
#   '2024',
#   '094',
#   '120000',
#   '1l'],
#  ['endeavor',
#   'go',
#   'private',
#   'deal',
#   'majority',
#   'shareholder',
#   'silver',
#   'lake'],
#  ['feid', 'announces', 'joint', 'album', 'yandel', 'here', 'know'],
#  ['perfection'],
#  ['microsoft', 'technology', 'giant', 'split', 'team', 'office', 'globally'],
#  ['coinbase', 'integrate', 'btc', 'lightning', 'network'],
#  ['katy',
#   'perry',
#   'teenage',
#   'dream',
#   'album',
#   'cover',
#   'actually',
#   'painting'],
#  ['bizarrap',
#   'natanael',
#   'cano',
#   'drop',
#   'explosive',
#   'two',
#   'song',
#   'collaboration',
#   'bzrp',
#   'music',
#   'session',
#   '59',
#   'stream'],
#  ['atta',
#   'baby',
#   'flag',
#   'hole',
#   '40',
#   '500',
#   'winner',
#   'money',
#   'bag',
#   'money',
#   'bag',
#   'radio',
#   'button',
#   'repost',
#   'video',
#   'radio',
#   'button',
#   'reply',
#   'say',
#   'something',
#   'nice',
#   'somebody',
#   'radio',
#   'button',
#   'put',
#   'easy',
#   'way',
#   'pay',
#   'post',
#   'wellpmslive'],
#  ['get',
#   'us',
#   'even',
#   'get',
#   'loudly',
#   'cry',
#   'face',
#   'pink',
#   'heart',
#   'gagcitybaltimore'],
#  ['amateur', 'scientist', 'measure', 'snowfall', '50', 'year'],
#  ['beyoncs',
#   'cowboy',
#   'carter',
#   'legendary',
#   'inspiration',
#   'new',
#   'collaborator',
#   'stream',
#   'linda',
#   'martell',
#   'dolly',
#   'parton',
#   'brittney',
#   'spencer'],
#  ['today',
#   'candid',
#   'conversation',
#   'president',
#   'xi',
#   'jinping',
#   'people',
#   'republic',
#   'china',
#   'range',
#   'issue',
#   'include',
#   'area',
#   'cooperation',
#   'area',
#   'difference',
#   'emphasize',
#   'importance',
#   'maintain',
#   'peace',
#   'stability',
#   'across',
#   'taiwan',
#   'strait',
#   'south'],
#  ['sister',
#   'ship',
#   '1',
#   '22h',
#   '32m',
#   '47s',
#   'light',
#   'travel',
#   'time',
#   'earth',
#   '2024',
#   '094',
#   '120000',
#   '1l'],
#  ['gagcity',
#   'everything',
#   'nicki',
#   'monica',
#   '50',
#   'cent',
#   'need',
#   'do',
#   'two',
#   'heart',
#   'gagcitydc'],
#  ['last', 'signed', 'copy', 'find', 'heaven', 'available', 'star'],
#  ['usa',
#   'today',
#   'attend',
#   "'s",
#   'gagcitydc',
#   'give',
#   'review',
#   'show',
#   'first',
#   'us',
#   'run',
#   'eight',
#   'year',
#   'minaj',
#   'craft',
#   'grandiose',
#   'productionshe',
#   'still',
#   'queen',
#   'rap',
#   'reason'],
#  ['damn', 'nigga', 'buy', 'god'],
#  ['gagcitybaltimore', 'gagcity', 'ribbon', 'beat', 'heart'],
#  ['get',
#   '45',
#   'min',
#   'give',
#   'away',
#   'personal',
#   'tkts',
#   'soldoutminaj',
#   'show',
#   'guy',
#   'im',
#   'station',
#   'head',
#   'nanabooboo',
#   'barbz',
#   'dont',
#   'start',
#   'miss',
#   'face',
#   'hand',
#   'mouth'],
#  ['take',
#   'get',
#   'music',
#   'industry',
#   'go',
#   'green',
#   'live',
#   'veteran',
#   'amy',
#   'morrison',
#   'idea'],
#  ['artist', 'big', 'hit', 'maker'],
#  ['drew', 'goddard', 'set', 'write', 'direct', 'new', 'matrix', 'movie'],
#  ['remember',
#   'remember',
#   'withdraw',
#   'tournament',
#   '6',
#   'year',
#   'old',
#   'beat',
#   'first',
#   'two',
#   'adult',
#   'lose',
#   '3',
#   'row',
#   'ask',
#   'able',
#   'beat',
#   'chess',
#   'im',
#   'grow',
#   'reply',
#   'son',
#   'youre',
#   'grow',
#   'youll',
#   'beat',
#   'anyone',
#   'anything'],
#  ['school', 'shoot', 'brings', 'tough', 'question', 'finland'],
#  ['say', 'house', 'gucci', 'best', 'poster'],
#  ['try',
#   'say',
#   'ghetto',
#   'get',
#   'call',
#   'ghetto',
#   'doesnt',
#   'hinder',
#   'career',
#   'essence',
#   'write',
#   'article',
#   'ask',
#   'viral',
#   'birthday',
#   'trip',
#   'sponsor',
#   'brand',
#   'yall',
#   'say',
#   'im',
#   'ghetto',
#   'marketable',
#   'im',
#   'give'],
#  ['binance',
#   'respectfully',
#   'request',
#   'tigran',
#   'gambaryan',
#   'decision',
#   'make',
#   'power',
#   'company',
#   'hold',
#   'responsible',
#   'current',
#   'discussion',
#   'ongoing',
#   'binance',
#   'nigerian',
#   'government',
#   'officialsbringtigranhomeread',
#   'backhand',
#   'index',
#   'point']]

# %% [markdown]
# ### Train Word2Vec model (skip-gram)

# %%
model_skipGram = Word2Vec(sentences=train_tokenized, vector_size=100, window=5,  min_count=1, workers=4, sg=1)
# save the trained model
model_skipGram.save('model/modelSkipGram.bin')

# %%
# load the trained model
model_sg = Word2Vec.load('model/modelSkipGram.bin')
print(type(model_sg.wv['binance']))
model_sg.wv['binance']
# Out:
# <class 'numpy.ndarray'>
# array([-0.01715061,  0.0024371 , -0.00404767,  0.00152807,  0.00076108,
#        -0.01306054,  0.00834662,  0.02935744, -0.00291367, -0.00995072,
#        -0.00447798, -0.02028175, -0.00466269,  0.01310427, -0.00465026,
#        -0.00780595,  0.0033968 , -0.02193251, -0.00644233, -0.00607408,
#        -0.00101301,  0.01504509,  0.00941008, -0.00095922,  0.00543354,
#         0.0048363 , -0.0138449 , -0.00268137, -0.00530938,  0.00632365,
#         0.01307777,  0.00159252,  0.00789268,  0.0012772 , -0.00772045,
#         0.01575958,  0.00909421, -0.01588465, -0.01566426, -0.0183822 ,
#        -0.0088186 , -0.01197623,  0.00324388, -0.00476131, -0.00024461,
#        -0.01185415, -0.01069439, -0.01249297,  0.0007575 ,  0.00035558,
#         0.00949792, -0.01234568, -0.00860571, -0.01030694, -0.01203183,
#         0.00513341,  0.01398354, -0.0063936 , -0.00528979,  0.00699421,
#         0.01028918,  0.00812965, -0.01125005,  0.00111191, -0.01891954,
#         0.01733762,  0.00475594, -0.00304403, -0.00749958,  0.00669195,
#         0.00431865,  0.0001037 ,  0.01403309,  0.00304889,  0.00324862,
#         0.00951238,  0.00355257,  0.00243818, -0.02119537,  0.00892858,
#        -0.008218  ,  0.00623809, -0.00325258,  0.01177029, -0.00161238,
#         0.00926513, -0.00257392,  0.0037531 ,  0.00976623, -0.00045466,
#         0.02262847,  0.00106601,  0.0037435 , -0.00094007,  0.01113533,
#         0.00198311,  0.00295531, -0.0026954 ,  0.01230993,  0.00491322],
#       dtype=float32)

# %% [markdown]
# ### Convert all words to vectors

# %%
def convert_to_vector(model, tokenized_sentence):
    vector = []
    for word in tokenized_sentence:
        if word in model.wv:
            vector.append(model.wv[word])
    
    # return the average of the vectors
    output = np.mean(vector, axis=0) if vector else np.zeros(model.vector_size)
    
    return output

train_vectors = np.array([convert_to_vector(model_sg, sentence) for sentence in train_tokenized])
test_vectors = np.array([convert_to_vector(model_sg, sentence) for sentence in test_tokenized])
train_vectors.shape
# Out:
# (674, 100)

# %% [markdown]
# ### Cross-validation using RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=42)
cross_val_score(clf, train_vectors, train['Label'], cv=5)
# Out:
# array([0.66666667, 0.60740741, 0.60740741, 0.62962963, 0.59701493])

# %% [markdown]
# ### Train the classifier and get the performance on test set

# %%
from sklearn.metrics import accuracy_score

# train the model
clf.fit(train_vectors, train['Label'])

# predict the test set
y_pred = clf.predict(test_vectors)
accuracy_score(test['Label'], y_pred)
# Out:
# 0.6804733727810651
