# %% [markdown]
# ### Read Data

# %%
#pip install langdetect

# %%
import pandas as pd
from langdetect import detect, LangDetectException

# %%
# language detection
def detect_lang(text):
    try:
        return detect(text)
    except LangDetectException:
        return None

df_texts = pd.read_csv('data/labeled_texts.csv', encoding='utf-8-sig')
df_texts = df_texts['Content']
df_texts.dropna(inplace=True)
df_texts = pd.DataFrame(df_texts)

# detect language and add a new column
df_texts['lang'] = df_texts['Content'].apply(detect_lang)

# remove French texts
df_texts = df_texts[df_texts['lang'] == 'en']['Content']

df_texts
# Out:
# 1     In 2013, this dude on YouTube begged everyone ...
# 2     Christopher Nolan planted 500 acres of corn fo...
# 3     the one who was the last survivor of genocide ...
# 4     Kai Cenat room setup for his 50+ hour Red Dead...
# 5     Reminder ...\r\n\r\nThis tweet is about nothin...
# 6            There is nothing Catholic about Joe Biden.
# 7     Your child doesn't have ADHD, hes just been ea...
# 8     SHOCK REPORT:  Biden declares Easter Sunday 20...
# 9     #BREAKING: A large barge crashed into the Arka...
# 10             i thought they already seen the original
# 11    BIDEN RENAMES EASTER SUNDAY “TRANSGENDER DAY O...
# 12    Wemby spoiled Jalen Brunson’s 61pt game then t...
# 13    The last time Larry David stretched out his le...
# 14                 Interesting method to poach an egg.
# 16                   that cat took off like scooby doo
# 17                                         Cost of love
# 18         How these vehicles are painted  ohmytechness
# 19    Chance Perdomo has passed away at the age of 2...
# 21    Pigeon wants to come inside to save itself fro...
# 22    Joe Biden actually declared that Easter Sunday...
# 23    NEW: Massive turnout for fallen NYPD officer J...
# 24    BREAKING NEWS: Sean Diddy Combs just released ...
# 25    Carrom is a tabletop game which resembles snoo...
# 26     SERBIA has been invited to attend BRICS 2024 ...
# 27    BREAKING: Israel has just hit a car in Souther...
# 28    Jake Paul & Mike Tyson fight now has new rules...
# 29    White Student Asked To Be As Racist As Possibl...
# 30    It’s absolutely insane to be spending this muc...
# 31    WHAT'S GOING ON???\r\n\r\nCanada just approved...
# 32                          pete davidson is too quick
# 33    Eminem's first ever time in the studio with Dr...
# 34    Sketch breaks character after Steve gifts him ...
# 35    #BREAKING: Over Ten Thousand New York Police O...
# 36    Shark swallows diver's camera, captures video ...
# 37     PUTIN: OUTLAWED transgender surgeries & hormo...
# 38                          Awwww so beautiful moment!
# 39    Ezra Miller has been replaced as the voice of ...
# 41                              cat collecting evidence
# 42    Biden Condemns Jesus For Rising Again On Trans...
# 43    Stephen A. Smith says Michael Jordan feels bet...
# 44    Large-Scale Protests are ongoing tonight in Te...
# 45    How these trainer shoes are made  smartest.worker
# 46    “Stop saying Christ is King”\r\n\r\n“Don’t get...
# 47    If Joe Biden tries to go to Church tomorrow af...
# Name: Content, dtype: object

# %%
texts = [text for text in df_texts]
print(texts)
len(texts)
# Out:
# ['In 2013, this dude on YouTube begged everyone to buy just $1 worth of bitcoin', 'Christopher Nolan planted 500 acres of corn for Interstellar rather than use CGI.', 'the one who was the last survivor of genocide of his people', 'Kai Cenat room setup for his 50+ hour Red Dead Redemption 2 stream ', "Reminder ...\r\n\r\nThis tweet is about nothing but it'll still get more views than Don Lemon's show. ", 'There is nothing Catholic about Joe Biden.', "Your child doesn't have ADHD, hes just been eating artificial food coloring for breakfast the last 6 years of his life", 'SHOCK REPORT:  Biden declares Easter Sunday 2024 as "TRANSGENDER DAY OF VISIBILITY" \r\n\r\nThis is like declaring \'NATIONAL BACON WEEK\' during the Muslim Ramadan..', '#BREAKING: A large barge crashed into the Arkansas River bridge, causing damage to both the ship and the bridge pillar #Sallisaw | #OklahomaEarlier this evening, just before 1:30 p.m., a large barge crashed into and struck the Arkansas River bridge at the Kerr Reservoir…', 'i thought they already seen the original', 'BIDEN RENAMES EASTER SUNDAY “TRANSGENDER DAY OF VISIBILITY”\r\n\r\n“NOW, THEREFORE, I, JOSEPH R. BIDEN JR., President of the United States of America, by virtue of the authority vested in me by the Constitution and the laws of the United States, do hereby proclaim March 31, 2024,…', 'Wemby spoiled Jalen Brunson’s 61pt game then threw the game ball into the crowd ', 'The last time Larry David stretched out his legs at a basketball game.', 'Interesting method to poach an egg. ', 'that cat took off like scooby doo ', 'Cost of love', 'How these vehicles are painted  ohmytechness', 'Chance Perdomo has passed away at the age of 27 in a motorcycle accident', 'Pigeon wants to come inside to save itself from hail', 'Joe Biden actually declared that Easter Sunday is now a Transgender holiday.', 'NEW: Massive turnout for fallen NYPD officer Jonathan Diller in Massapequa, Long Island.\r\n\r\nOver 10,000 officers showed up with some traveling from as far as Toronto and Miami to pay tribute to Diller.\r\n \r\nOver 700 motorcyclists lined the path to the cemetery, saluting when the…', 'BREAKING NEWS: Sean Diddy Combs just released his first video since his Homeland Security human trafficking raid on his mansions. Puffy appears to be in good spirits despite the allegations. \r\n\r\nThe last update on this case, 6 hours ago Homeland Security subpoenaed every…', "Carrom is a tabletop game which resembles snooker,  subbuteo and air hockey. It's played by propelling discs and potting them into the four corner pockets on a wooden playing board.\r\n\r\nThis is Carrom King Haji Ali Agariya.", ' SERBIA has been invited to attend BRICS 2024 summit.', 'BREAKING: Israel has just hit a car in Southern Lebanon with a drone strike, carrying 2 UN Observers\r\n\r\nThe UN Observers have been killed.', 'Jake Paul & Mike Tyson fight now has new rules. \r\n\r\n• 16 oz gloves \r\n• 2 minute rounds\r\n• No official judges\r\n• No winner unless KO\r\n• Each fighter must pass a EEG & EKG test', 'White Student Asked To Be As Racist As Possible For 5 Seconds, Declines and Is Then Beat Mercilessly', 'It’s absolutely insane to be spending this much money on a slot machine.', "WHAT'S GOING ON???\r\n\r\nCanada just approved a 27 year old woman with autism for medically assisted death (MAiD) despite having no health problems. \r\n\r\nHer father has been objecting saying she isn't capable of making this decision.\r\n\r\nSHARE if you think this must stop!", 'pete davidson is too quick ', 'Eminem\'s first ever time in the studio with Dr Dre and they recorded \'My Name Is"', 'Sketch breaks character after Steve gifts him a $25k Rolex and $50k cash ', '#BREAKING: Over Ten Thousand New York Police Officers have Gathered for Slain NYPD Officer Jonathan Diller’s Funeral#Massapequa | #NewYork \r\nWitness as reported estimate of over ten thousand New York law enforcement officers pay tribute to fallen NYPD Officer Jonathan…', "Shark swall ...
# 44

# %% [markdown]
# ### Text Preprocessing

# %%
#pip install tweet-preprocessor

# %%
# importing the needed libraries
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from gensim.parsing.preprocessing import remove_stopwords
import re 
import string
import html
import preprocessor as p

# %%
def get_wordnet_tag(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('R'):
        return 'r'
    elif tag.startswith('V'):
        return 'v'
    else:
        return None

# %%
def clean_tweet(tweet):
    # remove URLs, mentions, reserved words (RT, FAV), emojis, and smileys
    p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.RESERVED, p.OPT.EMOJI, p.OPT.SMILEY)
    cleaned_tweet = p.clean(tweet)

    # Replacing '-' with ' '
    sentence_cleaned_v1 = re.sub(r'-', ' ', cleaned_tweet)

    # Removing any character which is not a space, letter or a number
    regular_expression_num_letters = r'[^a-zA-Z0-9 ]'
    sentence_cleaned_v2 = re.sub(regular_expression_num_letters, '', sentence_cleaned_v1)

    # Removing any extra spaces
    sentence_cleaned_v3 = re.sub(r'\s+', ' ', sentence_cleaned_v2)

    # Remove Stopwords
    stop_words_removed = remove_stopwords(sentence_cleaned_v3)

    # Tokenize the tweet
    tokens = word_tokenize(stop_words_removed)

    # handle abbreviations
    tokens_normalized = ["Computer-generated Imagery" if token == "CGI" else token for token in tokens]

    # POS tagging
    pos_tagged = pos_tag(tokens_normalized)

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = [word if get_wordnet_tag(tag) is None else lemmatizer.lemmatize(word, get_wordnet_tag(tag)) for word, tag in pos_tagged]

    result = lemmatized_sentence
    
    return result

# %%
def get_cleaned_tweets(tweets):
    return [clean_tweet(tweet) for tweet in tweets]

# %%
result = get_cleaned_tweets(texts)
result
# Out:
# [['In', '2013', 'dude', 'YouTube', 'beg', 'buy', '1', 'worth', 'bitcoin'],
#  ['Christopher',
#   'Nolan',
#   'plant',
#   '500',
#   'acre',
#   'corn',
#   'Interstellar',
#   'use',
#   'Computer-generated Imagery'],
#  ['survivor', 'genocide', 'people'],
#  ['Kai',
#   'Cenat',
#   'room',
#   'setup',
#   '50',
#   'hour',
#   'Red',
#   'Dead',
#   'Redemption',
#   '2',
#   'stream'],
#  ['Reminder', 'This', 'tweet', 'itll', 'view', 'Don', 'Lemons'],
#  ['There', 'Catholic', 'Joe', 'Biden'],
#  ['Your',
#   'child',
#   'doesnt',
#   'ADHD',
#   'hes',
#   'eat',
#   'artificial',
#   'food',
#   'color',
#   'breakfast',
#   '6',
#   'year',
#   'life'],
#  ['SHOCK',
#   'REPORT',
#   'Biden',
#   'declare',
#   'Easter',
#   'Sunday',
#   '2024',
#   'TRANSGENDER',
#   'DAY',
#   'OF',
#   'VISIBILITY',
#   'This',
#   'like',
#   'declare',
#   'NATIONAL',
#   'BACON',
#   'WEEK',
#   'Muslim',
#   'Ramadan'],
#  ['BREAKING',
#   'A',
#   'large',
#   'barge',
#   'crash',
#   'Arkansas',
#   'River',
#   'bridge',
#   'cause',
#   'damage',
#   'ship',
#   'bridge',
#   'pillar',
#   'Sallisaw',
#   'OklahomaEarlier',
#   'even',
#   '130',
#   'pm',
#   'large',
#   'barge',
#   'crash',
#   'struck',
#   'Arkansas',
#   'River',
#   'bridge',
#   'Kerr',
#   'Reservoir'],
#  ['think', 'see', 'original'],
#  ['BIDEN',
#   'RENAMES',
#   'EASTER',
#   'SUNDAY',
#   'TRANSGENDER',
#   'DAY',
#   'OF',
#   'VISIBILITY',
#   'NOW',
#   'THEREFORE',
#   'I',
#   'JOSEPH',
#   'R',
#   'BIDEN',
#   'JR',
#   'President',
#   'United',
#   'States',
#   'America',
#   'virtue',
#   'authority',
#   'vest',
#   'Constitution',
#   'law',
#   'United',
#   'States',
#   'proclaim',
#   'March',
#   '31',
#   '2024'],
#  ['Wemby',
#   'spoil',
#   'Jalen',
#   'Brunsons',
#   '61pt',
#   'game',
#   'throw',
#   'game',
#   'ball',
#   'crowd'],
#  ['The', 'time', 'Larry', 'David', 'stretch', 'legs', 'basketball', 'game'],
#  ['Interesting', 'method', 'poach', 'egg'],
#  ['cat', 'take', 'like', 'scooby', 'doo'],
#  ['Cost', 'love'],
#  ['How', 'vehicle', 'paint', 'ohmytechness'],
#  ['Chance', 'Perdomo', 'pass', 'away', 'age', '27', 'motorcycle', 'accident'],
#  ['Pigeon', 'want', 'come', 'inside', 'save', 'hail'],
#  ['Joe',
#   'Biden',
#   'actually',
#   'declare',
#   'Easter',
#   'Sunday',
#   'Transgender',
#   'holiday'],
#  ['NEW',
#   'Massive',
#   'turnout',
#   'fall',
#   'NYPD',
#   'officer',
#   'Jonathan',
#   'Diller',
#   'Massapequa',
#   'Long',
#   'Island',
#   'Over',
#   '10000',
#   'officer',
#   'show',
#   'travel',
#   'far',
#   'Toronto',
#   'Miami',
#   'pay',
#   'tribute',
#   'Diller',
#   'Over',
#   '700',
#   'motorcyclist',
#   'line',
#   'path',
#   'cemetery',
#   'salute'],
#  ['BREAKING',
#   'NEWS',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'release',
#   'video',
#   'Homeland',
#   'Security',
#   'human',
#   'trafficking',
#   'raid',
#   'mansion',
#   'Puffy',
#   'appear',
#   'good',
#   'spirit',
#   'despite',
#   'allegation',
#   'The',
#   'update',
#   'case',
#   '6',
#   'hour',
#   'ago',
#   'Homeland',
#   'Security',
#   'subpoenaed'],
#  ['Carrom',
#   'tabletop',
#   'game',
#   'resemble',
#   'snooker',
#   'subbuteo',
#   'air',
#   'hockey',
#   'Its',
#   'played',
#   'propelling',
#   'disc',
#   'pot',
#   'corner',
#   'pocket',
#   'wooden',
#   'play',
#   'board',
#   'This',
#   'Carrom',
#   'King',
#   'Haji',
#   'Ali',
#   'Agariya'],
#  ['SERBIA', 'invite', 'attend', 'BRICS', '2024', 'summit'],
#  ['BREAKING',
#   'Israel',
#   'hit',
#   'car',
#   'Southern',
#   'Lebanon',
#   'drone',
#   'strike',
#   'carry',
#   '2',
#   'UN',
#   'Observers',
#   'The',
#   'UN',
#   'Observers',
#   'kill'],
#  ['Jake',
#   'Paul',
#   'Mike',
#   'Tyson',
#   'fight',
#   'new',
#   'rule',
#   '16',
#   'oz',
#   'glove',
#   '2',
#   'minute',
#   'round',
#   'No',
#   'official',
#   'judge',
#   'No',
#   'winner',
#   'KO',
#   'Each',
#   'fighter',
#   'pas',
#   'EEG',
#   'EKG',
#   'test'],
#  ['White',
#   'Student',
#   'Asked',
#   'To',
#   'Be',
#   'As',
#   'Racist',
#   'As',
#   'Possible',
#   'For',
#   '5',
#   'Seconds',
#   'Declines',
#   'Is',
#   'Then',
#   'Beat',
#   'Mercilessly'],
#  ['Its', 'absolutely', 'insane', 'spending', 'money', 'slot', 'machine'],
#  ['WHATS',
#   'GOING',
#   'ON',
#   'Canada',
#   'approve',
#   '27',
#   'year',
#   'old',
#   'woman',
#   'autism',
#   'medically',
#   'assist',
#   'death',
#   'MAiD',
#   'despite',
#   'have',
#   'health',
#   'problem',
#   'Her',
#   'father',
#   'object',
#   'say',
#   'isnt',
#   'capable',
#   'make',
#   'decision',
#   'SHARE',
#   'think',
#   'stop'],
#  ['pete', 'davidson', 'quick'],
#  ['Eminems', 'time', 'studio', 'Dr', 'Dre', 'record', 'My', 'Name', 'Is'],
#  ['Sketch',
#   'break',
#   'character',
#   'Steve',
#   'gift',
#   '25k',
#   'Rolex',
#   '50k',
#   'cash'],
#  ['BREAKING',
#   'Over',
#   'Ten',
#   'Thousand',
#   'New',
#   'York',
#   'Police',
#   'Officers',
#   'Gathered',
#   'Slain',
#   'NYPD',
#   'Officer',
#   'Jonathan',
#   'Dillers',
#   'FuneralMassapequa',
#   'NewYork',
#   'Witness',
#   'report',
#   'estimate',
#   'thousand',
#   'New',
#   'York',
#   'law',
#   'enforcement',
#   'officer',
#   'pay',
#   'tribute',
#   'fall',
#   'NYPD',
#   'Officer',
#   'Jonathan'],
#  ['Shark', 'swallow', 'diver', 'camera', 'capture', 'video', 'inside', 'body'],
#  ['PUTIN',
#   'OUTLAWED',
#   'transgender',
#   'surgery',
#   'hormonal',
#   'therapy',
#   'NATIONWIDE',
#   'BIDEN',
#   'PROCLAIMS',
#   'Easter',
#   'Trans',
#   'Visibility',
#   'Day'],
#  ['Awwww', 'beautiful', 'moment'],
#  ['Ezra',
#   'Miller',
#   'replace',
#   'voice',
#   'DA',
#   'Sinclair',
#   'Invincible',
#   'S2',
#   'Eric',
#   'Bauza',
#   'voice',
#   'role'],
#  ['cat', 'collect', 'evidence'],
#  ['Biden',
#   'Condemns',
#   'Jesus',
#   'For',
#   'Rising',
#   'Again',
#   'On',
#   'Trans',
#   'Day',
#   'Of',
#   'Visibility'],
#  ['Stephen',
#   'A',
#   'Smith',
#   'say',
#   'Michael',
#   'Jordan',
#   'feel',
#   'betray',
#   'Scottie',
#   'Pippen',
#   'offering',
#   'condolence',
#   'father',
#   'murder',
#   'MJs',
#   'quote',
#   'word',
#   'I',
#   'hope',
#   'worth',
#   'I',
#   'sayVia',
#   'ht'],
#  ['Large',
#   'Scale',
#   'Protests',
#   'ongoing',
#   'tonight',
#   'Tel',
#   'Aviv',
#   'Israel',
#   'dont',
#   'believe',
#   'Israel',
#   'Defense',
#   'Force',
#   'current',
#   'Government',
#   'Eliminate',
#   'Hamas',
#   'Rescue',
#   'Exchange',
#   'roughly',
#   '100',
#   'Hostage',
#   'hold',
#   'Gaza',
#   'Strip'],
#  ['How', 'trainer', 'shoe', 'smartestworker'],
#  ['Stop',
#   'say',
#   'Christ',
#   'King',
#   'Dont',
#   'upset',
#   'Easter',
#   'declare',
#   'Trans',
#   'Day',
#   'Rage',
#   'Be',
#   'Good',
#   'Little',
#   'Conservative',
#   'Do',
#   'Watch',
#   'country',
#   'take',
#   'eye'],
#  ['If',
#   'Joe',
#   'Biden',
#   'try',
#   'Church',
#   'tomorrow',
#   'replace',
#   'Easter',
#   'Trans',
#   'Day',
#   'Visibility',
#   'PRESIDENTIAL',
#   'PROCLAMATION',
#   'Priest',
#   'solemn',
#   'duty',
#   'Christ',
#   'remove',
#   'Church',
#   'serve',
#   'Communion']]

# %% [markdown]
# ### Save Output

# %%
import pickle

# Save the dictionary to a file using Pickle
with open('data/preprocessing_output.pkl', 'wb') as file:
    pickle.dump(result, file)

# %% [markdown]
# ### Load Output

# %%
# to read the pkl file:
with open('data/preprocessing_output.pkl', 'rb') as file:
    loaded_list = pickle.load(file)
    
# Print the dictionary
print(loaded_list)
# Out:
# [['In', '2013', 'dude', 'YouTube', 'beg', 'buy', '1', 'worth', 'bitcoin'], ['Christopher', 'Nolan', 'plant', '500', 'acre', 'corn', 'Interstellar', 'use', 'Computer-generated Imagery'], ['survivor', 'genocide', 'people'], ['Kai', 'Cenat', 'room', 'setup', '50', 'hour', 'Red', 'Dead', 'Redemption', '2', 'stream'], ['Reminder', 'This', 'tweet', 'itll', 'view', 'Don', 'Lemons'], ['There', 'Catholic', 'Joe', 'Biden'], ['Your', 'child', 'doesnt', 'ADHD', 'hes', 'eat', 'artificial', 'food', 'color', 'breakfast', '6', 'year', 'life'], ['SHOCK', 'REPORT', 'Biden', 'declare', 'Easter', 'Sunday', '2024', 'TRANSGENDER', 'DAY', 'OF', 'VISIBILITY', 'This', 'like', 'declare', 'NATIONAL', 'BACON', 'WEEK', 'Muslim', 'Ramadan'], ['BREAKING', 'A', 'large', 'barge', 'crash', 'Arkansas', 'River', 'bridge', 'cause', 'damage', 'ship', 'bridge', 'pillar', 'Sallisaw', 'OklahomaEarlier', 'even', '130', 'pm', 'large', 'barge', 'crash', 'struck', 'Arkansas', 'River', 'bridge', 'Kerr', 'Reservoir'], ['think', 'see', 'original'], ['BIDEN', 'RENAMES', 'EASTER', 'SUNDAY', 'TRANSGENDER', 'DAY', 'OF', 'VISIBILITY', 'NOW', 'THEREFORE', 'I', 'JOSEPH', 'R', 'BIDEN', 'JR', 'President', 'United', 'States', 'America', 'virtue', 'authority', 'vest', 'Constitution', 'law', 'United', 'States', 'proclaim', 'March', '31', '2024'], ['Wemby', 'spoil', 'Jalen', 'Brunsons', '61pt', 'game', 'throw', 'game', 'ball', 'crowd'], ['The', 'time', 'Larry', 'David', 'stretch', 'legs', 'basketball', 'game'], ['Interesting', 'method', 'poach', 'egg'], ['cat', 'take', 'like', 'scooby', 'doo'], ['Cost', 'love'], ['How', 'vehicle', 'paint', 'ohmytechness'], ['Chance', 'Perdomo', 'pass', 'away', 'age', '27', 'motorcycle', 'accident'], ['Pigeon', 'want', 'come', 'inside', 'save', 'hail'], ['Joe', 'Biden', 'actually', 'declare', 'Easter', 'Sunday', 'Transgender', 'holiday'], ['NEW', 'Massive', 'turnout', 'fall', 'NYPD', 'officer', 'Jonathan', 'Diller', 'Massapequa', 'Long', 'Island', 'Over', '10000', 'officer', 'show', 'travel', 'far', 'Toronto', 'Miami', 'pay', 'tribute', 'Diller', 'Over', '700', 'motorcyclist', 'line', 'path', 'cemetery', 'salute'], ['BREAKING', 'NEWS', 'Sean', 'Diddy', 'Combs', 'release', 'video', 'Homeland', 'Security', 'human', 'trafficking', 'raid', 'mansion', 'Puffy', 'appear', 'good', 'spirit', 'despite', 'allegation', 'The', 'update', 'case', '6', 'hour', 'ago', 'Homeland', 'Security', 'subpoenaed'], ['Carrom', 'tabletop', 'game', 'resemble', 'snooker', 'subbuteo', 'air', 'hockey', 'Its', 'played', 'propelling', 'disc', 'pot', 'corner', 'pocket', 'wooden', 'play', 'board', 'This', 'Carrom', 'King', 'Haji', 'Ali', 'Agariya'], ['SERBIA', 'invite', 'attend', 'BRICS', '2024', 'summit'], ['BREAKING', 'Israel', 'hit', 'car', 'Southern', 'Lebanon', 'drone', 'strike', 'carry', '2', 'UN', 'Observers', 'The', 'UN', 'Observers', 'kill'], ['Jake', 'Paul', 'Mike', 'Tyson', 'fight', 'new', 'rule', '16', 'oz', 'glove', '2', 'minute', 'round', 'No', 'official', 'judge', 'No', 'winner', 'KO', 'Each', 'fighter', 'pas', 'EEG', 'EKG', 'test'], ['White', 'Student', 'Asked', 'To', 'Be', 'As', 'Racist', 'As', 'Possible', 'For', '5', 'Seconds', 'Declines', 'Is', 'Then', 'Beat', 'Mercilessly'], ['Its', 'absolutely', 'insane', 'spending', 'money', 'slot', 'machine'], ['WHATS', 'GOING', 'ON', 'Canada', 'approve', '27', 'year', 'old', 'woman', 'autism', 'medically', 'assist', 'death', 'MAiD', 'despite', 'have', 'health', 'problem', 'Her', 'father', 'object', 'say', 'isnt', 'capable', 'make', 'decision', 'SHARE', 'think', 'stop'], ['pete', 'davidson', 'quick'], ['Eminems', 'time', 'studio', 'Dr', 'Dre', 'record', 'My', 'Name', 'Is'], ['Sketch', 'break', 'character', 'Steve', 'gift', '25k', 'Rolex', '50k', 'cash'], ['BREAKING', 'Over', 'Ten', 'Thousand', 'New', 'York', 'Police', 'Officers', 'Gathered', 'Slain', 'NYPD', 'Officer', 'Jonathan', 'Dillers', 'FuneralMassapequa', 'NewYork', 'Witness', 'report', 'estimate', 'thousand', 'New', 'York', 'law', 'enforcement', 'officer', 'pay', 'tribute', ' ...
