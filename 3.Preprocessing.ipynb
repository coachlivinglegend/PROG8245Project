# %% [markdown]
# ### Read Data

# %%
#pip install langdetect

# %%
import pandas as pd
from langdetect import detect, LangDetectException

# %%
# language detection
def detect_lang(text):
    try:
        return detect(text)
    except LangDetectException:
        return None

df_texts = pd.read_csv('data/texts.csv', encoding='cp949')
df_texts = df_texts['Content']
df_texts.dropna(inplace=True)
df_texts = pd.DataFrame(df_texts)

# detect language and add a new column
df_texts['lang'] = df_texts['Content'].apply(detect_lang)

# remove French texts
df_texts = df_texts[df_texts['lang'] != 'fr']['Content']

df_texts
# Out:
# 0      There’s renters of every age in this country. ...
# 1      Young Canadians put a lot of their hard-earned...
# 2                             i wonder where she is now
# 3      The Canada Carbon Rebate puts hundreds of doll...
# 4      The economy should be recognizing and rewardin...
#                              ...
# 495                                          EXCUSE ME?!
# 496                                    It's over, folks.
# 497    First peek at the Nostalgia emotion in ‘INSIDE...
# 498    It is difficult, but I would like to stop usin...
# 499    I’m writing something about the famous field o...
# Name: Content, Length: 422, dtype: object

# %%
texts = [text for text in df_texts]
print(texts)
len(texts)
# Out:
# ['There’s renters of every age in this country. Our new renter protections ? against unfair rent hikes, renovictions, and bad landlords ? will be there for every one of you.', 'Young Canadians put a lot of their hard-earned money towards rent every month. We think that should count for a lot more ? like towards your credit score.', 'i wonder where she is now ', 'The Canada Carbon Rebate puts hundreds of dollars back in Canadians’ pockets every quarter. Oddly, some Premiers are against that ? and they want to scrap your rebates. \r\n\r\nHere’s what I had to say about that:', 'The economy should be recognizing and rewarding the work of young Canadians ? just as it did for their parents and grandparents.\r\n\r\nThat’s what this Budget is all about.', 'Don’t think, just type.\r\n\r\nWhat is a GREAT monthly salary.', 'Introducing AnimeChain, in collaboration with  and ', 'how is that even possible???', 'Grok has normal mode and fun mode. Tonight, we decided to add an unhinged fun mode. It is next-level ', 'the softest paws ', 'Imagine if Harry Potter ended like this', 'The next 10 years are going to be crazy.\r\n\r\nTech bros are going to have to put down their MacBooks.\r\n\r\nAnd learn how to use a hammer.', "When Kurt Russell was a kid, he worked with Charles Bronson.   \r\n\r\nOn discovering it was Bronson's birthday, Russell gave him a gift.   \r\n\r\nBronson took the gift and left without a word, leaving Russell worried he had upset him.   \r\n\r\nLater, Bronson called Russell to his dressing room…", 'Baby monkey eating dragon fruit..', 'DEVELOPING: This footage of an episode of Dan Schneider’s Nickelodeon TV series ‘All That,’ where a thick milky white slime was being poured on child star Shane Lyon’s face in an attempt wake him up and Sean Diddy Combs told the children to also put a toy helicopter down his…', 'Are you this old?', 'thanking God for not being born like this', 'Personal trainer.', 'Is this accurate?   Does anybody know?', 'BREAKING: Election integrity organization Omega4America says they are worried Trump may lose in all swing states if nothing changes because they’ve found abundant “phantom voters” registered on their rolls. \r\n\r\n“Every state we test, all 26, has from 7% to 18% of its registered…', 'Just a reminder, Palworld died a month ago. \r\n\r\nAlso Pokemon day was only just a month ago…', 'so interesting tbh', 'Friend making $20/hr as a barista: “No worries bro, I"ll cover this one and you\'ll get the next one!”\r\n\r\nFriend making $450k as a software engineer: “Can you Venmo me $3.62 for your share of the Uber ride?”', " Russia has CANCELLED Guinea Bissau's DEBT.  \r\n\r\nGuinea Bissau will use the money saved towards improving healthcare and education.", 'Awww Grandma was confused for a moment. ', 'Quiz time. Can you guess what is being heated here?  No cheating\r\n\r\nCredit:  Potterandsons', 'Population of Earth: 8 Billion \r\n\r\nGlobal Impressions Last Year on ??: 5 Trillion+', ' New Record\r\n\r\nLamine Yamal has become the youngest player to watch Endrick score for Brazil', 'My two personalities', "Father's blood is strong.", 'Oh nothing, just a lion and a lioness cuddling each other.', 'When Aaron Hernandez’s teammates realized he had issues', 'what is going on here', 'Michael Jackson realizes the press take pictures every time he moves', 'A different way of making corn   coo_king001', 'Mike Lindell, Ronna McDaniel and Rudy Giuliani are in a rowboat that’s sinking in the middle of a lake. You can only save one of them ? who would you choose?', "Diddy's son King, 25, is spotted looking tense outside rapper's LA mansion as he wears what fans call ‘Illuminati sweatpants’ beside his bright red dog.", 'Pregnancy was humbled', '“content that focuses on intimate body parts for a prolonged period of time will not be allowed.”\r\n\r\nTwitch is changing their content guidelines starting March 29th', 'The bridge collapsed at 1.30 am - by  8 am the next morning, all officials had done an "investigatio ...
# 422

# %% [markdown]
# ### Text Preprocessing

# %%
#pip install tweet-preprocessor

# %%
# importing the needed libraries
import numpy as np
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from gensim.parsing.preprocessing import remove_stopwords
import re 
import string
import html
import preprocessor as p

# %%
def clean_tweet(tweet):
    # remove URLs, mentions, reserved words (RT, FAV), emojis, and smileys
    p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.RESERVED, p.OPT.EMOJI, p.OPT.SMILEY)
    tweet = p.clean(tweet)

    # Tokenize the tweet
    tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)
    tokens = tknzr.tokenize(tweet)

    # handle abbreviations
    tokens_normalized = ["to be honest" if token == "tbh" else token for token in tokens]

    # join words back into sentences
    cleaned_sentence = [' '.join(tokens_normalized)]

    # Replacing '-' with ' '
    sentence_cleaned_v1 = re.sub(r'-', ' ', cleaned_sentence[0])

    # Removing any character which is not a space, letter or a number
    regular_expression_num_letters = r'[^a-zA-Z0-9 ]'
    sentence_cleaned_v2 = re.sub(regular_expression_num_letters, '', sentence_cleaned_v1)

    # Removing any extra spaces
    sentence_cleaned_v3 = re.sub(r'\s+', ' ', sentence_cleaned_v2)

    # Remove Stopwords
    stop_words_removed = remove_stopwords(sentence_cleaned_v3)

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = [lemmatizer.lemmatize(word) for word in stop_words_removed.split()]

    result = lemmatized_sentence
    
    return result

# %%
def get_cleaned_tweets(tweets):
    return [clean_tweet(tweet) for tweet in tweets]

# %%
result = get_cleaned_tweets(texts)
result
# Out:
# [['Theres',
#   'renter',
#   'age',
#   'country',
#   'Our',
#   'new',
#   'renter',
#   'protection',
#   'unfair',
#   'rent',
#   'hike',
#   'renovictions',
#   'bad',
#   'landlord'],
#  ['Young',
#   'Canadians',
#   'lot',
#   'hard',
#   'earned',
#   'money',
#   'rent',
#   'month',
#   'We',
#   'think',
#   'count',
#   'lot',
#   'like',
#   'credit',
#   'score'],
#  ['wonder'],
#  ['The',
#   'Canada',
#   'Carbon',
#   'Rebate',
#   'put',
#   'hundred',
#   'dollar',
#   'Canadians',
#   'pocket',
#   'quarter',
#   'Oddly',
#   'Premiers',
#   'want',
#   'scrap',
#   'rebate',
#   'Heres',
#   'I'],
#  ['The',
#   'economy',
#   'recognizing',
#   'rewarding',
#   'work',
#   'young',
#   'Canadians',
#   'parent',
#   'grandparent',
#   'Thats',
#   'Budget'],
#  ['Dont', 'think', 'type', 'What', 'GREAT', 'monthly', 'salary'],
#  ['Introducing', 'AnimeChain', 'collaboration'],
#  ['possible'],
#  ['Grok',
#   'normal',
#   'mode',
#   'fun',
#   'mode',
#   'Tonight',
#   'decided',
#   'add',
#   'unhinged',
#   'fun',
#   'mode',
#   'It',
#   'level'],
#  ['softest', 'paw'],
#  ['Imagine', 'Harry', 'Potter', 'ended', 'like'],
#  ['The',
#   '10',
#   'year',
#   'going',
#   'crazy',
#   'Tech',
#   'bros',
#   'going',
#   'MacBooks',
#   'And',
#   'learn',
#   'use',
#   'hammer'],
#  ['When',
#   'Kurt',
#   'Russell',
#   'kid',
#   'worked',
#   'Charles',
#   'Bronson',
#   'On',
#   'discovering',
#   'Bronsons',
#   'birthday',
#   'Russell',
#   'gave',
#   'gift',
#   'Bronson',
#   'took',
#   'gift',
#   'left',
#   'word',
#   'leaving',
#   'Russell',
#   'worried',
#   'upset',
#   'Later',
#   'Bronson',
#   'called',
#   'Russell',
#   'dressing',
#   'room'],
#  ['Baby', 'monkey', 'eating', 'dragon', 'fruit'],
#  ['DEVELOPING',
#   'This',
#   'footage',
#   'episode',
#   'Dan',
#   'Schneiders',
#   'Nickelodeon',
#   'TV',
#   'series',
#   'All',
#   'That',
#   'milky',
#   'white',
#   'slime',
#   'poured',
#   'child',
#   'star',
#   'Shane',
#   'Lyons',
#   'face',
#   'attempt',
#   'wake',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'told',
#   'child',
#   'toy',
#   'helicopter'],
#  ['Are', 'old'],
#  ['thanking', 'God', 'born', 'like'],
#  ['Personal', 'trainer'],
#  ['Is', 'accurate', 'Does', 'anybody', 'know'],
#  ['BREAKING',
#   'Election',
#   'integrity',
#   'organization',
#   'Omega',
#   '4America',
#   'say',
#   'worried',
#   'Trump',
#   'lose',
#   'swing',
#   'state',
#   'change',
#   'theyve',
#   'abundant',
#   'phantom',
#   'voter',
#   'registered',
#   'roll',
#   'Every',
#   'state',
#   'test',
#   '26',
#   '7',
#   '18',
#   'registered'],
#  ['Just',
#   'reminder',
#   'Palworld',
#   'died',
#   'month',
#   'ago',
#   'Also',
#   'Pokemon',
#   'day',
#   'month',
#   'ago'],
#  ['interesting', 'honest'],
#  ['Friend',
#   'making',
#   '20',
#   'hr',
#   'barista',
#   'No',
#   'worry',
#   'bro',
#   'I',
#   'll',
#   'cover',
#   'youll',
#   'Friend',
#   'making',
#   '450k',
#   'software',
#   'engineer',
#   'Can',
#   'Venmo',
#   '362',
#   'share',
#   'Uber',
#   'ride'],
#  ['Russia',
#   'CANCELLED',
#   'Guinea',
#   'Bissaus',
#   'DEBT',
#   'Guinea',
#   'Bissau',
#   'use',
#   'money',
#   'saved',
#   'improving',
#   'healthcare',
#   'education'],
#  ['Awww', 'Grandma', 'confused', 'moment'],
#  ['Quiz',
#   'time',
#   'Can',
#   'guess',
#   'heated',
#   'No',
#   'cheating',
#   'Credit',
#   'Potterandsons'],
#  ['Population',
#   'Earth',
#   '8',
#   'Billion',
#   'Global',
#   'Impressions',
#   'Last',
#   'Year',
#   '5',
#   'Trillion'],
#  ['New',
#   'Record',
#   'Lamine',
#   'Yamal',
#   'youngest',
#   'player',
#   'watch',
#   'Endrick',
#   'score',
#   'Brazil'],
#  ['My', 'personality'],
#  ['Fathers', 'blood', 'strong'],
#  ['Oh', 'lion', 'lioness', 'cuddling'],
#  ['When', 'Aaron', 'Hernandezs', 'teammate', 'realized', 'issue'],
#  ['going'],
#  ['Michael', 'Jackson', 'realizes', 'press', 'picture', 'time', 'move'],
#  ['A', 'different', 'way', 'making', 'corn', 'cooking', '001'],
#  ['Mike',
#   'Lindell',
#   'Ronna',
#   'McDaniel',
#   'Rudy',
#   'Giuliani',
#   'rowboat',
#   'thats',
#   'sinking',
#   'middle',
#   'lake',
#   'You',
#   'save',
#   'choose'],
#  ['Diddys',
#   'son',
#   'King',
#   '25',
#   'spotted',
#   'looking',
#   'tense',
#   'outside',
#   'rapper',
#   'LA',
#   'mansion',
#   'wear',
#   'fan',
#   'Illuminati',
#   'sweatpants',
#   'bright',
#   'red',
#   'dog'],
#  ['Pregnancy', 'humbled'],
#  ['content',
#   'focus',
#   'intimate',
#   'body',
#   'part',
#   'prolonged',
#   'period',
#   'time',
#   'allowed',
#   'Twitch',
#   'changing',
#   'content',
#   'guideline',
#   'starting',
#   'March',
#   '29th'],
#  ['The',
#   'bridge',
#   'collapsed',
#   '130',
#   '8',
#   'morning',
#   'official',
#   'investigation',
#   'determined',
#   'incident',
#   '4',
#   'hour',
#   'later',
#   'Biden',
#   'hit',
#   'mic',
#   'said',
#   'tax',
#   'payer',
#   'pay',
#   'rebuild',
#   'Nothing',
#   'pull',
#   'finger'],
#  ['JUST',
#   'IN',
#   'BlackRock',
#   'CEO',
#   'Larry',
#   'Fink',
#   'say',
#   'Spot',
#   'Bitcoin',
#   'ETF',
#   'fastest',
#   'growing',
#   'ETF',
#   'history',
#   'he',
#   'bullish',
#   'BTC',
#   'long',
#   'term'],
#  ['Wow',
#   'The',
#   'victim',
#   'lost',
#   '4M',
#   'deal',
#   'according',
#   'NYPost',
#   'For',
#   'shame'],
#  ['Jon',
#   'Stewart',
#   'overvalued',
#   'NYC',
#   'apartment',
#   '827',
#   'Will',
#   'Leticia',
#   'James',
#   'Of',
#   'course'],
#  ['Bam'],
#  ['Yung',
#   'Miami',
#   'accused',
#   'transporting',
#   'pink',
#   'cocaine',
#   'Diddy',
#   'new',
#   'court',
#   'document'],
#  ['Should',
#   'school',
#   'banned',
#   'teaching',
#   'woke',
#   'gender',
#   'ideology',
#   'kid'],
#  ['BOMSHELL',
#   'REPORT',
#   'Accusations',
#   'emerge',
#   'Michael',
#   'Cohen',
#   'HAVING',
#   'AN',
#   'AFFAIR',
#   'Stormy',
#   'Daniels',
#   '2006',
#   'hush',
#   'money',
#   'scheme',
#   'cooked',
#   'Michael',
#   'Cohen',
#   'EXTORT',
#   'THE',
#   'TRUMP',
#   'ORGANIZATION',
#   '2016',
#   'election',
#   'Avenatti',
#   'shared',
#   'detail',
#   'client',
#   'Stormy'],
#  ['New',
#   'Skeledirge',
#   'Pokemon',
#   'sweater',
#   'go',
#   'kinda',
#   'hard',
#   'It',
#   'scarlet',
#   'violet',
#   'flame',
#   'nice'],
#  ['Justified', 'Father', 'run', 'Teacher', 'sleeping', 'daughter'],
#  ['This',
#   'Women',
#   'Aviation',
#   'Conference',
#   'Orlando',
#   'There',
#   'booth',
#   'pilot',
#   'sign',
#   'fly',
#   'adolescent',
#   'undergo',
#   's',
#   'x',
#   'change',
#   'surgery',
#   'puberty',
#   'blocker',
#   'This',
#   'desperate',
#   'trans',
#   'kid',
#   'Isnt',
#   'word',
#   'transport',
#   'kid'],
#  ['The',
#   'US',
#   'dollar',
#   'lost',
#   '25',
#   'purchasing',
#   'power',
#   'January',
#   '2020',
#   'Every',
#   '1',
#   'worth',
#   '075',
#   'good',
#   'Insane'],
#  ['EXTREMELY',
#   'UNSETTLING',
#   'Someone',
#   'recorded',
#   'moment',
#   'TV',
#   'bird',
#   'disappear',
#   'air',
#   'LIVE',
#   'coverage',
#   'bridge',
#   'collapse',
#   'In',
#   'movie',
#   'Obamas',
#   'produced',
#   'Leave',
#   'The',
#   'World',
#   'Behind',
#   'bird',
#   'start',
#   'acting',
#   'crazy',
#   'highly',
#   'unusual',
#   'way'],
#  ['fuck', 'thread', 'badly'],
#  ['Jack',
#   'Black',
#   'think',
#   'RedDeadRedemption',
#   'good',
#   'film',
#   'adaptation',
#   'I',
#   'believe',
#   'havent',
#   'started',
#   'making',
#   'movie',
#   'Rockstar',
#   'Games'],
#  ['Hey',
#   'dont',
#   'understand',
#   '8',
#   '10',
#   'family',
#   'money',
#   'Why',
#   'want',
#   'rob',
#   'rebate'],
#  ['Im',
#   'voting',
#   'Liberal',
#   'party',
#   'I',
#   'agree',
#   'price',
#   'carbon',
#   'like',
#   'expert',
#   'IStandWithTrudeau'],
#  ['happened', '2', 'year', 'ago', 'today'],
#  ['My', 'mood'],
#  ['BREAKING',
#   'During',
#   'announcement',
#   'Vancouver',
#   'Prime',
#   'Minister',
#   'Trudeau',
#   'announces',
#   'new',
#   'Renters',
#   'Bill',
#   'Rights',
#   'includes',
#   'protection',
#   'tenant',
#   'legal',
#   'funding',
#   'fight',
#   'unfair',
#   'practice',
#   'landlord',
#   'rent',
#   'count',
#   'credit',
#   'score',
#   'profile'],
#  ['Hey',
#   'supporter',
#   'Poilievre',
#   'PM',
#   'scrap',
#   'carbon',
#   'tax',
#   'rebate',
#   'Whats',
#   'going',
#   'reduce',
#   'Canadas',
#   'carbon',
#   'emission'],
#  ['Dont', 'worry', 'bring', 'CN', 'Tower', 'repair'],
#  ['Going',
#   'forward',
#   'account',
#   '2500',
#   'verified',
#   'subscriber',
#   'follower',
#   'Premium',
#   'feature',
#   'free',
#   'account',
#   '5000',
#   'Premium',
#   'free'],
#  ['Joe',
#   'Lieberman',
#   'I',
#   'didnt',
#   'eye',
#   'eye',
#   'extraordinary',
#   'career',
#   'public',
#   'service',
#   'including',
#   'decade',
#   'spent',
#   'fighting',
#   'people',
#   'Connecticut',
#   'He',
#   'worked',
#   'hard',
#   'repeal',
#   'Dont',
#   'Ask',
#   'Dont',
#   'Tell',
#   'helped',
#   'pas',
#   'Affordable',
#   'Care',
#   'Act',
#   'In'],
#  ['This', 'flock', 'sheep', 'washed'],
#  ['Ask', 'theyre', 'hiding', 'captain', 'hit', 'bridge', 'youll', 'answer'],
#  ['baking', 'bean'],
#  ['afford', 'sleeve'],
#  ['god',
#   'bruh',
#   'shit',
#   'diddy',
#   'court',
#   'doc',
#   'making',
#   'sick',
#   'section',
#   '73',
#   'page'],
#  ['Why', 'America', 'destroy', 'city', 'A', 'thread'],
#  ['Man', 'introduces', 'puppy', 'dog', 'traffic'],
#  ['believe', 'happened'],
#  ['BREAKING',
#   'NEWS',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'private',
#   'jet',
#   'landed',
#   'Opa',
#   'Locka',
#   'Florida',
#   'Private',
#   'guard',
#   'umbrella',
#   'left',
#   'Puffys',
#   'property',
#   'shortly',
#   'plane',
#   'landed',
#   'detail',
#   'currently',
#   'developing',
#   'sex',
#   'trafficking',
#   'investigation',
#   'There',
#   'new',
#   'confirmation'],
#  ['An',
#   'upset',
#   'Michelle',
#   'Phillips',
#   'eating',
#   'banana',
#   'Mamas',
#   'Papas',
#   'performance',
#   'California',
#   'Dreaming',
#   'Ed',
#   'Sullivan',
#   'Show',
#   'lip',
#   'sync',
#   '1967'],
#  ['Giant', 'alligator', 'bend', 'metal', 'fence', 'forcing', 'way'],
#  ['BREAKING',
#   'Police',
#   'scene',
#   'male',
#   'suspect',
#   'went',
#   'mass',
#   'stabbing',
#   'spree',
#   'injuring',
#   'numerous',
#   'people',
#   'resulting',
#   'multiple',
#   'fatality',
#   'Rockford',
#   'IllinoisCurrently',
#   'numerous',
#   'law',
#   'enforcement',
#   'agency',
#   'scene',
#   'Rockford',
#   'Illinois'],
#  ['She', 'thought', 'Dana', 'white', 'Joe', 'Rogan'],
#  ['A', 'ton', 'Cocoa', 'worth', 'ton', 'Copper', 'What', 'heck', 'going'],
#  ['7', 'Eleven', 'releasing', 'hot', 'dog', 'flavored', 'water'],
#  ['Meeting', 'favorite', 'character'],
#  ['BREAKING',
#   'Police',
#   'audio',
#   'released',
#   'capture',
#   'dispatcher',
#   'discussing',
#   'officer',
#   'approaching',
#   'container',
#   'ship',
#   'subsequent',
#   'collapse',
#   'Francis',
#   'Scott',
#   'Key',
#   'Bridge',
#   'Baltimore',
#   'In',
#   'audio',
#   'hear',
#   'officer',
#   'trying',
#   'best',
#   'traffic',
#   'stopped'],
#  ['Goodmorning'],
#  ['Canadas',
#   'Deputy',
#   'Prime',
#   'Minister',
#   'Chrystia',
#   'Freeland',
#   'exhibit',
#   'bizarre',
#   'behavior',
#   'press',
#   'conference',
#   'community',
#   'center',
#   'Vancouver',
#   'Freeland',
#   'repeatedly',
#   'twitch',
#   'display',
#   'erratic',
#   'body',
#   'movement',
#   'stand',
#   'Trudeau'],
#  ['The', 'dog', 'didnt', 'notice', 'mom', 'room', 'look'],
#  ['Breaking',
#   'Graphic',
#   'bystander',
#   'video',
#   'captured',
#   'masked',
#   'black',
#   'male',
#   'stabbing',
#   'person',
#   'repeatedly',
#   'moving',
#   'train',
#   'London',
#   'The',
#   'train',
#   'traveling',
#   'Shortlands',
#   'Beckenham',
#   'station',
#   'Victoria',
#   'Station',
#   'A',
#   'nearby',
#   'school',
#   'placed',
#   'lockdown',
#   'The',
#   'person',
#   'stabbed'],
#  ['Einstein', 'Oppenheimer', '1930s'],
#  ['The',
#   'vessel',
#   'steered',
#   'hard',
#   'right',
#   'minute',
#   'hit',
#   'bridge',
#   'cause',
#   'damage',
#   'And',
#   'save',
#   'breath',
#   'telling',
#   'Its',
#   'freaking',
#   'video',
#   'brain',
#   'dead',
#   'useful',
#   'idiot'],
#  ['Hold', 'tight'],
#  ['A', 'sleeping', 'octopus', 'change', 'color', 'dreaming'],
#  ['Eminem', 'Mark', 'Wahlberg', 'TRL', 'live', '1999'],
#  ['Did', 'I', 'hear', 'hose'],
#  ['This', 'Paris', 'main', 'airport'],
#  ['thats',
#   'got',
#   'emasculating',
#   'night',
#   'night',
#   'he',
#   'length',
#   'damn',
#   'court'],
#  ['This',
#   'delivery',
#   'guy',
#   'Brampton',
#   'Canada',
#   'harassed',
#   'worthless',
#   'customer',
#   'who',
#   'trying',
#   'content',
#   'TikTok',
#   'If',
#   'know',
#   'Id',
#   'like',
#   'send',
#   'huge',
#   'tip'],
#  ['BREAKING',
#   'Evacuations',
#   'underway',
#   'Massive',
#   'Fire',
#   'Explosions',
#   'Comfuel',
#   'Gas',
#   'Station',
#   'people',
#   'running',
#   'building',
#   'BowlingGreen',
#   'KentuckyCurrently',
#   'numerous',
#   'business',
#   'nearby',
#   'school',
#   'evacuation',
#   'dozen',
#   'emergency',
#   'crew'],
#  ['wonder', 'right'],
#  ['BREAKING',
#   'Prominent',
#   'LGBTQ',
#   'activist',
#   'Trey',
#   'Farmer',
#   'arrested',
#   'child',
#   'p',
#   'rn',
#   'charge',
#   'Trey',
#   'alumnus',
#   'Princeton',
#   'President',
#   'Queer',
#   'Princeton',
#   'Alumni',
#   'organization'],
#  ['You',
#   'In',
#   'Canada',
#   'talking',
#   'making',
#   'people',
#   'pay',
#   'RAIN',
#   'TAX',
#   'Yes',
#   'people',
#   'paying',
#   'rain',
#   'land',
#   'property',
#   'Whats',
#   'breathing',
#   'tax'],
#  ['clip', 'million', 'time', 'funnier', 'abruptly', 'cut'],
#  ['Oklahoma',
#   'man',
#   'arrested',
#   'allegedly',
#   'trying',
#   'steal',
#   'pair',
#   'Balenciaga',
#   'shoe',
#   'woman',
#   'met',
#   'selling',
#   'app'],
#  ['Am',
#   'I',
#   'crazy',
#   'think',
#   'THIS',
#   'literally',
#   'EXPENSIVE',
#   'This',
#   'veggie',
#   'platter',
#   '45',
#   'Thats',
#   'INSANE',
#   'Is',
#   'worth',
#   '45',
#   'With',
#   'tax',
#   'thats',
#   'like',
#   '50',
#   'What',
#   'hell',
#   'going',
#   'Canada'],
#  ['Skip', 'Bayless', 'BUCKET'],
#  ['fossilized',
#   'Odontochile',
#   'trilobite',
#   '400',
#   'million',
#   'year',
#   'old',
#   'rock',
#   'North',
#   'Africa',
#   'This',
#   'marine',
#   'animal',
#   'goldbugsofficial'],
#  ['Offset',
#   'You',
#   'gotta',
#   'stop',
#   'wearing',
#   'tight',
#   'pant',
#   'bruh',
#   'Shannon',
#   'Sharpe',
#   'I',
#   'Offset',
#   'got',
#   'bruh',
#   'tryna',
#   'tell',
#   'like',
#   'player',
#   'Shannon',
#   'Sharpe',
#   'I',
#   'aint',
#   'finna',
#   'let',
#   'change',
#   'man',
#   'Offset',
#   'It',
#   'aint',
#   'youre',
#   'big',
#   'LLMMFFAAOOO'],
#  ['NEWS',
#   'The',
#   'Event',
#   'Horizon',
#   'Telescope',
#   'captured',
#   'image',
#   'supermassive',
#   'black',
#   'hole',
#   'Sagittarius',
#   'A',
#   'polarized',
#   'light'],
#  ['There', 'game', 'coming', 'play', '2d', '3d', 'time'],
#  ['JUST',
#   'IN',
#   'BlackRock',
#   'CEO',
#   'Larry',
#   'Fink',
#   'say',
#   'spot',
#   'Bitcoin',
#   'ETF',
#   'fastest',
#   'growing',
#   'ETF',
#   'history',
#   'ETFs'],
#  ['Joe',
#   'Rogan',
#   'belief',
#   'Israel',
#   'committing',
#   'genocide',
#   'small',
#   'scale',
#   'Holocaust',
#   'Gaza'],
#  ['Sharing',
#   'wonderful',
#   'Sarah',
#   'Cooper',
#   'video',
#   'reason',
#   'whatsoever',
#   'TrumpBible'],
#  ['BREAKING',
#   'Venezuelan',
#   'migrant',
#   'influencer',
#   'sparked',
#   'fury',
#   'TikTok',
#   'squatting',
#   'tip',
#   'fugitive',
#   'fleeing',
#   'ICE',
#   'custody',
#   'post',
#   'snotty',
#   'sobbing',
#   'clip',
#   'threatened',
#   'powerful',
#   'people',
#   'family',
#   'life',
#   'danger',
#   'people',
#   'looking'],
#  ['Happy', 'Gilmore', '2', 'cast', 'far'],
#  ['GET', 'ErdoganArmsIsrael', 'TRENDING', 'RIGHT', 'NOW'],
#  ['The',
#   'cost',
#   'rent',
#   'high',
#   'doesnt',
#   'count',
#   'credit',
#   'score',
#   'Thats',
#   'right',
#   'fixing',
#   'Were',
#   'unlocking',
#   'door',
#   'middle',
#   'class',
#   'million',
#   'young',
#   'Canadians',
#   'Most',
#   'importantly',
#   'going',
#   'build',
#   'home',
#   'apartment'],
#  ['This', 'restaurant', 'took', 'marketing', 'level'],
#  ['cat', 'like'],
#  ['We', 'conspiracy', 'theorist', '54', '0', 'right'],
#  ['cat', 'walmart'],
#  ['bro', 'got', 'evicted'],
#  ['ANDREW',
#   'TATE',
#   'ON',
#   'PDIDDY',
#   'YOU',
#   'CAN',
#   'RAPE',
#   'KIDS',
#   'IF',
#   'YOU',
#   'COMPLY',
#   'WITH',
#   'THE',
#   'SYSTEM',
#   'If',
#   'youre',
#   'P',
#   'Diddy',
#   'f',
#   'people',
#   'as',
#   'f',
#   'underage',
#   'kid',
#   'thats',
#   'fine',
#   'long',
#   'comply',
#   'know',
#   'owner',
#   'But',
#   'youre',
#   'like',
#   'refuse',
#   'bow'],
#  ['Slavery', 'abolished', 'It', 'expanded', 'include'],
#  ['YOUR',
#   'REACTION',
#   'Jon',
#   'Stewart',
#   'overvalued',
#   'NYC',
#   'home',
#   '829',
#   'slamming',
#   'Trumps',
#   'civil',
#   'case',
#   'victimless'],
#  ['Americas',
#   'famous',
#   'Rabbi',
#   'claim',
#   '1',
#   'ISRAELI',
#   'soldier',
#   'life',
#   'equal',
#   '35',
#   'AMERICAN',
#   'soldier',
#   'life',
#   'DISGUSTING'],
#  ['Thoughts'],
#  ['Rabbi',
#   'Shmuley',
#   'asks',
#   'Alex',
#   'Jones',
#   'hate',
#   'Jews',
#   'better',
#   'sex'],
#  ['DeSantis',
#   'Kicked',
#   'Out',
#   'Of',
#   'Republican',
#   'Party',
#   'For',
#   'Accomplishing',
#   'Too',
#   'Many',
#   'Things'],
#  ['BREAKING',
#   'Natalie',
#   'Pershall',
#   'man',
#   'pretending',
#   'woman',
#   'sentenced',
#   '6',
#   'year',
#   'probation',
#   '87',
#   'day',
#   'jail',
#   'register',
#   's',
#   'x',
#   'offender',
#   'taking',
#   'picture',
#   'female',
#   'woman',
#   'bathroom',
#   'company',
#   'office',
#   'This',
#   'happens',
#   'inclusive'],
#  ['The',
#   'story',
#   'John',
#   'D',
#   'Rockefeller',
#   'banned',
#   'natural',
#   'medicine',
#   'Western',
#   'world',
#   'created',
#   'monopoly',
#   'force',
#   'ten',
#   'million',
#   'people',
#   'poison',
#   'daily',
#   'Shocking'],
#  ['Migrants',
#   'fighting',
#   'Charles',
#   'Gaulle',
#   'Airport',
#   'Paris',
#   'effort',
#   'stop',
#   'migrant',
#   'getting',
#   'deported',
#   'France'],
#  ['Is', 'clear', 'victim'],
#  ['isnt', 'gzso', 'youre', 'saying', 'happen', 'plestinians'],
#  ['What', 'scene', 'horror', 'movie', 'haunt', 'day'],
#  ['Rally',
#   'sport',
#   'fan',
#   'turn',
#   'mechanic',
#   '5',
#   'minute',
#   'Greenstranger',
#   '2'],
#  ['hasan',
#   'having',
#   'mental',
#   'breakdown',
#   'discord',
#   'cuz',
#   'watch',
#   'stream',
#   'anymore'],
#  ['UK',
#   'Train',
#   'Stabbing',
#   'Disturbing',
#   'clip',
#   'Hate',
#   'sharing',
#   'people',
#   'world',
#   'truly',
#   'need',
#   'understand',
#   'quickly',
#   'Society',
#   'degrading',
#   'recognisability',
#   'Stay',
#   'safe'],
#  ['Joe',
#   'Rogan',
#   'Jan',
#   '6',
#   'conspiracy',
#   'Trump',
#   'Bro',
#   'took',
#   'November',
#   '2020',
#   '81',
#   'million',
#   'vote',
#   'Why',
#   'Nancy',
#   'Pelosi',
#   'Chuck',
#   'Shumer',
#   'attack',
#   'stop',
#   'certification',
#   'Bidens',
#   'win',
#   'Dude',
#   'million',
#   'listener',
#   'brain'],
#  ['I',
#   'think',
#   'dangerous',
#   'initiative',
#   'Nigel',
#   'Farage',
#   'remark',
#   'recent',
#   'unelected',
#   'EU',
#   'head',
#   'Ursula',
#   'von',
#   'der',
#   'Leyen',
#   'world',
#   'leader',
#   'roll',
#   'digital',
#   'ID',
#   'CBDCs',
#   'cashless',
#   'society',
#   'globally',
#   '2030',
#   'If',
#   'careful',
#   'head'],
#  ['CAMILA', 'CABELLO', 'PLAYBOI', 'CARTI', 'I', 'LUV', 'IT', 'OUT', 'NOW'],
#  ['BREAKING',
#   'Donald',
#   'Trump',
#   'fly',
#   'New',
#   'York',
#   'honor',
#   'Officer',
#   'Jonathan',
#   'Diller',
#   'He',
#   'called',
#   'slain',
#   'NYPD',
#   'officer',
#   'widow',
#   'personally',
#   'facilitate',
#   'paying',
#   'mortgage',
#   'alongside',
#   'Tunnels',
#   'Towers',
#   'The',
#   'medium',
#   'doesnt',
#   'want',
#   'know',
#   'Officer',
#   'Diller',
#   'survived',
#   'wife'],
#  ['HUGE',
#   'NEWS',
#   'The',
#   'Louisiana',
#   'senate',
#   'passed',
#   'BAN',
#   'rule',
#   'mandate',
#   'World',
#   'Health',
#   'Organization',
#   'World',
#   'Economic',
#   'Forum',
#   'UN',
#   'enforced',
#   'state',
#   'Do',
#   'support'],
#  ['Jon', 'Stewart', 'overvalued', 'NYC', 'home', '829'],
#  ['How', 'feel'],
#  ['DEVELOPING',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'son',
#   'spotted',
#   'getting',
#   'intimate',
#   'girlfriend',
#   'Homeland',
#   'Securitys',
#   'Investigation',
#   'Agents',
#   'raided',
#   'rapper',
#   'home',
#   'Monday',
#   'Christian',
#   'Combs',
#   'seen',
#   'unbothered',
#   'kissing',
#   'girlfriend',
#   'video',
#   'The',
#   '25',
#   'year',
#   'old',
#   'girlfriend'],
#  ['This', 'employee', 'dream'],
#  ['cat', 'accidentally', 'pressed', 'turbo', 'button'],
#  ['If', 'youve', 'seen', 'reindeer', 'posing', 'aurora', 'today', 'day'],
#  ['Joe', 'Rogan', 'condemns', 'ISRAEL', 'committing', 'GENOCIDE', 'GAZA'],
#  ['Just',
#   'hour',
#   'bridge',
#   'collapsed',
#   'FBI',
#   'accident',
#   'Mayor',
#   'accident',
#   'Governor',
#   'accident',
#   'Biden',
#   'regime',
#   'accident',
#   'Me',
#   'thanks',
#   'Im',
#   'positive',
#   'wasnt',
#   'accident'],
#  ['PizzaGate', 'Sickos'],
#  ['Alex',
#   'Jones',
#   'call',
#   'Rabbi',
#   'Shmuley',
#   'Rabbi',
#   'Buttplug',
#   'Im',
#   'good',
#   'lap',
#   'dance',
#   'grandchild',
#   'Jones',
#   'told',
#   'Shmuley'],
#  ['laugh', 'reacts'],
#  ['Alex', 'Jones', 'asked', 'rabbi', 'butt', 'plug', 'inserted', 'interview'],
#  ['Aerial',
#   'footage',
#   'show',
#   'Zionists',
#   'destroyed',
#   'Gaza',
#   'ethnic',
#   'cleansing',
#   'scale',
#   'world',
#   'witnessed',
#   'history'],
#  ['What',
#   'happens',
#   'exceed',
#   'carbon',
#   'limit',
#   'discover',
#   'ability',
#   'buy',
#   'sell',
#   'suddenly',
#   'cut',
#   'Australian',
#   'senator',
#   'Ralph',
#   'Babet',
#   'implores',
#   'freedom',
#   'minded',
#   'people',
#   'resist',
#   'imposition',
#   'digital',
#   'ID',
#   'CBDCs',
#   'We',
#   'resist',
#   'push',
#   'digitise'],
#  ['So',
#   '20',
#   'year',
#   'old',
#   'alcohol',
#   'But',
#   '5',
#   'year',
#   'old',
#   'pick',
#   'gender',
#   'Make',
#   'sense'],
#  ['Diddy', 'Hired', 'As', 'New', 'President', 'Of', 'Nickelodeon', 'Studios'],
#  ['Ovechkin', 'rock'],
#  ['Joe',
#   'Rogan',
#   'Drops',
#   'Great',
#   'Question',
#   'Isnt',
#   'weird',
#   'lie',
#   'people',
#   'force',
#   'people',
#   'thing',
#   'hide',
#   'effect',
#   'sue',
#   'Vaccines',
#   'ONLY',
#   'product',
#   'sue',
#   'manufacturer',
#   'directly',
#   'This'],
#  ['Has', 'anybody', 'checked', 'Marthas', 'Vineyard'],
#  ['SCOOP',
#   'An',
#   'assignment',
#   'instructed',
#   'student',
#   'roam',
#   'school',
#   'looking',
#   'example',
#   'gender',
#   'inequity',
#   'The',
#   'assignment',
#   'asks',
#   'student',
#   'evidence',
#   'patriarchy',
#   'outside',
#   'school',
#   'life',
#   'Im',
#   'told',
#   'parent',
#   'upset',
#   'We'],
#  ['Oh'],
#  ['When',
#   'fascism',
#   'come',
#   'America',
#   'wrapped',
#   'flag',
#   'carrying',
#   'cross',
#   'I',
#   'didnt',
#   'think',
#   'literal'],
#  ['BREAKING',
#   'The',
#   'Ukrainian',
#   'Army',
#   'launched',
#   'major',
#   'attack',
#   'Russian',
#   'position',
#   'Russian',
#   'city',
#   'Belgorod',
#   'tonight',
#   'Civilians',
#   'seen',
#   'running',
#   'street',
#   'desperate',
#   'attempt',
#   'air',
#   'raid',
#   'shelter',
#   'Shouldnt',
#   'invaded',
#   'Ukraine'],
#  ['This',
#   'US',
#   'official',
#   'resigned',
#   'State',
#   'Dept',
#   'confirmed',
#   'US',
#   'aware',
#   'plenty',
#   'evidence',
#   'Israel',
#   'violating',
#   'international',
#   'law',
#   'Biden',
#   'administration',
#   'violating',
#   'US',
#   'law',
#   'continuing',
#   'supply',
#   'weapon',
#   'Rogue',
#   'state'],
#  ['Its',
#   'impossible',
#   'overstate',
#   'atrocious',
#   'decision',
#   'It',
#   'basically',
#   'license',
#   'kill',
#   'The',
#   'court',
#   'accepted',
#   'fact',
#   'woman',
#   'seeking',
#   'death',
#   'autistic',
#   'cognitive',
#   'impairment',
#   'result',
#   'She',
#   'applied',
#   'death',
#   'twice',
#   'twice',
#   'split'],
#  ['Why',
#   'American',
#   'taxpayer',
#   'paying',
#   'new',
#   'bridge',
#   'Baltimore',
#   'Shouldnt',
#   'ahem',
#   'private',
#   'company',
#   'responsible',
#   'destruction',
#   'bridge',
#   'pay',
#   'Taxpayer',
#   'PAID',
#   'bridge',
#   'Foreign',
#   'corporation',
#   'destroys',
#   'Now',
#   'taxpayer',
#   'pay',
#   'new',
#   'bridge',
#   'Uh',
#   'WTF'],
#  ['Australia',
#   'Passes',
#   'Digital',
#   'ID',
#   'Bill',
#   'The',
#   'WEF',
#   '2030',
#   'Agenda',
#   'accelerates',
#   'Australian',
#   'Government',
#   'pass',
#   'digital',
#   'ID',
#   'Listen',
#   'Senator',
#   'Babet',
#   'explain',
#   'Australians',
#   'step',
#   'closer',
#   'Social',
#   'credit',
#   'Co2',
#   'score',
#   'CBDCs',
#   'vaccine',
#   'passport',
#   'handy'],
#  ['US',
#   'President',
#   'Biden',
#   'called',
#   'Putin',
#   'butcher',
#   'called',
#   'urgent',
#   'aid',
#   'Ukraine',
#   'There',
#   'important',
#   'thing',
#   'including',
#   'finally',
#   'taking',
#   'care',
#   'helping',
#   'Ukraine',
#   'butcher',
#   'Putin',
#   'Biden',
#   'stated'],
#  ['White', 'men', '2024'],
#  ['Liberal',
#   'MP',
#   'Jenica',
#   'Atwin',
#   'tantrum',
#   'chair',
#   'member',
#   'I',
#   'Oil',
#   'Gas',
#   'sticker',
#   'laptop',
#   'She',
#   'literally',
#   'felt',
#   'need',
#   'interrupt',
#   'w',
#   'point',
#   'order',
#   'point'],
#  ['Describe', 'RFK', 'Jr', 'word', 'Dont', 'hold'],
#  ['Two',
#   'decade',
#   'ago',
#   'Israel',
#   'evacuated',
#   'Gaza',
#   'gave',
#   'Palestinians',
#   'autonomy',
#   'They',
#   'spent',
#   'billion',
#   'tunnel',
#   'weapon',
#   'They',
#   'celebrated',
#   'massacred',
#   '1200',
#   'Israelis',
#   'kidnapped',
#   'hundred',
#   'Now',
#   'thing',
#   'destruction',
#   'Israel',
#   'flag'],
#  ['NEW',
#   'VIDEO',
#   'FROM',
#   'OMG',
#   'Trump',
#   'Was',
#   'Right',
#   'Biden',
#   'doesnt',
#   'care',
#   'trade',
#   'state',
#   'Trevar',
#   'Kolodny',
#   'Cybersecurity',
#   'Infrastructure',
#   'Security',
#   'Agency',
#   'Official',
#   'Department',
#   'Homeland',
#   'Security',
#   'chemical',
#   'security',
#   'Kolodny',
#   'declares',
#   'I',
#   'dont',
#   'think',
#   'I',
#   'vote'],
#  ['Under',
#   'Trudeau',
#   'Canada',
#   'turned',
#   'nation',
#   'builder',
#   'producer',
#   'nation',
#   'taker',
#   'burner',
#   'The',
#   'New',
#   'Canada',
#   'burn',
#   'church',
#   'flush',
#   'cash',
#   'block',
#   'industry',
#   'That',
#   'legacy',
#   'The',
#   'Old',
#   'Canada',
#   'exists',
#   'fight'],
#  ['carti', 'camila', 'random', 'as', 'collab', 'work'],
#  ['Former',
#   'GOP',
#   'House',
#   'Speaker',
#   'Paul',
#   'Ryan',
#   'Trump',
#   'conservative',
#   'he',
#   'populist',
#   'authoritarian',
#   'narcissist'],
#  ['Two',
#   'decade',
#   'ago',
#   'Israel',
#   'evacuated',
#   'Gaza',
#   'gave',
#   'Palestinians',
#   'autonomy',
#   'They',
#   'spent',
#   'billion',
#   'tunnel',
#   'weapon',
#   'They',
#   'celebrated',
#   'massacred',
#   '1200',
#   'Israelis',
#   'kidnapped',
#   'hundred',
#   'Now',
#   'thing',
#   'destruction',
#   'Israel',
#   'flag'],
#  ['White', 'men', '2024'],
#  ['Liberal',
#   'MP',
#   'Jenica',
#   'Atwin',
#   'tantrum',
#   'chair',
#   'member',
#   'I',
#   'Oil',
#   'Gas',
#   'sticker',
#   'laptop',
#   'She',
#   'literally',
#   'felt',
#   'need',
#   'interrupt',
#   'w',
#   'point',
#   'order',
#   'point'],
#  ['Describe', 'RFK', 'Jr', 'word', 'Dont', 'hold'],
#  ['US',
#   'President',
#   'Biden',
#   'called',
#   'Putin',
#   'butcher',
#   'called',
#   'urgent',
#   'aid',
#   'Ukraine',
#   'There',
#   'important',
#   'thing',
#   'including',
#   'finally',
#   'taking',
#   'care',
#   'helping',
#   'Ukraine',
#   'butcher',
#   'Putin',
#   'Biden',
#   'stated'],
#  ['Its',
#   'impossible',
#   'overstate',
#   'atrocious',
#   'decision',
#   'It',
#   'basically',
#   'license',
#   'kill',
#   'The',
#   'court',
#   'accepted',
#   'fact',
#   'woman',
#   'seeking',
#   'death',
#   'autistic',
#   'cognitive',
#   'impairment',
#   'result',
#   'She',
#   'applied',
#   'death',
#   'twice',
#   'twice',
#   'split'],
#  ['Why',
#   'American',
#   'taxpayer',
#   'paying',
#   'new',
#   'bridge',
#   'Baltimore',
#   'Shouldnt',
#   'ahem',
#   'private',
#   'company',
#   'responsible',
#   'destruction',
#   'bridge',
#   'pay',
#   'Taxpayer',
#   'PAID',
#   'bridge',
#   'Foreign',
#   'corporation',
#   'destroys',
#   'Now',
#   'taxpayer',
#   'pay',
#   'new',
#   'bridge',
#   'Uh',
#   'WTF'],
#  ['Australia',
#   'Passes',
#   'Digital',
#   'ID',
#   'Bill',
#   'The',
#   'WEF',
#   '2030',
#   'Agenda',
#   'accelerates',
#   'Australian',
#   'Government',
#   'pass',
#   'digital',
#   'ID',
#   'Listen',
#   'Senator',
#   'Babet',
#   'explain',
#   'Australians',
#   'step',
#   'closer',
#   'Social',
#   'credit',
#   'Co2',
#   'score',
#   'CBDCs',
#   'vaccine',
#   'passport',
#   'handy'],
#  ['This',
#   'US',
#   'official',
#   'resigned',
#   'State',
#   'Dept',
#   'confirmed',
#   'US',
#   'aware',
#   'plenty',
#   'evidence',
#   'Israel',
#   'violating',
#   'international',
#   'law',
#   'Biden',
#   'administration',
#   'violating',
#   'US',
#   'law',
#   'continuing',
#   'supply',
#   'weapon',
#   'Rogue',
#   'state'],
#  ['When',
#   'fascism',
#   'come',
#   'America',
#   'wrapped',
#   'flag',
#   'carrying',
#   'cross',
#   'I',
#   'didnt',
#   'think',
#   'literal'],
#  ['BREAKING',
#   'The',
#   'Ukrainian',
#   'Army',
#   'launched',
#   'major',
#   'attack',
#   'Russian',
#   'position',
#   'Russian',
#   'city',
#   'Belgorod',
#   'tonight',
#   'Civilians',
#   'seen',
#   'running',
#   'street',
#   'desperate',
#   'attempt',
#   'air',
#   'raid',
#   'shelter',
#   'Shouldnt',
#   'invaded',
#   'Ukraine'],
#  ['SCOOP',
#   'An',
#   'assignment',
#   'instructed',
#   'student',
#   'roam',
#   'school',
#   'looking',
#   'example',
#   'gender',
#   'inequity',
#   'The',
#   'assignment',
#   'asks',
#   'student',
#   'evidence',
#   'patriarchy',
#   'outside',
#   'school',
#   'life',
#   'Im',
#   'told',
#   'parent',
#   'upset',
#   'We'],
#  ['Oh'],
#  ['Has', 'anybody', 'checked', 'Marthas', 'Vineyard'],
#  ['Ovechkin', 'rock'],
#  ['Joe',
#   'Rogan',
#   'Drops',
#   'Great',
#   'Question',
#   'Isnt',
#   'weird',
#   'lie',
#   'people',
#   'force',
#   'people',
#   'thing',
#   'hide',
#   'effect',
#   'sue',
#   'Vaccines',
#   'ONLY',
#   'product',
#   'sue',
#   'manufacturer',
#   'directly',
#   'This'],
#  ['So',
#   '20',
#   'year',
#   'old',
#   'alcohol',
#   'But',
#   '5',
#   'year',
#   'old',
#   'pick',
#   'gender',
#   'Make',
#   'sense'],
#  ['Diddy', 'Hired', 'As', 'New', 'President', 'Of', 'Nickelodeon', 'Studios'],
#  ['Aerial',
#   'footage',
#   'show',
#   'Zionists',
#   'destroyed',
#   'Gaza',
#   'ethnic',
#   'cleansing',
#   'scale',
#   'world',
#   'witnessed',
#   'history'],
#  ['What',
#   'happens',
#   'exceed',
#   'carbon',
#   'limit',
#   'discover',
#   'ability',
#   'buy',
#   'sell',
#   'suddenly',
#   'cut',
#   'Australian',
#   'senator',
#   'Ralph',
#   'Babet',
#   'implores',
#   'freedom',
#   'minded',
#   'people',
#   'resist',
#   'imposition',
#   'digital',
#   'ID',
#   'CBDCs',
#   'We',
#   'resist',
#   'push',
#   'digitise'],
#  ['Alex', 'Jones', 'asked', 'rabbi', 'butt', 'plug', 'inserted', 'interview'],
#  ['PizzaGate', 'Sickos'],
#  ['Alex',
#   'Jones',
#   'call',
#   'Rabbi',
#   'Shmuley',
#   'Rabbi',
#   'Buttplug',
#   'Im',
#   'good',
#   'lap',
#   'dance',
#   'grandchild',
#   'Jones',
#   'told',
#   'Shmuley'],
#  ['laugh', 'reacts'],
#  ['Just',
#   'hour',
#   'bridge',
#   'collapsed',
#   'FBI',
#   'accident',
#   'Mayor',
#   'accident',
#   'Governor',
#   'accident',
#   'Biden',
#   'regime',
#   'accident',
#   'Me',
#   'thanks',
#   'Im',
#   'positive',
#   'wasnt',
#   'accident'],
#  ['If', 'youve', 'seen', 'reindeer', 'posing', 'aurora', 'today', 'day'],
#  ['Joe', 'Rogan', 'condemns', 'ISRAEL', 'committing', 'GENOCIDE', 'GAZA'],
#  ['cat', 'accidentally', 'pressed', 'turbo', 'button'],
#  ['DEVELOPING',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'son',
#   'spotted',
#   'getting',
#   'intimate',
#   'girlfriend',
#   'Homeland',
#   'Securitys',
#   'Investigation',
#   'Agents',
#   'raided',
#   'rapper',
#   'home',
#   'Monday',
#   'Christian',
#   'Combs',
#   'seen',
#   'unbothered',
#   'kissing',
#   'girlfriend',
#   'video',
#   'The',
#   '25',
#   'year',
#   'old',
#   'girlfriend'],
#  ['This', 'employee', 'dream'],
#  ['How', 'feel'],
#  ['BREAKING',
#   'Donald',
#   'Trump',
#   'fly',
#   'New',
#   'York',
#   'honor',
#   'Officer',
#   'Jonathan',
#   'Diller',
#   'He',
#   'called',
#   'slain',
#   'NYPD',
#   'officer',
#   'widow',
#   'personally',
#   'facilitate',
#   'paying',
#   'mortgage',
#   'alongside',
#   'Tunnels',
#   'Towers',
#   'The',
#   'medium',
#   'doesnt',
#   'want',
#   'know',
#   'Officer',
#   'Diller',
#   'survived',
#   'wife'],
#  ['HUGE',
#   'NEWS',
#   'The',
#   'Louisiana',
#   'senate',
#   'passed',
#   'BAN',
#   'rule',
#   'mandate',
#   'World',
#   'Health',
#   'Organization',
#   'World',
#   'Economic',
#   'Forum',
#   'UN',
#   'enforced',
#   'state',
#   'Do',
#   'support'],
#  ['Jon', 'Stewart', 'overvalued', 'NYC', 'home', '829'],
#  ['CAMILA', 'CABELLO', 'PLAYBOI', 'CARTI', 'I', 'LUV', 'IT', 'OUT', 'NOW'],
#  ['UK',
#   'Train',
#   'Stabbing',
#   'Disturbing',
#   'clip',
#   'Hate',
#   'sharing',
#   'people',
#   'world',
#   'truly',
#   'need',
#   'understand',
#   'quickly',
#   'Society',
#   'degrading',
#   'recognisability',
#   'Stay',
#   'safe'],
#  ['Joe',
#   'Rogan',
#   'Jan',
#   '6',
#   'conspiracy',
#   'Trump',
#   'Bro',
#   'took',
#   'November',
#   '2020',
#   '81',
#   'million',
#   'vote',
#   'Why',
#   'Nancy',
#   'Pelosi',
#   'Chuck',
#   'Shumer',
#   'attack',
#   'stop',
#   'certification',
#   'Bidens',
#   'win',
#   'Dude',
#   'million',
#   'listener',
#   'brain'],
#  ['I',
#   'think',
#   'dangerous',
#   'initiative',
#   'Nigel',
#   'Farage',
#   'remark',
#   'recent',
#   'unelected',
#   'EU',
#   'head',
#   'Ursula',
#   'von',
#   'der',
#   'Leyen',
#   'world',
#   'leader',
#   'roll',
#   'digital',
#   'ID',
#   'CBDCs',
#   'cashless',
#   'society',
#   'globally',
#   '2030',
#   'If',
#   'careful',
#   'head'],
#  ['hasan',
#   'having',
#   'mental',
#   'breakdown',
#   'discord',
#   'cuz',
#   'watch',
#   'stream',
#   'anymore'],
#  ['What', 'scene', 'horror', 'movie', 'haunt', 'day'],
#  ['Rally',
#   'sport',
#   'fan',
#   'turn',
#   'mechanic',
#   '5',
#   'minute',
#   'Greenstranger',
#   '2'],
#  ['isnt', 'gzso', 'youre', 'saying', 'happen', 'plestinians'],
#  ['Migrants',
#   'fighting',
#   'Charles',
#   'Gaulle',
#   'Airport',
#   'Paris',
#   'effort',
#   'stop',
#   'migrant',
#   'getting',
#   'deported',
#   'France'],
#  ['Is', 'clear', 'victim'],
#  ['The',
#   'story',
#   'John',
#   'D',
#   'Rockefeller',
#   'banned',
#   'natural',
#   'medicine',
#   'Western',
#   'world',
#   'created',
#   'monopoly',
#   'force',
#   'ten',
#   'million',
#   'people',
#   'poison',
#   'daily',
#   'Shocking'],
#  ['Rabbi',
#   'Shmuley',
#   'asks',
#   'Alex',
#   'Jones',
#   'hate',
#   'Jews',
#   'better',
#   'sex'],
#  ['DeSantis',
#   'Kicked',
#   'Out',
#   'Of',
#   'Republican',
#   'Party',
#   'For',
#   'Accomplishing',
#   'Too',
#   'Many',
#   'Things'],
#  ['BREAKING',
#   'Natalie',
#   'Pershall',
#   'man',
#   'pretending',
#   'woman',
#   'sentenced',
#   '6',
#   'year',
#   'probation',
#   '87',
#   'day',
#   'jail',
#   'register',
#   's',
#   'x',
#   'offender',
#   'taking',
#   'picture',
#   'female',
#   'woman',
#   'bathroom',
#   'company',
#   'office',
#   'This',
#   'happens',
#   'inclusive'],
#  ['Thoughts'],
#  ['Slavery', 'abolished', 'It', 'expanded', 'include'],
#  ['YOUR',
#   'REACTION',
#   'Jon',
#   'Stewart',
#   'overvalued',
#   'NYC',
#   'home',
#   '829',
#   'slamming',
#   'Trumps',
#   'civil',
#   'case',
#   'victimless'],
#  ['Americas',
#   'famous',
#   'Rabbi',
#   'claim',
#   '1',
#   'ISRAELI',
#   'soldier',
#   'life',
#   'equal',
#   '35',
#   'AMERICAN',
#   'soldier',
#   'life',
#   'DISGUSTING'],
#  ['ANDREW',
#   'TATE',
#   'ON',
#   'PDIDDY',
#   'YOU',
#   'CAN',
#   'RAPE',
#   'KIDS',
#   'IF',
#   'YOU',
#   'COMPLY',
#   'WITH',
#   'THE',
#   'SYSTEM',
#   'If',
#   'youre',
#   'P',
#   'Diddy',
#   'f',
#   'people',
#   'as',
#   'f',
#   'underage',
#   'kid',
#   'thats',
#   'fine',
#   'long',
#   'comply',
#   'know',
#   'owner',
#   'But',
#   'youre',
#   'like',
#   'refuse',
#   'bow'],
#  ['cat', 'walmart'],
#  ['bro', 'got', 'evicted'],
#  ['We', 'conspiracy', 'theorist', '54', '0', 'right'],
#  ['The',
#   'cost',
#   'rent',
#   'high',
#   'doesnt',
#   'count',
#   'credit',
#   'score',
#   'Thats',
#   'right',
#   'fixing',
#   'Were',
#   'unlocking',
#   'door',
#   'middle',
#   'class',
#   'million',
#   'young',
#   'Canadians',
#   'Most',
#   'importantly',
#   'going',
#   'build',
#   'home',
#   'apartment'],
#  ['This', 'restaurant', 'took', 'marketing', 'level'],
#  ['cat', 'like'],
#  ['GET', 'ErdoganArmsIsrael', 'TRENDING', 'RIGHT', 'NOW'],
#  ['BREAKING',
#   'Venezuelan',
#   'migrant',
#   'influencer',
#   'sparked',
#   'fury',
#   'TikTok',
#   'squatting',
#   'tip',
#   'fugitive',
#   'fleeing',
#   'ICE',
#   'custody',
#   'post',
#   'snotty',
#   'sobbing',
#   'clip',
#   'threatened',
#   'powerful',
#   'people',
#   'family',
#   'life',
#   'danger',
#   'people',
#   'looking'],
#  ['Happy', 'Gilmore', '2', 'cast', 'far'],
#  ['JUST',
#   'IN',
#   'BlackRock',
#   'CEO',
#   'Larry',
#   'Fink',
#   'say',
#   'spot',
#   'Bitcoin',
#   'ETF',
#   'fastest',
#   'growing',
#   'ETF',
#   'history',
#   'ETFs'],
#  ['Joe',
#   'Rogan',
#   'belief',
#   'Israel',
#   'committing',
#   'genocide',
#   'small',
#   'scale',
#   'Holocaust',
#   'Gaza'],
#  ['Sharing',
#   'wonderful',
#   'Sarah',
#   'Cooper',
#   'video',
#   'reason',
#   'whatsoever',
#   'TrumpBible'],
#  ['Offset',
#   'You',
#   'gotta',
#   'stop',
#   'wearing',
#   'tight',
#   'pant',
#   'bruh',
#   'Shannon',
#   'Sharpe',
#   'I',
#   'Offset',
#   'got',
#   'bruh',
#   'tryna',
#   'tell',
#   'like',
#   'player',
#   'Shannon',
#   'Sharpe',
#   'I',
#   'aint',
#   'finna',
#   'let',
#   'change',
#   'man',
#   'Offset',
#   'It',
#   'aint',
#   'youre',
#   'big',
#   'LLMMFFAAOOO'],
#  ['NEWS',
#   'The',
#   'Event',
#   'Horizon',
#   'Telescope',
#   'captured',
#   'image',
#   'supermassive',
#   'black',
#   'hole',
#   'Sagittarius',
#   'A',
#   'polarized',
#   'light'],
#  ['There', 'game', 'coming', 'play', '2d', '3d', 'time'],
#  ['fossilized',
#   'Odontochile',
#   'trilobite',
#   '400',
#   'million',
#   'year',
#   'old',
#   'rock',
#   'North',
#   'Africa',
#   'This',
#   'marine',
#   'animal',
#   'goldbugsofficial'],
#  ['Am',
#   'I',
#   'crazy',
#   'think',
#   'THIS',
#   'literally',
#   'EXPENSIVE',
#   'This',
#   'veggie',
#   'platter',
#   '45',
#   'Thats',
#   'INSANE',
#   'Is',
#   'worth',
#   '45',
#   'With',
#   'tax',
#   'thats',
#   'like',
#   '50',
#   'What',
#   'hell',
#   'going',
#   'Canada'],
#  ['Skip', 'Bayless', 'BUCKET'],
#  ['Oklahoma',
#   'man',
#   'arrested',
#   'allegedly',
#   'trying',
#   'steal',
#   'pair',
#   'Balenciaga',
#   'shoe',
#   'woman',
#   'met',
#   'selling',
#   'app'],
#  ['BREAKING',
#   'Prominent',
#   'LGBTQ',
#   'activist',
#   'Trey',
#   'Farmer',
#   'arrested',
#   'child',
#   'p',
#   'rn',
#   'charge',
#   'Trey',
#   'alumnus',
#   'Princeton',
#   'President',
#   'Queer',
#   'Princeton',
#   'Alumni',
#   'organization'],
#  ['You',
#   'In',
#   'Canada',
#   'talking',
#   'making',
#   'people',
#   'pay',
#   'RAIN',
#   'TAX',
#   'Yes',
#   'people',
#   'paying',
#   'rain',
#   'land',
#   'property',
#   'Whats',
#   'breathing',
#   'tax'],
#  ['clip', 'million', 'time', 'funnier', 'abruptly', 'cut'],
#  ['wonder', 'right'],
#  ['BREAKING',
#   'Evacuations',
#   'underway',
#   'Massive',
#   'Fire',
#   'Explosions',
#   'Comfuel',
#   'Gas',
#   'Station',
#   'people',
#   'running',
#   'building',
#   'BowlingGreen',
#   'KentuckyCurrently',
#   'numerous',
#   'business',
#   'nearby',
#   'school',
#   'evacuation',
#   'dozen',
#   'emergency',
#   'crew'],
#  ['This', 'Paris', 'main', 'airport'],
#  ['thats',
#   'got',
#   'emasculating',
#   'night',
#   'night',
#   'he',
#   'length',
#   'damn',
#   'court'],
#  ['This',
#   'delivery',
#   'guy',
#   'Brampton',
#   'Canada',
#   'harassed',
#   'worthless',
#   'customer',
#   'who',
#   'trying',
#   'content',
#   'TikTok',
#   'If',
#   'know',
#   'Id',
#   'like',
#   'send',
#   'huge',
#   'tip'],
#  ['A', 'sleeping', 'octopus', 'change', 'color', 'dreaming'],
#  ['Eminem', 'Mark', 'Wahlberg', 'TRL', 'live', '1999'],
#  ['Did', 'I', 'hear', 'hose'],
#  ['Hold', 'tight'],
#  ['The',
#   'vessel',
#   'steered',
#   'hard',
#   'right',
#   'minute',
#   'hit',
#   'bridge',
#   'cause',
#   'damage',
#   'And',
#   'save',
#   'breath',
#   'telling',
#   'Its',
#   'freaking',
#   'video',
#   'brain',
#   'dead',
#   'useful',
#   'idiot'],
#  ['Breaking',
#   'Graphic',
#   'bystander',
#   'video',
#   'captured',
#   'masked',
#   'black',
#   'male',
#   'stabbing',
#   'person',
#   'repeatedly',
#   'moving',
#   'train',
#   'London',
#   'The',
#   'train',
#   'traveling',
#   'Shortlands',
#   'Beckenham',
#   'station',
#   'Victoria',
#   'Station',
#   'A',
#   'nearby',
#   'school',
#   'placed',
#   'lockdown',
#   'The',
#   'person',
#   'stabbed'],
#  ['Einstein', 'Oppenheimer', '1930s'],
#  ['The', 'dog', 'didnt', 'notice', 'mom', 'room', 'look'],
#  ['Goodmorning'],
#  ['Canadas',
#   'Deputy',
#   'Prime',
#   'Minister',
#   'Chrystia',
#   'Freeland',
#   'exhibit',
#   'bizarre',
#   'behavior',
#   'press',
#   'conference',
#   'community',
#   'center',
#   'Vancouver',
#   'Freeland',
#   'repeatedly',
#   'twitch',
#   'display',
#   'erratic',
#   'body',
#   'movement',
#   'stand',
#   'Trudeau'],
#  ['BREAKING',
#   'Police',
#   'audio',
#   'released',
#   'capture',
#   'dispatcher',
#   'discussing',
#   'officer',
#   'approaching',
#   'container',
#   'ship',
#   'subsequent',
#   'collapse',
#   'Francis',
#   'Scott',
#   'Key',
#   'Bridge',
#   'Baltimore',
#   'In',
#   'audio',
#   'hear',
#   'officer',
#   'trying',
#   'best',
#   'traffic',
#   'stopped'],
#  ['7', 'Eleven', 'releasing', 'hot', 'dog', 'flavored', 'water'],
#  ['Meeting', 'favorite', 'character'],
#  ['BREAKING',
#   'Police',
#   'scene',
#   'male',
#   'suspect',
#   'went',
#   'mass',
#   'stabbing',
#   'spree',
#   'injuring',
#   'numerous',
#   'people',
#   'resulting',
#   'multiple',
#   'fatality',
#   'Rockford',
#   'IllinoisCurrently',
#   'numerous',
#   'law',
#   'enforcement',
#   'agency',
#   'scene',
#   'Rockford',
#   'Illinois'],
#  ['She', 'thought', 'Dana', 'white', 'Joe', 'Rogan'],
#  ['A', 'ton', 'Cocoa', 'worth', 'ton', 'Copper', 'What', 'heck', 'going'],
#  ['Giant', 'alligator', 'bend', 'metal', 'fence', 'forcing', 'way'],
#  ['believe', 'happened'],
#  ['BREAKING',
#   'NEWS',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'private',
#   'jet',
#   'landed',
#   'Opa',
#   'Locka',
#   'Florida',
#   'Private',
#   'guard',
#   'umbrella',
#   'left',
#   'Puffys',
#   'property',
#   'shortly',
#   'plane',
#   'landed',
#   'detail',
#   'currently',
#   'developing',
#   'sex',
#   'trafficking',
#   'investigation',
#   'There',
#   'new',
#   'confirmation'],
#  ['An',
#   'upset',
#   'Michelle',
#   'Phillips',
#   'eating',
#   'banana',
#   'Mamas',
#   'Papas',
#   'performance',
#   'California',
#   'Dreaming',
#   'Ed',
#   'Sullivan',
#   'Show',
#   'lip',
#   'sync',
#   '1967'],
#  ['god',
#   'bruh',
#   'shit',
#   'diddy',
#   'court',
#   'doc',
#   'making',
#   'sick',
#   'section',
#   '73',
#   'page'],
#  ['Why', 'America', 'destroy', 'city', 'A', 'thread'],
#  ['Man', 'introduces', 'puppy', 'dog', 'traffic'],
#  ['afford', 'sleeve'],
#  ['Going',
#   'forward',
#   'account',
#   '2500',
#   'verified',
#   'subscriber',
#   'follower',
#   'Premium',
#   'feature',
#   'free',
#   'account',
#   '5000',
#   'Premium',
#   'free'],
#  ['Joe',
#   'Lieberman',
#   'I',
#   'didnt',
#   'eye',
#   'eye',
#   'extraordinary',
#   'career',
#   'public',
#   'service',
#   'including',
#   'decade',
#   'spent',
#   'fighting',
#   'people',
#   'Connecticut',
#   'He',
#   'worked',
#   'hard',
#   'repeal',
#   'Dont',
#   'Ask',
#   'Dont',
#   'Tell',
#   'helped',
#   'pas',
#   'Affordable',
#   'Care',
#   'Act',
#   'In'],
#  ['This', 'flock', 'sheep', 'washed'],
#  ['Ask', 'theyre', 'hiding', 'captain', 'hit', 'bridge', 'youll', 'answer'],
#  ['baking', 'bean'],
#  ['Dont', 'worry', 'bring', 'CN', 'Tower', 'repair'],
#  ['happened', '2', 'year', 'ago', 'today'],
#  ['My', 'mood'],
#  ['BREAKING',
#   'During',
#   'announcement',
#   'Vancouver',
#   'Prime',
#   'Minister',
#   'Trudeau',
#   'announces',
#   'new',
#   'Renters',
#   'Bill',
#   'Rights',
#   'includes',
#   'protection',
#   'tenant',
#   'legal',
#   'funding',
#   'fight',
#   'unfair',
#   'practice',
#   'landlord',
#   'rent',
#   'count',
#   'credit',
#   'score',
#   'profile'],
#  ['Hey',
#   'supporter',
#   'Poilievre',
#   'PM',
#   'scrap',
#   'carbon',
#   'tax',
#   'rebate',
#   'Whats',
#   'going',
#   'reduce',
#   'Canadas',
#   'carbon',
#   'emission'],
#  ['Going',
#   'forward',
#   'account',
#   '2500',
#   'verified',
#   'subscriber',
#   'follower',
#   'Premium',
#   'feature',
#   'free',
#   'account',
#   '5000',
#   'Premium',
#   'free'],
#  ['Joe',
#   'Lieberman',
#   'I',
#   'didnt',
#   'eye',
#   'eye',
#   'extraordinary',
#   'career',
#   'public',
#   'service',
#   'including',
#   'decade',
#   'spent',
#   'fighting',
#   'people',
#   'Connecticut',
#   'He',
#   'worked',
#   'hard',
#   'repeal',
#   'Dont',
#   'Ask',
#   'Dont',
#   'Tell',
#   'helped',
#   'pas',
#   'Affordable',
#   'Care',
#   'Act',
#   'In'],
#  ['This', 'flock', 'sheep', 'washed'],
#  ['Ask', 'theyre', 'hiding', 'captain', 'hit', 'bridge', 'youll', 'answer'],
#  ['baking', 'bean'],
#  ['afford', 'sleeve'],
#  ['god',
#   'bruh',
#   'shit',
#   'diddy',
#   'court',
#   'doc',
#   'making',
#   'sick',
#   'section',
#   '73',
#   'page'],
#  ['Why', 'America', 'destroy', 'city', 'A', 'thread'],
#  ['Man', 'introduces', 'puppy', 'dog', 'traffic'],
#  ['believe', 'happened'],
#  ['BREAKING',
#   'NEWS',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'private',
#   'jet',
#   'landed',
#   'Opa',
#   'Locka',
#   'Florida',
#   'Private',
#   'guard',
#   'umbrella',
#   'left',
#   'Puffys',
#   'property',
#   'shortly',
#   'plane',
#   'landed',
#   'detail',
#   'currently',
#   'developing',
#   'sex',
#   'trafficking',
#   'investigation',
#   'There',
#   'new',
#   'confirmation'],
#  ['An',
#   'upset',
#   'Michelle',
#   'Phillips',
#   'eating',
#   'banana',
#   'Mamas',
#   'Papas',
#   'performance',
#   'California',
#   'Dreaming',
#   'Ed',
#   'Sullivan',
#   'Show',
#   'lip',
#   'sync',
#   '1967'],
#  ['Giant', 'alligator', 'bend', 'metal', 'fence', 'forcing', 'way'],
#  ['BREAKING',
#   'Police',
#   'scene',
#   'male',
#   'suspect',
#   'went',
#   'mass',
#   'stabbing',
#   'spree',
#   'injuring',
#   'numerous',
#   'people',
#   'resulting',
#   'multiple',
#   'fatality',
#   'Rockford',
#   'IllinoisCurrently',
#   'numerous',
#   'law',
#   'enforcement',
#   'agency',
#   'scene',
#   'Rockford',
#   'Illinois'],
#  ['She', 'thought', 'Dana', 'white', 'Joe', 'Rogan'],
#  ['A', 'ton', 'Cocoa', 'worth', 'ton', 'Copper', 'What', 'heck', 'going'],
#  ['7', 'Eleven', 'releasing', 'hot', 'dog', 'flavored', 'water'],
#  ['Meeting', 'favorite', 'character'],
#  ['BREAKING',
#   'Police',
#   'audio',
#   'released',
#   'capture',
#   'dispatcher',
#   'discussing',
#   'officer',
#   'approaching',
#   'container',
#   'ship',
#   'subsequent',
#   'collapse',
#   'Francis',
#   'Scott',
#   'Key',
#   'Bridge',
#   'Baltimore',
#   'In',
#   'audio',
#   'hear',
#   'officer',
#   'trying',
#   'best',
#   'traffic',
#   'stopped'],
#  ['Goodmorning'],
#  ['Canadas',
#   'Deputy',
#   'Prime',
#   'Minister',
#   'Chrystia',
#   'Freeland',
#   'exhibit',
#   'bizarre',
#   'behavior',
#   'press',
#   'conference',
#   'community',
#   'center',
#   'Vancouver',
#   'Freeland',
#   'repeatedly',
#   'twitch',
#   'display',
#   'erratic',
#   'body',
#   'movement',
#   'stand',
#   'Trudeau'],
#  ['The', 'dog', 'didnt', 'notice', 'mom', 'room', 'look'],
#  ['Breaking',
#   'Graphic',
#   'bystander',
#   'video',
#   'captured',
#   'masked',
#   'black',
#   'male',
#   'stabbing',
#   'person',
#   'repeatedly',
#   'moving',
#   'train',
#   'London',
#   'The',
#   'train',
#   'traveling',
#   'Shortlands',
#   'Beckenham',
#   'station',
#   'Victoria',
#   'Station',
#   'A',
#   'nearby',
#   'school',
#   'placed',
#   'lockdown',
#   'The',
#   'person',
#   'stabbed'],
#  ['Einstein', 'Oppenheimer', '1930s'],
#  ['The',
#   'vessel',
#   'steered',
#   'hard',
#   'right',
#   'minute',
#   'hit',
#   'bridge',
#   'cause',
#   'damage',
#   'And',
#   'save',
#   'breath',
#   'telling',
#   'Its',
#   'freaking',
#   'video',
#   'brain',
#   'dead',
#   'useful',
#   'idiot'],
#  ['Hold', 'tight'],
#  ['A', 'sleeping', 'octopus', 'change', 'color', 'dreaming'],
#  ['Eminem', 'Mark', 'Wahlberg', 'TRL', 'live', '1999'],
#  ['Did', 'I', 'hear', 'hose'],
#  ['This', 'Paris', 'main', 'airport'],
#  ['thats',
#   'got',
#   'emasculating',
#   'night',
#   'night',
#   'he',
#   'length',
#   'damn',
#   'court'],
#  ['This',
#   'delivery',
#   'guy',
#   'Brampton',
#   'Canada',
#   'harassed',
#   'worthless',
#   'customer',
#   'who',
#   'trying',
#   'content',
#   'TikTok',
#   'If',
#   'know',
#   'Id',
#   'like',
#   'send',
#   'huge',
#   'tip'],
#  ['BREAKING',
#   'Evacuations',
#   'underway',
#   'Massive',
#   'Fire',
#   'Explosions',
#   'Comfuel',
#   'Gas',
#   'Station',
#   'people',
#   'running',
#   'building',
#   'BowlingGreen',
#   'KentuckyCurrently',
#   'numerous',
#   'business',
#   'nearby',
#   'school',
#   'evacuation',
#   'dozen',
#   'emergency',
#   'crew'],
#  ['wonder', 'right'],
#  ['BREAKING',
#   'Prominent',
#   'LGBTQ',
#   'activist',
#   'Trey',
#   'Farmer',
#   'arrested',
#   'child',
#   'p',
#   'rn',
#   'charge',
#   'Trey',
#   'alumnus',
#   'Princeton',
#   'President',
#   'Queer',
#   'Princeton',
#   'Alumni',
#   'organization'],
#  ['You',
#   'In',
#   'Canada',
#   'talking',
#   'making',
#   'people',
#   'pay',
#   'RAIN',
#   'TAX',
#   'Yes',
#   'people',
#   'paying',
#   'rain',
#   'land',
#   'property',
#   'Whats',
#   'breathing',
#   'tax'],
#  ['clip', 'million', 'time', 'funnier', 'abruptly', 'cut'],
#  ['Oklahoma',
#   'man',
#   'arrested',
#   'allegedly',
#   'trying',
#   'steal',
#   'pair',
#   'Balenciaga',
#   'shoe',
#   'woman',
#   'met',
#   'selling',
#   'app'],
#  ['Am',
#   'I',
#   'crazy',
#   'think',
#   'THIS',
#   'literally',
#   'EXPENSIVE',
#   'This',
#   'veggie',
#   'platter',
#   '45',
#   'Thats',
#   'INSANE',
#   'Is',
#   'worth',
#   '45',
#   'With',
#   'tax',
#   'thats',
#   'like',
#   '50',
#   'What',
#   'hell',
#   'going',
#   'Canada'],
#  ['Skip', 'Bayless', 'BUCKET'],
#  ['fossilized',
#   'Odontochile',
#   'trilobite',
#   '400',
#   'million',
#   'year',
#   'old',
#   'rock',
#   'North',
#   'Africa',
#   'This',
#   'marine',
#   'animal',
#   'goldbugsofficial'],
#  ['Offset',
#   'You',
#   'gotta',
#   'stop',
#   'wearing',
#   'tight',
#   'pant',
#   'bruh',
#   'Shannon',
#   'Sharpe',
#   'I',
#   'Offset',
#   'got',
#   'bruh',
#   'tryna',
#   'tell',
#   'like',
#   'player',
#   'Shannon',
#   'Sharpe',
#   'I',
#   'aint',
#   'finna',
#   'let',
#   'change',
#   'man',
#   'Offset',
#   'It',
#   'aint',
#   'youre',
#   'big',
#   'LLMMFFAAOOO'],
#  ['NEWS',
#   'The',
#   'Event',
#   'Horizon',
#   'Telescope',
#   'captured',
#   'image',
#   'supermassive',
#   'black',
#   'hole',
#   'Sagittarius',
#   'A',
#   'polarized',
#   'light'],
#  ['There', 'game', 'coming', 'play', '2d', '3d', 'time'],
#  ['JUST',
#   'IN',
#   'BlackRock',
#   'CEO',
#   'Larry',
#   'Fink',
#   'say',
#   'spot',
#   'Bitcoin',
#   'ETF',
#   'fastest',
#   'growing',
#   'ETF',
#   'history',
#   'ETFs'],
#  ['Joe',
#   'Rogan',
#   'belief',
#   'Israel',
#   'committing',
#   'genocide',
#   'small',
#   'scale',
#   'Holocaust',
#   'Gaza'],
#  ['Sharing',
#   'wonderful',
#   'Sarah',
#   'Cooper',
#   'video',
#   'reason',
#   'whatsoever',
#   'TrumpBible'],
#  ['BREAKING',
#   'Venezuelan',
#   'migrant',
#   'influencer',
#   'sparked',
#   'fury',
#   'TikTok',
#   'squatting',
#   'tip',
#   'fugitive',
#   'fleeing',
#   'ICE',
#   'custody',
#   'post',
#   'snotty',
#   'sobbing',
#   'clip',
#   'threatened',
#   'powerful',
#   'people',
#   'family',
#   'life',
#   'danger',
#   'people',
#   'looking'],
#  ['Happy', 'Gilmore', '2', 'cast', 'far'],
#  ['GET', 'ErdoganArmsIsrael', 'TRENDING', 'RIGHT', 'NOW'],
#  ['The',
#   'cost',
#   'rent',
#   'high',
#   'doesnt',
#   'count',
#   'credit',
#   'score',
#   'Thats',
#   'right',
#   'fixing',
#   'Were',
#   'unlocking',
#   'door',
#   'middle',
#   'class',
#   'million',
#   'young',
#   'Canadians',
#   'Most',
#   'importantly',
#   'going',
#   'build',
#   'home',
#   'apartment'],
#  ['This', 'restaurant', 'took', 'marketing', 'level'],
#  ['cat', 'like'],
#  ['We', 'conspiracy', 'theorist', '54', '0', 'right'],
#  ['cat', 'walmart'],
#  ['bro', 'got', 'evicted'],
#  ['ANDREW',
#   'TATE',
#   'ON',
#   'PDIDDY',
#   'YOU',
#   'CAN',
#   'RAPE',
#   'KIDS',
#   'IF',
#   'YOU',
#   'COMPLY',
#   'WITH',
#   'THE',
#   'SYSTEM',
#   'If',
#   'youre',
#   'P',
#   'Diddy',
#   'f',
#   'people',
#   'as',
#   'f',
#   'underage',
#   'kid',
#   'thats',
#   'fine',
#   'long',
#   'comply',
#   'know',
#   'owner',
#   'But',
#   'youre',
#   'like',
#   'refuse',
#   'bow'],
#  ['Slavery', 'abolished', 'It', 'expanded', 'include'],
#  ['YOUR',
#   'REACTION',
#   'Jon',
#   'Stewart',
#   'overvalued',
#   'NYC',
#   'home',
#   '829',
#   'slamming',
#   'Trumps',
#   'civil',
#   'case',
#   'victimless'],
#  ['Americas',
#   'famous',
#   'Rabbi',
#   'claim',
#   '1',
#   'ISRAELI',
#   'soldier',
#   'life',
#   'equal',
#   '35',
#   'AMERICAN',
#   'soldier',
#   'life',
#   'DISGUSTING'],
#  ['Thoughts'],
#  ['Rabbi',
#   'Shmuley',
#   'asks',
#   'Alex',
#   'Jones',
#   'hate',
#   'Jews',
#   'better',
#   'sex'],
#  ['DeSantis',
#   'Kicked',
#   'Out',
#   'Of',
#   'Republican',
#   'Party',
#   'For',
#   'Accomplishing',
#   'Too',
#   'Many',
#   'Things'],
#  ['BREAKING',
#   'Natalie',
#   'Pershall',
#   'man',
#   'pretending',
#   'woman',
#   'sentenced',
#   '6',
#   'year',
#   'probation',
#   '87',
#   'day',
#   'jail',
#   'register',
#   's',
#   'x',
#   'offender',
#   'taking',
#   'picture',
#   'female',
#   'woman',
#   'bathroom',
#   'company',
#   'office',
#   'This',
#   'happens',
#   'inclusive'],
#  ['The',
#   'story',
#   'John',
#   'D',
#   'Rockefeller',
#   'banned',
#   'natural',
#   'medicine',
#   'Western',
#   'world',
#   'created',
#   'monopoly',
#   'force',
#   'ten',
#   'million',
#   'people',
#   'poison',
#   'daily',
#   'Shocking'],
#  ['Migrants',
#   'fighting',
#   'Charles',
#   'Gaulle',
#   'Airport',
#   'Paris',
#   'effort',
#   'stop',
#   'migrant',
#   'getting',
#   'deported',
#   'France'],
#  ['Is', 'clear', 'victim'],
#  ['isnt', 'gzso', 'youre', 'saying', 'happen', 'plestinians'],
#  ['What', 'scene', 'horror', 'movie', 'haunt', 'day'],
#  ['Rally',
#   'sport',
#   'fan',
#   'turn',
#   'mechanic',
#   '5',
#   'minute',
#   'Greenstranger',
#   '2'],
#  ['hasan',
#   'having',
#   'mental',
#   'breakdown',
#   'discord',
#   'cuz',
#   'watch',
#   'stream',
#   'anymore'],
#  ['UK',
#   'Train',
#   'Stabbing',
#   'Disturbing',
#   'clip',
#   'Hate',
#   'sharing',
#   'people',
#   'world',
#   'truly',
#   'need',
#   'understand',
#   'quickly',
#   'Society',
#   'degrading',
#   'recognisability',
#   'Stay',
#   'safe'],
#  ['Joe',
#   'Rogan',
#   'Jan',
#   '6',
#   'conspiracy',
#   'Trump',
#   'Bro',
#   'took',
#   'November',
#   '2020',
#   '81',
#   'million',
#   'vote',
#   'Why',
#   'Nancy',
#   'Pelosi',
#   'Chuck',
#   'Shumer',
#   'attack',
#   'stop',
#   'certification',
#   'Bidens',
#   'win',
#   'Dude',
#   'million',
#   'listener',
#   'brain'],
#  ['I',
#   'think',
#   'dangerous',
#   'initiative',
#   'Nigel',
#   'Farage',
#   'remark',
#   'recent',
#   'unelected',
#   'EU',
#   'head',
#   'Ursula',
#   'von',
#   'der',
#   'Leyen',
#   'world',
#   'leader',
#   'roll',
#   'digital',
#   'ID',
#   'CBDCs',
#   'cashless',
#   'society',
#   'globally',
#   '2030',
#   'If',
#   'careful',
#   'head'],
#  ['CAMILA', 'CABELLO', 'PLAYBOI', 'CARTI', 'I', 'LUV', 'IT', 'OUT', 'NOW'],
#  ['BREAKING',
#   'Donald',
#   'Trump',
#   'fly',
#   'New',
#   'York',
#   'honor',
#   'Officer',
#   'Jonathan',
#   'Diller',
#   'He',
#   'called',
#   'slain',
#   'NYPD',
#   'officer',
#   'widow',
#   'personally',
#   'facilitate',
#   'paying',
#   'mortgage',
#   'alongside',
#   'Tunnels',
#   'Towers',
#   'The',
#   'medium',
#   'doesnt',
#   'want',
#   'know',
#   'Officer',
#   'Diller',
#   'survived',
#   'wife'],
#  ['HUGE',
#   'NEWS',
#   'The',
#   'Louisiana',
#   'senate',
#   'passed',
#   'BAN',
#   'rule',
#   'mandate',
#   'World',
#   'Health',
#   'Organization',
#   'World',
#   'Economic',
#   'Forum',
#   'UN',
#   'enforced',
#   'state',
#   'Do',
#   'support'],
#  ['Jon', 'Stewart', 'overvalued', 'NYC', 'home', '829'],
#  ['How', 'feel'],
#  ['DEVELOPING',
#   'Sean',
#   'Diddy',
#   'Combs',
#   'son',
#   'spotted',
#   'getting',
#   'intimate',
#   'girlfriend',
#   'Homeland',
#   'Securitys',
#   'Investigation',
#   'Agents',
#   'raided',
#   'rapper',
#   'home',
#   'Monday',
#   'Christian',
#   'Combs',
#   'seen',
#   'unbothered',
#   'kissing',
#   'girlfriend',
#   'video',
#   'The',
#   '25',
#   'year',
#   'old',
#   'girlfriend'],
#  ['This', 'employee', 'dream'],
#  ['cat', 'accidentally', 'pressed', 'turbo', 'button'],
#  ['If', 'youve', 'seen', 'reindeer', 'posing', 'aurora', 'today', 'day'],
#  ['Joe', 'Rogan', 'condemns', 'ISRAEL', 'committing', 'GENOCIDE', 'GAZA'],
#  ['Just',
#   'hour',
#   'bridge',
#   'collapsed',
#   'FBI',
#   'accident',
#   'Mayor',
#   'accident',
#   'Governor',
#   'accident',
#   'Biden',
#   'regime',
#   'accident',
#   'Me',
#   'thanks',
#   'Im',
#   'positive',
#   'wasnt',
#   'accident'],
#  ['PizzaGate', 'Sickos'],
#  ['Alex',
#   'Jones',
#   'call',
#   'Rabbi',
#   'Shmuley',
#   'Rabbi',
#   'Buttplug',
#   'Im',
#   'good',
#   'lap',
#   'dance',
#   'grandchild',
#   'Jones',
#   'told',
#   'Shmuley'],
#  ['laugh', 'reacts'],
#  ['Alex', 'Jones', 'asked', 'rabbi', 'butt', 'plug', 'inserted', 'interview'],
#  ['Aerial',
#   'footage',
#   'show',
#   'Zionists',
#   'destroyed',
#   'Gaza',
#   'ethnic',
#   'cleansing',
#   'scale',
#   'world',
#   'witnessed',
#   'history'],
#  ['What',
#   'happens',
#   'exceed',
#   'carbon',
#   'limit',
#   'discover',
#   'ability',
#   'buy',
#   'sell',
#   'suddenly',
#   'cut',
#   'Australian',
#   'senator',
#   'Ralph',
#   'Babet',
#   'implores',
#   'freedom',
#   'minded',
#   'people',
#   'resist',
#   'imposition',
#   'digital',
#   'ID',
#   'CBDCs',
#   'We',
#   'resist',
#   'push',
#   'digitise'],
#  ['So',
#   '20',
#   'year',
#   'old',
#   'alcohol',
#   'But',
#   '5',
#   'year',
#   'old',
#   'pick',
#   'gender',
#   'Make',
#   'sense'],
#  ['Diddy', 'Hired', 'As', 'New', 'President', 'Of', 'Nickelodeon', 'Studios'],
#  ['Ovechkin', 'rock'],
#  ['Joe',
#   'Rogan',
#   'Drops',
#   'Great',
#   'Question',
#   'Isnt',
#   'weird',
#   'lie',
#   'people',
#   'force',
#   'people',
#   'thing',
#   'hide',
#   'effect',
#   'sue',
#   'Vaccines',
#   'ONLY',
#   'product',
#   'sue',
#   'manufacturer',
#   'directly',
#   'This'],
#  ['Has', 'anybody', 'checked', 'Marthas', 'Vineyard'],
#  ['SCOOP',
#   'An',
#   'assignment',
#   'instructed',
#   'student',
#   'roam',
#   'school',
#   'looking',
#   'example',
#   'gender',
#   'inequity',
#   'The',
#   'assignment',
#   'asks',
#   'student',
#   'evidence',
#   'patriarchy',
#   'outside',
#   'school',
#   'life',
#   'Im',
#   'told',
#   'parent',
#   'upset',
#   'We'],
#  ['Oh'],
#  ['When',
#   'fascism',
#   'come',
#   'America',
#   'wrapped',
#   'flag',
#   'carrying',
#   'cross',
#   'I',
#   'didnt',
#   'think',
#   'literal'],
#  ['BREAKING',
#   'The',
#   'Ukrainian',
#   'Army',
#   'launched',
#   'major',
#   'attack',
#   'Russian',
#   'position',
#   'Russian',
#   'city',
#   'Belgorod',
#   'tonight',
#   'Civilians',
#   'seen',
#   'running',
#   'street',
#   'desperate',
#   'attempt',
#   'air',
#   'raid',
#   'shelter',
#   'Shouldnt',
#   'invaded',
#   'Ukraine'],
#  ['This',
#   'US',
#   'official',
#   'resigned',
#   'State',
#   'Dept',
#   'confirmed',
#   'US',
#   'aware',
#   'plenty',
#   'evidence',
#   'Israel',
#   'violating',
#   'international',
#   'law',
#   'Biden',
#   'administration',
#   'violating',
#   'US',
#   'law',
#   'continuing',
#   'supply',
#   'weapon',
#   'Rogue',
#   'state'],
#  ['Its',
#   'impossible',
#   'overstate',
#   'atrocious',
#   'decision',
#   'It',
#   'basically',
#   'license',
#   'kill',
#   'The',
#   'court',
#   'accepted',
#   'fact',
#   'woman',
#   'seeking',
#   'death',
#   'autistic',
#   'cognitive',
#   'impairment',
#   'result',
#   'She',
#   'applied',
#   'death',
#   'twice',
#   'twice',
#   'split'],
#  ['Why',
#   'American',
#   'taxpayer',
#   'paying',
#   'new',
#   'bridge',
#   'Baltimore',
#   'Shouldnt',
#   'ahem',
#   'private',
#   'company',
#   'responsible',
#   'destruction',
#   'bridge',
#   'pay',
#   'Taxpayer',
#   'PAID',
#   'bridge',
#   'Foreign',
#   'corporation',
#   'destroys',
#   'Now',
#   'taxpayer',
#   'pay',
#   'new',
#   'bridge',
#   'Uh',
#   'WTF'],
#  ['Australia',
#   'Passes',
#   'Digital',
#   'ID',
#   'Bill',
#   'The',
#   'WEF',
#   '2030',
#   'Agenda',
#   'accelerates',
#   'Australian',
#   'Government',
#   'pass',
#   'digital',
#   'ID',
#   'Listen',
#   'Senator',
#   'Babet',
#   'explain',
#   'Australians',
#   'step',
#   'closer',
#   'Social',
#   'credit',
#   'Co2',
#   'score',
#   'CBDCs',
#   'vaccine',
#   'passport',
#   'handy'],
#  ['US',
#   'President',
#   'Biden',
#   'called',
#   'Putin',
#   'butcher',
#   'called',
#   'urgent',
#   'aid',
#   'Ukraine',
#   'There',
#   'important',
#   'thing',
#   'including',
#   'finally',
#   'taking',
#   'care',
#   'helping',
#   'Ukraine',
#   'butcher',
#   'Putin',
#   'Biden',
#   'stated'],
#  ['White', 'men', '2024'],
#  ['Liberal',
#   'MP',
#   'Jenica',
#   'Atwin',
#   'tantrum',
#   'chair',
#   'member',
#   'I',
#   'Oil',
#   'Gas',
#   'sticker',
#   'laptop',
#   'She',
#   'literally',
#   'felt',
#   'need',
#   'interrupt',
#   'w',
#   'point',
#   'order',
#   'point'],
#  ['Describe', 'RFK', 'Jr', 'word', 'Dont', 'hold'],
#  ['Two',
#   'decade',
#   'ago',
#   'Israel',
#   'evacuated',
#   'Gaza',
#   'gave',
#   'Palestinians',
#   'autonomy',
#   'They',
#   'spent',
#   'billion',
#   'tunnel',
#   'weapon',
#   'They',
#   'celebrated',
#   'massacred',
#   '1200',
#   'Israelis',
#   'kidnapped',
#   'hundred',
#   'Now',
#   'thing',
#   'destruction',
#   'Israel',
#   'flag'],
#  ['NEW',
#   'VIDEO',
#   'FROM',
#   'OMG',
#   'Trump',
#   'Was',
#   'Right',
#   'Biden',
#   'doesnt',
#   'care',
#   'trade',
#   'state',
#   'Trevar',
#   'Kolodny',
#   'Cybersecurity',
#   'Infrastructure',
#   'Security',
#   'Agency',
#   'Official',
#   'Department',
#   'Homeland',
#   'Security',
#   'chemical',
#   'security',
#   'Kolodny',
#   'declares',
#   'I',
#   'dont',
#   'think',
#   'I',
#   'vote'],
#  ['Under',
#   'Trudeau',
#   'Canada',
#   'turned',
#   'nation',
#   'builder',
#   'producer',
#   'nation',
#   'taker',
#   'burner',
#   'The',
#   'New',
#   'Canada',
#   'burn',
#   'church',
#   'flush',
#   'cash',
#   'block',
#   'industry',
#   'That',
#   'legacy',
#   'The',
#   'Old',
#   'Canada',
#   'exists',
#   'fight'],
#  ['carti', 'camila', 'random', 'as', 'collab', 'work'],
#  ['Former',
#   'GOP',
#   'House',
#   'Speaker',
#   'Paul',
#   'Ryan',
#   'Trump',
#   'conservative',
#   'he',
#   'populist',
#   'authoritarian',
#   'narcissist'],
#  ['Cillians', 'reaction', 'time', 'winner'],
#  ['stop', 'thinking', 'cat', 'called', 'Keys', 'raise', 'arm', 'reason'],
#  ['TURKEY',
#   'SOLD',
#   'LARGE',
#   'QUANTITIES',
#   'WEAPONS',
#   'ISRAEL',
#   'October',
#   '7th',
#   'TURKEY',
#   'exported',
#   'following',
#   'item',
#   'ISRAEL',
#   '2024',
#   'Gunpowder',
#   'Explosive',
#   'substance',
#   'Flammable',
#   'substance',
#   'Ammunition',
#   'Weapons',
#   'Parts'],
#  ['Canada',
#   'RECESSION',
#   'Mortgage',
#   'delinquency',
#   'rate',
#   'ROSE',
#   '523',
#   'quarter',
#   '2023',
#   'Ontario',
#   'mortgage',
#   'delinquency',
#   'rate',
#   '135',
#   'Delinquency',
#   'rate',
#   'non',
#   'mortgage',
#   'including',
#   'credit',
#   'card',
#   'rose',
#   '30',
#   'This',
#   'absolutely',
#   'nut'],
#  ['Jordan',
#   'Peterson',
#   'go',
#   'breathing',
#   'fact',
#   'spitting',
#   'dragon',
#   'mode',
#   'left',
#   'wing',
#   'Big',
#   'Pharma',
#   'loving',
#   'vaccine',
#   'promoting',
#   'guest',
#   'I',
#   'chill'],
#  ['SHOCKING',
#   'report',
#   'reveals',
#   'criminal',
#   'ILLEGALS',
#   'given',
#   '7',
#   'TIMES',
#   'MORE',
#   'taxpayer',
#   'funded',
#   'assistance',
#   'suffering',
#   'military',
#   'family',
#   'WHAT'],
#  ['There',
#   'war',
#   'history',
#   '80',
#   'country',
#   'decimated',
#   '100',
#   'population',
#   'displaced',
#   '50',
#   'death',
#   'child',
#   'So',
#   'let',
#   'GENOCIDE'],
#  ['MAID',
#   'Canada',
#   'How',
#   'Justin',
#   'Trudeau',
#   'KILLING',
#   'Country',
#   'LITERALLY',
#   'Viva',
#   'Frei',
#   'Vlawg',
#   'PLEASE',
#   'SHARE'],
#  ['EVERYTHING', 'WAS', 'BETTER', 'UNDER', 'TRUMP'],
#  ['Trudeau',
#   'attempt',
#   'defend',
#   'carbon',
#   'tax',
#   'claiming',
#   'put',
#   'money',
#   'pocket',
#   'Canadians',
#   'Conservative',
#   'premier',
#   'country',
#   'misleading',
#   'Canadians'],
#  ['BREAKING',
#   'Pablo',
#   'Mendoza',
#   'man',
#   'country',
#   'illegally',
#   'arrested',
#   'r',
#   'ping',
#   'mentally',
#   'incapacitated',
#   '14',
#   'year',
#   'old',
#   'girl',
#   'Alabama',
#   'Bidens',
#   'open',
#   'border',
#   'allows',
#   'p',
#   'do',
#   'criminal',
#   'roam',
#   'country',
#   'harming',
#   'Americans',
#   'BidensBorderBloodbath'],
#  ['BREAKING',
#   'Former',
#   'Presidents',
#   'Obama',
#   'Clinton',
#   'teaming',
#   'huge',
#   'fundraising',
#   'push',
#   'President',
#   'Biden',
#   'NYC',
#   'Meanwhile',
#   'trump',
#   'Vice',
#   'President',
#   'endorse',
#   'criminal',
#   'as',
#   'Says',
#   'lot'],
#  ['Egypt',
#   'built',
#   'world',
#   'strongest',
#   'border',
#   'defense',
#   'border',
#   'Gaza',
#   'Row',
#   'row',
#   'wall',
#   'fence',
#   'What',
#   'afraid',
#   'The',
#   'answer',
#   'Hamas',
#   'Muslim',
#   'Brotherhood'],
#  ['This',
#   'Blood',
#   'Eagle',
#   'torture',
#   'method',
#   'Vikings',
#   'represented',
#   'Museum',
#   'Medieval',
#   'Tortures',
#   'It',
#   'consisted',
#   'incising',
#   'condemned',
#   'man',
#   'separating',
#   'rib',
#   'spine',
#   'spreading',
#   'lung',
#   'like',
#   'wing',
#   'eagle'],
#  ['Donald',
#   'Trump',
#   'want',
#   'send',
#   'money',
#   'Anything',
#   'help',
#   '5',
#   '10',
#   '25',
#   '100Were',
#   'going',
#   'use',
#   'money'],
#  ['Do', 'agree', 'Scott', 'Moe'],
#  ['EXCUSE', 'ME'],
#  ['Its', 'folk'],
#  ['First', 'peek', 'Nostalgia', 'emotion', 'INSIDE', 'OUT', '2', 'Source'],
#  ['It',
#   'difficult',
#   'I',
#   'like',
#   'stop',
#   'account',
#   'Thank',
#   'reading',
#   'Sega',
#   'Group',
#   'information',
#   'Please',
#   'continue',
#   'look',
#   'forward',
#   'future',
#   'Atlus',
#   'Sega'],
#  ['Im',
#   'writing',
#   'famous',
#   'field',
#   'nominative',
#   'determinism',
#   'love',
#   'best',
#   'example',
#   'Mine',
#   'far',
#   'consultant',
#   'urologist',
#   'Mr',
#   'Burns',
#   'Cox']]
